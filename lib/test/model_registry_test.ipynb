# %%
project_root_dir = !git rev-parse --show-toplevel
project_root_dir = project_root_dir[0]

import os
import sys
import requests

sys.path.append(os.path.join(project_root_dir, 'lib'))
from model_registry import *

# %% [markdown]
# # Download from slave

# %%
# %%time
mr = ModelRegistry('com.develorium.neurovision.15_transformer', 'http://nexus:8081')
content = mr.get_asset_content('15d_predict_noncausal_02', 1, 'pt', 'main')
print(f'{len(content):_}')
# Out:
# ...
# 160_064_927
# CPU times: user 1.86 s, sys: 1.67 s, total: 3.53 s
# Wall time: 13.9 s

# %%
# %%time
mr = ModelRegistry('com.develorium.neurovision.15_transformer', 'http://nexus:8081', 'http://nexus-slave:8081')
content = mr.get_asset_content('15d_predict_noncausal_02', 1, 'pt', 'main')
print(f'{len(content):_}')
# Out:
# ...
# 160_064_927
# CPU times: user 349 ms, sys: 329 ms, total: 678 ms
# Wall time: 695 ms
