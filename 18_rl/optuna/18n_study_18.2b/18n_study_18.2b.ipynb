# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 5 поколений по 6 млн шагов с последующим отбором чемпионов. Наследники этих чемпионов будут использоваться на следующем шаге.
#
# Данный эксперимент - это второй шаг. Делаем как в 17-ой серии - натаскиваем агента проходить медвежьи уровни, чтобы потом отпустить в свободное плавание.
#
# Особенности:
# - `vision_head` из `18d_world_model_09`
# - **`vision_head.is_trainable=False`**
# - энкодер из чемпионов `18n_study_18.1`
# - **`encoder.is_trainable=True`**
# - механика повторяет 17-ых агентов
# - `prediction_coef=0.1`
# - `sequence_length=10`
# - `batch_size=128`
# - `vf_coef=0.2`

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    generations_count = 5
    generation_ind = 1
    generation_steps_count = 6_000_000
    all_generations_steps_count = generation_steps_count * generations_count
    learn_rate_range = (0.00025, 0.00025 * 0.1)
    ent_coef_range = (0.05, 0.05 * 0.1)
    ####
    
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False

    parent = optuna_trial.suggest_categorical('parent', [
        '18n_ppo_tr_frostbite_06:32',
        '18n_ppo_tr_frostbite_06:26',
        '18n_ppo_tr_frostbite_06:24',
        '18n_ppo_tr_frostbite_06:21',
        '18n_ppo_tr_frostbite_06:13',
        '18n_ppo_tr_frostbite_06:11',
        '18n_ppo_tr_frostbite_06:10',
    ])
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights=parent)
    HP.encoder.is_trainable = True

    HP.agent.parent = parent 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(500000)' # video capture policy depending on steps
    HP.video.capture_env_rams = [
        'com.develorium.neurolab.frostbite_ram:level5_101:1', # bear level, night
    ]
    HP.video.capture_env_ram_patches = [
        ['no_score', 'last_life', 'full_igloo', 'temperature_10', 'bailey_to_the_right_of_igloo', 'bear_to_the_left_of_igloo'],
        ['no_score', 'last_life', 'full_igloo', 'temperature_10', 'bailey_to_the_left_of_igloo', 'bear_to_the_left_of_igloo'],
        ['no_score', 'last_life', 'full_igloo', 'temperature_10', 'bear_chases_bailey_to_the_right_of_igloo'],
        ['no_score', 'last_life', 'full_igloo', 'temperature_10', 'bear_chases_bailey_to_the_left_of_igloo'],
        ['no_score', 'last_life', 'full_igloo', 'temperature_20', 'bailey_near_center'],
    ]
    HP.video.break_on_level_passed = True
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = generation_steps_count # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = [
        'com.develorium.neurolab.frostbite_ram:level1_101:1', 
        'com.develorium.neurolab.frostbite_ram:level4_101:1', # bear level, day
        'com.develorium.neurolab.frostbite_ram:level5_101:1', # bear level, night
    ]
    HP.ppo.rollout_env_ram_patches = [
        ['no_score', 'three_lives', 'no_igloo'], # 0
            
        ['no_score', 'last_life', 'full_igloo', 'temperature_10', 'bailey_to_the_right_of_igloo', 'bear_to_the_left_of_igloo'], # 1
        ['no_score', 'last_life', 'full_igloo', 'temperature_10', 'bailey_to_the_left_of_igloo', 'bear_to_the_left_of_igloo'], # 2
        ['no_score', 'last_life', 'full_igloo', 'temperature_10', 'bear_chases_bailey_to_the_right_of_igloo'], # 3
        ['no_score', 'last_life', 'full_igloo', 'temperature_10', 'bear_chases_bailey_to_the_left_of_igloo'], # 4
        ['no_score', 'last_life', 'full_igloo', 'temperature_20', 'bailey_near_center'], # 5
    ]
    # 80% of time learn to pass level 5, 20% of time - keep old experience
    HP.ppo.rollout_env_stories = [
        '0,1;0', # for levels 1 and 4 - play an ordinary game
        '2;1:6', # for night level - use conditioning 
        '2;1:6', # to teach an agent 
        '2;1:6', # to enter blinking igloo
        '2;1:6', # ...
    ]
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    learn_rate_change_speed = (learn_rate_range[1] - learn_rate_range[0]) / generations_count
    learn_rate_a = learn_rate_range[0] + learn_rate_change_speed * generation_ind
    learn_rate_b = learn_rate_a + learn_rate_change_speed
    HP.ppo.learn_rate = f'linear({learn_rate_a}, {learn_rate_b})'
    # HP.ppo.learn_rate = 'linear(0.00025, 0.00015)'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    ent_coef_change_speed = (ent_coef_range[1] - ent_coef_range[0]) / generations_count
    ent_coef_a = ent_coef_range[0] + ent_coef_change_speed * generation_ind
    ent_coef_b = ent_coef_a + ent_coef_change_speed
    HP.ppo.ent_coef = f'linear({ent_coef_a}, {ent_coef_b})' # coefficient of the entropy member within loss function
    # HP.ppo.ent_coef = 'linear(0.05, 0.03)' # coefficient of the entropy member within loss function
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Неплохо, похоже на результаты `17e_study_23.2b`.
#
# Чемпионы:
# - `18n_ppo_tr_frostbite_06:112`
# - `18n_ppo_tr_frostbite_06:85`
# - `18n_ppo_tr_frostbite_06:95`
# - `18n_ppo_tr_frostbite_06:107`
#
#
# <img src="./img/levels_passed.png">
# <img src="./img/reward.png">
# <img src="./img/episode_r.png">
#
# **Выводы**
# 1) делаем третий шаг

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_18.2b/18n_study_18.2b.ipynb',
#  'optuna_study_name': '18n_study_18.2b',
#  'optuna_study_serial': '18.2b',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_18.2b/18n_study_18.2b.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-19 14:28:33,969] A new study created in Journal with name: 18n_study_18.2b
# 2026.09.19-14:28:34.343947     0.261 >> Model instance registered, version=85
# 2026.09.19-14:28:34.354576     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch85.ipynb"
# 2026.09.19-14:28:34.355310     0.004 >> 4.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:85"; running launches=1
# 2026.09.19-14:29:05.927085     0.201 >> Model instance registered, version=86
# 2026.09.19-14:29:05.938459     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch86.ipynb"
# 2026.09.19-14:29:05.938841     0.004 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:86"; running launches=2
# 2026.09.19-14:29:37.768854     0.194 >> Model instance registered, version=87
# 2026.09.19-14:29:37.781216     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch87.ipynb"
# 2026.09.19-14:29:37.781519     0.004 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:87"; running launches=3
# 2026.09.19-14:30:08.894365     0.187 >> Model instance registered, version=88
# 2026.09.19-14:30:08.906942     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch88.ipynb"
# 2026.09.19-14:30:08.907210     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:88"; running launches=4
# 2026.09.19-15:09:28.924000     0.280 >> Model instance registered, version=89
# 2026.09.19-15:09:28.941220     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch89.ipynb"
# 2026.09.19-15:09:28.942556     0.008 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:89"; running launches=5
# 2026.09.19-15:09:59.828117     0.216 >> Model instance registered, version=90
# 2026.09.19-15:09:59.841047     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch90.ipynb"
# 2026.09.19-15:09:59.842017     0.001 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:90"; running launches=6
# 2026.09.19-15:10:30.781095     0.193 >> Model instance registered, version=91
# 2026.09.19-15:10:30.790152     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch91.ipynb"
# 2026.09.19-15:10:30.790351     0.004 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:91"; running launches=7
# 2026.09.19-15:11:01.687405     0.198 >> Model instance registered, version=92
# 2026.09.19-15:11:01.700726     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch92.ipynb"
# 2026.09.19-15:11:01.701214     0.006 >> 4.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:92"; running launches=8
# 2026.09.19-15:11:32.710209     0.225 >> Model instance registered, version=93
# 2026.09.19-15:11:32.723023     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch93.ipynb"
# 2026.09.19-15:11:32.723524     0.005 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:93"; running launches=9
# 2026.09.19-15:12:04.518561     0.272 >> Model instance registered, version=94
# 2026.09.19-15:12:04.528124     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch94.ipynb"
# 2026.09.19-15:12:04.528351     0.004 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:94"; running launches=10
# 2026.09.19-15:12:35.475047     0.222 >> Model instance registered, version=95
# 2026.09.19-15:12:35.485471     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch95.ipynb"
# 2026.09.19-15:12:35.485836     0.004 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:95"; running launches=11
# 2026.09.19-15:13:06.415597     0.233 >> Model instance registered, version=96
# 2026.09.19-15:13:06.426604     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch96.ipynb"
# 2026.09.19-15:13:06.427365     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:96"; running launches=12
# 2026.09.19-15:50:48.959987     3.987 >> Trial 0 (18n_ppo_tr_frostbite_06:85) finished with value: 5553.846153846154 and parameters: {'parent': '18n_ppo_tr_frostbite_06:10'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-15:50:50.715147     0.004 >> Launch "18n_ppo_tr_frostbite_06:85" completed
# 2026.09.19-15:50:50.716199     0.001 >> 1 (+1) launches completed; running launches=11
# 2026.09.19-15:51:16.508188     0.196 >> Model instance registered, version=97
# 2026.09.19-15:51:16.518133     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:97"; running launches=12
# 2026.09.19-15:51:16.518262     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch97.ipynb"
# 2026.09.19-15:52:30.984434     2.863 >> Trial 3 (18n_ppo_tr_frostbite_06:88) finished with value: 3757.6923076923076 and parameters: {'parent': '18n_ppo_tr_frostbite_06:13'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-15:52:33.417831     0.003 >> Launch "18n_ppo_tr_frostbite_06:88" completed
# 2026.09.19-15:52:33.418711     0.001 >> 2 (+1) launches completed; running launches=11
# 2026.09.19-15:52:59.200234     0.197 >> Model instance registered, version=98
# 2026.09.19-15:52:59.208158     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:98"; running launches=12
# 2026.09.19-15:52:59.208270     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch98.ipynb"
# 2026.09.19-15:54:34.631633     1.625 >> Trial 1 (18n_ppo_tr_frostbite_06:86) finished with value: 4042.3076923076924 and parameters: {'parent': '18n_ppo_tr_frostbite_06:32'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-15:54:38.124192     0.002 >> Launch "18n_ppo_tr_frostbite_06:86" completed
# 2026.09.19-15:54:38.125096     0.001 >> 3 (+1) launches completed; running launches=11
# 2026.09.19-15:55:03.889167     0.200 >> Model instance registered, version=99
# 2026.09.19-15:55:03.902779     0.005 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:99"; running launches=12
# 2026.09.19-15:55:03.902956     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch99.ipynb"
# 2026.09.19-15:55:04.118579     0.216 >> Trial 2 (18n_ppo_tr_frostbite_06:87) finished with value: 4046.153846153846 and parameters: {'parent': '18n_ppo_tr_frostbite_06:11'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-15:55:09.010748     0.001 >> Launch "18n_ppo_tr_frostbite_06:87" completed
# 2026.09.19-15:55:09.011457     0.001 >> 4 (+1) launches completed; running launches=11
# 2026.09.19-15:55:35.064900     0.188 >> Model instance registered, version=100
# 2026.09.19-15:55:35.076556     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:100"; running launches=12
# 2026.09.19-15:55:35.076661     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch100.ipynb"
# 2026.09.19-16:27:26.406038     1.202 >> Trial 4 (18n_ppo_tr_frostbite_06:89) finished with value: 4861.538461538462 and parameters: {'parent': '18n_ppo_tr_frostbite_06:10'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-16:27:30.322523     0.003 >> Launch "18n_ppo_tr_frostbite_06:89" completed
# 2026.09.19-16:27:30.323412     0.001 >> 5 (+1) launches completed; running launches=11
# 2026.09.19-16:27:57.106709     0.221 >> Model instance registered, version=101
# 2026.09.19-16:27:57.119380     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:101"; running launches=12
# 2026.09.19-16:27:57.119512     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch101.ipynb"
# 2026.09.19-16:29:17.640165     3.782 >> Trial 6 (18n_ppo_tr_frostbite_06:91) finished with value: 4646.153846153846 and parameters: {'parent': '18n_ppo_tr_frostbite_06:13'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-16:29:18.973218     0.001 >> Launch "18n_ppo_tr_frostbite_06:91" completed
# 2026.09.19-16:29:18.973924     0.001 >> 6 (+1) launches completed; running launches=11
# 2026.09.19-16:29:44.734667     0.186 >> Model instance registered, version=102
# 2026.09.19-16:29:44.743070     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:102"; running launches=12
# 2026.09.19-16:29:44.743164     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch102.ipynb"
# 2026.09.19-16:30:07.168592     1.946 >> Trial 5 (18n_ppo_tr_frostbite_06:90) finished with value: 3915.3846153846152 and parameters: {'parent': '18n_ppo_tr_frostbite_06:11'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-16:30:10.342814     0.002 >> Launch "18n_ppo_tr_frostbite_06:90" completed
# 2026.09.19-16:30:10.343658     0.001 >> 7 (+1) launches completed; running launches=11
# 2026.09.19-16:30:36.063849     0.147 >> Trial 7 (18n_ppo_tr_frostbite_06:92) finished with value: 3980.769230769231 and parameters: {'parent': '18n_ppo_tr_frostbite_06:11'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-16:30:36.131917     0.068 >> Model instance registered, version=103
# 2026.09.19-16:30:36.143665     0.003 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:103"; running launches=12
# 2026.09.19-16:30:36.143801     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch103.ipynb"
# 2026.09.19-16:30:36.144843     0.001 >> Launch "18n_ppo_tr_frostbite_06:92" completed
# 2026.09.19-16:30:36.145848     0.001 >> 8 (+1) launches completed; running launches=11
# 2026.09.19-16:31:07.438594     0.193 >> Model instance registered, version=104
# 2026.09.19-16:31:07.448672     0.003 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:104"; running launches=12
# 2026.09.19-16:31:07.448788     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch104.ipynb"
# 2026.09.19-16:36:57.234957     0.391 >> Model instance registered, version=105
# 2026.09.19-16:36:57.245330     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch105.ipynb"
# 2026.09.19-16:36:57.246051     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:105"; running launches=13
# 2026.09.19-16:37:52.397430     3.874 >> Trial 8 (18n_ppo_tr_frostbite_06:93) finished with value: 3830.769230769231 and parameters: {'parent': '18n_ppo_tr_frostbite_06:11'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-16:37:53.642160     0.002 >> Launch "18n_ppo_tr_frostbite_06:93" completed
# 2026.09.19-16:37:53.643136     0.001 >> 9 (+1) launches completed; running launches=12
# 2026.09.19-16:38:19.639898     0.199 >> Model instance registered, version=106
# 2026.09.19-16:38:19.650923     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:106"; running launches=13
# 2026.09.19-16:38:19.651166     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch106.ipynb"
# 2026.09.19-16:39:51.684934     4.696 >> Trial 9 (18n_ppo_tr_frostbite_06:94) finished with value: 3623.076923076923 and parameters: {'parent': '18n_ppo_tr_frostbite_06:21'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-16:39:52.099336     0.001 >> Launch "18n_ppo_tr_frostbite_06:94" completed
# 2026.09.19-16:39:52.100020     0.001 >> 10 (+1) launches completed; running launches=12
# 2026.09.19-16:40:17.861275     0.194 >> Model instance registered, version=107
# 2026.09.19-16:40:17.874822     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:107"; running launches=13
# 2026.09.19-16:40:17.874957     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch107.ipynb"
# 2026.09.19-16:40:23.283333     0.301 >> Trial 10 (18n_ppo_tr_frostbite_06:95) finished with value: 4757.692307692308 and parameters: {'parent': '18n_ppo_tr_frostbite_06:21'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-16:40:28.099364     0.002 >> Launch "18n_ppo_tr_frostbite_06:95" completed
# 2026.09.19-16:40:28.100115     0.001 >> 11 (+1) launches completed; running launches=12
# 2026.09.19-16:40:48.910500     0.188 >> Model instance registered, version=108
# 2026.09.19-16:40:48.920473     0.003 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:108"; running launches=13
# 2026.09.19-16:40:48.920605     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch108.ipynb"
# 2026.09.19-16:41:15.642778     0.747 >> Trial 11 (18n_ppo_tr_frostbite_06:96) finished with value: 4196.153846153846 and parameters: {'parent': '18n_ppo_tr_frostbite_06:11'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-16:41:20.027090     0.004 >> Launch "18n_ppo_tr_frostbite_06:96" completed
# 2026.09.19-16:41:20.028506     0.001 >> 12 (+1) launches completed; running launches=12
# 2026.09.19-16:41:40.739522     0.231 >> Model instance registered, version=109
# 2026.09.19-16:41:40.754677     0.005 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:109"; running launches=13
# 2026.09.19-16:41:40.754814     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch109.ipynb"
# 2026.09.19-16:42:11.705250     0.238 >> Model instance registered, version=110
# 2026.09.19-16:42:11.717082     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch110.ipynb"
# 2026.09.19-16:42:11.718021     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:110"; running launches=14
# 2026.09.19-17:16:18.329260     1.430 >> Trial 12 (18n_ppo_tr_frostbite_06:97) finished with value: 3796.153846153846 and parameters: {'parent': '18n_ppo_tr_frostbite_06:13'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-17:16:22.010544     0.001 >> Launch "18n_ppo_tr_frostbite_06:97" completed
# 2026.09.19-17:16:22.011242     0.001 >> 13 (+1) launches completed; running launches=13
# 2026.09.19-17:16:47.864193     0.276 >> Model instance registered, version=111
# 2026.09.19-17:16:47.879619     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:111"; running launches=14
# 2026.09.19-17:16:47.879814     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch111.ipynb"
# 2026.09.19-17:18:29.465297     3.661 >> Trial 13 (18n_ppo_tr_frostbite_06:98) finished with value: 4411.538461538462 and parameters: {'parent': '18n_ppo_tr_frostbite_06:24'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-17:18:30.916341     0.001 >> Launch "18n_ppo_tr_frostbite_06:98" completed
# 2026.09.19-17:18:30.916822     0.000 >> 14 (+1) launches completed; running launches=13
# 2026.09.19-17:18:56.794290     0.222 >> Model instance registered, version=112
# 2026.09.19-17:18:56.812328     0.007 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:112"; running launches=14
# 2026.09.19-17:18:56.812601     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch112.ipynb"
# 2026.09.19-17:25:03.890268     1.581 >> Trial 14 (18n_ppo_tr_frostbite_06:99) finished with value: 4346.153846153846 and parameters: {'parent': '18n_ppo_tr_frostbite_06:26'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-17:25:07.426826     0.001 >> Launch "18n_ppo_tr_frostbite_06:99" completed
# 2026.09.19-17:25:07.427618     0.001 >> 15 (+1) launches completed; running launches=13
# 2026.09.19-17:25:33.516530     0.183 >> Model instance registered, version=113
# 2026.09.19-17:25:33.527671     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:113"; running launches=14
# 2026.09.19-17:25:33.527822     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch113.ipynb"
# 2026.09.19-17:25:55.861031     1.875 >> Trial 15 (18n_ppo_tr_frostbite_06:100) finished with value: 3842.3076923076924 and parameters: {'parent': '18n_ppo_tr_frostbite_06:13'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-17:25:59.147492     0.002 >> Launch "18n_ppo_tr_frostbite_06:100" completed
# 2026.09.19-17:25:59.148861     0.001 >> 16 (+1) launches completed; running launches=13
# 2026.09.19-17:26:24.973375     0.240 >> Model instance registered, version=114
# 2026.09.19-17:26:24.982898     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:114"; running launches=14
# 2026.09.19-17:26:24.983104     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch114.ipynb"
# 2026.09.19-17:39:17.507968     1.818 >> Trial 16 (18n_ppo_tr_frostbite_06:101) finished with value: 3808.3333333333335 and parameters: {'parent': '18n_ppo_tr_frostbite_06:13'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-17:39:20.806494     0.002 >> Launch "18n_ppo_tr_frostbite_06:101" completed
# 2026.09.19-17:39:20.807439     0.001 >> 17 (+1) launches completed; running launches=13
# 2026.09.19-17:40:38.764948     0.877 >> Trial 17 (18n_ppo_tr_frostbite_06:102) finished with value: 4106.363636363636 and parameters: {'parent': '18n_ppo_tr_frostbite_06:32'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-17:40:43.003808     0.001 >> Launch "18n_ppo_tr_frostbite_06:102" completed
# 2026.09.19-17:40:43.004752     0.001 >> 18 (+1) launches completed; running launches=12
# 2026.09.19-17:41:20.177261     0.342 >> Trial 18 (18n_ppo_tr_frostbite_06:103) finished with value: 3772.7272727272725 and parameters: {'parent': '18n_ppo_tr_frostbite_06:24'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-17:41:24.958408     0.002 >> Launch "18n_ppo_tr_frostbite_06:103" completed
# 2026.09.19-17:41:24.959422     0.001 >> 19 (+1) launches completed; running launches=11
# 2026.09.19-17:45:59.158536     0.286 >> Trial 19 (18n_ppo_tr_frostbite_06:104) finished with value: 4084.6153846153848 and parameters: {'parent': '18n_ppo_tr_frostbite_06:24'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-17:46:03.991782     0.002 >> Launch "18n_ppo_tr_frostbite_06:104" completed
# 2026.09.19-17:46:03.992653     0.001 >> 20 (+1) launches completed; running launches=10
# 2026.09.19-17:57:57.642366     4.620 >> Trial 29 (18n_ppo_tr_frostbite_06:114) failed: launch_result_metadata={'error_code': 1, 'error_message': 'Failed to fetch result file "/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch114.metrics_suite.json" in container: 404 Client Error for http+docker://localhost/v1.52/containers/a7575a0da9ca4276843c3ce5a59c63227afb9678a154b1eef843dfb289a4b062/archive?path=%2Fneurolab%2Frun%2F18_rl%2F18n_ppo_tr_frostbite_06-launch114.metrics_suite.json: Not Found ("Could not find the file /neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch114.metrics_suite.json in container a7575a0da9ca4276843c3ce5a59c63227afb9678a154b1eef843dfb289a4b062")', 'is_ok': False, 'runner_name': 'baki_1789486103.903'}
# 2026.09.19-17:57:57.772649     0.130 >> Trial 28 (18n_ppo_tr_frostbite_06:113) failed: launch_result_metadata={'error_code': 1, 'error_message': 'Failed to fetch result file "/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch113.metrics_suite.json" in container: 404 Client Error for http+docker://localhost/v1.52/containers/4d6c44e26f3575b6182f356247260b2639fc2fedc5d3382888f57d54c36f4051/archive?path=%2Fneurolab%2Frun%2F18_rl%2F18n_ppo_tr_frostbite_06-launch113.metrics_suite.json: Not Found ("Could not find the file /neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch113.metrics_suite.json in container 4d6c44e26f3575b6182f356247260b2639fc2fedc5d3382888f57d54c36f4051")', 'is_ok': False, 'runner_name': 'baki_1789583424.973'}
# 2026.09.19-17:57:58.141251     0.004 >> Launch "18n_ppo_tr_frostbite_06:114" completed
# 2026.09.19-17:57:58.141983     0.001 >> Launch "18n_ppo_tr_frostbite_06:113" completed
# 2026.09.19-17:57:58.142468     0.000 >> 22 (+2) launches completed; running launches=8
# 2026.09.19-18:05:30.841284     3.668 >> Trial 20 (18n_ppo_tr_frostbite_06:105) finished with value: 4269.2307692307695 and parameters: {'parent': '18n_ppo_tr_frostbite_06:10'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-18:05:32.291591     0.002 >> Launch "18n_ppo_tr_frostbite_06:105" completed
# 2026.09.19-18:05:32.292507     0.001 >> 23 (+1) launches completed; running launches=7
# 2026.09.19-18:05:41.723659     4.318 >> Trial 21 (18n_ppo_tr_frostbite_06:106) finished with value: 4506.923076923077 and parameters: {'parent': '18n_ppo_tr_frostbite_06:13'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-18:05:42.522531     0.001 >> Launch "18n_ppo_tr_frostbite_06:106" completed
# 2026.09.19-18:05:42.523128     0.001 >> 24 (+1) launches completed; running launches=6
# 2026.09.19-18:08:36.723510     3.292 >> Trial 22 (18n_ppo_tr_frostbite_06:107) finished with value: 4919.2307692307695 and parameters: {'parent': '18n_ppo_tr_frostbite_06:10'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-18:08:38.613099     0.002 >> Launch "18n_ppo_tr_frostbite_06:107" completed
# 2026.09.19-18:08:38.614201     0.001 >> 25 (+1) launches completed; running launches=5
# 2026.09.19-18:09:52.691153     1.996 >> Trial 23 (18n_ppo_tr_frostbite_06:108) finished with value: 4684.615384615385 and parameters: {'parent': '18n_ppo_tr_frostbite_06:10'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-18:09:55.810613     0.001 >> Launch "18n_ppo_tr_frostbite_06:108" completed
# 2026.09.19-18:09:55.811126     0.001 >> 26 (+1) launches completed; running launches=4
# 2026.09.19-18:10:24.875146     3.209 >> Trial 24 (18n_ppo_tr_frostbite_06:109) finished with value: 4261.538461538462 and parameters: {'parent': '18n_ppo_tr_frostbite_06:10'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-18:10:26.848011     0.002 >> Launch "18n_ppo_tr_frostbite_06:109" completed
# 2026.09.19-18:10:26.849321     0.001 >> 27 (+1) launches completed; running launches=3
# 2026.09.19-18:11:03.299378     0.321 >> Trial 25 (18n_ppo_tr_frostbite_06:110) finished with value: 4303.846153846154 and parameters: {'parent': '18n_ppo_tr_frostbite_06:10'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-18:11:08.117265     0.003 >> Launch "18n_ppo_tr_frostbite_06:110" completed
# 2026.09.19-18:11:08.118304     0.001 >> 28 (+1) launches completed; running launches=2
# 2026.09.19-18:45:53.536126     3.981 >> Trial 26 (18n_ppo_tr_frostbite_06:111) finished with value: 4380.7692307692305 and parameters: {'parent': '18n_ppo_tr_frostbite_06:10'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-18:45:54.673451     0.002 >> Launch "18n_ppo_tr_frostbite_06:111" completed
# 2026.09.19-18:45:54.674419     0.001 >> 29 (+1) launches completed; running launches=1
# 2026.09.19-18:47:38.448781     0.806 >> Trial 27 (18n_ppo_tr_frostbite_06:112) finished with value: 4673.076923076923 and parameters: {'parent': '18n_ppo_tr_frostbite_06:10'}. Best is trial 0 with value: 5553.846153846154
# 2026.09.19-18:47:42.758525     0.002 >> Launch "18n_ppo_tr_frostbite_06:112" completed
# 2026.09.19-18:47:42.759517     0.001 >> 30 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-19 18:47:47,795] Using an existing study with name '18n_study_18.2b' instead of creating a new one.
# 2026.09.19-18:47:47.798366     5.039 >> Study statistics:
# 2026.09.19-18:47:47.801508     0.003 >> 	Number of finished trials: 30
# 2026.09.19-18:47:47.802689     0.001 >> 	Number of pruned trials: 0
# 2026.09.19-18:47:47.803489     0.001 >> 	Number of complete trials: 28
# 2026.09.19-18:47:47.804636     0.001 >> Best trial:
# 2026.09.19-18:47:47.805743     0.001 >> 	Value: 5553.846153846154
# 2026.09.19-18:47:47.806607     0.001 >> 	Model version: 85
# 2026.09.19-18:47:47.808255     0.002 >> 	Params:
# 2026.09.19-18:47:47.809073     0.001 >> 		parent: 18n_ppo_tr_frostbite_06:10
