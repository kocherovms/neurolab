# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 6 шагов. На каждом шаге отбираем чемпионов для продолжения след. шага.
#
# Данный эксперимент - это шестой шаг. Тут идея, чтобы "продавить" 5 уровень, но при этом не затереть имующийся опыт. При этом не пользуемся РАМ-ами, т.к. выяснилось, что на непервых уровнях и так хватает стохастичности с т.з. врагов. И наоборот фиксация на RAM=`com.develorium.neurolab.frostbite_ram:level5:1:cls=none` это есть убивания стохастичности, т.к. враги всегда одинаковые.

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False

    parent = optuna_trial.suggest_categorical('parent', [
        '18n_ppo_tr_frostbite_06:521',
        '18n_ppo_tr_frostbite_06:494',
        '18n_ppo_tr_frostbite_06:519',
    ])
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights=parent)
    HP.encoder.is_trainable = True

    HP.agent.parent = parent 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(300000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = None
    HP.video.capture_env_ram_patches = None
    HP.video.break_on_level_passed = False
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = 3_000_000 # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = None
    HP.ppo.rollout_env_ram_patches = [
        ['nine_lives'], 
    ]

    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    HP.ppo.learn_rate = f'const({0.00025 - 0.0002 / 6 * 5})'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    HP.ppo.ent_coef = f'const({0.05 - 0.04 / 6 * 5})'
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Ну тут уже повеселее, чем `18n_study_19.6d`. Народился аж агент `18n_ppo_tr_frostbite_06:610`, который со скором >50500. Закончил! Да и несколько других агентов есть, которые по ходу коснулись рубежа 50000:
# - `18n_ppo_tr_frostbite_06:610`
# - `18n_ppo_tr_frostbite_06:607` (два раза)
# - `18n_ppo_tr_frostbite_06:609` (два раза)
# - `18n_ppo_tr_frostbite_06:613` (один раз)
#
# Это уже явно стабильнее и выше, чем `18n_study_18.5e`!
#
# Теперь можно оптимизировать пайплайн обучения, чтобы найти минимально необходимое кол-во шагов для получения агентов, проходящих 5 уровней.
#
# <img src="./img/score.png">
# <img src="./img/episode_r.png">
# <img src="./img/episode_lp.png">
#
# **Выводы**
# 1) да, очень важно поддерживать опыт на всём курсе обучения
# 2) встроенной стохастичности хватает
# 3) надо оптимизировать путь, кажется, что 6 шагов даже много

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.6e/18n_study_19.6e.ipynb',
#  'optuna_study_name': '18n_study_19.6e',
#  'optuna_study_serial': '19.6e',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.6e/18n_study_19.6e.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-23 21:53:21,526] A new study created in Journal with name: 18n_study_19.6e
# 2026.09.23-21:53:21.823417     0.276 >> Model instance registered, version=601
# 2026.09.23-21:53:21.837876     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch601.ipynb"
# 2026.09.23-21:53:21.838343     0.005 >> 0.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:601"; running launches=1
# 2026.09.23-21:54:18.375910     0.243 >> Model instance registered, version=602
# 2026.09.23-21:54:18.388245     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch602.ipynb"
# 2026.09.23-21:54:18.388480     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:602"; running launches=2
# 2026.09.23-21:54:49.428766     0.245 >> Model instance registered, version=603
# 2026.09.23-21:54:49.438832     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch603.ipynb"
# 2026.09.23-21:54:49.439073     0.004 >> 6.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:603"; running launches=3
# 2026.09.23-21:55:20.393066     0.232 >> Model instance registered, version=604
# 2026.09.23-21:55:20.401802     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch604.ipynb"
# 2026.09.23-21:55:20.402047     0.004 >> 11.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:604"; running launches=4
# 2026.09.23-21:55:51.323406     0.232 >> Model instance registered, version=605
# 2026.09.23-21:55:51.333211     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch605.ipynb"
# 2026.09.23-21:55:51.333437     0.004 >> 10.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:605"; running launches=5
# 2026.09.23-21:56:22.266220     0.223 >> Model instance registered, version=606
# 2026.09.23-21:56:22.274782     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch606.ipynb"
# 2026.09.23-21:56:22.275532     0.001 >> 9.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:606"; running launches=6
# 2026.09.23-21:56:53.342314     0.287 >> Model instance registered, version=607
# 2026.09.23-21:56:53.354923     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch607.ipynb"
# 2026.09.23-21:56:53.355610     0.005 >> 8.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:607"; running launches=7
# 2026.09.23-21:57:24.341431     0.244 >> Model instance registered, version=608
# 2026.09.23-21:57:24.355906     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch608.ipynb"
# 2026.09.23-21:57:24.356354     0.007 >> 7.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:608"; running launches=8
# 2026.09.23-21:57:55.294191     0.264 >> Model instance registered, version=609
# 2026.09.23-21:57:55.308026     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch609.ipynb"
# 2026.09.23-21:57:55.308368     0.006 >> 6.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:609"; running launches=9
# 2026.09.23-21:58:26.293244     0.280 >> Model instance registered, version=610
# 2026.09.23-21:58:26.301641     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch610.ipynb"
# 2026.09.23-21:58:26.301869     0.004 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:610"; running launches=10
# 2026.09.23-21:58:57.399376     0.273 >> Model instance registered, version=611
# 2026.09.23-21:58:57.411182     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch611.ipynb"
# 2026.09.23-21:58:57.412157     0.001 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:611"; running launches=11
# 2026.09.23-21:59:28.382730     0.273 >> Model instance registered, version=612
# 2026.09.23-21:59:28.399144     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch612.ipynb"
# 2026.09.23-21:59:28.399599     0.008 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:612"; running launches=12
# 2026.09.23-21:59:59.438670     0.297 >> Model instance registered, version=613
# 2026.09.23-21:59:59.459722     0.009 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch613.ipynb"
# 2026.09.23-21:59:59.461831     0.011 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:613"; running launches=13
# 2026.09.23-22:00:30.433264     0.241 >> Model instance registered, version=614
# 2026.09.23-22:00:30.445206     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch614.ipynb"
# 2026.09.23-22:00:30.446167     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:614"; running launches=14
# 2026.09.23-22:31:45.187808     1.124 >> Trial 2 (18n_ppo_tr_frostbite_06:603) finished with value: 40404.00026164317 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 2 with value: 40404.00026164317
# 2026.09.23-22:31:49.180888     0.002 >> Launch "18n_ppo_tr_frostbite_06:603" completed
# 2026.09.23-22:31:49.181827     0.001 >> 1 (+1) launches completed; running launches=13
# 2026.09.23-22:32:15.243315     0.219 >> Model instance registered, version=615
# 2026.09.23-22:32:15.252481     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:615"; running launches=14
# 2026.09.23-22:32:15.252556     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch615.ipynb"
# 2026.09.23-22:38:37.870607     3.406 >> Trial 7 (18n_ppo_tr_frostbite_06:608) finished with value: 40404.00028987198 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 7 with value: 40404.00028987198
# 2026.09.23-22:38:39.586901     0.002 >> Launch "18n_ppo_tr_frostbite_06:608" completed
# 2026.09.23-22:38:39.588495     0.002 >> 2 (+1) launches completed; running launches=13
# 2026.09.23-22:38:41.513519     1.925 >> Trial 8 (18n_ppo_tr_frostbite_06:609) finished with value: 30505.000302122833 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 7 with value: 40404.00028987198
# 2026.09.23-22:38:44.711987     0.003 >> Launch "18n_ppo_tr_frostbite_06:609" completed
# 2026.09.23-22:38:44.713218     0.001 >> 3 (+1) launches completed; running launches=12
# 2026.09.23-22:38:55.278524     0.324 >> Model instance registered, version=616
# 2026.09.23-22:38:55.291920     0.004 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:616"; running launches=13
# 2026.09.23-22:38:55.292067     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch616.ipynb"
# 2026.09.23-22:39:26.247972     0.255 >> Model instance registered, version=617
# 2026.09.23-22:39:26.263010     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:617"; running launches=14
# 2026.09.23-22:39:26.263125     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch617.ipynb"
# 2026.09.23-22:39:48.318681     1.597 >> Trial 1 (18n_ppo_tr_frostbite_06:602) finished with value: 20404.00027681089 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 7 with value: 40404.00028987198
# 2026.09.23-22:39:51.842474     0.002 >> Launch "18n_ppo_tr_frostbite_06:602" completed
# 2026.09.23-22:39:51.843497     0.001 >> 4 (+1) launches completed; running launches=13
# 2026.09.23-22:40:16.083340     3.785 >> Trial 11 (18n_ppo_tr_frostbite_06:612) finished with value: 40404.00029197861 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 11 with value: 40404.00029197861
# 2026.09.23-22:40:17.678336     0.260 >> Model instance registered, version=618
# 2026.09.23-22:40:17.688422     0.004 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:618"; running launches=14
# 2026.09.23-22:40:17.688649     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch618.ipynb"
# 2026.09.23-22:40:17.689335     0.001 >> Launch "18n_ppo_tr_frostbite_06:612" completed
# 2026.09.23-22:40:17.691172     0.002 >> 5 (+1) launches completed; running launches=13
# 2026.09.23-22:40:40.224778     2.068 >> Trial 0 (18n_ppo_tr_frostbite_06:601) finished with value: 40404.000273148595 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 11 with value: 40404.00029197861
# 2026.09.23-22:40:43.273417     0.001 >> Launch "18n_ppo_tr_frostbite_06:601" completed
# 2026.09.23-22:40:43.274522     0.001 >> 6 (+1) launches completed; running launches=12
# 2026.09.23-22:40:49.045717     0.266 >> Model instance registered, version=619
# 2026.09.23-22:40:49.060365     0.006 >> 1.7 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:619"; running launches=13
# 2026.09.23-22:40:49.060494     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch619.ipynb"
# 2026.09.23-22:40:52.688548     3.628 >> Trial 3 (18n_ppo_tr_frostbite_06:604) finished with value: 40404.00028549668 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 11 with value: 40404.00029197861
# 2026.09.23-22:40:54.178143     0.002 >> Launch "18n_ppo_tr_frostbite_06:604" completed
# 2026.09.23-22:40:54.179405     0.001 >> 7 (+1) launches completed; running launches=12
# 2026.09.23-22:41:09.660016     0.089 >> Trial 4 (18n_ppo_tr_frostbite_06:605) finished with value: 40404.000290358126 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 11 with value: 40404.00029197861
# 2026.09.23-22:41:09.661582     0.002 >> Launch "18n_ppo_tr_frostbite_06:605" completed
# 2026.09.23-22:41:09.663457     0.002 >> 8 (+1) launches completed; running launches=11
# 2026.09.23-22:41:18.616732     3.839 >> Trial 5 (18n_ppo_tr_frostbite_06:606) finished with value: 40404.00029528439 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 5 with value: 40404.00029528439
# 2026.09.23-22:41:20.153300     0.260 >> Model instance registered, version=620
# 2026.09.23-22:41:20.165031     0.004 >> 3.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:620"; running launches=12
# 2026.09.23-22:41:20.165180     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch620.ipynb"
# 2026.09.23-22:41:20.165501     0.000 >> Launch "18n_ppo_tr_frostbite_06:606" completed
# 2026.09.23-22:41:20.166173     0.001 >> 9 (+1) launches completed; running launches=11
# 2026.09.23-22:41:51.115770     0.268 >> Model instance registered, version=621
# 2026.09.23-22:41:51.129354     0.005 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:621"; running launches=12
# 2026.09.23-22:41:51.129477     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch621.ipynb"
# 2026.09.23-22:42:22.094849     0.209 >> Model instance registered, version=622
# 2026.09.23-22:42:22.103919     0.004 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:622"; running launches=13
# 2026.09.23-22:42:22.104416     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch622.ipynb"
# 2026.09.23-22:42:53.218785     0.334 >> Model instance registered, version=623
# 2026.09.23-22:42:53.233761     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:623"; running launches=14
# 2026.09.23-22:42:53.233918     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch623.ipynb"
# 2026.09.23-22:44:23.820727     3.018 >> Trial 6 (18n_ppo_tr_frostbite_06:607) finished with value: 40405.00031450332 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 6 with value: 40405.00031450332
# 2026.09.23-22:44:25.375731     1.555 >> Trial 10 (18n_ppo_tr_frostbite_06:611) finished with value: 30404.00028264463 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 6 with value: 40405.00031450332
# 2026.09.23-22:44:25.917246     0.002 >> Launch "18n_ppo_tr_frostbite_06:611" completed
# 2026.09.23-22:44:25.918275     0.001 >> Launch "18n_ppo_tr_frostbite_06:607" completed
# 2026.09.23-22:44:25.918821     0.001 >> 11 (+2) launches completed; running launches=12
# 2026.09.23-22:44:36.437646     0.303 >> Model instance registered, version=624
# 2026.09.23-22:44:36.451611     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:624"; running launches=13
# 2026.09.23-22:44:36.451717     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch624.ipynb"
# 2026.09.23-22:45:07.519684     0.295 >> Model instance registered, version=625
# 2026.09.23-22:45:07.534798     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:625"; running launches=14
# 2026.09.23-22:45:07.534930     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch625.ipynb"
# 2026.09.23-22:45:27.844907     4.963 >> Trial 13 (18n_ppo_tr_frostbite_06:614) finished with value: 40404.00025399449 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 6 with value: 40405.00031450332
# 2026.09.23-22:45:28.000582     0.002 >> Launch "18n_ppo_tr_frostbite_06:614" completed
# 2026.09.23-22:45:28.001612     0.001 >> 12 (+1) launches completed; running launches=13
# 2026.09.23-22:45:53.829809     0.244 >> Model instance registered, version=626
# 2026.09.23-22:45:53.841434     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:626"; running launches=14
# 2026.09.23-22:45:53.841536     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch626.ipynb"
# 2026.09.23-22:46:37.146909     2.371 >> Trial 9 (18n_ppo_tr_frostbite_06:610) finished with value: 50504.00029671042 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-22:46:39.894076     0.003 >> Launch "18n_ppo_tr_frostbite_06:610" completed
# 2026.09.23-22:46:39.895394     0.001 >> 13 (+1) launches completed; running launches=13
# 2026.09.23-22:47:05.765231     0.261 >> Model instance registered, version=627
# 2026.09.23-22:47:05.781043     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:627"; running launches=14
# 2026.09.23-22:47:05.781233     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch627.ipynb"
# 2026.09.23-22:48:59.885974     1.226 >> Trial 12 (18n_ppo_tr_frostbite_06:613) finished with value: 40504.000288608004 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-22:49:03.803516     0.004 >> Launch "18n_ppo_tr_frostbite_06:613" completed
# 2026.09.23-22:49:03.804867     0.001 >> 14 (+1) launches completed; running launches=13
# 2026.09.23-22:49:29.702439     0.318 >> Model instance registered, version=628
# 2026.09.23-22:49:29.716345     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:628"; running launches=14
# 2026.09.23-22:49:29.716547     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch628.ipynb"
# 2026.09.23-23:11:07.837922     3.537 >> Trial 14 (18n_ppo_tr_frostbite_06:615) finished with value: 40404.0002879274 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-23:11:09.553531     0.002 >> Launch "18n_ppo_tr_frostbite_06:615" completed
# 2026.09.23-23:11:09.554402     0.001 >> 15 (+1) launches completed; running launches=13
# 2026.09.23-23:11:35.481275     0.230 >> Model instance registered, version=629
# 2026.09.23-23:11:35.491435     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:629"; running launches=14
# 2026.09.23-23:11:35.492062     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch629.ipynb"
# 2026.09.23-23:20:26.397891     3.019 >> Trial 15 (18n_ppo_tr_frostbite_06:616) finished with value: 40404.00029800681 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-23:20:28.500117     0.003 >> Launch "18n_ppo_tr_frostbite_06:616" completed
# 2026.09.23-23:20:28.500818     0.001 >> 16 (+1) launches completed; running launches=13
# 2026.09.23-23:20:38.926890     0.090 >> Trial 16 (18n_ppo_tr_frostbite_06:617) finished with value: 30404.000285658727 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-23:20:38.927682     0.001 >> Launch "18n_ppo_tr_frostbite_06:617" completed
# 2026.09.23-23:20:38.928033     0.000 >> 17 (+1) launches completed; running launches=12
# 2026.09.23-23:20:44.457404     0.393 >> Model instance registered, version=630
# 2026.09.23-23:20:44.468568     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:630"; running launches=13
# 2026.09.23-23:20:44.468715     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch630.ipynb"
# 2026.09.23-23:21:23.524273     3.073 >> Trial 18 (18n_ppo_tr_frostbite_06:619) finished with value: 40404.00028559391 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-23:21:25.568786     0.002 >> Launch "18n_ppo_tr_frostbite_06:619" completed
# 2026.09.23-23:21:25.569702     0.001 >> 18 (+1) launches completed; running launches=12
# 2026.09.23-23:24:18.978794     3.825 >> Trial 17 (18n_ppo_tr_frostbite_06:618) finished with value: 40404.00027071787 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-23:24:20.274562     0.004 >> Launch "18n_ppo_tr_frostbite_06:618" completed
# 2026.09.23-23:24:20.275533     0.001 >> 19 (+1) launches completed; running launches=11
# 2026.09.23-23:27:01.534229     2.468 >> Trial 19 (18n_ppo_tr_frostbite_06:620) finished with value: 40404.00030140982 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-23:27:04.182574     0.002 >> Launch "18n_ppo_tr_frostbite_06:620" completed
# 2026.09.23-23:27:04.183443     0.001 >> 20 (+1) launches completed; running launches=10
# 2026.09.23-23:27:30.974584     1.208 >> Trial 20 (18n_ppo_tr_frostbite_06:621) finished with value: 40404.00027353752 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-23:27:34.887634     0.004 >> Launch "18n_ppo_tr_frostbite_06:621" completed
# 2026.09.23-23:27:34.888786     0.001 >> 21 (+1) launches completed; running launches=9
# 2026.09.23-23:28:12.300658     1.595 >> Trial 21 (18n_ppo_tr_frostbite_06:622) finished with value: 40404.00025140172 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-23:28:15.824685     0.002 >> Launch "18n_ppo_tr_frostbite_06:622" completed
# 2026.09.23-23:28:15.825658     0.001 >> 22 (+1) launches completed; running launches=8
# 2026.09.23-23:29:35.598290     2.761 >> Trial 23 (18n_ppo_tr_frostbite_06:624) finished with value: 40404.00029593259 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-23:29:37.951828     0.002 >> Launch "18n_ppo_tr_frostbite_06:624" completed
# 2026.09.23-23:29:37.952767     0.001 >> 23 (+1) launches completed; running launches=7
# 2026.09.23-23:30:45.123215     0.505 >> Trial 24 (18n_ppo_tr_frostbite_06:625) finished with value: 40404.00028620969 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-23:30:48.495679     3.372 >> Trial 25 (18n_ppo_tr_frostbite_06:626) finished with value: 40404.00022453411 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-23:30:49.735579     0.002 >> Launch "18n_ppo_tr_frostbite_06:626" completed
# 2026.09.23-23:30:49.736660     0.001 >> Launch "18n_ppo_tr_frostbite_06:625" completed
# 2026.09.23-23:30:49.737447     0.001 >> 25 (+2) launches completed; running launches=5
# 2026.09.23-23:31:26.142544     0.387 >> Trial 22 (18n_ppo_tr_frostbite_06:623) finished with value: 40404.0002735051 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-23:31:30.881358     0.002 >> Launch "18n_ppo_tr_frostbite_06:623" completed
# 2026.09.23-23:31:30.882289     0.001 >> 26 (+1) launches completed; running launches=4
# 2026.09.23-23:35:38.618376     1.898 >> Trial 26 (18n_ppo_tr_frostbite_06:627) finished with value: 40404.000277264626 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-23:35:41.841211     0.001 >> Launch "18n_ppo_tr_frostbite_06:627" completed
# 2026.09.23-23:35:41.842198     0.001 >> 27 (+1) launches completed; running launches=3
# 2026.09.23-23:37:47.500821     2.249 >> Trial 27 (18n_ppo_tr_frostbite_06:628) finished with value: 40304.000271625344 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-23:37:50.372625     0.002 >> Launch "18n_ppo_tr_frostbite_06:628" completed
# 2026.09.23-23:37:50.373826     0.001 >> 28 (+1) launches completed; running launches=2
# 2026.09.23-23:40:19.197468     0.038 >> Trial 28 (18n_ppo_tr_frostbite_06:629) finished with value: 40404.00025516124 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-23:40:19.198625     0.001 >> Launch "18n_ppo_tr_frostbite_06:629" completed
# 2026.09.23-23:40:19.198972     0.000 >> 29 (+1) launches completed; running launches=1
# 2026.09.23-23:45:26.822426     5.091 >> Trial 29 (18n_ppo_tr_frostbite_06:630) finished with value: 40404.000272208716 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 9 with value: 50504.00029671042
# 2026.09.23-23:45:26.841563     0.001 >> Launch "18n_ppo_tr_frostbite_06:630" completed
# 2026.09.23-23:45:26.842056     0.000 >> 30 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-23 23:45:31,871] Using an existing study with name '18n_study_19.6e' instead of creating a new one.
# 2026.09.23-23:45:31.873469     5.031 >> Study statistics:
# 2026.09.23-23:45:31.875154     0.002 >> 	Number of finished trials: 30
# 2026.09.23-23:45:31.875682     0.001 >> 	Number of pruned trials: 0
# 2026.09.23-23:45:31.876108     0.000 >> 	Number of complete trials: 30
# 2026.09.23-23:45:31.876664     0.001 >> Best trial:
# 2026.09.23-23:45:31.877395     0.001 >> 	Value: 50504.00029671042
# 2026.09.23-23:45:31.877872     0.000 >> 	Model version: 610
# 2026.09.23-23:45:31.878314     0.000 >> 	Params:
# 2026.09.23-23:45:31.878670     0.000 >> 		parent: 18n_ppo_tr_frostbite_06:494
