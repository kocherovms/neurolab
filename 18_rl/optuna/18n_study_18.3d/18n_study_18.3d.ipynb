# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 5 поколений по 6 млн шагов с последующим отбором чемпионов. Наследники этих чемпионов будут использоваться на следующем шаге.
#
# Данный эксперимент - это третий шаг. Хотим, чтобы агент научился чисто проходить 1-ый уровень: для этого 3 экзамена. Используем чемпионов со 2-ого шага `18n_study_18.2c`.

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False

    parent = optuna_trial.suggest_categorical('parent', [
        '18n_ppo_tr_frostbite_06:210',
        '18n_ppo_tr_frostbite_06:203',
        '18n_ppo_tr_frostbite_06:208',
    ])
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights=parent)
    HP.encoder.is_trainable = True

    HP.agent.parent = parent 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(200000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = [
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=exam1',
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=exam2',
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=exam3',
    ]
    HP.video.capture_env_ram_patches = [
        ['no_score', 'last_life', 'no_igloo', 'temperature_45'],
    ]
    HP.video.break_on_level_passed = True
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = 2_000_000 # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = [
        'com.develorium.neurolab.frostbite_ram:level1_101:1', 
    ]
    HP.ppo.rollout_env_ram_patches = [
        ['no_score', 'last_life', 'no_igloo', 'bailey_safe_random_spawn'],
    ]
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    HP.ppo.learn_rate = 'const(0.00016)'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    HP.ppo.ent_coef = 'const(0.032)'
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Вот это неожиданно. Тренили агентов, тренили, а они даже единственного экзамена не смогли выдержать. Посмотрел через `18n_explore_02`, на что способоен агент `18n_ppo_tr_frostbite_06:277`. Выяснилось:
# 1) агент неплохо умеет проходить первый уровень на одной жизни, даже когда `bailye_safe_random_spawn`
# 2) агент не может пройти первый уровень на одной жизни, когда используется экзаменационный RAM
#
# При этом во втором случае даже толком очков не может набрать - обычно сразу плюхается в воду и всё. Такое ощущение, что надо агенту ещё больще разнообразить входные условия.
#
# <img src="./img/score.png">
# <img src="./img/episode_r.png">
#
# **Выводы**
# 1) выточить RAM для тренинга
# 2) перезапустить исследование

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_18.3d/18n_study_18.3d.ipynb',
#  'optuna_study_name': '18n_study_18.3d',
#  'optuna_study_serial': '18.3d',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_18.3d/18n_study_18.3d.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-21 11:49:43,541] A new study created in Journal with name: 18n_study_18.3d
# 2026.09.21-11:49:43.773458     0.207 >> Model instance registered, version=277
# 2026.09.21-11:49:43.788009     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch277.ipynb"
# 2026.09.21-11:49:43.788709     0.001 >> 6.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:277"; running launches=1
# 2026.09.21-11:50:14.725577     0.217 >> Model instance registered, version=278
# 2026.09.21-11:50:14.734647     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch278.ipynb"
# 2026.09.21-11:50:14.734956     0.004 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:278"; running launches=2
# 2026.09.21-11:50:45.664595     0.232 >> Model instance registered, version=279
# 2026.09.21-11:50:45.678119     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch279.ipynb"
# 2026.09.21-11:50:45.678426     0.006 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:279"; running launches=3
# 2026.09.21-11:51:16.609351     0.244 >> Model instance registered, version=280
# 2026.09.21-11:51:16.619563     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch280.ipynb"
# 2026.09.21-11:51:16.619758     0.004 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:280"; running launches=4
# 2026.09.21-11:51:47.537639     0.227 >> Model instance registered, version=281
# 2026.09.21-11:51:47.548719     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch281.ipynb"
# 2026.09.21-11:51:47.549557     0.005 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:281"; running launches=5
# 2026.09.21-11:52:18.436984     0.196 >> Model instance registered, version=282
# 2026.09.21-11:52:18.445598     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch282.ipynb"
# 2026.09.21-11:52:18.445786     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:282"; running launches=6
# 2026.09.21-12:23:51.435432     1.880 >> Trial 0 (18n_ppo_tr_frostbite_06:277) finished with value: 5.185545292497164e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:203'}. Best is trial 0 with value: 5.185545292497164e-07
# 2026.09.21-12:23:54.675586     0.002 >> Launch "18n_ppo_tr_frostbite_06:277" completed
# 2026.09.21-12:23:54.676478     0.001 >> 1 (+1) launches completed; running launches=5
# 2026.09.21-12:24:20.519383     0.215 >> Model instance registered, version=283
# 2026.09.21-12:24:20.533705     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:283"; running launches=6
# 2026.09.21-12:24:20.533818     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch283.ipynb"
# 2026.09.21-12:25:19.580384     2.497 >> Trial 2 (18n_ppo_tr_frostbite_06:279) finished with value: 3.5650623885918005e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 0 with value: 5.185545292497164e-07
# 2026.09.21-12:25:22.192426     0.001 >> Launch "18n_ppo_tr_frostbite_06:279" completed
# 2026.09.21-12:25:22.192823     0.000 >> 2 (+1) launches completed; running launches=5
# 2026.09.21-12:25:22.523336     0.331 >> Trial 4 (18n_ppo_tr_frostbite_06:281) finished with value: 5.509641873278237e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:203'}. Best is trial 4 with value: 5.509641873278237e-07
# 2026.09.21-12:25:27.300019     0.001 >> Launch "18n_ppo_tr_frostbite_06:281" completed
# 2026.09.21-12:25:27.300453     0.000 >> 3 (+1) launches completed; running launches=4
# 2026.09.21-12:25:32.634407     0.221 >> Model instance registered, version=284
# 2026.09.21-12:25:32.646519     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:284"; running launches=5
# 2026.09.21-12:25:32.646618     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch284.ipynb"
# 2026.09.21-12:26:04.121602     0.202 >> Model instance registered, version=285
# 2026.09.21-12:26:04.136072     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:285"; running launches=6
# 2026.09.21-12:26:04.136401     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch285.ipynb"
# 2026.09.21-12:26:24.344849     4.845 >> Trial 1 (18n_ppo_tr_frostbite_06:278) finished with value: 3.240965807810728e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:203'}. Best is trial 4 with value: 5.509641873278237e-07
# 2026.09.21-12:26:24.620744     0.002 >> Launch "18n_ppo_tr_frostbite_06:278" completed
# 2026.09.21-12:26:24.621651     0.001 >> 4 (+1) launches completed; running launches=5
# 2026.09.21-12:26:50.856427     0.222 >> Model instance registered, version=286
# 2026.09.21-12:26:50.868430     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:286"; running launches=6
# 2026.09.21-12:26:50.868616     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch286.ipynb"
# 2026.09.21-12:27:12.206065     0.650 >> Trial 5 (18n_ppo_tr_frostbite_06:282) finished with value: 1.166747690811862e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:208'}. Best is trial 5 with value: 1.166747690811862e-06
# 2026.09.21-12:27:16.665583     0.001 >> Launch "18n_ppo_tr_frostbite_06:282" completed
# 2026.09.21-12:27:16.666256     0.001 >> 5 (+1) launches completed; running launches=5
# 2026.09.21-12:27:42.468806     0.221 >> Model instance registered, version=287
# 2026.09.21-12:27:42.483257     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:287"; running launches=6
# 2026.09.21-12:27:42.483458     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch287.ipynb"
# 2026.09.21-12:28:11.930082     3.647 >> Trial 3 (18n_ppo_tr_frostbite_06:280) finished with value: 4.861448711716091e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 5 with value: 1.166747690811862e-06
# 2026.09.21-12:28:13.398027     0.001 >> Launch "18n_ppo_tr_frostbite_06:280" completed
# 2026.09.21-12:28:13.398408     0.000 >> 6 (+1) launches completed; running launches=5
# 2026.09.21-12:28:39.165537     0.204 >> Model instance registered, version=288
# 2026.09.21-12:28:39.179961     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:288"; running launches=6
# 2026.09.21-12:28:39.180137     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch288.ipynb"
# 2026.09.21-12:58:31.826072     4.439 >> Trial 7 (18n_ppo_tr_frostbite_06:284) finished with value: 6.157835034840382e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:203'}. Best is trial 5 with value: 1.166747690811862e-06
# 2026.09.21-12:58:32.503326     0.001 >> Launch "18n_ppo_tr_frostbite_06:284" completed
# 2026.09.21-12:58:32.504106     0.001 >> 7 (+1) launches completed; running launches=5
# 2026.09.21-12:58:58.836507     0.252 >> Model instance registered, version=289
# 2026.09.21-12:58:58.846264     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:289"; running launches=6
# 2026.09.21-12:58:58.846360     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch289.ipynb"
# 2026.09.21-13:00:01.088522     5.077 >> Trial 8 (18n_ppo_tr_frostbite_06:285) finished with value: 3.889158969372873e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 5 with value: 1.166747690811862e-06
# 2026.09.21-13:00:01.121017     0.001 >> Launch "18n_ppo_tr_frostbite_06:285" completed
# 2026.09.21-13:00:01.121453     0.000 >> 8 (+1) launches completed; running launches=5
# 2026.09.21-13:00:27.170046     0.213 >> Model instance registered, version=290
# 2026.09.21-13:00:27.184915     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:290"; running launches=6
# 2026.09.21-13:00:27.185162     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch290.ipynb"
# 2026.09.21-13:01:02.153414     4.239 >> Trial 6 (18n_ppo_tr_frostbite_06:283) finished with value: 4.861448711716091e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 5 with value: 1.166747690811862e-06
# 2026.09.21-13:01:03.314903     0.004 >> Launch "18n_ppo_tr_frostbite_06:283" completed
# 2026.09.21-13:01:03.316249     0.001 >> 9 (+1) launches completed; running launches=5
# 2026.09.21-13:01:29.311264     0.194 >> Model instance registered, version=291
# 2026.09.21-13:01:29.321289     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:291"; running launches=6
# 2026.09.21-13:01:29.321397     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch291.ipynb"
# 2026.09.21-13:02:03.422342     3.381 >> Trial 10 (18n_ppo_tr_frostbite_06:287) finished with value: 7.130124777183601e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 5 with value: 1.166747690811862e-06
# 2026.09.21-13:02:05.158951     0.002 >> Launch "18n_ppo_tr_frostbite_06:287" completed
# 2026.09.21-13:02:05.159779     0.001 >> 10 (+1) launches completed; running launches=5
# 2026.09.21-13:02:31.065148     0.344 >> Model instance registered, version=292
# 2026.09.21-13:02:31.079425     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:292"; running launches=6
# 2026.09.21-13:02:31.079559     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch292.ipynb"
# 2026.09.21-13:03:23.527351     1.338 >> Trial 9 (18n_ppo_tr_frostbite_06:286) finished with value: 8.426511100307892e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 5 with value: 1.166747690811862e-06
# 2026.09.21-13:03:27.300807     0.001 >> Launch "18n_ppo_tr_frostbite_06:286" completed
# 2026.09.21-13:03:27.301304     0.000 >> 11 (+1) launches completed; running launches=5
# 2026.09.21-13:03:53.130904     0.286 >> Model instance registered, version=293
# 2026.09.21-13:03:53.145917     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:293"; running launches=6
# 2026.09.21-13:03:53.146134     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch293.ipynb"
# 2026.09.21-13:05:26.325323     0.308 >> Trial 11 (18n_ppo_tr_frostbite_06:288) finished with value: 7.454221357964673e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:203'}. Best is trial 5 with value: 1.166747690811862e-06
# 2026.09.21-13:05:31.133389     0.001 >> Launch "18n_ppo_tr_frostbite_06:288" completed
# 2026.09.21-13:05:31.133887     0.000 >> 12 (+1) launches completed; running launches=5
# 2026.09.21-13:05:52.572995     0.290 >> Model instance registered, version=294
# 2026.09.21-13:05:52.588281     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:294"; running launches=6
# 2026.09.21-13:05:52.588459     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch294.ipynb"
# 2026.09.21-13:33:16.868104     3.366 >> Trial 12 (18n_ppo_tr_frostbite_06:289) finished with value: 6.806028196402528e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:208'}. Best is trial 5 with value: 1.166747690811862e-06
# 2026.09.21-13:33:18.738592     0.002 >> Launch "18n_ppo_tr_frostbite_06:289" completed
# 2026.09.21-13:33:18.739566     0.001 >> 13 (+1) launches completed; running launches=5
# 2026.09.21-13:33:44.533338     0.197 >> Model instance registered, version=295
# 2026.09.21-13:33:44.543313     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:295"; running launches=6
# 2026.09.21-13:33:44.543399     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch295.ipynb"
# 2026.09.21-13:34:45.014702     4.053 >> Trial 13 (18n_ppo_tr_frostbite_06:290) finished with value: 4.861448711716091e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:208'}. Best is trial 5 with value: 1.166747690811862e-06
# 2026.09.21-13:34:46.084180     0.002 >> Launch "18n_ppo_tr_frostbite_06:290" completed
# 2026.09.21-13:34:46.085158     0.001 >> 14 (+1) launches completed; running launches=5
# 2026.09.21-13:35:11.870521     0.204 >> Model instance registered, version=296
# 2026.09.21-13:35:11.884136     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:296"; running launches=6
# 2026.09.21-13:35:11.884279     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch296.ipynb"
# 2026.09.21-13:37:40.036485     4.492 >> Trial 15 (18n_ppo_tr_frostbite_06:292) finished with value: 7.778317938745746e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:208'}. Best is trial 5 with value: 1.166747690811862e-06
# 2026.09.21-13:37:40.662387     0.002 >> Launch "18n_ppo_tr_frostbite_06:292" completed
# 2026.09.21-13:37:40.663170     0.001 >> 15 (+1) launches completed; running launches=5
# 2026.09.21-13:38:06.505425     0.215 >> Model instance registered, version=297
# 2026.09.21-13:38:06.514826     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:297"; running launches=6
# 2026.09.21-13:38:06.514978     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch297.ipynb"
# 2026.09.21-13:38:21.962209     0.120 >> Trial 14 (18n_ppo_tr_frostbite_06:291) finished with value: 9.722897423432182e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 5 with value: 1.166747690811862e-06
# 2026.09.21-13:38:26.961735     0.002 >> Launch "18n_ppo_tr_frostbite_06:291" completed
# 2026.09.21-13:38:26.962665     0.001 >> 16 (+1) launches completed; running launches=5
# 2026.09.21-13:38:37.432862     0.222 >> Model instance registered, version=298
# 2026.09.21-13:38:37.443944     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:298"; running launches=6
# 2026.09.21-13:38:37.444805     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch298.ipynb"
# 2026.09.21-13:39:51.588729     2.314 >> Trial 16 (18n_ppo_tr_frostbite_06:293) finished with value: 9.39880084265111e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:208'}. Best is trial 5 with value: 1.166747690811862e-06
# 2026.09.21-13:39:54.396308     0.002 >> Launch "18n_ppo_tr_frostbite_06:293" completed
# 2026.09.21-13:39:54.397235     0.001 >> 17 (+1) launches completed; running launches=5
# 2026.09.21-13:40:20.199640     0.227 >> Model instance registered, version=299
# 2026.09.21-13:40:20.212243     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:299"; running launches=6
# 2026.09.21-13:40:20.212435     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch299.ipynb"
# 2026.09.21-13:42:14.260404     1.103 >> Trial 17 (18n_ppo_tr_frostbite_06:294) finished with value: 1.393615297358613e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:208'}. Best is trial 17 with value: 1.393615297358613e-06
# 2026.09.21-13:42:18.277749     0.002 >> Launch "18n_ppo_tr_frostbite_06:294" completed
# 2026.09.21-13:42:18.278781     0.001 >> 18 (+1) launches completed; running launches=5
# 2026.09.21-14:08:25.596568     1.454 >> Trial 18 (18n_ppo_tr_frostbite_06:295) finished with value: 9.722897423432182e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:208'}. Best is trial 17 with value: 1.393615297358613e-06
# 2026.09.21-14:08:29.260433     0.001 >> Launch "18n_ppo_tr_frostbite_06:295" completed
# 2026.09.21-14:08:29.261338     0.001 >> 19 (+1) launches completed; running launches=4
# 2026.09.21-14:09:48.931537     2.866 >> Trial 19 (18n_ppo_tr_frostbite_06:296) finished with value: 1.1019283746556473e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:208'}. Best is trial 17 with value: 1.393615297358613e-06
# 2026.09.21-14:09:51.183457     0.003 >> Launch "18n_ppo_tr_frostbite_06:296" completed
# 2026.09.21-14:09:51.184297     0.001 >> 20 (+1) launches completed; running launches=3
# 2026.09.21-14:10:19.982133     3.233 >> Trial 21 (18n_ppo_tr_frostbite_06:298) finished with value: 1.2315670069680764e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:208'}. Best is trial 17 with value: 1.393615297358613e-06
# 2026.09.21-14:10:21.997632     0.002 >> Launch "18n_ppo_tr_frostbite_06:298" completed
# 2026.09.21-14:10:21.998573     0.001 >> 21 (+1) launches completed; running launches=2
# 2026.09.21-14:10:47.793773     0.214 >> Model instance registered, version=300
# 2026.09.21-14:10:47.807286     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:300"; running launches=3
# 2026.09.21-14:10:47.807415     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch300.ipynb"
# 2026.09.21-14:12:03.472068     4.062 >> Trial 20 (18n_ppo_tr_frostbite_06:297) finished with value: 5.83373845405931e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:208'}. Best is trial 17 with value: 1.393615297358613e-06
# 2026.09.21-14:12:04.529015     0.002 >> Launch "18n_ppo_tr_frostbite_06:297" completed
# 2026.09.21-14:12:04.530216     0.001 >> 22 (+1) launches completed; running launches=2
# 2026.09.21-14:12:30.344409     0.225 >> Model instance registered, version=301
# 2026.09.21-14:12:30.357667     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:301"; running launches=3
# 2026.09.21-14:12:30.357811     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch301.ipynb"
# 2026.09.21-14:12:44.365967     3.774 >> Trial 22 (18n_ppo_tr_frostbite_06:299) failed: launch_result_metadata={'error_code': 1, 'error_message': 'Failed to fetch result file "/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch299.metrics_suite.json" in container: 404 Client Error for http+docker://localhost/v1.52/containers/a5d9143f3ae2668e1bce68dfc2948dd761fc00140620a9afe843e66125b3a1f9/archive?path=%2Fneurolab%2Frun%2F18_rl%2F18n_ppo_tr_frostbite_06-launch299.metrics_suite.json: Not Found ("Could not find the file /neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch299.metrics_suite.json in container a5d9143f3ae2668e1bce68dfc2948dd761fc00140620a9afe843e66125b3a1f9")', 'is_ok': False, 'runner_name': 'baki_1789486130.207'}
# 2026.09.21-14:12:45.707183     0.001 >> Launch "18n_ppo_tr_frostbite_06:299" completed
# 2026.09.21-14:12:45.708358     0.001 >> 23 (+1) launches completed; running launches=2
# 2026.09.21-14:12:53.920704     3.101 >> Trial 23 (18n_ppo_tr_frostbite_06:300) failed: launch_result_metadata={'error_code': 1, 'error_message': 'Container is lost', 'is_ok': False, 'runner_name': 'baki_1789486109.933'}
# 2026.09.21-14:12:55.937869     0.001 >> Launch "18n_ppo_tr_frostbite_06:300" completed
# 2026.09.21-14:12:55.938586     0.001 >> 24 (+1) launches completed; running launches=1
# 2026.09.21-14:13:01.257362     0.205 >> Model instance registered, version=302
# 2026.09.21-14:13:01.268529     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:302"; running launches=2
# 2026.09.21-14:13:01.268653     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch302.ipynb"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 54
#      51 except TimeoutError as e:
#      52     pass
# ---> 54 time.sleep(5)
#
# KeyboardInterrupt:

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
