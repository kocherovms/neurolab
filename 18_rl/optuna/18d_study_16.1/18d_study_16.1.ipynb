# %% [markdown]
# # Goal
#
# Что можно выжать из простого `MSE` при `launch_goal=train_predictor`? Тестируем гиперпараметры:
# - `d_projected`
# - `learn_rate`

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18d_world_model_07.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.launch_goal = 'train_predictor'
    
    HP.general.comment = None
    HP.general.random_seed = random.randint(0, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.dataset.train = [
        'train_dataset_seq_eq_5_max_eq_0:101',
        'train_dataset_seq_eq_5_max_eq_0:102',
        'train_dataset_seq_eq_5_max_eq_0:103',
        'train_dataset_seq_eq_5_max_eq_0:104',
        'train_dataset_seq_eq_5_max_eq_0:105',
        'train_dataset_seq_eq_5_max_eq_0:106',
        'train_dataset_seq_eq_5_max_eq_0:107',
        'train_dataset_seq_eq_5_max_eq_0:108',
        'train_dataset_seq_eq_5_max_eq_0:109',
        'train_dataset_seq_eq_5_max_eq_0:110',
    ]
    HP.dataset.test = 'test_dataset_seq_eq_5_max_eq_0:101'

    HP.model.parent = '18d_world_model_07:8'
    HP.model.sequence_length = 4
    HP.model.actions_count = 6
    HP.model.ob_shape = (1, 178, 152)
    HP.model.d_model = 256
    HP.model.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.model.encoder = dict(
        is_trainable=HP.launch_goal in ('train_encoder', 'train_all', None),
        vision_head=dict(grid=(6,6), features_counts=(16, 32, 64, 128)),
    )
    HP.model.predictor = dict(
        is_trainable=HP.launch_goal in ('train_predictor', 'train_all', None),
        down_translator=None,
        parent=None, # do not load from HP.model.parent
    )
    HP.model.renderer = dict(
        is_trainable=HP.launch_goal in ('train_encoder', 'train_all', None),
        projector=dict(type='linear'), 
        render_engine=dict(
            type='layer', 
            layers_count=4, 
            features_counts=(96, 64, 32, 16),
        ),
    )
    HP.model.struct_projector = dict(
        is_trainable=HP.launch_goal in ('train_predictor', 'train_all', None),
        d_inner=HP.model.d_model,
        d_projected=optuna_trial.suggest_categorical('d_projected', [128, 192, 256]),
        parent=None, # do not load from HP.model.parent
    )
    
    HP.train.epochs_count = 100
    HP.train.batch_size = 128
    HP.train.optimizer = 'AdamW'
    HP.train.max_grad_norm = 1.0
    HP.train.learn_rate = f'const({optuna_trial.suggest_float('learn_rate', 0.0001, 0.01)})'
    HP.train.bce_loss_coef = 'const(1.0)'
    HP.train.edge_loss_coef = 'const(1.0)'
    HP.train.recon_loss_coef = 'const(0.0)'
    HP.train.pred_loss = dict(
        type='MSE', 
        loss_coef='const(1.0)', 
    )
    
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# ssim выше `0.67` даже не взобрался. Даже анализировать нечего, полный провал.
#
# <img src="./img/ssim.png">
#
# **Выводы**
# 1) попробовать `MSE` без `struct_projector`.

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18d_world_model_07.ipynb',
#  'target_notebook_name': '18d_world_model_07',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18d_study_16.1/18d_study_16.1.ipynb',
#  'optuna_study_name': '18d_study_16.1',
#  'optuna_study_serial': '16.1',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18d_study_16.1/18d_study_16.1.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 100
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-10 17:59:07,254] Using an existing study with name '18d_study_16.1' instead of creating a new one.
# 2026.09.10-17:59:07.498171     0.176 >> Model instance registered, version=195
# 2026.09.10-17:59:07.512294     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch195.ipynb"
# 2026.09.10-17:59:07.512540     0.006 >> 6.0 idle runners exist, submitted launch "18d_world_model_07:195"; running launches=1
# 2026.09.10-17:59:38.740880     0.183 >> Model instance registered, version=196
# 2026.09.10-17:59:38.755381     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch196.ipynb"
# 2026.09.10-17:59:38.755709     0.006 >> 5.3 idle runners exist, submitted launch "18d_world_model_07:196"; running launches=2
# 2026.09.10-18:00:09.889675     0.201 >> Model instance registered, version=197
# 2026.09.10-18:00:09.906799     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch197.ipynb"
# 2026.09.10-18:00:09.907146     0.008 >> 4.5 idle runners exist, submitted launch "18d_world_model_07:197"; running launches=3
# 2026.09.10-18:00:41.524988     0.181 >> Model instance registered, version=198
# 2026.09.10-18:00:41.540614     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch198.ipynb"
# 2026.09.10-18:00:41.541200     0.008 >> 3.7 idle runners exist, submitted launch "18d_world_model_07:198"; running launches=4
# 2026.09.10-18:01:12.552994     0.179 >> Model instance registered, version=199
# 2026.09.10-18:01:12.563297     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch199.ipynb"
# 2026.09.10-18:01:12.563620     0.005 >> 2.8 idle runners exist, submitted launch "18d_world_model_07:199"; running launches=5
# 2026.09.10-18:01:43.679389     0.194 >> Model instance registered, version=200
# 2026.09.10-18:01:43.695243     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch200.ipynb"
# 2026.09.10-18:01:43.695857     0.008 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:200"; running launches=6
# 2026.09.10-18:09:19.859447     0.163 >> Model instance registered, version=201
# 2026.09.10-18:09:19.872003     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch201.ipynb"
# 2026.09.10-18:09:19.872221     0.005 >> 1.3 idle runners exist, submitted launch "18d_world_model_07:201"; running launches=7
# 2026.09.10-18:09:50.738056     0.189 >> Model instance registered, version=202
# 2026.09.10-18:09:50.753058     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch202.ipynb"
# 2026.09.10-18:09:50.753608     0.007 >> 3.5 idle runners exist, submitted launch "18d_world_model_07:202"; running launches=8
# 2026.09.10-18:10:22.258361     0.403 >> Model instance registered, version=203
# 2026.09.10-18:10:22.284315     0.011 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch203.ipynb"
# 2026.09.10-18:10:22.285154     0.011 >> 2.5 idle runners exist, submitted launch "18d_world_model_07:203"; running launches=9
# 2026.09.10-18:10:53.497757     0.273 >> Model instance registered, version=204
# 2026.09.10-18:10:53.513331     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch204.ipynb"
# 2026.09.10-18:10:53.514030     0.005 >> 1.5 idle runners exist, submitted launch "18d_world_model_07:204"; running launches=10
# 2026.09.10-18:12:58.597232     4.617 >> Trial 1 (18d_world_model_07:195) finished with value: 0.6532535064034164 and parameters: {'d_projected': 256, 'learn_rate': 0.008893275132380255}. Best is trial 1 with value: 0.6532535064034164
# 2026.09.10-18:12:59.089505     0.001 >> Launch "18d_world_model_07:195" completed
# 2026.09.10-18:12:59.090031     0.001 >> 1 (+1) launches completed; running launches=9
# 2026.09.10-18:13:24.835302     0.171 >> Model instance registered, version=205
# 2026.09.10-18:13:24.846804     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:205"; running launches=10
# 2026.09.10-18:13:24.846972     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch205.ipynb"
# 2026.09.10-18:14:16.090574     0.069 >> Trial 2 (18d_world_model_07:196) finished with value: 0.6560612777248025 and parameters: {'d_projected': 128, 'learn_rate': 0.006631630527679454}. Best is trial 2 with value: 0.6560612777248025
# 2026.09.10-18:14:16.091317     0.001 >> Launch "18d_world_model_07:196" completed
# 2026.09.10-18:14:16.091736     0.000 >> 2 (+1) launches completed; running launches=9
# 2026.09.10-18:14:41.954923     0.189 >> Model instance registered, version=206
# 2026.09.10-18:14:41.971883     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:206"; running launches=10
# 2026.09.10-18:14:41.972029     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch206.ipynb"
# 2026.09.10-18:15:03.925365     1.503 >> Trial 3 (18d_world_model_07:197) finished with value: 0.6460618213750422 and parameters: {'d_projected': 192, 'learn_rate': 0.00930008154028602}. Best is trial 2 with value: 0.6560612777248025
# 2026.09.10-18:15:07.539190     0.001 >> Launch "18d_world_model_07:197" completed
# 2026.09.10-18:15:07.539941     0.001 >> 3 (+1) launches completed; running launches=9
# 2026.09.10-18:15:35.689247     0.215 >> Model instance registered, version=207
# 2026.09.10-18:15:35.705932     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:207"; running launches=10
# 2026.09.10-18:15:35.706072     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch207.ipynb"
# 2026.09.10-18:15:42.668681     1.711 >> Trial 4 (18d_world_model_07:198) finished with value: 0.6323317997157574 and parameters: {'d_projected': 256, 'learn_rate': 0.008563736305357752}. Best is trial 2 with value: 0.6560612777248025
# 2026.09.10-18:15:46.075105     0.002 >> Launch "18d_world_model_07:198" completed
# 2026.09.10-18:15:46.076316     0.001 >> 4 (+1) launches completed; running launches=9
# 2026.09.10-18:15:55.552184     4.073 >> Trial 5 (18d_world_model_07:199) finished with value: 0.6473783063702285 and parameters: {'d_projected': 256, 'learn_rate': 0.00611051880256972}. Best is trial 2 with value: 0.6560612777248025
# 2026.09.10-18:15:56.590781     0.001 >> Launch "18d_world_model_07:199" completed
# 2026.09.10-18:15:56.591500     0.001 >> 5 (+1) launches completed; running launches=8
# 2026.09.10-18:16:06.898793     0.087 >> Model instance registered, version=208
# 2026.09.10-18:16:06.912761     0.006 >> 2.0 idle runners exist, submitted launch "18d_world_model_07:208"; running launches=9
# 2026.09.10-18:16:06.912892     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch208.ipynb"
# 2026.09.10-18:16:15.853835     3.829 >> Trial 6 (18d_world_model_07:200) finished with value: 0.6148783937096596 and parameters: {'d_projected': 128, 'learn_rate': 0.003703395567768324}. Best is trial 2 with value: 0.6560612777248025
# 2026.09.10-18:16:17.138837     0.001 >> Launch "18d_world_model_07:200" completed
# 2026.09.10-18:16:17.139677     0.001 >> 6 (+1) launches completed; running launches=8
# 2026.09.10-18:16:37.777633     0.174 >> Model instance registered, version=209
# 2026.09.10-18:16:37.787180     0.005 >> 2.7 idle runners exist, submitted launch "18d_world_model_07:209"; running launches=9
# 2026.09.10-18:16:37.787357     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch209.ipynb"
# 2026.09.10-18:17:00.771472     1.829 >> Trial 7 (18d_world_model_07:201) finished with value: 0.5731796869076788 and parameters: {'d_projected': 128, 'learn_rate': 0.0008824810162167021}. Best is trial 2 with value: 0.6560612777248025
# 2026.09.10-18:17:04.055497     0.001 >> Launch "18d_world_model_07:201" completed
# 2026.09.10-18:17:04.056282     0.001 >> 7 (+1) launches completed; running launches=8
# 2026.09.10-18:17:09.388667     0.219 >> Model instance registered, version=210
# 2026.09.10-18:17:09.403054     0.008 >> 2.2 idle runners exist, submitted launch "18d_world_model_07:210"; running launches=9
# 2026.09.10-18:17:09.403311     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch210.ipynb"
# 2026.09.10-18:17:40.727801     0.198 >> Model instance registered, version=211
# 2026.09.10-18:17:40.745979     0.007 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:211"; running launches=10
# 2026.09.10-18:17:40.746107     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch211.ipynb"
# 2026.09.10-18:17:40.983023     0.237 >> Trial 8 (18d_world_model_07:202) finished with value: 0.6507524261251092 and parameters: {'d_projected': 256, 'learn_rate': 0.004959068294828593}. Best is trial 2 with value: 0.6560612777248025
# 2026.09.10-18:17:45.857775     0.001 >> Launch "18d_world_model_07:202" completed
# 2026.09.10-18:17:45.858498     0.001 >> 8 (+1) launches completed; running launches=9
# 2026.09.10-18:18:11.729888     0.191 >> Trial 9 (18d_world_model_07:203) finished with value: 0.6484539364464581 and parameters: {'d_projected': 192, 'learn_rate': 0.0076201481920891686}. Best is trial 2 with value: 0.6560612777248025
# 2026.09.10-18:18:11.771016     0.041 >> Model instance registered, version=212
# 2026.09.10-18:18:11.784980     0.005 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:212"; running launches=10
# 2026.09.10-18:18:11.786226     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch212.ipynb"
# 2026.09.10-18:18:11.786575     0.002 >> Launch "18d_world_model_07:203" completed
# 2026.09.10-18:18:11.787868     0.001 >> 9 (+1) launches completed; running launches=9
# 2026.09.10-18:18:42.339859     4.980 >> Trial 10 (18d_world_model_07:204) finished with value: 0.6525514842942357 and parameters: {'d_projected': 256, 'learn_rate': 0.006190667840180276}. Best is trial 2 with value: 0.6560612777248025
# 2026.09.10-18:18:42.695235     0.217 >> Model instance registered, version=213
# 2026.09.10-18:18:42.707830     0.006 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:213"; running launches=10
# 2026.09.10-18:18:42.707975     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch213.ipynb"
# 2026.09.10-18:18:42.708486     0.001 >> Launch "18d_world_model_07:204" completed
# 2026.09.10-18:18:42.709359     0.001 >> 10 (+1) launches completed; running launches=9
# 2026.09.10-18:19:13.750481     0.225 >> Model instance registered, version=214
# 2026.09.10-18:19:13.768809     0.007 >> 1.5 idle runners exist, submitted launch "18d_world_model_07:214"; running launches=10
# 2026.09.10-18:19:13.768988     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch214.ipynb"
# 2026.09.10-18:24:35.811833     2.934 >> Trial 15 (18d_world_model_07:209) finished with value: 0.6260174727067351 and parameters: {'d_projected': 192, 'learn_rate': 0.0036957775407747318}. Best is trial 2 with value: 0.6560612777248025
# 2026.09.10-18:24:37.993397     0.002 >> Launch "18d_world_model_07:209" completed
# 2026.09.10-18:24:37.994519     0.001 >> 11 (+1) launches completed; running launches=9
# 2026.09.10-18:25:03.807982     0.238 >> Model instance registered, version=215
# 2026.09.10-18:25:03.826102     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:215"; running launches=10
# 2026.09.10-18:25:03.826492     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch215.ipynb"
# 2026.09.10-18:25:56.434486     1.377 >> Trial 17 (18d_world_model_07:211) finished with value: 0.6506067155860364 and parameters: {'d_projected': 128, 'learn_rate': 0.008810273155796114}. Best is trial 2 with value: 0.6560612777248025
# 2026.09.10-18:26:00.171660     0.002 >> Launch "18d_world_model_07:211" completed
# 2026.09.10-18:26:00.172457     0.001 >> 12 (+1) launches completed; running launches=9
# 2026.09.10-18:26:05.972755     0.687 >> Trial 18 (18d_world_model_07:212) finished with value: 0.5883261673152447 and parameters: {'d_projected': 128, 'learn_rate': 0.002497291101008885}. Best is trial 2 with value: 0.6560612777248025
# 2026.09.10-18:26:10.401303     0.001 >> Launch "18d_world_model_07:212" completed
# 2026.09.10-18:26:10.402551     0.001 >> 13 (+1) launches completed; running launches=8
# 2026.09.10-18:26:15.931460     0.231 >> Model instance registered, version=216
# 2026.09.10-18:26:15.952582     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:216"; running launches=9
# 2026.09.10-18:26:15.952852     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch216.ipynb"
# 2026.09.10-18:26:27.424402     1.254 >> Trial 19 (18d_world_model_07:213) finished with value: 0.6295718085020781 and parameters: {'d_projected': 128, 'learn_rate': 0.00985764205016543}. Best is trial 2 with value: 0.6560612777248025
# 2026.09.10-18:26:31.393371     0.001 >> Launch "18d_world_model_07:213" completed
# 2026.09.10-18:26:31.394164     0.001 >> 14 (+1) launches completed; running launches=8
# 2026.09.10-18:26:48.121709     0.199 >> Model instance registered, version=217
# 2026.09.10-18:26:48.139342     0.006 >> 2.3 idle runners exist, submitted launch "18d_world_model_07:217"; running launches=9
# 2026.09.10-18:26:48.139871     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch217.ipynb"
# 2026.09.10-18:26:48.423714     0.284 >> Trial 11 (18d_world_model_07:205) finished with value: 0.5873772674240172 and parameters: {'d_projected': 256, 'learn_rate': 0.003108426691483716}. Best is trial 2 with value: 0.6560612777248025
# 2026.09.10-18:26:53.253379     0.002 >> Launch "18d_world_model_07:205" completed
# 2026.09.10-18:26:53.254397     0.001 >> 15 (+1) launches completed; running launches=8
# 2026.09.10-18:27:19.011816     0.192 >> Model instance registered, version=218
# 2026.09.10-18:27:19.025545     0.005 >> 2.5 idle runners exist, submitted launch "18d_world_model_07:218"; running launches=9
# 2026.09.10-18:27:19.025803     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch218.ipynb"
# 2026.09.10-18:27:49.900936     0.192 >> Model instance registered, version=219
# 2026.09.10-18:27:49.912794     0.004 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:219"; running launches=10
# 2026.09.10-18:27:49.912964     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch219.ipynb"
# 2026.09.10-18:28:52.177340     0.742 >> Trial 12 (18d_world_model_07:206) finished with value: 0.6536935498006642 and parameters: {'d_projected': 128, 'learn_rate': 0.007220158262859973}. Best is trial 2 with value: 0.6560612777248025
# 2026.09.10-18:28:56.553951     0.002 >> Launch "18d_world_model_07:206" completed
# 2026.09.10-18:28:56.554890     0.001 >> 16 (+1) launches completed; running launches=9
# 2026.09.10-18:29:22.340033     0.188 >> Model instance registered, version=220
# 2026.09.10-18:29:22.355801     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:220"; running launches=10
# 2026.09.10-18:29:22.355955     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch220.ipynb"
# 2026.09.10-18:29:49.340654     1.349 >> Trial 13 (18d_world_model_07:207) finished with value: 0.6571515598334372 and parameters: {'d_projected': 192, 'learn_rate': 0.006125488453043474}. Best is trial 13 with value: 0.6571515598334372
# 2026.09.10-18:29:53.107043     0.001 >> Launch "18d_world_model_07:207" completed
# 2026.09.10-18:29:53.108086     0.001 >> 17 (+1) launches completed; running launches=9
# 2026.09.10-18:30:19.355296     0.209 >> Model instance registered, version=221
# 2026.09.10-18:30:19.369901     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:221"; running launches=10
# 2026.09.10-18:30:19.370060     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch221.ipynb"
# 2026.09.10-18:30:46.036093     1.117 >> Trial 14 (18d_world_model_07:208) finished with value: 0.5867653647437692 and parameters: {'d_projected': 128, 'learn_rate': 0.003932104414479725}. Best is trial 13 with value: 0.6571515598334372
# 2026.09.10-18:30:50.029432     0.001 >> Launch "18d_world_model_07:208" completed
# 2026.09.10-18:30:50.030208     0.001 >> 18 (+1) launches completed; running launches=9
# 2026.09.10-18:31:06.152286     0.759 >> Trial 16 (18d_world_model_07:210) finished with value: 0.6321599152870476 and parameters: {'d_projected': 192, 'learn_rate': 0.0032150514836003143}. Best is trial 13 with value: 0.6571515598334372
# 2026.09.10-18:31:10.632668     0.113 >> Model instance registered, version=222
# 2026.09.10-18:31:10.643309     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:222"; running launches=10
# 2026.09.10-18:31:10.643399     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch222.ipynb"
# 2026.09.10-18:31:10.643780     0.000 >> Launch "18d_world_model_07:210" completed
# 2026.09.10-18:31:10.644767     0.001 >> 19 (+1) launches completed; running launches=9
# 2026.09.10-18:31:41.539140     0.192 >> Model instance registered, version=223
# 2026.09.10-18:31:41.554152     0.006 >> 1.5 idle runners exist, submitted launch "18d_world_model_07:223"; running launches=10
# 2026.09.10-18:31:41.554307     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch223.ipynb"
# 2026.09.10-18:32:30.552087     2.948 >> Trial 21 (18d_world_model_07:215) finished with value: 0.6430252422578633 and parameters: {'d_projected': 128, 'learn_rate': 0.009963592006200396}. Best is trial 13 with value: 0.6571515598334372
# 2026.09.10-18:32:32.720749     0.001 >> Launch "18d_world_model_07:215" completed
# 2026.09.10-18:32:32.721458     0.001 >> 20 (+1) launches completed; running launches=9
# 2026.09.10-18:32:37.400105     4.679 >> Trial 20 (18d_world_model_07:214) finished with value: 0.6527392999269068 and parameters: {'d_projected': 128, 'learn_rate': 0.007456167249690802}. Best is trial 13 with value: 0.6571515598334372
# 2026.09.10-18:32:37.836649     0.001 >> Launch "18d_world_model_07:214" completed
# 2026.09.10-18:32:37.837452     0.001 >> 21 (+1) launches completed; running launches=8
# 2026.09.10-18:32:48.267762     0.197 >> Model instance registered, version=224
# 2026.09.10-18:32:48.281450     0.005 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:224"; running launches=9
# 2026.09.10-18:32:48.281708     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch224.ipynb"
# 2026.09.10-18:33:19.210952     0.181 >> Model instance registered, version=225
# 2026.09.10-18:33:19.220171     0.004 >> 1.5 idle runners exist, submitted launch "18d_world_model_07:225"; running launches=10
# 2026.09.10-18:33:19.220319     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch225.ipynb"
# 2026.09.10-18:34:21.524023     1.901 >> Trial 22 (18d_world_model_07:216) finished with value: 0.6513181761838496 and parameters: {'d_projected': 128, 'learn_rate': 0.007580984808300089}. Best is trial 13 with value: 0.6571515598334372
# 2026.09.10-18:34:24.742855     0.002 >> Launch "18d_world_model_07:216" completed
# 2026.09.10-18:34:24.743964     0.001 >> 22 (+1) launches completed; running launches=9
# 2026.09.10-18:34:50.483789     0.172 >> Model instance registered, version=226
# 2026.09.10-18:34:50.493639     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:226"; running launches=10
# 2026.09.10-18:34:50.493778     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch226.ipynb"
# 2026.09.10-18:35:02.277001     1.555 >> Trial 24 (18d_world_model_07:218) finished with value: 0.6470155818387866 and parameters: {'d_projected': 128, 'learn_rate': 0.007347737629526899}. Best is trial 13 with value: 0.6571515598334372
# 2026.09.10-18:35:05.837122     0.002 >> Launch "18d_world_model_07:218" completed
# 2026.09.10-18:35:05.838035     0.001 >> 23 (+1) launches completed; running launches=9
# 2026.09.10-18:35:21.990480     0.182 >> Model instance registered, version=227
# 2026.09.10-18:35:22.005537     0.007 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:227"; running launches=10
# 2026.09.10-18:35:22.006246     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch227.ipynb"
# 2026.09.10-18:35:22.034727     0.028 >> Trial 25 (18d_world_model_07:219) finished with value: 0.638524264562875 and parameters: {'d_projected': 128, 'learn_rate': 0.007465790919531615}. Best is trial 13 with value: 0.6571515598334372
# 2026.09.10-18:35:22.035379     0.001 >> Launch "18d_world_model_07:219" completed
# 2026.09.10-18:35:22.035802     0.000 >> 24 (+1) launches completed; running launches=9
# 2026.09.10-18:35:52.968619     0.180 >> Model instance registered, version=228
# 2026.09.10-18:35:52.979415     0.005 >> 1.5 idle runners exist, submitted launch "18d_world_model_07:228"; running launches=10
# 2026.09.10-18:35:52.979892     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch228.ipynb"
# 2026.09.10-18:39:47.537682     4.053 >> Trial 23 (18d_world_model_07:217) finished with value: 0.6580704348161817 and parameters: {'d_projected': 128, 'learn_rate': 0.007345698031117711}. Best is trial 23 with value: 0.6580704348161817
# 2026.09.10-18:39:48.599301     0.001 >> Launch "18d_world_model_07:217" completed
# 2026.09.10-18:39:48.600376     0.001 >> 25 (+1) launches completed; running launches=9
# 2026.09.10-18:40:24.007497     4.717 >> Trial 30 (18d_world_model_07:224) finished with value: 0.6551561988890171 and parameters: {'d_projected': 192, 'learn_rate': 0.0071958988818439755}. Best is trial 23 with value: 0.6580704348161817
# 2026.09.10-18:40:24.409785     0.002 >> Launch "18d_world_model_07:224" completed
# 2026.09.10-18:40:24.410598     0.001 >> 26 (+1) launches completed; running launches=8
# 2026.09.10-18:40:29.693854     0.167 >> Model instance registered, version=229
# 2026.09.10-18:40:29.708360     0.005 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:229"; running launches=9
# 2026.09.10-18:40:29.708550     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch229.ipynb"
# 2026.09.10-18:41:00.593993     0.215 >> Model instance registered, version=230
# 2026.09.10-18:41:00.609105     0.006 >> 1.5 idle runners exist, submitted launch "18d_world_model_07:230"; running launches=10
# 2026.09.10-18:41:00.609298     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch230.ipynb"
# 2026.09.10-18:42:35.115255     1.353 >> Trial 32 (18d_world_model_07:226) finished with value: 0.6572795188985765 and parameters: {'d_projected': 192, 'learn_rate': 0.00667738003531638}. Best is trial 23 with value: 0.6580704348161817
# 2026.09.10-18:42:38.878173     0.001 >> Launch "18d_world_model_07:226" completed
# 2026.09.10-18:42:38.879114     0.001 >> 27 (+1) launches completed; running launches=9
# 2026.09.10-18:42:56.701321     2.494 >> Trial 33 (18d_world_model_07:227) finished with value: 0.6535902246832848 and parameters: {'d_projected': 192, 'learn_rate': 0.006734272736758738}. Best is trial 23 with value: 0.6580704348161817
# 2026.09.10-18:42:59.534150     0.216 >> Model instance registered, version=231
# 2026.09.10-18:42:59.543400     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:231"; running launches=10
# 2026.09.10-18:42:59.543953     0.001 >> Launch "18d_world_model_07:227" completed
# 2026.09.10-18:42:59.543502     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch231.ipynb"
# 2026.09.10-18:42:59.544207     0.000 >> 28 (+1) launches completed; running launches=9
# 2026.09.10-18:43:06.157678     0.259 >> Trial 26 (18d_world_model_07:220) finished with value: 0.6444325759075582 and parameters: {'d_projected': 128, 'learn_rate': 0.006983306838144784}. Best is trial 23 with value: 0.6580704348161817
# 2026.09.10-18:43:11.011657     0.001 >> Launch "18d_world_model_07:220" completed
# 2026.09.10-18:43:11.012324     0.001 >> 29 (+1) launches completed; running launches=8
# 2026.09.10-18:43:27.410831     0.464 >> Trial 34 (18d_world_model_07:228) finished with value: 0.6486966917291284 and parameters: {'d_projected': 192, 'learn_rate': 0.006480322389572058}. Best is trial 23 with value: 0.6580704348161817
# 2026.09.10-18:43:32.236608     0.171 >> Model instance registered, version=232
# 2026.09.10-18:43:32.249665     0.005 >> 2.8 idle runners exist, submitted launch "18d_world_model_07:232"; running launches=9
# 2026.09.10-18:43:32.249811     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch232.ipynb"
# 2026.09.10-18:43:32.250295     0.001 >> Launch "18d_world_model_07:228" completed
# 2026.09.10-18:43:32.251247     0.001 >> 30 (+1) launches completed; running launches=8
# 2026.09.10-18:44:03.175851     0.238 >> Model instance registered, version=233
# 2026.09.10-18:44:03.192050     0.007 >> 2.5 idle runners exist, submitted launch "18d_world_model_07:233"; running launches=9
# 2026.09.10-18:44:03.192185     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch233.ipynb"
# 2026.09.10-18:44:17.184147     0.285 >> Trial 27 (18d_world_model_07:221) finished with value: 0.664288841187954 and parameters: {'d_projected': 192, 'learn_rate': 0.007208723635631243}. Best is trial 27 with value: 0.664288841187954
# 2026.09.10-18:44:22.017844     0.002 >> Launch "18d_world_model_07:221" completed
# 2026.09.10-18:44:22.018750     0.001 >> 31 (+1) launches completed; running launches=8
# 2026.09.10-18:44:42.650958     0.180 >> Model instance registered, version=234
# 2026.09.10-18:44:42.665034     0.006 >> 2.2 idle runners exist, submitted launch "18d_world_model_07:234"; running launches=9
# 2026.09.10-18:44:42.665178     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch234.ipynb"
# KeyboardInterrupt

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-10 18:44:49,444] Using an existing study with name '18d_study_16.1' instead of creating a new one.
# 2026.09.10-18:44:49.445921     6.781 >> Study statistics:
# 2026.09.10-18:44:49.448098     0.002 >> 	Number of finished trials: 41
# 2026.09.10-18:44:49.448645     0.001 >> 	Number of pruned trials: 0
# 2026.09.10-18:44:49.449111     0.000 >> 	Number of complete trials: 32
# 2026.09.10-18:44:49.449755     0.001 >> Best trial:
# 2026.09.10-18:44:49.450391     0.001 >> 	Value: 0.664288841187954
# 2026.09.10-18:44:49.450880     0.000 >> 	Model version: 221
# 2026.09.10-18:44:49.452677     0.002 >> 	Params:
# 2026.09.10-18:44:49.453814     0.001 >> 		d_projected: 192
# 2026.09.10-18:44:49.454303     0.000 >> 		learn_rate: 0.007208723635631243
