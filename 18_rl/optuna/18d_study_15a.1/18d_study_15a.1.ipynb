# %% [markdown]
# # Goal
#
# Продолжение/дополнение к 14-ому и 15-ому исследованиям. А что если вовсе без `struct_projector` (`type='nn.Identity'`)?

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18d_world_model_07.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.launch_goal = 'train_predictor'
    
    HP.general.comment = None
    HP.general.random_seed = random.randint(0, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.dataset.train = [
        'train_dataset_seq_eq_5_max_eq_0:101',
        'train_dataset_seq_eq_5_max_eq_0:102',
        'train_dataset_seq_eq_5_max_eq_0:103',
        'train_dataset_seq_eq_5_max_eq_0:104',
        'train_dataset_seq_eq_5_max_eq_0:105',
        'train_dataset_seq_eq_5_max_eq_0:106',
        'train_dataset_seq_eq_5_max_eq_0:107',
        'train_dataset_seq_eq_5_max_eq_0:108',
        'train_dataset_seq_eq_5_max_eq_0:109',
        'train_dataset_seq_eq_5_max_eq_0:110',
    ]
    HP.dataset.test = 'test_dataset_seq_eq_5_max_eq_0:101'

    HP.model.parent = '18d_world_model_07:8'
    HP.model.sequence_length = 4
    HP.model.actions_count = 6
    HP.model.ob_shape = (1, 178, 152)
    HP.model.d_model = 256
    HP.model.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.model.encoder = dict(
        is_trainable=HP.launch_goal in ('train_encoder', 'train_all', None),
        vision_head=dict(grid=(6,6), features_counts=(16, 32, 64, 128)),
    )
    HP.model.predictor = dict(
        is_trainable=HP.launch_goal in ('train_predictor', 'train_all', None),
        down_translator=None,
        parent=None, # do not load from HP.model.parent
    )
    HP.model.renderer = dict(
        is_trainable=HP.launch_goal in ('train_encoder', 'train_all', None),
        projector=dict(type='linear'), 
        render_engine=dict(
            type='layer', 
            layers_count=4, 
            features_counts=(96, 64, 32, 16),
        ),
    )
    HP.model.struct_projector = dict(
        is_trainable=HP.launch_goal in ('train_predictor', 'train_all', None),
        type='Identity',
        parent=None, # do not load from HP.model.parent
    )
    
    HP.train.epochs_count = 100
    HP.train.batch_size = 128
    HP.train.optimizer = 'AdamW'
    HP.train.max_grad_norm = 1.0
    HP.train.learn_rate = f'const({optuna_trial.suggest_float('learn_rate', 0.0001, 0.01)})'
    HP.train.bce_loss_coef = 'const(1.0)'
    HP.train.edge_loss_coef = 'const(1.0)'
    HP.train.recon_loss_coef = 'const(0.0)'
    HP.train.pred_loss = dict(
        type='InfoNCE', 
        loss_coef='const(1.0)', 
        temperature=optuna_trial.suggest_float('info_nce_loss.temperature', 0.01, 0.5)
    )
    
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Без прожектора всё очень грустно. Даже анализировать нечего.
#
# <img src="./img/ssim.png">
#
# **Выводы**
# 1) для `InfoNCE` прожектор показан!

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18d_world_model_07.ipynb',
#  'target_notebook_name': '18d_world_model_07',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18d_study_15a.1/18d_study_15a.1.ipynb',
#  'optuna_study_name': '18d_study_15a.1',
#  'optuna_study_serial': '15a.1',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18d_study_15a.1/18d_study_15a.1.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-10 21:00:38,413] A new study created in Journal with name: 18d_study_15a.1
# 2026.09.10-21:00:38.608055     0.167 >> Model instance registered, version=310
# 2026.09.10-21:00:38.619395     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch310.ipynb"
# 2026.09.10-21:00:38.619868     0.006 >> 6.0 idle runners exist, submitted launch "18d_world_model_07:310"; running launches=1
# 2026.09.10-21:01:09.844102     0.205 >> Model instance registered, version=311
# 2026.09.10-21:01:09.853801     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch311.ipynb"
# 2026.09.10-21:01:09.854031     0.004 >> 5.5 idle runners exist, submitted launch "18d_world_model_07:311"; running launches=2
# 2026.09.10-21:01:41.080353     0.225 >> Model instance registered, version=312
# 2026.09.10-21:01:41.091986     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch312.ipynb"
# 2026.09.10-21:01:41.092207     0.005 >> 4.5 idle runners exist, submitted launch "18d_world_model_07:312"; running launches=3
# 2026.09.10-21:02:12.965614     0.221 >> Model instance registered, version=313
# 2026.09.10-21:02:12.981419     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch313.ipynb"
# 2026.09.10-21:02:12.981680     0.007 >> 3.5 idle runners exist, submitted launch "18d_world_model_07:313"; running launches=4
# 2026.09.10-21:02:43.990155     0.235 >> Model instance registered, version=314
# 2026.09.10-21:02:44.000453     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch314.ipynb"
# 2026.09.10-21:02:44.000711     0.005 >> 2.7 idle runners exist, submitted launch "18d_world_model_07:314"; running launches=5
# 2026.09.10-21:03:15.304847     0.235 >> Model instance registered, version=315
# 2026.09.10-21:03:15.318681     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch315.ipynb"
# 2026.09.10-21:03:15.318918     0.005 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:315"; running launches=6
# 2026.09.10-21:03:46.207927     0.233 >> Model instance registered, version=316
# 2026.09.10-21:03:46.225138     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch316.ipynb"
# 2026.09.10-21:03:46.225405     0.008 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:316"; running launches=7
# 2026.09.10-21:09:49.183882     4.961 >> Trial 0 (18d_world_model_07:310) finished with value: 0.6650238810107112 and parameters: {'learn_rate': 0.005727561652427694, 'info_nce_loss.temperature': 0.46692967150446935}. Best is trial 0 with value: 0.6650238810107112
# 2026.09.10-21:09:49.342671     0.002 >> Launch "18d_world_model_07:310" completed
# 2026.09.10-21:09:49.343489     0.001 >> 1 (+1) launches completed; running launches=6
# 2026.09.10-21:10:41.826140     0.465 >> Trial 1 (18d_world_model_07:311) finished with value: 0.6633093259297311 and parameters: {'learn_rate': 0.004230139618018122, 'info_nce_loss.temperature': 0.47853594649204517}. Best is trial 0 with value: 0.6650238810107112
# 2026.09.10-21:10:46.474854     0.003 >> Launch "18d_world_model_07:311" completed
# 2026.09.10-21:10:46.475693     0.001 >> 2 (+1) launches completed; running launches=5
# 2026.09.10-21:11:01.221855     4.524 >> Trial 2 (18d_world_model_07:312) finished with value: 0.6448336723260581 and parameters: {'learn_rate': 0.0035715517390468685, 'info_nce_loss.temperature': 0.17768853266438378}. Best is trial 0 with value: 0.6650238810107112
# 2026.09.10-21:11:02.114069     0.308 >> Model instance registered, version=317
# 2026.09.10-21:11:02.131126     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:317"; running launches=6
# 2026.09.10-21:11:02.131359     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch317.ipynb"
# 2026.09.10-21:11:02.131826     0.001 >> Launch "18d_world_model_07:312" completed
# 2026.09.10-21:11:02.133121     0.001 >> 3 (+1) launches completed; running launches=5
# 2026.09.10-21:11:33.020995     0.199 >> Model instance registered, version=318
# 2026.09.10-21:11:33.036878     0.007 >> 1.5 idle runners exist, submitted launch "18d_world_model_07:318"; running launches=6
# 2026.09.10-21:11:33.037033     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch318.ipynb"
# 2026.09.10-21:11:58.967241     3.140 >> Trial 3 (18d_world_model_07:313) finished with value: 0.6523594902828336 and parameters: {'learn_rate': 0.004480041439096847, 'info_nce_loss.temperature': 0.22991713219141352}. Best is trial 0 with value: 0.6650238810107112
# 2026.09.10-21:12:00.944726     0.001 >> Launch "18d_world_model_07:313" completed
# 2026.09.10-21:12:00.945561     0.001 >> 4 (+1) launches completed; running launches=5
# 2026.09.10-21:12:06.258855     0.195 >> Model instance registered, version=319
# 2026.09.10-21:12:06.268417     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:319"; running launches=6
# 2026.09.10-21:12:06.268512     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch319.ipynb"
# 2026.09.10-21:12:38.601362     0.232 >> Trial 4 (18d_world_model_07:314) finished with value: 0.6579853175207973 and parameters: {'learn_rate': 0.005502509624471222, 'info_nce_loss.temperature': 0.25869092544773414}. Best is trial 0 with value: 0.6650238810107112
# 2026.09.10-21:12:43.658630     0.003 >> Launch "18d_world_model_07:314" completed
# 2026.09.10-21:12:43.659850     0.001 >> 5 (+1) launches completed; running launches=5
# 2026.09.10-21:13:04.291861     0.172 >> Model instance registered, version=320
# 2026.09.10-21:13:04.301606     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:320"; running launches=6
# 2026.09.10-21:13:04.301750     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch320.ipynb"
# 2026.09.10-21:13:12.532013     3.116 >> Trial 5 (18d_world_model_07:315) finished with value: 0.6578721944242716 and parameters: {'learn_rate': 0.002726214960121446, 'info_nce_loss.temperature': 0.4231275958969849}. Best is trial 0 with value: 0.6650238810107112
# 2026.09.10-21:13:14.522757     0.001 >> Launch "18d_world_model_07:315" completed
# 2026.09.10-21:13:14.523173     0.000 >> 6 (+1) launches completed; running launches=5
# 2026.09.10-21:13:35.838871     0.168 >> Model instance registered, version=321
# 2026.09.10-21:13:35.853272     0.006 >> 1.3 idle runners exist, submitted launch "18d_world_model_07:321"; running launches=6
# 2026.09.10-21:13:35.853430     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch321.ipynb"
# 2026.09.10-21:18:48.761823     0.247 >> Trial 6 (18d_world_model_07:316) finished with value: 0.6715298527851701 and parameters: {'learn_rate': 0.009592451611182284, 'info_nce_loss.temperature': 0.41265250856221586}. Best is trial 6 with value: 0.6715298527851701
# 2026.09.10-21:18:53.636232     0.002 >> Launch "18d_world_model_07:316" completed
# 2026.09.10-21:18:53.637050     0.001 >> 7 (+1) launches completed; running launches=5
# 2026.09.10-21:19:14.603860     0.184 >> Model instance registered, version=322
# 2026.09.10-21:19:14.617438     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:322"; running launches=6
# 2026.09.10-21:19:14.617542     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch322.ipynb"
# 2026.09.10-21:20:22.487409     1.397 >> Trial 7 (18d_world_model_07:317) finished with value: 0.5988425547257066 and parameters: {'learn_rate': 0.003034335846956608, 'info_nce_loss.temperature': 0.09192625238527713}. Best is trial 6 with value: 0.6715298527851701
# 2026.09.10-21:20:26.207374     0.003 >> Launch "18d_world_model_07:317" completed
# 2026.09.10-21:20:26.208510     0.001 >> 8 (+1) launches completed; running launches=5
# 2026.09.10-21:20:51.396686     4.567 >> Trial 8 (18d_world_model_07:318) finished with value: 0.6458588507957757 and parameters: {'learn_rate': 0.0038012331111421764, 'info_nce_loss.temperature': 0.19764945885741358}. Best is trial 6 with value: 0.6715298527851701
# 2026.09.10-21:20:52.145364     0.207 >> Model instance registered, version=323
# 2026.09.10-21:20:52.161177     0.007 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:323"; running launches=6
# 2026.09.10-21:20:52.161403     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch323.ipynb"
# 2026.09.10-21:20:52.162026     0.001 >> Launch "18d_world_model_07:318" completed
# 2026.09.10-21:20:52.163145     0.001 >> 9 (+1) launches completed; running launches=5
# 2026.09.10-21:21:04.949681     2.563 >> Trial 9 (18d_world_model_07:319) finished with value: 0.6650619837455451 and parameters: {'learn_rate': 0.009080807043499574, 'info_nce_loss.temperature': 0.38085611015475385}. Best is trial 6 with value: 0.6715298527851701
# 2026.09.10-21:21:07.503712     0.001 >> Launch "18d_world_model_07:319" completed
# 2026.09.10-21:21:07.504682     0.001 >> 10 (+1) launches completed; running launches=4
# 2026.09.10-21:21:23.263598     0.231 >> Model instance registered, version=324
# 2026.09.10-21:21:23.279044     0.006 >> 2.2 idle runners exist, submitted launch "18d_world_model_07:324"; running launches=5
# 2026.09.10-21:21:23.279183     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch324.ipynb"
# 2026.09.10-21:21:54.166966     0.193 >> Model instance registered, version=325
# 2026.09.10-21:21:54.178565     0.005 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:325"; running launches=6
# 2026.09.10-21:21:54.178678     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch325.ipynb"
# 2026.09.10-21:22:36.218216     0.539 >> Trial 10 (18d_world_model_07:320) finished with value: 0.5124326676595956 and parameters: {'learn_rate': 0.0017973831147879331, 'info_nce_loss.temperature': 0.018604260195095684}. Best is trial 6 with value: 0.6715298527851701
# 2026.09.10-21:22:40.798264     0.001 >> Launch "18d_world_model_07:320" completed
# 2026.09.10-21:22:40.799549     0.001 >> 11 (+1) launches completed; running launches=5
# 2026.09.10-21:22:55.270526     4.237 >> Trial 11 (18d_world_model_07:321) finished with value: 0.6565972976386547 and parameters: {'learn_rate': 0.0010280727008558405, 'info_nce_loss.temperature': 0.30285183226875423}. Best is trial 6 with value: 0.6715298527851701
# 2026.09.10-21:22:56.353840     0.205 >> Model instance registered, version=326
# 2026.09.10-21:22:56.367280     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:326"; running launches=6
# 2026.09.10-21:22:56.367390     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch326.ipynb"
# 2026.09.10-21:22:56.367810     0.001 >> Launch "18d_world_model_07:321" completed
# 2026.09.10-21:22:56.368561     0.001 >> 12 (+1) launches completed; running launches=5
# 2026.09.10-21:23:27.252279     0.210 >> Model instance registered, version=327
# 2026.09.10-21:23:27.266960     0.006 >> 1.5 idle runners exist, submitted launch "18d_world_model_07:327"; running launches=6
# 2026.09.10-21:23:27.267145     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch327.ipynb"
# 2026.09.10-21:28:25.346937     5.893 >> Trial 12 (18d_world_model_07:322) finished with value: 0.6649880083277822 and parameters: {'learn_rate': 0.005702925550477553, 'info_nce_loss.temperature': 0.4280187200687517}. Best is trial 6 with value: 0.6715298527851701
# 2026.09.10-21:28:25.374129     0.002 >> Launch "18d_world_model_07:322" completed
# 2026.09.10-21:28:25.375118     0.001 >> 13 (+1) launches completed; running launches=5
# 2026.09.10-21:29:17.590807     0.227 >> Model instance registered, version=328
# 2026.09.10-21:29:17.604312     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:328"; running launches=6
# 2026.09.10-21:29:17.604505     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch328.ipynb"
# 2026.09.10-21:30:08.395824     2.548 >> Trial 13 (18d_world_model_07:323) finished with value: 0.6473912997171283 and parameters: {'learn_rate': 0.0014427003270008865, 'info_nce_loss.temperature': 0.18893172840468478}. Best is trial 6 with value: 0.6715298527851701
# 2026.09.10-21:30:10.962396     0.001 >> Launch "18d_world_model_07:323" completed
# 2026.09.10-21:30:10.963025     0.001 >> 14 (+1) launches completed; running launches=5
# 2026.09.10-21:30:37.376009     0.295 >> Model instance registered, version=329
# 2026.09.10-21:30:37.386129     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:329"; running launches=6
# 2026.09.10-21:30:37.386428     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch329.ipynb"
# 2026.09.10-21:31:17.896356     4.067 >> Trial 14 (18d_world_model_07:324) finished with value: 0.6617619418539107 and parameters: {'learn_rate': 0.009911379689976137, 'info_nce_loss.temperature': 0.34497961004273414}. Best is trial 6 with value: 0.6715298527851701
# 2026.09.10-21:31:19.421933     0.003 >> Launch "18d_world_model_07:324" completed
# 2026.09.10-21:31:19.423249     0.001 >> 15 (+1) launches completed; running launches=5
# 2026.09.10-21:31:34.928278     0.022 >> Trial 15 (18d_world_model_07:325) finished with value: 0.661665266379714 and parameters: {'learn_rate': 0.009120378596179295, 'info_nce_loss.temperature': 0.3409267950692079}. Best is trial 6 with value: 0.6715298527851701
# 2026.09.10-21:31:34.929218     0.001 >> Launch "18d_world_model_07:325" completed
# 2026.09.10-21:31:34.929822     0.001 >> 16 (+1) launches completed; running launches=4
# 2026.09.10-21:31:40.230027     0.184 >> Model instance registered, version=330
# 2026.09.10-21:31:40.244494     0.006 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:330"; running launches=5
# 2026.09.10-21:31:40.244952     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch330.ipynb"
# 2026.09.10-21:32:11.425945     0.235 >> Model instance registered, version=331
# 2026.09.10-21:32:11.440385     0.005 >> 1.5 idle runners exist, submitted launch "18d_world_model_07:331"; running launches=6
# 2026.09.10-21:32:11.440512     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch331.ipynb"
# 2026.09.10-21:32:38.410521     0.302 >> Trial 16 (18d_world_model_07:326) finished with value: 0.6663722330704331 and parameters: {'learn_rate': 0.009990617723172798, 'info_nce_loss.temperature': 0.3729744345943733}. Best is trial 6 with value: 0.6715298527851701
# 2026.09.10-21:32:47.516905     0.203 >> Model instance registered, version=332
# 2026.09.10-21:32:47.532151     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:332"; running launches=7
# 2026.09.10-21:32:47.532375     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch332.ipynb"
# 2026.09.10-21:32:47.533432     0.001 >> Launch "18d_world_model_07:326" completed
# 2026.09.10-21:32:47.535408     0.002 >> 17 (+1) launches completed; running launches=6
# 2026.09.10-21:32:55.694862     0.264 >> Trial 17 (18d_world_model_07:327) finished with value: 0.6620781333185732 and parameters: {'learn_rate': 0.009722207612190887, 'info_nce_loss.temperature': 0.3706966583813093}. Best is trial 6 with value: 0.6715298527851701
# 2026.09.10-21:33:00.551875     0.001 >> Launch "18d_world_model_07:327" completed
# 2026.09.10-21:33:00.553078     0.001 >> 18 (+1) launches completed; running launches=5
# 2026.09.10-21:33:21.824996     0.196 >> Model instance registered, version=333
# 2026.09.10-21:33:21.840088     0.006 >> 1.5 idle runners exist, submitted launch "18d_world_model_07:333"; running launches=6
# 2026.09.10-21:33:21.840214     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch333.ipynb"
# 2026.09.10-21:38:17.288247     3.336 >> Trial 18 (18d_world_model_07:328) finished with value: 0.6584513387642801 and parameters: {'learn_rate': 0.00997462800065961, 'info_nce_loss.temperature': 0.35543011735169416}. Best is trial 6 with value: 0.6715298527851701
# 2026.09.10-21:38:19.076869     0.001 >> Launch "18d_world_model_07:328" completed
# 2026.09.10-21:38:19.077554     0.001 >> 19 (+1) launches completed; running launches=5
# 2026.09.10-21:38:45.102487     0.422 >> Model instance registered, version=334
# 2026.09.10-21:38:45.119759     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:334"; running launches=6
# 2026.09.10-21:38:45.120124     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch334.ipynb"
# 2026.09.10-21:39:37.987998     1.710 >> Trial 19 (18d_world_model_07:329) finished with value: 0.6632006214931607 and parameters: {'learn_rate': 0.009927086986041124, 'info_nce_loss.temperature': 0.34572422505451256}. Best is trial 6 with value: 0.6715298527851701
# 2026.09.10-21:39:41.398924     0.002 >> Launch "18d_world_model_07:329" completed
# 2026.09.10-21:39:41.400080     0.001 >> 20 (+1) launches completed; running launches=5
# 2026.09.10-21:40:07.873202     0.200 >> Model instance registered, version=335
# 2026.09.10-21:40:07.886665     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:335"; running launches=6
# 2026.09.10-21:40:07.886873     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch335.ipynb"
# 2026.09.10-21:41:13.106895     3.751 >> Trial 20 (18d_world_model_07:330) finished with value: 0.6642124932259321 and parameters: {'learn_rate': 0.0077788199368356205, 'info_nce_loss.temperature': 0.38816310709682644}. Best is trial 6 with value: 0.6715298527851701
# 2026.09.10-21:41:14.468680     0.001 >> Launch "18d_world_model_07:330" completed
# 2026.09.10-21:41:14.469294     0.001 >> 21 (+1) launches completed; running launches=5
# 2026.09.10-21:41:40.231147     0.186 >> Model instance registered, version=336
# 2026.09.10-21:41:40.243344     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:336"; running launches=6
# 2026.09.10-21:41:40.243480     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch336.ipynb"
# 2026.09.10-21:41:41.747724     1.504 >> Trial 21 (18d_world_model_07:331) finished with value: 0.6648655505850911 and parameters: {'learn_rate': 0.007149870213833391, 'info_nce_loss.temperature': 0.3796994843788241}. Best is trial 6 with value: 0.6715298527851701
# 2026.09.10-21:41:45.350306     0.001 >> Launch "18d_world_model_07:331" completed
# 2026.09.10-21:41:45.350870     0.001 >> 22 (+1) launches completed; running launches=5
# 2026.09.10-21:42:11.084119     0.176 >> Model instance registered, version=337
# 2026.09.10-21:42:11.097535     0.005 >> 1.5 idle runners exist, submitted launch "18d_world_model_07:337"; running launches=6
# 2026.09.10-21:42:11.097658     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch337.ipynb"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 54
#      51 except TimeoutError as e:
#      52     pass
# ---> 54 time.sleep(5)
#
# KeyboardInterrupt:

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
