# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 6 шагов. На каждом шаге отбираем чемпионов для продолжения след. шага.
#
# Данный эксперимент - это первый шаг. Здесь агент должен научиться проходить первый уровень.

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False

    parent = optuna_trial.suggest_categorical('parent', [
        '18n_ppo_tr_frostbite_06:388',
        '18n_ppo_tr_frostbite_06:396',
        '18n_ppo_tr_frostbite_06:412',
    ])
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights=parent)
    HP.encoder.is_trainable = True

    HP.agent.parent = parent 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(300000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = [
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=exam1',
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=exam2',
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=exam3',
    ]
    HP.video.capture_env_ram_patches = [
        ['no_score', 'last_life', 'no_igloo', 'temperature_45'],
    ]
    HP.video.break_on_level_passed = True
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = 3_000_000 # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = [
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=train1',
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=train2',
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=train3',
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=train4',
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=train5',
    ]
    HP.ppo.rollout_env_ram_patches = [
        ['no_score', 'last_life', 'no_igloo', 'temperature_45', 'bailey_safe_random_spawn'],
    ]
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    HP.ppo.learn_rate = 'const(0.000217)'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    HP.ppo.ent_coef = 'const(0.043)'
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Есть прохождение одного экзамена.
#
# Чемпионы:
# - `18n_ppo_tr_frostbite_06:439`
# - `18n_ppo_tr_frostbite_06:428`
# - `18n_ppo_tr_frostbite_06:436`
# - `18n_ppo_tr_frostbite_06:440`
# - `18n_ppo_tr_frostbite_06:445`
#
# <img src="./img/score.png">
# <img src="./img/episode_r.png">
#
# **Выводы**
# 1) едем дальше не чемпионах

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.2a/18n_study_19.2a.ipynb',
#  'optuna_study_name': '18n_study_19.2a',
#  'optuna_study_serial': '19.2a',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.2a/18n_study_19.2a.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-22 15:01:53,345] A new study created in Journal with name: 18n_study_19.2a
# 2026.09.22-15:01:53.584053     0.212 >> Model instance registered, version=416
# 2026.09.22-15:01:53.598105     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch416.ipynb"
# 2026.09.22-15:01:53.598342     0.004 >> 6.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:416"; running launches=1
# 2026.09.22-15:02:24.492859     0.202 >> Model instance registered, version=417
# 2026.09.22-15:02:24.501633     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch417.ipynb"
# 2026.09.22-15:02:24.501880     0.004 >> 5.5 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:417"; running launches=2
# 2026.09.22-15:02:55.407789     0.205 >> Model instance registered, version=418
# 2026.09.22-15:02:55.416860     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch418.ipynb"
# 2026.09.22-15:02:55.417213     0.004 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:418"; running launches=3
# 2026.09.22-15:03:27.241470     0.207 >> Model instance registered, version=419
# 2026.09.22-15:03:27.255565     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch419.ipynb"
# 2026.09.22-15:03:27.256252     0.006 >> 3.5 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:419"; running launches=4
# 2026.09.22-15:03:59.494838     0.206 >> Model instance registered, version=420
# 2026.09.22-15:03:59.503852     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch420.ipynb"
# 2026.09.22-15:03:59.504580     0.005 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:420"; running launches=5
# 2026.09.22-15:04:30.436130     0.245 >> Model instance registered, version=421
# 2026.09.22-15:04:30.451227     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch421.ipynb"
# 2026.09.22-15:04:30.451525     0.008 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:421"; running launches=6
# 2026.09.22-15:51:43.565811     1.567 >> Trial 2 (18n_ppo_tr_frostbite_06:418) finished with value: 10100.000008167233 and parameters: {'parent': '18n_ppo_tr_frostbite_06:412'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-15:51:47.194196     0.003 >> Launch "18n_ppo_tr_frostbite_06:418" completed
# 2026.09.22-15:51:47.195106     0.001 >> 1 (+1) launches completed; running launches=5
# 2026.09.22-15:52:13.000539     0.214 >> Model instance registered, version=422
# 2026.09.22-15:52:13.015216     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:422"; running launches=6
# 2026.09.22-15:52:13.015343     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch422.ipynb"
# 2026.09.22-15:54:09.287977     2.890 >> Trial 3 (18n_ppo_tr_frostbite_06:419) finished with value: 6.481931615621456e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:388'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-15:54:11.651498     0.003 >> Launch "18n_ppo_tr_frostbite_06:419" completed
# 2026.09.22-15:54:11.652746     0.001 >> 2 (+1) launches completed; running launches=5
# 2026.09.22-15:54:37.472783     0.246 >> Model instance registered, version=423
# 2026.09.22-15:54:37.486574     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:423"; running launches=6
# 2026.09.22-15:54:37.486704     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch423.ipynb"
# 2026.09.22-15:55:03.257082     0.219 >> Trial 0 (18n_ppo_tr_frostbite_06:416) finished with value: 2.236266407389402e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:388'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-15:55:07.746247     4.489 >> Trial 1 (18n_ppo_tr_frostbite_06:417) finished with value: 2.4955436720142603e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:388'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-15:55:08.358567     0.207 >> Model instance registered, version=424
# 2026.09.22-15:55:08.371824     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:424"; running launches=7
# 2026.09.22-15:55:08.371953     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch424.ipynb"
# 2026.09.22-15:55:08.372423     0.001 >> Launch "18n_ppo_tr_frostbite_06:417" completed
# 2026.09.22-15:55:08.373192     0.001 >> Launch "18n_ppo_tr_frostbite_06:416" completed
# 2026.09.22-15:55:08.373492     0.000 >> 4 (+2) launches completed; running launches=5
# 2026.09.22-15:55:39.486696     0.241 >> Model instance registered, version=425
# 2026.09.22-15:55:39.496444     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:425"; running launches=6
# 2026.09.22-15:55:39.496594     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch425.ipynb"
# 2026.09.22-15:55:54.220607     4.475 >> Trial 4 (18n_ppo_tr_frostbite_06:420) finished with value: 5.023497002106628e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:388'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-15:55:54.864264     0.002 >> Launch "18n_ppo_tr_frostbite_06:420" completed
# 2026.09.22-15:55:54.865202     0.001 >> 5 (+1) launches completed; running launches=5
# 2026.09.22-15:56:10.471072     0.220 >> Model instance registered, version=426
# 2026.09.22-15:56:10.485785     0.007 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:426"; running launches=6
# 2026.09.22-15:56:10.485976     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch426.ipynb"
# 2026.09.22-15:56:25.559873     4.845 >> Trial 5 (18n_ppo_tr_frostbite_06:421) finished with value: 4.116026575919624e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:412'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-15:56:25.830868     0.002 >> Launch "18n_ppo_tr_frostbite_06:421" completed
# 2026.09.22-15:56:25.831909     0.001 >> 6 (+1) launches completed; running launches=5
# 2026.09.22-15:56:41.392370     0.215 >> Model instance registered, version=427
# 2026.09.22-15:56:41.406668     0.005 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:427"; running launches=6
# 2026.09.22-15:56:41.406817     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch427.ipynb"
# 2026.09.22-16:42:46.594229     3.232 >> Trial 7 (18n_ppo_tr_frostbite_06:423) finished with value: 4.796629395559876e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:412'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-16:42:48.707733     0.003 >> Launch "18n_ppo_tr_frostbite_06:423" completed
# 2026.09.22-16:42:48.708761     0.001 >> 7 (+1) launches completed; running launches=5
# 2026.09.22-16:43:15.026715     0.209 >> Model instance registered, version=428
# 2026.09.22-16:43:15.035575     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:428"; running launches=6
# 2026.09.22-16:43:15.035713     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch428.ipynb"
# 2026.09.22-16:43:24.662150     4.519 >> Trial 6 (18n_ppo_tr_frostbite_06:422) finished with value: 3.143736833576406e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:412'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-16:43:25.257794     0.002 >> Launch "18n_ppo_tr_frostbite_06:422" completed
# 2026.09.22-16:43:25.259041     0.001 >> 8 (+1) launches completed; running launches=5
# 2026.09.22-16:43:46.110662     0.220 >> Model instance registered, version=429
# 2026.09.22-16:43:46.123010     0.004 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:429"; running launches=6
# 2026.09.22-16:43:46.123165     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch429.ipynb"
# 2026.09.22-16:44:09.986330     3.410 >> Trial 11 (18n_ppo_tr_frostbite_06:427) finished with value: 1.0000081348241776 and parameters: {'parent': '18n_ppo_tr_frostbite_06:396'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-16:44:11.682794     0.000 >> Launch "18n_ppo_tr_frostbite_06:427" completed
# 2026.09.22-16:44:11.683152     0.000 >> 9 (+1) launches completed; running launches=5
# 2026.09.22-16:44:37.476294     0.231 >> Model instance registered, version=430
# 2026.09.22-16:44:37.490900     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:430"; running launches=6
# 2026.09.22-16:44:37.491170     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch430.ipynb"
# 2026.09.22-16:47:50.518336     2.922 >> Trial 9 (18n_ppo_tr_frostbite_06:425) finished with value: 9.722897423432182e-07 and parameters: {'parent': '18n_ppo_tr_frostbite_06:388'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-16:47:53.033581     0.004 >> Launch "18n_ppo_tr_frostbite_06:425" completed
# 2026.09.22-16:47:53.035127     0.002 >> 10 (+1) launches completed; running launches=5
# 2026.09.22-16:48:56.071717     1.384 >> Trial 8 (18n_ppo_tr_frostbite_06:424) finished with value: 10000.000003532652 and parameters: {'parent': '18n_ppo_tr_frostbite_06:412'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-16:48:59.805459     0.002 >> Launch "18n_ppo_tr_frostbite_06:424" completed
# 2026.09.22-16:48:59.806438     0.001 >> 11 (+1) launches completed; running launches=4
# 2026.09.22-16:49:18.304238     2.922 >> Trial 10 (18n_ppo_tr_frostbite_06:426) finished with value: 100.00000414843623 and parameters: {'parent': '18n_ppo_tr_frostbite_06:388'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-16:49:20.720062     0.221 >> Model instance registered, version=431
# 2026.09.22-16:49:20.729159     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:431"; running launches=5
# 2026.09.22-16:49:20.729363     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch431.ipynb"
# 2026.09.22-16:49:20.730013     0.001 >> Launch "18n_ppo_tr_frostbite_06:426" completed
# 2026.09.22-16:49:20.731167     0.001 >> 12 (+1) launches completed; running launches=4
# 2026.09.22-16:49:51.666782     0.256 >> Model instance registered, version=432
# 2026.09.22-16:49:51.676217     0.003 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:432"; running launches=5
# 2026.09.22-16:49:51.676314     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch432.ipynb"
# 2026.09.22-17:33:14.491680     2.849 >> Trial 13 (18n_ppo_tr_frostbite_06:429) finished with value: 2.9816885431858693e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:388'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-17:33:16.753594     0.001 >> Launch "18n_ppo_tr_frostbite_06:429" completed
# 2026.09.22-17:33:16.754259     0.001 >> 13 (+1) launches completed; running launches=4
# 2026.09.22-17:33:43.013924     0.214 >> Model instance registered, version=433
# 2026.09.22-17:33:43.023524     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:433"; running launches=5
# 2026.09.22-17:33:43.023654     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch433.ipynb"
# 2026.09.22-17:35:04.415211     4.062 >> Trial 12 (18n_ppo_tr_frostbite_06:428) finished with value: 10001.000004278076 and parameters: {'parent': '18n_ppo_tr_frostbite_06:388'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-17:35:05.468883     0.001 >> Launch "18n_ppo_tr_frostbite_06:428" completed
# 2026.09.22-17:35:05.469646     0.001 >> 14 (+1) launches completed; running launches=4
# 2026.09.22-17:35:31.247720     0.209 >> Model instance registered, version=434
# 2026.09.22-17:35:31.257246     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:434"; running launches=5
# 2026.09.22-17:35:31.257356     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch434.ipynb"
# 2026.09.22-17:41:19.443706     2.919 >> Trial 16 (18n_ppo_tr_frostbite_06:432) finished with value: 101.00000534759359 and parameters: {'parent': '18n_ppo_tr_frostbite_06:412'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-17:41:21.766558     0.002 >> Launch "18n_ppo_tr_frostbite_06:432" completed
# 2026.09.22-17:41:21.767683     0.001 >> 15 (+1) launches completed; running launches=4
# 2026.09.22-17:41:46.882546     4.544 >> Trial 14 (18n_ppo_tr_frostbite_06:430) finished with value: 2.4955436720142603e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:388'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-17:41:47.669056     0.218 >> Model instance registered, version=435
# 2026.09.22-17:41:47.680792     0.003 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:435"; running launches=5
# 2026.09.22-17:41:47.680927     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch435.ipynb"
# 2026.09.22-17:41:47.681497     0.001 >> Launch "18n_ppo_tr_frostbite_06:430" completed
# 2026.09.22-17:41:47.682266     0.001 >> 16 (+1) launches completed; running launches=4
# 2026.09.22-17:42:19.319949     0.217 >> Model instance registered, version=436
# 2026.09.22-17:42:19.331637     0.004 >> 1.5 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:436"; running launches=5
# 2026.09.22-17:42:19.331776     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch436.ipynb"
# 2026.09.22-17:42:37.585574     2.728 >> Trial 15 (18n_ppo_tr_frostbite_06:431) finished with value: 2.787230594717226e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:412'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-17:42:39.970901     0.001 >> Launch "18n_ppo_tr_frostbite_06:431" completed
# 2026.09.22-17:42:39.971812     0.001 >> 17 (+1) launches completed; running launches=4
# 2026.09.22-17:43:06.304422     0.209 >> Model instance registered, version=437
# 2026.09.22-17:43:06.315126     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:437"; running launches=5
# 2026.09.22-17:43:06.315247     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch437.ipynb"
# 2026.09.22-18:22:23.423127     3.592 >> Trial 18 (18n_ppo_tr_frostbite_06:434) finished with value: 4.7642197374817694e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:396'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-18:22:24.945829     0.002 >> Launch "18n_ppo_tr_frostbite_06:434" completed
# 2026.09.22-18:22:24.946728     0.001 >> 18 (+1) launches completed; running launches=4
# 2026.09.22-18:22:50.734167     0.219 >> Model instance registered, version=438
# 2026.09.22-18:22:50.746134     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:438"; running launches=5
# 2026.09.22-18:22:50.746250     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch438.ipynb"
# 2026.09.22-18:23:13.109665     1.751 >> Trial 17 (18n_ppo_tr_frostbite_06:433) finished with value: 3.824339653216658e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:412'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-18:23:16.477184     0.002 >> Launch "18n_ppo_tr_frostbite_06:433" completed
# 2026.09.22-18:23:16.478076     0.001 >> 19 (+1) launches completed; running launches=4
# 2026.09.22-18:23:42.267297     0.220 >> Model instance registered, version=439
# 2026.09.22-18:23:42.276376     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:439"; running launches=5
# 2026.09.22-18:23:42.276832     0.000 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch439.ipynb"
# 2026.09.22-18:33:12.927128     4.326 >> Trial 19 (18n_ppo_tr_frostbite_06:435) finished with value: 1.0000051207259764 and parameters: {'parent': '18n_ppo_tr_frostbite_06:396'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-18:33:14.438382     0.003 >> Launch "18n_ppo_tr_frostbite_06:435" completed
# 2026.09.22-18:33:14.439397     0.001 >> 20 (+1) launches completed; running launches=4
# 2026.09.22-18:33:40.239658     0.229 >> Model instance registered, version=440
# 2026.09.22-18:33:40.250655     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:440"; running launches=5
# 2026.09.22-18:33:40.250782     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch440.ipynb"
# 2026.09.22-18:33:43.678182     3.427 >> Trial 20 (18n_ppo_tr_frostbite_06:436) finished with value: 10000.000004180845 and parameters: {'parent': '18n_ppo_tr_frostbite_06:396'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-18:33:45.395266     0.003 >> Launch "18n_ppo_tr_frostbite_06:436" completed
# 2026.09.22-18:33:45.396206     0.001 >> 21 (+1) launches completed; running launches=4
# 2026.09.22-18:34:11.250695     0.275 >> Model instance registered, version=441
# 2026.09.22-18:34:11.263409     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:441"; running launches=5
# 2026.09.22-18:34:11.263561     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch441.ipynb"
# 2026.09.22-18:36:25.707589     1.306 >> Trial 21 (18n_ppo_tr_frostbite_06:437) finished with value: 4.796629395559876e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:396'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-18:36:29.519194     0.002 >> Launch "18n_ppo_tr_frostbite_06:437" completed
# 2026.09.22-18:36:29.519977     0.001 >> 22 (+1) launches completed; running launches=4
# 2026.09.22-18:36:55.301117     0.209 >> Model instance registered, version=442
# 2026.09.22-18:36:55.316785     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:442"; running launches=5
# 2026.09.22-18:36:55.316943     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch442.ipynb"
# 2026.09.22-19:08:44.416209     4.991 >> Trial 22 (18n_ppo_tr_frostbite_06:438) finished with value: 4.6345811051693405e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:396'}. Best is trial 2 with value: 10100.000008167233
# 2026.09.22-19:08:44.543901     0.004 >> Launch "18n_ppo_tr_frostbite_06:438" completed
# 2026.09.22-19:08:44.544861     0.001 >> 23 (+1) launches completed; running launches=4
# 2026.09.22-19:09:10.813791     0.222 >> Model instance registered, version=443
# 2026.09.22-19:09:10.828191     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:443"; running launches=5
# 2026.09.22-19:09:10.828328     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch443.ipynb"
# 2026.09.22-19:11:07.369219     3.717 >> Trial 23 (18n_ppo_tr_frostbite_06:439) finished with value: 10101.000007389403 and parameters: {'parent': '18n_ppo_tr_frostbite_06:396'}. Best is trial 23 with value: 10101.000007389403
# 2026.09.22-19:11:08.767333     0.001 >> Launch "18n_ppo_tr_frostbite_06:439" completed
# 2026.09.22-19:11:08.768449     0.001 >> 24 (+1) launches completed; running launches=4
# 2026.09.22-19:11:34.684458     0.214 >> Model instance registered, version=444
# 2026.09.22-19:11:34.698564     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:444"; running launches=5
# 2026.09.22-19:11:34.698685     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch444.ipynb"
# 2026.09.22-19:25:02.832590     1.239 >> Trial 24 (18n_ppo_tr_frostbite_06:440) finished with value: 10000.000004958678 and parameters: {'parent': '18n_ppo_tr_frostbite_06:396'}. Best is trial 23 with value: 10101.000007389403
# 2026.09.22-19:25:06.802627     0.001 >> Launch "18n_ppo_tr_frostbite_06:440" completed
# 2026.09.22-19:25:06.803252     0.001 >> 25 (+1) launches completed; running launches=4
# 2026.09.22-19:25:33.212501     0.307 >> Model instance registered, version=445
# 2026.09.22-19:25:33.227434     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:445"; running launches=5
# 2026.09.22-19:25:33.227565     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch445.ipynb"
# 2026.09.22-19:26:32.985091     3.384 >> Trial 25 (18n_ppo_tr_frostbite_06:441) finished with value: 2.8520499108734404e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:396'}. Best is trial 23 with value: 10101.000007389403
# 2026.09.22-19:26:34.720090     0.002 >> Launch "18n_ppo_tr_frostbite_06:441" completed
# 2026.09.22-19:26:34.721434     0.001 >> 26 (+1) launches completed; running launches=4
# 2026.09.22-19:30:22.834131     1.652 >> Trial 26 (18n_ppo_tr_frostbite_06:442) finished with value: 3.5650623885918002e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:396'}. Best is trial 23 with value: 10101.000007389403
# 2026.09.22-19:30:26.310435     0.004 >> Launch "18n_ppo_tr_frostbite_06:442" completed
# 2026.09.22-19:30:26.311324     0.001 >> 27 (+1) launches completed; running launches=3
# 2026.09.22-19:55:18.413229     4.926 >> Trial 27 (18n_ppo_tr_frostbite_06:443) finished with value: 3.4678334143574783e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:396'}. Best is trial 23 with value: 10101.000007389403
# 2026.09.22-19:55:18.605140     0.002 >> Launch "18n_ppo_tr_frostbite_06:443" completed
# 2026.09.22-19:55:18.606207     0.001 >> 28 (+1) launches completed; running launches=2
# 2026.09.22-20:00:20.729041     3.550 >> Trial 28 (18n_ppo_tr_frostbite_06:444) finished with value: 5.833738454059309e-06 and parameters: {'parent': '18n_ppo_tr_frostbite_06:396'}. Best is trial 23 with value: 10101.000007389403
# 2026.09.22-20:00:22.296000     0.002 >> Launch "18n_ppo_tr_frostbite_06:444" completed
# 2026.09.22-20:00:22.297025     0.001 >> 29 (+1) launches completed; running launches=1
# 2026.09.22-20:07:14.600471     1.670 >> Trial 29 (18n_ppo_tr_frostbite_06:445) finished with value: 10100.000008329282 and parameters: {'parent': '18n_ppo_tr_frostbite_06:396'}. Best is trial 23 with value: 10101.000007389403
# 2026.09.22-20:07:18.053386     0.002 >> Launch "18n_ppo_tr_frostbite_06:445" completed
# 2026.09.22-20:07:18.054315     0.001 >> 30 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-22 20:10:07,387] Using an existing study with name '18n_study_19.2a' instead of creating a new one.
# 2026.09.22-20:10:07.388345   164.295 >> Study statistics:
# 2026.09.22-20:10:07.389908     0.002 >> 	Number of finished trials: 30
# 2026.09.22-20:10:07.390627     0.001 >> 	Number of pruned trials: 0
# 2026.09.22-20:10:07.391043     0.000 >> 	Number of complete trials: 30
# 2026.09.22-20:10:07.391615     0.001 >> Best trial:
# 2026.09.22-20:10:07.392135     0.001 >> 	Value: 10101.000007389403
# 2026.09.22-20:10:07.392500     0.000 >> 	Model version: 439
# 2026.09.22-20:10:07.392802     0.000 >> 	Params:
# 2026.09.22-20:10:07.393132     0.000 >> 		parent: 18n_ppo_tr_frostbite_06:396
