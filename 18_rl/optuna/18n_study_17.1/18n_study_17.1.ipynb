# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 5 поколений по 6 млн шагов с последующим отбором чемпионов. Наследники этих чемпионов будут использоваться на следующем шаге.
#
# Данный эксперимент - это первый шаг. Здесь агент должен научиться заходить в иглу = прорыв.
#
# Здесь исправлена ошибка `18n_study_16.1`, когда энкодер в оптимизацию не был включен. Теперь экондер ПОЛУЧАЕТ градиенты и может меняться.
#
# Особенности:
# - энкодер из `18d_world_model_08`
# - **`encoder.is_trainable=True`**
# - механика повторяет 17-ых агентов
# - `prediction_coef=0.1`
# - `sequence_length=10`
# - `batch_size=128`
# - `vf_coef=0.2`

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_05.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    generations_count = 5
    generation_ind = 0
    generation_steps_count = 6_000_000
    all_generations_steps_count = generation_steps_count * generations_count
    learn_rate_range = (0.00025, 0.00025 * 0.1)
    ent_coef_range = (0.05, 0.05 * 0.1)
    ####
    
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.ob_encoder.parent = '18d_world_model_08:217'
    HP.ob_encoder.is_trainable = True

    HP.agent.parent = None 
    HP.agent.sequence_length = 10
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    
    # Video params
    HP.video.capture_policy = 'every(500000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = None
    HP.video.capture_env_ram_patches = None
    HP.video.break_on_level_passed = False
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = generation_steps_count # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = None
    HP.ppo.rollout_env_ram_patches = [
        ['last_life', 'full_igloo', 'bailey_right_at_the_igloo_door', 'temperature_10'],
        ['last_life', 'full_igloo', 'bailey_very_near_igloo_door', 'temperature_10'],  
        ['last_life', 'full_igloo', 'bailey_near_center', 'temperature_10'],
        ['last_life', 'one_remaining_igloo', 'bailey_near_center', 'temperature_10'],
        ['last_life', 'three_remaining_igloo', 'bailey_near_center', 'temperature_20'],
        ['last_life', 'half_igloo', 'bailey_near_center'],
        ['last_life', 'half_igloo'],
        ['last_life'],
    ]
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 128 
    learn_rate_change_speed = (learn_rate_range[1] - learn_rate_range[0]) / generations_count
    learn_rate_a = learn_rate_range[0] + learn_rate_change_speed * generation_ind
    learn_rate_b = learn_rate_a + learn_rate_change_speed
    HP.ppo.learn_rate = f'linear({learn_rate_a}, {learn_rate_b})'
    # HP.ppo.learn_rate = 'linear(0.00025, 0.00015)'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    ent_coef_change_speed = (ent_coef_range[1] - ent_coef_range[0]) / generations_count
    ent_coef_a = ent_coef_range[0] + ent_coef_change_speed * generation_ind
    ent_coef_b = ent_coef_a + ent_coef_change_speed
    HP.ppo.ent_coef = f'linear({ent_coef_a}, {ent_coef_b})' # coefficient of the entropy member within loss function
    # HP.ppo.ent_coef = 'linear(0.05, 0.03)' # coefficient of the entropy member within loss function
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Если сравнивать с `18n_study_15.1`, то сразу обнаруживается, что с размороженным энкодером обучение идёт веселей. Даже на 10-и запусках три агентов добралась до прохождения 2-х уровней. А один агент (`18n_ppo_tr_frostbite_05/opt_17.1/13`) даже смог удержать этот результат до конца. Это результат, сравнимый с исследованием 23.1 17-ых агентов.
#
# Получается, что в латентанх энкодера тоже должны быть составляющие для успешного прохождения уровней. Одного тренинг на реконструкцию/предсказаине недостаточно.
#
# <img src="./img/levels_passed.png">
# <img src="./img/reward.png">
# <img src="./img/episode_r.png">
# <img src="./img/value_mean.png">
#
# **Выводы**
# 1) в том или ином виде нужно обеспечить поток градиентов к энкодеру: фичей из `WorldModel` не хватает

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_05.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_05',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_17.1/18n_study_17.1.ipynb',
#  'optuna_study_name': '18n_study_17.1',
#  'optuna_study_serial': '17.1',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_17.1/18n_study_17.1.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-16 12:21:10,323] A new study created in Journal with name: 18n_study_17.1
# 2026.09.16-12:21:10.554571     0.211 >> Model instance registered, version=5
# 2026.09.16-12:21:10.565184     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch5.ipynb"
# 2026.09.16-12:21:10.565425     0.004 >> 4.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:5"; running launches=1
# 2026.09.16-12:21:41.790284     0.205 >> Model instance registered, version=6
# 2026.09.16-12:21:41.803544     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch6.ipynb"
# 2026.09.16-12:21:41.803773     0.006 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:6"; running launches=2
# 2026.09.16-12:22:12.704685     0.200 >> Model instance registered, version=7
# 2026.09.16-12:22:12.717759     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch7.ipynb"
# 2026.09.16-12:22:12.718181     0.006 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:7"; running launches=3
# 2026.09.16-12:22:44.440699     0.205 >> Model instance registered, version=8
# 2026.09.16-12:22:44.450795     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch8.ipynb"
# 2026.09.16-12:22:44.451392     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:8"; running launches=4
# 2026.09.16-12:31:23.198431     0.190 >> Model instance registered, version=9
# 2026.09.16-12:31:23.208679     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch9.ipynb"
# 2026.09.16-12:31:23.208914     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:9"; running launches=5
# 2026.09.16-12:31:54.619279     0.187 >> Model instance registered, version=10
# 2026.09.16-12:31:54.633414     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch10.ipynb"
# 2026.09.16-12:31:54.633755     0.006 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:10"; running launches=6
# 2026.09.16-12:32:25.764120     0.182 >> Model instance registered, version=11
# 2026.09.16-12:32:25.773847     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch11.ipynb"
# 2026.09.16-12:32:25.774433     0.001 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:11"; running launches=7
# 2026.09.16-12:32:57.706038     0.276 >> Model instance registered, version=12
# 2026.09.16-12:32:57.719976     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch12.ipynb"
# 2026.09.16-12:32:57.720542     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:12"; running launches=8
# 2026.09.16-12:35:11.478926     0.178 >> Model instance registered, version=13
# 2026.09.16-12:35:11.488182     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch13.ipynb"
# 2026.09.16-12:35:11.488393     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:13"; running launches=9
# 2026.09.16-12:35:42.371920     0.190 >> Model instance registered, version=14
# 2026.09.16-12:35:42.382440     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch14.ipynb"
# 2026.09.16-12:35:42.382630     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:14"; running launches=10
# 2026.09.16-15:34:19.480126     2.889 >> Trial 1 (18n_ppo_tr_frostbite_05:6) finished with value: 1184.6153846153845 and parameters: {}. Best is trial 1 with value: 1184.6153846153845
# 2026.09.16-15:34:21.712333     0.002 >> Launch "18n_ppo_tr_frostbite_05:6" completed
# 2026.09.16-15:34:21.713435     0.001 >> 1 (+1) launches completed; running launches=9
# 2026.09.16-15:34:47.755917     0.216 >> Model instance registered, version=15
# 2026.09.16-15:34:47.771107     0.007 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:15"; running launches=10
# 2026.09.16-15:34:47.771390     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch15.ipynb"
# 2026.09.16-15:35:48.362868     4.112 >> Trial 3 (18n_ppo_tr_frostbite_05:8) finished with value: 1396.1538461538462 and parameters: {}. Best is trial 3 with value: 1396.1538461538462
# 2026.09.16-15:35:49.368786     0.001 >> Launch "18n_ppo_tr_frostbite_05:8" completed
# 2026.09.16-15:35:49.369761     0.001 >> 2 (+1) launches completed; running launches=9
# 2026.09.16-15:36:15.183333     0.240 >> Model instance registered, version=16
# 2026.09.16-15:36:15.195477     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:16"; running launches=10
# 2026.09.16-15:36:15.195610     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch16.ipynb"
# 2026.09.16-15:50:19.695314     2.041 >> Trial 4 (18n_ppo_tr_frostbite_05:9) finished with value: 589.2307692307693 and parameters: {}. Best is trial 3 with value: 1396.1538461538462
# 2026.09.16-15:50:22.779748     0.003 >> Launch "18n_ppo_tr_frostbite_05:9" completed
# 2026.09.16-15:50:22.781063     0.001 >> 3 (+1) launches completed; running launches=9
# 2026.09.16-15:50:49.231048     0.243 >> Model instance registered, version=17
# 2026.09.16-15:50:49.243867     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:17"; running launches=10
# 2026.09.16-15:50:49.243974     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch17.ipynb"
# 2026.09.16-15:50:59.477332     0.018 >> Trial 5 (18n_ppo_tr_frostbite_05:10) finished with value: 1145.3846153846155 and parameters: {}. Best is trial 3 with value: 1396.1538461538462
# 2026.09.16-15:50:59.477987     0.001 >> Launch "18n_ppo_tr_frostbite_05:10" completed
# 2026.09.16-15:50:59.478500     0.001 >> 4 (+1) launches completed; running launches=9
# 2026.09.16-15:51:20.268334     0.316 >> Model instance registered, version=18
# 2026.09.16-15:51:20.283820     0.005 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:18"; running launches=10
# 2026.09.16-15:51:20.284008     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch18.ipynb"
# 2026.09.16-15:52:10.008515     3.241 >> Trial 6 (18n_ppo_tr_frostbite_05:11) finished with value: 960.7692307692307 and parameters: {}. Best is trial 3 with value: 1396.1538461538462
# 2026.09.16-15:52:11.886787     0.002 >> Launch "18n_ppo_tr_frostbite_05:11" completed
# 2026.09.16-15:52:11.887825     0.001 >> 5 (+1) launches completed; running launches=9
# 2026.09.16-15:52:37.750113     0.266 >> Model instance registered, version=19
# 2026.09.16-15:52:37.764028     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:19"; running launches=10
# 2026.09.16-15:52:37.764161     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch19.ipynb"
# 2026.09.16-15:54:00.365200     0.526 >> Trial 7 (18n_ppo_tr_frostbite_05:12) finished with value: 226.15384615384616 and parameters: {}. Best is trial 3 with value: 1396.1538461538462
# 2026.09.16-15:54:00.428518     0.063 >> Trial 9 (18n_ppo_tr_frostbite_05:14) finished with value: 1563.8461538461538 and parameters: {}. Best is trial 9 with value: 1563.8461538461538
# 2026.09.16-15:54:04.955028     0.001 >> Launch "18n_ppo_tr_frostbite_05:12" completed
# 2026.09.16-15:54:04.956146     0.001 >> Launch "18n_ppo_tr_frostbite_05:14" completed
# 2026.09.16-15:54:04.957195     0.001 >> 7 (+2) launches completed; running launches=8
# 2026.09.16-15:54:09.870849     4.914 >> Trial 8 (18n_ppo_tr_frostbite_05:13) finished with value: 1427.6923076923076 and parameters: {}. Best is trial 9 with value: 1563.8461538461538
# 2026.09.16-15:54:10.260246     0.189 >> Model instance registered, version=20
# 2026.09.16-15:54:10.273400     0.005 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:20"; running launches=9
# 2026.09.16-15:54:10.273543     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch20.ipynb"
# 2026.09.16-15:54:10.274130     0.001 >> Launch "18n_ppo_tr_frostbite_05:13" completed
# 2026.09.16-15:54:10.275610     0.001 >> 8 (+1) launches completed; running launches=8
# 2026.09.16-15:54:41.181494     0.194 >> Model instance registered, version=21
# 2026.09.16-15:54:41.193387     0.004 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:21"; running launches=9
# 2026.09.16-15:54:41.193713     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch21.ipynb"
# 2026.09.16-15:55:02.466197     0.143 >> Trial 12 (18n_ppo_tr_frostbite_05:17) failed: launch_result_metadata={'error_code': 1, 'error_message': 'Failed to fetch result file "/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch17.metrics_suite.json" in container: 404 Client Error for http+docker://localhost/v1.52/containers/70cbb2a9f002f9a9e7beeebd5b75096aaf834e33d141fa460166cdd8693280fe/archive?path=%2Fneurolab%2Frun%2F18_rl%2F18n_ppo_tr_frostbite_05-launch17.metrics_suite.json: Not Found ("Could not find the file /neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch17.metrics_suite.json in container 70cbb2a9f002f9a9e7beeebd5b75096aaf834e33d141fa460166cdd8693280fe")', 'is_ok': False, 'runner_name': 'selectel1_1789551071.234'}
# 2026.09.16-15:55:07.439176     0.001 >> Launch "18n_ppo_tr_frostbite_05:17" completed
# 2026.09.16-15:55:07.439899     0.001 >> 9 (+1) launches completed; running launches=8
# 2026.09.16-15:55:12.789646     0.231 >> Model instance registered, version=22
# 2026.09.16-15:55:12.801200     0.003 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_05:22"; running launches=9
# 2026.09.16-15:55:12.801348     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch22.ipynb"
# 2026.09.16-16:00:12.126263     1.665 >> Trial 0 (18n_ppo_tr_frostbite_05:5) finished with value: 1056.1538461538462 and parameters: {}. Best is trial 9 with value: 1563.8461538461538
# 2026.09.16-16:00:15.579371     0.002 >> Launch "18n_ppo_tr_frostbite_05:5" completed
# 2026.09.16-16:00:15.581364     0.002 >> 10 (+1) launches completed; running launches=8
# 2026.09.16-16:02:36.241676     2.187 >> Trial 2 (18n_ppo_tr_frostbite_05:7) finished with value: 1792.3076923076924 and parameters: {}. Best is trial 2 with value: 1792.3076923076924
# 2026.09.16-16:02:39.174476     0.002 >> Launch "18n_ppo_tr_frostbite_05:7" completed
# 2026.09.16-16:02:39.175669     0.001 >> 11 (+1) launches completed; running launches=7
# 2026.09.16-16:11:30.587867     1.647 >> Trial 11 (18n_ppo_tr_frostbite_05:16) failed: launch_result_metadata={'error_code': 1, 'error_message': 'Failed to fetch result file "/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch16.metrics_suite.json" in container: 404 Client Error for http+docker://localhost/v1.52/containers/9e264ef0fbb0e551a30fb30af18a3134573ad831fcde668266b3ca7d497c5711/archive?path=%2Fneurolab%2Frun%2F18_rl%2F18n_ppo_tr_frostbite_05-launch16.metrics_suite.json: Not Found ("Could not find the file /neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch16.metrics_suite.json in container 9e264ef0fbb0e551a30fb30af18a3134573ad831fcde668266b3ca7d497c5711")', 'is_ok': False, 'runner_name': 'baki_1789486130.207'}
# 2026.09.16-16:11:34.847571     0.002 >> Launch "18n_ppo_tr_frostbite_05:16" completed
# 2026.09.16-16:11:34.848481     0.001 >> 12 (+1) launches completed; running launches=6
# 2026.09.16-16:11:34.979985     0.132 >> Trial 10 (18n_ppo_tr_frostbite_05:15) failed: launch_result_metadata={'error_code': 1, 'error_message': 'Failed to fetch result file "/neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch15.metrics_suite.json" in container: 404 Client Error for http+docker://localhost/v1.52/containers/b669754c2f29a5654f55b99224dd8fa32ed1f3c1d853686ec428001c3f2f6449/archive?path=%2Fneurolab%2Frun%2F18_rl%2F18n_ppo_tr_frostbite_05-launch15.metrics_suite.json: Not Found ("Could not find the file /neurolab/run/18_rl/18n_ppo_tr_frostbite_05-launch15.metrics_suite.json in container b669754c2f29a5654f55b99224dd8fa32ed1f3c1d853686ec428001c3f2f6449")', 'is_ok': False, 'runner_name': 'baki_1789549716.322'}
# 2026.09.16-16:11:39.970233     0.002 >> Launch "18n_ppo_tr_frostbite_05:15" completed
# 2026.09.16-16:11:39.971219     0.001 >> 13 (+1) launches completed; running launches=5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 54
#      51 except TimeoutError as e:
#      52     pass
# ---> 54 time.sleep(5)
#
# KeyboardInterrupt:

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
