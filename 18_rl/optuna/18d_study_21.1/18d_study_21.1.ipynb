# %% [markdown]
# # Goal
#
# Запуск 72 показал (см. результаты `18d_study_19.1`), что лучше использовать все экшны. Проводим повторно исследование. Тестируем гиперпараметры:
# - `struct_projector=dict(type='Identity')`
# - `pred_latents_source='separate'`
# - `learn_rate`
# - `pred_loss_type='MSE'`
# - **учёт всех экшнов**

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18d_world_model_08.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.launch_goal = 'train_predictor'
    
    HP.general.comment = None
    HP.general.random_seed = random.randint(0, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True

    HP.dataset.train = [
        '18b_dataset_02:7:cls=train,no=1,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=2,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=3,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=4,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=5,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=6,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=7,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=8,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=9,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=10,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=11,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=12,seq=8,mp=0',
    ]
    HP.dataset.test = '18b_dataset_02:7:cls=test,no=1,seq=8,mp=0'

    HP.model.parent = '18d_world_model_07:8'
    # Give 4 obs, predict next 4 obs
    HP.model.input_sequence_length = 4
    HP.model.actions_count = 6
    HP.model.ob_shape = (1, 178, 152)
    HP.model.d_model = 256
    HP.model.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.model.encoder = dict(
        is_trainable=HP.launch_goal in ('train_encoder', 'train_all', None),
        vision_head=dict(grid=(6,6), features_counts=(16, 32, 64, 128)),
    )
    HP.model.predictor = dict(
        is_trainable=HP.launch_goal in ('train_predictor', 'train_all', None),
        pred_latents_source='separate',
        parent=None, # do not load from HP.model.parent
    )
    HP.model.renderer = dict(
        is_trainable=HP.launch_goal in ('train_encoder', 'train_all', None),
        projector=dict(type='linear'), 
        render_engine=dict(
            type='layer', 
            layers_count=4, 
            features_counts=(96, 64, 32, 16),
        ),
    )
    HP.model.struct_projector = dict(
        is_trainable=HP.launch_goal in ('train_predictor', 'train_all', None),
        type='Identity',
        parent=None, # do not load from HP.model.parent
    )
    
    HP.train.epochs_count = 100
    HP.train.batch_size = 128
    HP.train.optimizer = 'AdamW'
    HP.train.max_grad_norm = 1.0
    HP.train.learn_rate = f'const({optuna_trial.suggest_float('learn_rate', 0.0001, 0.01)})'
    HP.train.bce_loss_coef = 'const(1.0)'
    HP.train.edge_loss_coef = 'const(1.0)'
    HP.train.recon_loss_coef = 'const(0.0)'
    HP.train.pred_loss = dict(
        type='MSE', 
        loss_coef='const(1.0)', 
    )
    
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Чуть лучше, чем `18d_study_20.1`
#
# <img src="./img/ssim.png">
#
# **Выводы**
# 1) оставляем учёт всех экшнов
# 2) дотрениваем вторым шагом на малом learn rate

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18d_world_model_08.ipynb',
#  'target_notebook_name': '18d_world_model_08',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18d_study_21.1/18d_study_21.1.ipynb',
#  'optuna_study_name': '18d_study_21.1',
#  'optuna_study_serial': '21.1',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18d_study_21.1/18d_study_21.1.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 18
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-14 16:12:47,749] Using an existing study with name '18d_study_21.1' instead of creating a new one.
# 2026.09.14-16:12:47.999706     0.222 >> Model instance registered, version=153
# 2026.09.14-16:12:48.018948     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch153.ipynb"
# 2026.09.14-16:12:48.019642     0.008 >> 9.0 idle runners exist, submitted launch "18d_world_model_08:153"; running launches=1
# 2026.09.14-16:13:19.139676     0.191 >> Model instance registered, version=154
# 2026.09.14-16:13:19.153123     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch154.ipynb"
# 2026.09.14-16:13:19.153661     0.007 >> 8.3 idle runners exist, submitted launch "18d_world_model_08:154"; running launches=2
# 2026.09.14-16:13:50.731635     0.200 >> Model instance registered, version=155
# 2026.09.14-16:13:50.745859     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch155.ipynb"
# 2026.09.14-16:13:50.746197     0.007 >> 7.5 idle runners exist, submitted launch "18d_world_model_08:155"; running launches=3
# 2026.09.14-16:14:21.667970     0.155 >> Model instance registered, version=156
# 2026.09.14-16:14:21.681732     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch156.ipynb"
# 2026.09.14-16:14:21.681941     0.007 >> 6.5 idle runners exist, submitted launch "18d_world_model_08:156"; running launches=4
# 2026.09.14-16:14:53.331235     0.179 >> Model instance registered, version=157
# 2026.09.14-16:14:53.348535     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch157.ipynb"
# 2026.09.14-16:14:53.348762     0.007 >> 5.5 idle runners exist, submitted launch "18d_world_model_08:157"; running launches=5
# 2026.09.14-16:15:24.259668     0.208 >> Model instance registered, version=158
# 2026.09.14-16:15:24.279251     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch158.ipynb"
# 2026.09.14-16:15:24.279471     0.007 >> 4.5 idle runners exist, submitted launch "18d_world_model_08:158"; running launches=6
# 2026.09.14-16:15:55.168034     0.184 >> Model instance registered, version=159
# 2026.09.14-16:15:55.181457     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch159.ipynb"
# 2026.09.14-16:15:55.181667     0.007 >> 3.5 idle runners exist, submitted launch "18d_world_model_08:159"; running launches=7
# 2026.09.14-16:16:26.533507     0.202 >> Model instance registered, version=160
# 2026.09.14-16:16:26.555931     0.010 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch160.ipynb"
# 2026.09.14-16:16:26.556329     0.010 >> 2.7 idle runners exist, submitted launch "18d_world_model_08:160"; running launches=8
# 2026.09.14-16:16:57.453632     0.234 >> Model instance registered, version=161
# 2026.09.14-16:16:57.470245     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch161.ipynb"
# 2026.09.14-16:16:57.470581     0.008 >> 1.3 idle runners exist, submitted launch "18d_world_model_08:161"; running launches=9
# 2026.09.14-16:24:41.406952     1.369 >> Trial 33 (18d_world_model_08:156) finished with value: 0.947848089498929 and parameters: {'learn_rate': 0.001789338907504441}. Best is trial 25 with value: 0.9629031383468101
# 2026.09.14-16:24:45.146619     0.001 >> Launch "18d_world_model_08:156" completed
# 2026.09.14-16:24:45.147099     0.000 >> 1 (+1) launches completed; running launches=8
# 2026.09.14-16:25:10.957989     4.799 >> Trial 30 (18d_world_model_08:153) finished with value: 0.9534365599674114 and parameters: {'learn_rate': 0.0019693619065063103}. Best is trial 25 with value: 0.9629031383468101
# 2026.09.14-16:25:11.464187     0.189 >> Model instance registered, version=162
# 2026.09.14-16:25:11.477478     0.006 >> 1.2 idle runners exist, submitted launch "18d_world_model_08:162"; running launches=9
# 2026.09.14-16:25:11.477598     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch162.ipynb"
# 2026.09.14-16:25:11.477958     0.000 >> Launch "18d_world_model_08:153" completed
# 2026.09.14-16:25:11.478647     0.001 >> 2 (+1) launches completed; running launches=8
# 2026.09.14-16:25:42.679471     0.186 >> Model instance registered, version=163
# 2026.09.14-16:25:42.694275     0.007 >> 1.5 idle runners exist, submitted launch "18d_world_model_08:163"; running launches=9
# 2026.09.14-16:25:42.694893     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch163.ipynb"
# 2026.09.14-16:27:01.836341     2.006 >> Trial 36 (18d_world_model_08:159) finished with value: 0.9486813661282656 and parameters: {'learn_rate': 0.0017429766519034618}. Best is trial 25 with value: 0.9629031383468101
# 2026.09.14-16:27:04.943616     0.001 >> Launch "18d_world_model_08:159" completed
# 2026.09.14-16:27:04.944186     0.001 >> 3 (+1) launches completed; running launches=8
# 2026.09.14-16:27:30.829558     0.204 >> Model instance registered, version=164
# 2026.09.14-16:27:30.843570     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:164"; running launches=9
# 2026.09.14-16:27:30.843739     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch164.ipynb"
# 2026.09.14-16:27:39.273312     3.324 >> Trial 38 (18d_world_model_08:161) finished with value: 0.9604628248597616 and parameters: {'learn_rate': 0.0012921614263919506}. Best is trial 25 with value: 0.9629031383468101
# 2026.09.14-16:27:41.063682     0.002 >> Launch "18d_world_model_08:161" completed
# 2026.09.14-16:27:41.064584     0.001 >> 4 (+1) launches completed; running launches=8
# 2026.09.14-16:28:01.670119     0.164 >> Model instance registered, version=165
# 2026.09.14-16:28:01.688919     0.007 >> 1.5 idle runners exist, submitted launch "18d_world_model_08:165"; running launches=9
# 2026.09.14-16:28:01.689135     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch165.ipynb"
# 2026.09.14-16:28:08.678666     1.545 >> Trial 35 (18d_world_model_08:158) finished with value: 0.9612317638236936 and parameters: {'learn_rate': 0.0012758963122756482}. Best is trial 25 with value: 0.9629031383468101
# 2026.09.14-16:28:12.247421     0.001 >> Launch "18d_world_model_08:158" completed
# 2026.09.14-16:28:12.248303     0.001 >> 5 (+1) launches completed; running launches=8
# 2026.09.14-16:28:32.891359     0.203 >> Model instance registered, version=166
# 2026.09.14-16:28:32.905184     0.006 >> 1.2 idle runners exist, submitted launch "18d_world_model_08:166"; running launches=9
# 2026.09.14-16:28:32.905374     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch166.ipynb"
# 2026.09.14-16:29:13.635193     4.777 >> Trial 37 (18d_world_model_08:160) finished with value: 0.9481646464466863 and parameters: {'learn_rate': 0.0017589568112749208}. Best is trial 25 with value: 0.9629031383468101
# 2026.09.14-16:29:13.977513     0.002 >> Launch "18d_world_model_08:160" completed
# 2026.09.14-16:29:13.978475     0.001 >> 6 (+1) launches completed; running launches=8
# 2026.09.14-16:29:39.743150     0.178 >> Model instance registered, version=167
# 2026.09.14-16:29:39.759068     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:167"; running launches=9
# 2026.09.14-16:29:39.759202     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch167.ipynb"
# 2026.09.14-16:30:49.523996     2.880 >> Trial 31 (18d_world_model_08:154) finished with value: 0.9511024292258136 and parameters: {'learn_rate': 0.0019505079749072428}. Best is trial 25 with value: 0.9629031383468101
# 2026.09.14-16:30:51.760787     0.001 >> Launch "18d_world_model_08:154" completed
# 2026.09.14-16:30:51.761660     0.001 >> 7 (+1) launches completed; running launches=8
# 2026.09.14-16:31:17.520783     0.185 >> Model instance registered, version=168
# 2026.09.14-16:31:17.541837     0.009 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:168"; running launches=9
# 2026.09.14-16:31:17.541961     0.009 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch168.ipynb"
# 2026.09.14-16:31:35.821985     2.672 >> Trial 32 (18d_world_model_08:155) finished with value: 0.9520354925417432 and parameters: {'learn_rate': 0.0019708083360327564}. Best is trial 25 with value: 0.9629031383468101
# 2026.09.14-16:31:38.270779     0.002 >> Launch "18d_world_model_08:155" completed
# 2026.09.14-16:31:38.271595     0.001 >> 8 (+1) launches completed; running launches=8
# 2026.09.14-16:32:04.037906     0.185 >> Model instance registered, version=169
# 2026.09.14-16:32:04.064844     0.012 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:169"; running launches=9
# 2026.09.14-16:32:04.065003     0.012 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch169.ipynb"
# 2026.09.14-16:32:17.938274     3.659 >> Trial 34 (18d_world_model_08:157) finished with value: 0.9515493892191208 and parameters: {'learn_rate': 0.0018854577463570646}. Best is trial 25 with value: 0.9629031383468101
# 2026.09.14-16:32:19.396593     0.002 >> Launch "18d_world_model_08:157" completed
# 2026.09.14-16:32:19.397501     0.001 >> 9 (+1) launches completed; running launches=8
# 2026.09.14-16:32:34.961754     0.205 >> Model instance registered, version=170
# 2026.09.14-16:32:34.975984     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:170"; running launches=9
# 2026.09.14-16:32:34.976182     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch170.ipynb"
# 2026.09.14-16:36:16.767769     0.004 >> Trial 40 (18d_world_model_08:163) finished with value: 0.961603255261523 and parameters: {'learn_rate': 0.0010605359232813227}. Best is trial 25 with value: 0.9629031383468101
# 2026.09.14-16:36:16.768635     0.001 >> Launch "18d_world_model_08:163" completed
# 2026.09.14-16:36:16.768983     0.000 >> 10 (+1) launches completed; running launches=8
# 2026.09.14-16:37:48.693974     4.882 >> Trial 39 (18d_world_model_08:162) finished with value: 0.9588810744702612 and parameters: {'learn_rate': 0.0011126818529846642}. Best is trial 25 with value: 0.9629031383468101
# 2026.09.14-16:37:48.930571     0.002 >> Launch "18d_world_model_08:162" completed
# 2026.09.14-16:37:48.931466     0.001 >> 11 (+1) launches completed; running launches=7
# 2026.09.14-16:38:36.770153     1.520 >> Trial 41 (18d_world_model_08:164) finished with value: 0.958084147762295 and parameters: {'learn_rate': 0.0010647856641044515}. Best is trial 25 with value: 0.9629031383468101
# 2026.09.14-16:38:40.366517     0.002 >> Launch "18d_world_model_08:164" completed
# 2026.09.14-16:38:40.367276     0.001 >> 12 (+1) launches completed; running launches=6
# 2026.09.14-16:39:14.365463     3.030 >> Trial 43 (18d_world_model_08:166) finished with value: 0.9455503020299917 and parameters: {'learn_rate': 0.0023026129631957297}. Best is trial 25 with value: 0.9629031383468101
# 2026.09.14-16:39:16.445027     0.001 >> Launch "18d_world_model_08:166" completed
# 2026.09.14-16:39:16.445479     0.000 >> 13 (+1) launches completed; running launches=5
# 2026.09.14-16:40:40.041834     1.604 >> Trial 42 (18d_world_model_08:165) finished with value: 0.9572699505556346 and parameters: {'learn_rate': 0.0009454460703146273}. Best is trial 25 with value: 0.9629031383468101
# 2026.09.14-16:40:43.558365     0.002 >> Launch "18d_world_model_08:165" completed
# 2026.09.14-16:40:43.559352     0.001 >> 14 (+1) launches completed; running launches=4
# 2026.09.14-16:42:16.072073     0.360 >> Trial 44 (18d_world_model_08:167) finished with value: 0.9503327665023258 and parameters: {'learn_rate': 0.0024405550790715254}. Best is trial 25 with value: 0.9629031383468101
# 2026.09.14-16:42:20.827334     0.002 >> Launch "18d_world_model_08:167" completed
# 2026.09.14-16:42:20.828418     0.001 >> 15 (+1) launches completed; running launches=3
# 2026.09.14-16:48:52.205438     1.438 >> Trial 45 (18d_world_model_08:168) finished with value: 0.9562720680177453 and parameters: {'learn_rate': 0.001068017923250636}. Best is trial 25 with value: 0.9629031383468101
# 2026.09.14-16:48:55.883620     0.001 >> Launch "18d_world_model_08:168" completed
# 2026.09.14-16:48:55.884407     0.001 >> 16 (+1) launches completed; running launches=2
# 2026.09.14-16:49:45.686026     3.729 >> Trial 46 (18d_world_model_08:169) finished with value: 0.9641078845682153 and parameters: {'learn_rate': 0.0009330190376915289}. Best is trial 46 with value: 0.9641078845682153
# 2026.09.14-16:49:47.075576     0.003 >> Launch "18d_world_model_08:169" completed
# 2026.09.14-16:49:47.076376     0.001 >> 17 (+1) launches completed; running launches=1
# 2026.09.14-16:50:21.866124     3.390 >> Trial 47 (18d_world_model_08:170) finished with value: 0.9586291591289293 and parameters: {'learn_rate': 0.0009013134534979863}. Best is trial 46 with value: 0.9641078845682153
# 2026.09.14-16:50:23.600736     0.004 >> Launch "18d_world_model_08:170" completed
# 2026.09.14-16:50:23.602003     0.001 >> 18 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-14 16:50:36,572] Using an existing study with name '18d_study_21.1' instead of creating a new one.
# 2026.09.14-16:50:36.574729    12.973 >> Study statistics:
# 2026.09.14-16:50:36.578856     0.004 >> 	Number of finished trials: 48
# 2026.09.14-16:50:36.579715     0.001 >> 	Number of pruned trials: 0
# 2026.09.14-16:50:36.580364     0.001 >> 	Number of complete trials: 48
# 2026.09.14-16:50:36.581206     0.001 >> Best trial:
# 2026.09.14-16:50:36.582007     0.001 >> 	Value: 0.9641078845682153
# 2026.09.14-16:50:36.582497     0.000 >> 	Model version: 169
# 2026.09.14-16:50:36.582914     0.000 >> 	Params:
# 2026.09.14-16:50:36.583295     0.000 >> 		learn_rate: 0.0009330190376915289
