# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 6 шагов. На каждом шаге отбираем чемпионов для продолжения след. шага.
#
# Данный эксперимент - это шестой шаг. Здесь агент 80% играет на пятом уровне c 9 жизнями, и по 5% с первого/второго/третьего/четвёртого.
#
# Тут идея, чтобы "продавить" 5 уровень, но при этом не затереть имующийся опыт.

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False

    parent = optuna_trial.suggest_categorical('parent', [
        '18n_ppo_tr_frostbite_06:521',
        '18n_ppo_tr_frostbite_06:494',
        '18n_ppo_tr_frostbite_06:519',
    ])
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights=parent)
    HP.encoder.is_trainable = True

    HP.agent.parent = parent 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(200000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = None
    HP.video.capture_env_ram_patches = None
    HP.video.break_on_level_passed = False
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = 3_000_000 # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = [
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=none', # 0
        'com.develorium.neurolab.frostbite_ram:level2:1:cls=none', # 1
        'com.develorium.neurolab.frostbite_ram:level3:1:cls=none', # 2
        'com.develorium.neurolab.frostbite_ram:level4:1:cls=none', # 3
        
        'com.develorium.neurolab.frostbite_ram:level5:1:cls=none', # 4
    ]
    HP.ppo.rollout_env_ram_patches = [
        ['no_score', 'three_lives', 'no_igloo', 'temperature_45', 'bailey_safe_random_spawn'], # 0
        ['no_score', 'nine_lives', 'no_igloo', 'temperature_45'], # 1
    ]
    HP.ppo.rollout_env_stories = (
        ['0;0'] +      # level 1 - 5% time
        ['1;0'] +      # level 2 - 5% time
        ['2;0'] +      # level 3 - 5% time
        ['3;0'] +      # level 4 - 5% time
        ['4;1'] * 16   # level 5 - 80% time
    )
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    HP.ppo.learn_rate = f'const({0.00025 - 0.0002 / 6 * 5})'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    HP.ppo.ent_coef = f'const({0.05 - 0.04 / 6 * 5})'
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Ну что, получилось выточить ещё парочку 5 очковых. Один агент (`18n_ppo_tr_frostbite_06/598`) аж два раза прошёл этот рубеж, правда в конце расстроился.
#
# Также раздумывал над стохастичностью. Точнее проверил. Оказалось, что всё таки стохастичность есть в игре. Это на первом уровне она видимо выключена, чтобы игроку было попроще. А вот потом стохастичность работает - враги всегда по разному двигаются, поэтому как ни крути пространство состоянию будет каждый раз разными. И это справедливо даже тогда, когда жизнь теряешь. Т.е. одинаковых траекторий прохождения не будет, т.к. каждый раз разная конфигурация врагов.
#
# Поэтому `com.develorium.neurolab.frostbite_ram:level5:1:cls=none/no_score+nine_lives+no_igloo+temperature_45` вот так лучше не делать. Это как раз сетит 5 уровень **всегда в одно и то же состояние по крайней мере на ПЕРВУЮ жизнь**. Потом всё равно стохастичность начинается, но тем не менее.
#
# <img src="./img/score.png">
# <img src="./img/episode_r.png">
# <img src="./img/episode_lp.png">
#
# **Выводы**
# 1) опять попробовать играть с первого уровня и 9-ью жизнями. Почему я всегда возвращаюсь к этой идее? =)

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.6d/18n_study_19.6d.ipynb',
#  'optuna_study_name': '18n_study_19.6d',
#  'optuna_study_serial': '19.6d',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.6d/18n_study_19.6d.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-23 19:47:04,658] A new study created in Journal with name: 18n_study_19.6d
# 2026.09.23-19:47:04.904842     0.207 >> Model instance registered, version=571
# 2026.09.23-19:47:04.915210     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch571.ipynb"
# 2026.09.23-19:47:04.915740     0.005 >> 6.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:571"; running launches=1
# 2026.09.23-19:47:36.147810     0.231 >> Model instance registered, version=572
# 2026.09.23-19:47:36.161214     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch572.ipynb"
# 2026.09.23-19:47:36.161594     0.005 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:572"; running launches=2
# 2026.09.23-19:48:07.074556     0.205 >> Model instance registered, version=573
# 2026.09.23-19:48:07.086806     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch573.ipynb"
# 2026.09.23-19:48:07.087656     0.006 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:573"; running launches=3
# 2026.09.23-19:48:38.314847     0.367 >> Model instance registered, version=574
# 2026.09.23-19:48:38.332065     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch574.ipynb"
# 2026.09.23-19:48:38.333160     0.009 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:574"; running launches=4
# 2026.09.23-19:49:09.542668     0.336 >> Model instance registered, version=575
# 2026.09.23-19:49:09.560971     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch575.ipynb"
# 2026.09.23-19:49:09.561403     0.007 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:575"; running launches=5
# 2026.09.23-19:49:40.805075     0.344 >> Model instance registered, version=576
# 2026.09.23-19:49:40.818468     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch576.ipynb"
# 2026.09.23-19:49:40.818753     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:576"; running launches=6
# 2026.09.23-20:07:45.982407     0.292 >> Model instance registered, version=577
# 2026.09.23-20:07:45.998122     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch577.ipynb"
# 2026.09.23-20:07:45.999440     0.001 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:577"; running launches=7
# 2026.09.23-20:08:18.761910     0.311 >> Model instance registered, version=578
# 2026.09.23-20:08:18.773536     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch578.ipynb"
# 2026.09.23-20:08:18.773926     0.004 >> 5.5 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:578"; running launches=8
# 2026.09.23-20:08:51.201311     0.280 >> Model instance registered, version=579
# 2026.09.23-20:08:51.210910     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch579.ipynb"
# 2026.09.23-20:08:51.211142     0.004 >> 6.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:579"; running launches=9
# 2026.09.23-20:09:22.797894     0.241 >> Model instance registered, version=580
# 2026.09.23-20:09:22.807198     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch580.ipynb"
# 2026.09.23-20:09:22.807448     0.004 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:580"; running launches=10
# 2026.09.23-20:09:54.021636     0.241 >> Model instance registered, version=581
# 2026.09.23-20:09:54.032251     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch581.ipynb"
# 2026.09.23-20:09:54.032490     0.004 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:581"; running launches=11
# 2026.09.23-20:10:09.653465     0.002 >> Launch "18n_ppo_tr_frostbite_06:581" failed: Command '['papermill', '/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch581.ipynb', '/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch581.ipynb', '--no-progress-bar']' returned non-zero exit status 1.
# 2026.09.23-20:10:09.654718     0.001 >> 1 (+1) launches completed; running launches=10
# 2026.09.23-20:10:25.562740     0.240 >> Model instance registered, version=582
# 2026.09.23-20:10:25.576307     0.005 >> 4.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:582"; running launches=11
# 2026.09.23-20:10:25.576611     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch582.ipynb"
# 2026.09.23-20:10:58.695171     0.299 >> Model instance registered, version=583
# 2026.09.23-20:10:58.709611     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch583.ipynb"
# 2026.09.23-20:10:58.709946     0.006 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:583"; running launches=12
# 2026.09.23-20:11:29.797155     0.273 >> Model instance registered, version=584
# 2026.09.23-20:11:29.807250     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch584.ipynb"
# 2026.09.23-20:11:29.807875     0.006 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:584"; running launches=13
# 2026.09.23-20:12:02.384145     0.199 >> Model instance registered, version=585
# 2026.09.23-20:12:02.397753     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch585.ipynb"
# 2026.09.23-20:12:02.398278     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:585"; running launches=14
# 2026.09.23-20:32:31.584105     0.433 >> Trial 0 (18n_ppo_tr_frostbite_06:571) finished with value: 40403.0002041221 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-20:32:36.275105     0.002 >> Launch "18n_ppo_tr_frostbite_06:571" completed
# 2026.09.23-20:32:36.276212     0.001 >> 2 (+1) launches completed; running launches=13
# 2026.09.23-20:32:57.273641     0.223 >> Model instance registered, version=586
# 2026.09.23-20:32:57.287974     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:586"; running launches=14
# 2026.09.23-20:32:57.288166     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch586.ipynb"
# 2026.09.23-20:33:20.826561     3.095 >> Trial 1 (18n_ppo_tr_frostbite_06:572) finished with value: 30303.000139215685 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-20:33:22.841042     0.001 >> Launch "18n_ppo_tr_frostbite_06:572" completed
# 2026.09.23-20:33:22.841604     0.001 >> 3 (+1) launches completed; running launches=13
# 2026.09.23-20:33:48.897862     0.233 >> Model instance registered, version=587
# 2026.09.23-20:33:48.907715     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:587"; running launches=14
# 2026.09.23-20:33:48.909148     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch587.ipynb"
# 2026.09.23-20:36:02.944388     0.363 >> Trial 5 (18n_ppo_tr_frostbite_06:576) finished with value: 30303.000237009805 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-20:36:07.705804     0.003 >> Launch "18n_ppo_tr_frostbite_06:576" completed
# 2026.09.23-20:36:07.707033     0.001 >> 4 (+1) launches completed; running launches=13
# 2026.09.23-20:36:28.838037     0.224 >> Model instance registered, version=588
# 2026.09.23-20:36:28.848493     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:588"; running launches=14
# 2026.09.23-20:36:28.848585     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch588.ipynb"
# 2026.09.23-20:37:29.715672     4.587 >> Trial 3 (18n_ppo_tr_frostbite_06:574) finished with value: 40403.00016878342 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-20:37:30.245795     0.002 >> Launch "18n_ppo_tr_frostbite_06:574" completed
# 2026.09.23-20:37:30.246912     0.001 >> 5 (+1) launches completed; running launches=13
# 2026.09.23-20:37:56.344981     0.277 >> Model instance registered, version=589
# 2026.09.23-20:37:56.355941     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:589"; running launches=14
# 2026.09.23-20:37:56.356116     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch589.ipynb"
# 2026.09.23-20:38:04.353974     2.889 >> Trial 2 (18n_ppo_tr_frostbite_06:573) finished with value: 403.00018558377894 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-20:38:06.578104     0.002 >> Launch "18n_ppo_tr_frostbite_06:573" completed
# 2026.09.23-20:38:06.579235     0.001 >> 6 (+1) launches completed; running launches=13
# 2026.09.23-20:38:27.375142     0.241 >> Model instance registered, version=590
# 2026.09.23-20:38:27.387063     0.004 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:590"; running launches=14
# 2026.09.23-20:38:27.387180     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch590.ipynb"
# 2026.09.23-20:39:06.412633     3.221 >> Trial 4 (18n_ppo_tr_frostbite_06:575) finished with value: 30303.000165129233 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-20:39:08.308971     0.001 >> Launch "18n_ppo_tr_frostbite_06:575" completed
# 2026.09.23-20:39:08.309810     0.001 >> 7 (+1) launches completed; running launches=13
# 2026.09.23-20:39:34.123708     0.225 >> Model instance registered, version=591
# 2026.09.23-20:39:34.137235     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:591"; running launches=14
# 2026.09.23-20:39:34.137433     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch591.ipynb"
# 2026.09.23-20:50:11.782058     0.890 >> Trial 6 (18n_ppo_tr_frostbite_06:577) finished with value: 30304.00020053476 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-20:50:16.013425     0.002 >> Launch "18n_ppo_tr_frostbite_06:577" completed
# 2026.09.23-20:50:16.014360     0.001 >> 8 (+1) launches completed; running launches=13
# 2026.09.23-20:50:41.854101     0.259 >> Model instance registered, version=592
# 2026.09.23-20:50:41.864624     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:592"; running launches=14
# 2026.09.23-20:50:41.864780     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch592.ipynb"
# 2026.09.23-20:52:38.436660     3.751 >> Trial 7 (18n_ppo_tr_frostbite_06:578) finished with value: 30303.00016931818 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-20:52:39.805382     0.002 >> Launch "18n_ppo_tr_frostbite_06:578" completed
# 2026.09.23-20:52:39.806276     0.001 >> 9 (+1) launches completed; running launches=13
# 2026.09.23-20:52:48.120131     3.181 >> Trial 9 (18n_ppo_tr_frostbite_06:580) finished with value: 30403.000245699644 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-20:52:50.075462     0.006 >> Launch "18n_ppo_tr_frostbite_06:580" completed
# 2026.09.23-20:52:50.076688     0.001 >> 10 (+1) launches completed; running launches=12
# 2026.09.23-20:52:55.399269     0.210 >> Model instance registered, version=593
# 2026.09.23-20:52:55.409323     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:593"; running launches=13
# 2026.09.23-20:52:55.409411     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch593.ipynb"
# 2026.09.23-20:53:26.398744     0.240 >> Model instance registered, version=594
# 2026.09.23-20:53:26.415316     0.007 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:594"; running launches=14
# 2026.09.23-20:53:26.415884     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch594.ipynb"
# 2026.09.23-20:56:09.049383     3.491 >> Trial 14 (18n_ppo_tr_frostbite_06:585) finished with value: 20303.000162522283 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-20:56:10.669846     0.001 >> Launch "18n_ppo_tr_frostbite_06:585" completed
# 2026.09.23-20:56:10.670636     0.001 >> 11 (+1) launches completed; running launches=13
# 2026.09.23-20:56:27.722261     1.685 >> Trial 8 (18n_ppo_tr_frostbite_06:579) finished with value: 40203.00019131016 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-20:56:31.373241     0.221 >> Model instance registered, version=595
# 2026.09.23-20:56:31.381718     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:595"; running launches=14
# 2026.09.23-20:56:31.381871     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch595.ipynb"
# 2026.09.23-20:56:31.382287     0.001 >> Launch "18n_ppo_tr_frostbite_06:579" completed
# 2026.09.23-20:56:31.383399     0.001 >> 12 (+1) launches completed; running launches=13
# 2026.09.23-20:57:02.375373     0.229 >> Model instance registered, version=596
# 2026.09.23-20:57:02.389756     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:596"; running launches=14
# 2026.09.23-20:57:02.389896     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch596.ipynb"
# 2026.09.23-20:59:49.635508     3.347 >> Trial 12 (18n_ppo_tr_frostbite_06:583) finished with value: 30303.000206016044 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-20:59:51.407455     0.002 >> Launch "18n_ppo_tr_frostbite_06:583" completed
# 2026.09.23-20:59:51.408681     0.001 >> 13 (+1) launches completed; running launches=13
# 2026.09.23-21:00:17.192928     0.202 >> Model instance registered, version=597
# 2026.09.23-21:00:17.202260     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:597"; running launches=14
# 2026.09.23-21:00:17.202395     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch597.ipynb"
# 2026.09.23-21:01:40.662649     0.916 >> Trial 13 (18n_ppo_tr_frostbite_06:584) finished with value: 20304.000217268273 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-21:01:44.867799     0.001 >> Launch "18n_ppo_tr_frostbite_06:584" completed
# 2026.09.23-21:01:44.868889     0.001 >> 14 (+1) launches completed; running launches=13
# 2026.09.23-21:02:00.784378     0.338 >> Trial 11 (18n_ppo_tr_frostbite_06:582) finished with value: 40303.000236608736 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-21:02:05.809912     0.240 >> Model instance registered, version=598
# 2026.09.23-21:02:05.823405     0.005 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:598"; running launches=14
# 2026.09.23-21:02:05.823542     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch598.ipynb"
# 2026.09.23-21:02:05.824176     0.001 >> Launch "18n_ppo_tr_frostbite_06:582" completed
# 2026.09.23-21:02:05.825240     0.001 >> 15 (+1) launches completed; running launches=13
# 2026.09.23-21:02:37.359216     0.245 >> Model instance registered, version=599
# 2026.09.23-21:02:37.373277     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:599"; running launches=14
# 2026.09.23-21:02:37.373507     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch599.ipynb"
# 2026.09.23-21:17:42.524128     0.942 >> Trial 15 (18n_ppo_tr_frostbite_06:586) finished with value: 20203.00013099376 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-21:17:46.696884     0.001 >> Launch "18n_ppo_tr_frostbite_06:586" completed
# 2026.09.23-21:17:46.697542     0.001 >> 16 (+1) launches completed; running launches=13
# 2026.09.23-21:18:12.479148     0.214 >> Model instance registered, version=600
# 2026.09.23-21:18:12.490788     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:600"; running launches=14
# 2026.09.23-21:18:12.490914     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch600.ipynb"
# 2026.09.23-21:19:20.066420     5.066 >> Trial 16 (18n_ppo_tr_frostbite_06:587) finished with value: 30303.000168181818 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-21:19:20.111112     0.001 >> Launch "18n_ppo_tr_frostbite_06:587" completed
# 2026.09.23-21:19:20.111783     0.001 >> 17 (+1) launches completed; running launches=13
# 2026.09.23-21:22:34.087051     4.105 >> Trial 17 (18n_ppo_tr_frostbite_06:588) finished with value: 30404.00024701426 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-21:22:35.102674     0.002 >> Launch "18n_ppo_tr_frostbite_06:588" completed
# 2026.09.23-21:22:35.103603     0.001 >> 18 (+1) launches completed; running launches=12
# 2026.09.23-21:27:46.581486     3.203 >> Trial 19 (18n_ppo_tr_frostbite_06:590) finished with value: 30203.000140106953 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-21:27:48.496539     0.002 >> Launch "18n_ppo_tr_frostbite_06:590" completed
# 2026.09.23-21:27:48.497325     0.001 >> 19 (+1) launches completed; running launches=11
# 2026.09.23-21:28:11.658734     2.691 >> Trial 18 (18n_ppo_tr_frostbite_06:589) finished with value: 40302.00016441622 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-21:28:14.094180     0.004 >> Launch "18n_ppo_tr_frostbite_06:589" completed
# 2026.09.23-21:28:14.096073     0.002 >> 20 (+1) launches completed; running launches=10
# 2026.09.23-21:29:30.373704     4.349 >> Trial 20 (18n_ppo_tr_frostbite_06:591) finished with value: 40203.000193538326 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-21:29:31.145829     0.002 >> Launch "18n_ppo_tr_frostbite_06:591" completed
# 2026.09.23-21:29:31.146902     0.001 >> 21 (+1) launches completed; running launches=9
# 2026.09.23-21:34:50.101393     1.250 >> Trial 21 (18n_ppo_tr_frostbite_06:592) finished with value: 304.0002366532977 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-21:34:53.971908     0.002 >> Launch "18n_ppo_tr_frostbite_06:592" completed
# 2026.09.23-21:34:53.973039     0.001 >> 22 (+1) launches completed; running launches=8
# 2026.09.23-21:35:16.835036     2.402 >> Trial 22 (18n_ppo_tr_frostbite_06:593) finished with value: 30304.000181194297 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-21:35:19.549694     0.001 >> Launch "18n_ppo_tr_frostbite_06:593" completed
# 2026.09.23-21:35:19.550625     0.001 >> 23 (+1) launches completed; running launches=7
# 2026.09.23-21:36:37.080470     0.327 >> Trial 23 (18n_ppo_tr_frostbite_06:594) finished with value: 30303.000228186276 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-21:36:41.876012     0.002 >> Launch "18n_ppo_tr_frostbite_06:594" completed
# 2026.09.23-21:36:41.877043     0.001 >> 24 (+1) launches completed; running launches=6
# 2026.09.23-21:38:07.216496     3.375 >> Trial 25 (18n_ppo_tr_frostbite_06:596) finished with value: 20303.000199844028 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-21:38:08.962161     0.001 >> Launch "18n_ppo_tr_frostbite_06:596" completed
# 2026.09.23-21:38:08.963035     0.001 >> 25 (+1) launches completed; running launches=5
# 2026.09.23-21:43:50.103678     2.604 >> Trial 24 (18n_ppo_tr_frostbite_06:595) finished with value: 30202.00016535205 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-21:43:52.619608     0.002 >> Launch "18n_ppo_tr_frostbite_06:595" completed
# 2026.09.23-21:43:52.620536     0.001 >> 26 (+1) launches completed; running launches=4
# 2026.09.23-21:48:52.841203     2.876 >> Trial 26 (18n_ppo_tr_frostbite_06:597) finished with value: 20402.00019576649 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-21:48:55.086112     0.001 >> Launch "18n_ppo_tr_frostbite_06:597" completed
# 2026.09.23-21:48:55.086964     0.001 >> 27 (+1) launches completed; running launches=3
# 2026.09.23-21:49:33.390415     2.490 >> Trial 27 (18n_ppo_tr_frostbite_06:598) finished with value: 10403.000256840463 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-21:49:36.018541     0.002 >> Launch "18n_ppo_tr_frostbite_06:598" completed
# 2026.09.23-21:49:36.019742     0.001 >> 28 (+1) launches completed; running launches=2
# 2026.09.23-21:49:55.018857     3.651 >> Trial 28 (18n_ppo_tr_frostbite_06:599) finished with value: 30403.0002307041 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 0 with value: 40403.0002041221
# 2026.09.23-21:49:56.484143     0.001 >> Launch "18n_ppo_tr_frostbite_06:599" completed
# 2026.09.23-21:49:56.485253     0.001 >> 29 (+1) launches completed; running launches=1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 54
#      51 except TimeoutError as e:
#      52     pass
# ---> 54 time.sleep(5)
#
# KeyboardInterrupt:

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
