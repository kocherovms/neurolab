# %% [markdown]
# # Goal
#
# Что можно выжать из простого `InfoNCE` при `launch_goal=train_predictor`? Тестируем гиперпараметры:
# - `learn_rate`
# - `batch_size`
# - `temperature`

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18d_world_model_07.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.launch_goal = 'train_predictor'
    
    HP.general.comment = None
    HP.general.random_seed = random.randint(0, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.dataset.train = [
        'train_dataset_seq_eq_5_max_eq_0:101',
        'train_dataset_seq_eq_5_max_eq_0:102',
        'train_dataset_seq_eq_5_max_eq_0:103',
        'train_dataset_seq_eq_5_max_eq_0:104',
        'train_dataset_seq_eq_5_max_eq_0:105',
        'train_dataset_seq_eq_5_max_eq_0:106',
        'train_dataset_seq_eq_5_max_eq_0:107',
        'train_dataset_seq_eq_5_max_eq_0:108',
        'train_dataset_seq_eq_5_max_eq_0:109',
        'train_dataset_seq_eq_5_max_eq_0:110',
    ]
    HP.dataset.test = 'test_dataset_seq_eq_5_max_eq_0:101'

    HP.model.parent = '18d_world_model_07:8'
    HP.model.sequence_length = 4
    HP.model.actions_count = 6
    HP.model.ob_shape = (1, 178, 152)
    HP.model.d_model = 256
    HP.model.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.model.encoder = dict(
        is_trainable=HP.launch_goal in ('train_encoder', 'train_all', None),
        vision_head=dict(grid=(6,6), features_counts=(16, 32, 64, 128)),
    )
    HP.model.predictor = dict(
        is_trainable=HP.launch_goal in ('train_predictor', 'train_all', None),
        down_translator=None,
    )
    HP.model.renderer = dict(
        is_trainable=HP.launch_goal in ('train_encoder', 'train_all', None),
        projector=dict(type='linear'), 
        render_engine=dict(
            type='layer', 
            layers_count=4, 
            features_counts=(96, 64, 32, 16),
        ),
    )
    HP.model.info_nce_projector = dict(
        is_trainable=HP.launch_goal in ('train_predictor', 'train_all', None),
        d_inner=HP.model.d_model,
        d_projected=HP.model.d_model // 2,
    )
    
    HP.train.epochs_count = 100
    HP.train.batch_size = optuna_trial.suggest_categorical('batch_size', [64, 128, 256]) 
    HP.train.optimizer = 'AdamW'
    HP.train.max_grad_norm = 1.0
    HP.train.learn_rate = f'const({optuna_trial.suggest_float('learn_rate', 0.0001, 0.01)})'
    HP.train.bce_loss_coef = 'const(1.0)'
    HP.train.edge_loss_coef = 'const(1.0)'
    HP.train.recon_loss_coef = 'const(0.0)'
    HP.train.pred_loss = dict(
        type='InfoNCE', 
        loss_coef='const(1.0)', 
        temperature=optuna_trial.suggest_float('info_nce_loss.temperature', 0.01, 0.5)
    )
    
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Лучший результат имеет trial 22 (18d_world_model_07:38) `ssim=0.927907049190253`:
# - `batch_size=128`
# - `learn_rate=0.0017728410259359208`
# - `info_nce_loss.temperature=0.1822801464493423`
#
# <img src="./img/ssim.png">
#
# **Выводы**
# 1) показано к употреблению
# 2) посмотреть, что теперь с MSE будет

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18d_world_model_07.ipynb',
#  'target_notebook_name': '18d_world_model_07',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18d_study_14.1/18d_study_14.1.ipynb',
#  'optuna_study_name': '18d_study_14.1',
#  'optuna_study_serial': '14.1',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18d_study_14.1/18d_study_14.1.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 100
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-09 21:46:46,333] A new study created in Journal with name: 18d_study_14.1
# 2026.09.09-21:46:46.729610     0.205 >> Model instance registered, version=16
# 2026.09.09-21:46:46.740251     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch16.ipynb"
# 2026.09.09-21:46:46.740601     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:16"; running launches=1
# 2026.09.09-21:47:17.701719     0.147 >> Model instance registered, version=17
# 2026.09.09-21:47:17.715871     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch17.ipynb"
# 2026.09.09-21:47:17.716370     0.006 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:17"; running launches=2
# 2026.09.09-21:47:48.631510     0.216 >> Model instance registered, version=18
# 2026.09.09-21:47:48.649596     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch18.ipynb"
# 2026.09.09-21:47:48.649908     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:18"; running launches=3
# 2026.09.09-21:50:03.209224     0.175 >> Model instance registered, version=19
# 2026.09.09-21:50:03.225260     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch19.ipynb"
# 2026.09.09-21:50:03.225503     0.006 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:19"; running launches=4
# 2026.09.09-21:50:34.489758     0.177 >> Model instance registered, version=20
# 2026.09.09-21:50:34.500595     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch20.ipynb"
# 2026.09.09-21:50:34.500859     0.005 >> 3.0 idle runners exist, submitted launch "18d_world_model_07:20"; running launches=5
# 2026.09.09-21:51:05.707605     0.161 >> Model instance registered, version=21
# 2026.09.09-21:51:05.716750     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch21.ipynb"
# 2026.09.09-21:51:05.716989     0.004 >> 3.0 idle runners exist, submitted launch "18d_world_model_07:21"; running launches=6
# 2026.09.09-21:51:37.561473     0.171 >> Model instance registered, version=22
# 2026.09.09-21:51:37.574641     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch22.ipynb"
# 2026.09.09-21:51:37.574916     0.005 >> 2.0 idle runners exist, submitted launch "18d_world_model_07:22"; running launches=7
# 2026.09.09-21:52:08.436962     0.174 >> Model instance registered, version=23
# 2026.09.09-21:52:08.452422     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch23.ipynb"
# 2026.09.09-21:52:08.452911     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:23"; running launches=8
# 2026.09.09-21:54:41.087412     2.091 >> Trial 1 (18d_world_model_07:17) finished with value: 0.8408757206052542 and parameters: {'batch_size': 256, 'learn_rate': 0.0007609697905160153, 'info_nce_loss.temperature': 0.07896838380133843}. Best is trial 1 with value: 0.8408757206052542
# 2026.09.09-21:54:44.118413     0.002 >> Launch "18d_world_model_07:17" completed
# 2026.09.09-21:54:44.119272     0.001 >> 1 (+1) launches completed; running launches=7
# 2026.09.09-21:55:10.207456     0.152 >> Model instance registered, version=24
# 2026.09.09-21:55:10.217243     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:24"; running launches=8
# 2026.09.09-21:55:10.217390     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch24.ipynb"
# 2026.09.09-22:01:07.121508     1.077 >> Trial 3 (18d_world_model_07:19) finished with value: 0.8996261139400303 and parameters: {'batch_size': 128, 'learn_rate': 0.009667866683705622, 'info_nce_loss.temperature': 0.3613976672115377}. Best is trial 3 with value: 0.8996261139400303
# 2026.09.09-22:01:11.165845     0.002 >> Launch "18d_world_model_07:19" completed
# 2026.09.09-22:01:11.166787     0.001 >> 2 (+1) launches completed; running launches=7
# 2026.09.09-22:01:57.382380     0.192 >> Model instance registered, version=25
# 2026.09.09-22:01:57.396857     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:25"; running launches=8
# 2026.09.09-22:01:57.396999     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch25.ipynb"
# 2026.09.09-22:02:00.742903     3.346 >> Trial 5 (18d_world_model_07:21) finished with value: 0.9235389614477754 and parameters: {'batch_size': 128, 'learn_rate': 0.0021886002998279214, 'info_nce_loss.temperature': 0.41295523996219413}. Best is trial 5 with value: 0.9235389614477754
# 2026.09.09-22:02:02.504761     0.001 >> Launch "18d_world_model_07:21" completed
# 2026.09.09-22:02:02.505254     0.000 >> 3 (+1) launches completed; running launches=7
# 2026.09.09-22:03:11.775401     1.719 >> Trial 8 (18d_world_model_07:24) finished with value: 0.8448796030133963 and parameters: {'batch_size': 256, 'learn_rate': 0.005963095157211399, 'info_nce_loss.temperature': 0.15703963337374888}. Best is trial 5 with value: 0.9235389614477754
# 2026.09.09-22:03:15.166118     0.001 >> Launch "18d_world_model_07:24" completed
# 2026.09.09-22:03:15.166548     0.000 >> 4 (+1) launches completed; running launches=6
# 2026.09.09-22:03:20.818231     0.444 >> Trial 0 (18d_world_model_07:16) finished with value: 0.9093210499268025 and parameters: {'batch_size': 64, 'learn_rate': 0.0014531302033484199, 'info_nce_loss.temperature': 0.32015534829554937}. Best is trial 5 with value: 0.9235389614477754
# 2026.09.09-22:03:25.494242     0.002 >> Launch "18d_world_model_07:16" completed
# 2026.09.09-22:03:25.495350     0.001 >> 5 (+1) launches completed; running launches=5
# 2026.09.09-22:03:30.782953     0.178 >> Model instance registered, version=26
# 2026.09.09-22:03:30.797904     0.006 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:26"; running launches=6
# 2026.09.09-22:03:30.798573     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch26.ipynb"
# 2026.09.09-22:04:01.772168     0.187 >> Model instance registered, version=27
# 2026.09.09-22:04:01.783838     0.006 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:27"; running launches=7
# 2026.09.09-22:04:01.783955     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch27.ipynb"
# 2026.09.09-22:06:52.734433     0.259 >> Trial 2 (18d_world_model_07:18) finished with value: 0.903666659956798 and parameters: {'batch_size': 64, 'learn_rate': 0.00130551480475449, 'info_nce_loss.temperature': 0.20066615690654757}. Best is trial 5 with value: 0.9235389614477754
# 2026.09.09-22:06:57.595023     0.001 >> Launch "18d_world_model_07:18" completed
# 2026.09.09-22:06:57.596119     0.001 >> 6 (+1) launches completed; running launches=6
# 2026.09.09-22:07:19.337909     0.177 >> Model instance registered, version=28
# 2026.09.09-22:07:19.353096     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:28"; running launches=7
# 2026.09.09-22:07:19.353334     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch28.ipynb"
# 2026.09.09-22:08:46.631820     0.173 >> Model instance registered, version=29
# 2026.09.09-22:08:46.641806     0.004 >> 1.3 idle runners exist, submitted launch "18d_world_model_07:29"; running launches=8
# 2026.09.09-22:08:46.641920     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch29.ipynb"
# 2026.09.09-22:09:17.493141     0.170 >> Model instance registered, version=30
# 2026.09.09-22:09:17.503821     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch30.ipynb"
# 2026.09.09-22:09:17.504014     0.004 >> 3.7 idle runners exist, submitted launch "18d_world_model_07:30"; running launches=9
# 2026.09.09-22:09:39.601404     1.634 >> Trial 6 (18d_world_model_07:22) finished with value: 0.801594375865534 and parameters: {'batch_size': 64, 'learn_rate': 0.006179303241420388, 'info_nce_loss.temperature': 0.08343475898233502}. Best is trial 5 with value: 0.9235389614477754
# 2026.09.09-22:09:43.081580     0.001 >> Launch "18d_world_model_07:22" completed
# 2026.09.09-22:09:43.082408     0.001 >> 7 (+1) launches completed; running launches=8
# 2026.09.09-22:09:48.641312     0.223 >> Model instance registered, version=31
# 2026.09.09-22:09:48.653592     0.005 >> 2.8 idle runners exist, submitted launch "18d_world_model_07:31"; running launches=9
# 2026.09.09-22:09:48.653708     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch31.ipynb"
# 2026.09.09-22:10:19.914541     0.174 >> Model instance registered, version=32
# 2026.09.09-22:10:19.928264     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch32.ipynb"
# 2026.09.09-22:10:19.928538     0.005 >> 2.7 idle runners exist, submitted launch "18d_world_model_07:32"; running launches=10
# 2026.09.09-22:10:50.764944     0.149 >> Model instance registered, version=33
# 2026.09.09-22:10:50.775100     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch33.ipynb"
# 2026.09.09-22:10:50.775316     0.004 >> 3.7 idle runners exist, submitted launch "18d_world_model_07:33"; running launches=11
# 2026.09.09-22:11:22.158993     0.162 >> Model instance registered, version=34
# 2026.09.09-22:11:22.172908     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch34.ipynb"
# 2026.09.09-22:11:22.173111     0.006 >> 4.7 idle runners exist, submitted launch "18d_world_model_07:34"; running launches=12
# 2026.09.09-22:11:31.932909     4.641 >> Trial 10 (18d_world_model_07:26) finished with value: 0.8024927256628871 and parameters: {'batch_size': 256, 'learn_rate': 0.005600782330495874, 'info_nce_loss.temperature': 0.2876086153112376}. Best is trial 5 with value: 0.9235389614477754
# 2026.09.09-22:11:32.400480     0.001 >> Launch "18d_world_model_07:26" completed
# 2026.09.09-22:11:32.400956     0.000 >> 8 (+1) launches completed; running launches=11
# 2026.09.09-22:11:53.104027     0.159 >> Model instance registered, version=35
# 2026.09.09-22:11:53.119479     0.007 >> 4.3 idle runners exist, submitted launch "18d_world_model_07:35"; running launches=12
# 2026.09.09-22:11:53.119775     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch35.ipynb"
# 2026.09.09-22:12:24.613620     0.149 >> Model instance registered, version=36
# 2026.09.09-22:12:24.628375     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch36.ipynb"
# 2026.09.09-22:12:24.628648     0.007 >> 3.7 idle runners exist, submitted launch "18d_world_model_07:36"; running launches=13
# 2026.09.09-22:12:56.185728     0.186 >> Model instance registered, version=37
# 2026.09.09-22:12:56.200996     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch37.ipynb"
# 2026.09.09-22:12:56.201570     0.008 >> 2.5 idle runners exist, submitted launch "18d_world_model_07:37"; running launches=14
# 2026.09.09-22:13:05.395328     4.076 >> Trial 9 (18d_world_model_07:25) finished with value: 0.8500860100612044 and parameters: {'batch_size': 128, 'learn_rate': 0.008753597915220825, 'info_nce_loss.temperature': 0.1340521395802508}. Best is trial 5 with value: 0.9235389614477754
# 2026.09.09-22:13:06.434686     0.002 >> Launch "18d_world_model_07:25" completed
# 2026.09.09-22:13:06.435834     0.001 >> 9 (+1) launches completed; running launches=13
# 2026.09.09-22:13:27.765784     0.228 >> Model instance registered, version=38
# 2026.09.09-22:13:27.776968     0.004 >> 2.5 idle runners exist, submitted launch "18d_world_model_07:38"; running launches=14
# 2026.09.09-22:13:27.777069     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch38.ipynb"
# 2026.09.09-22:13:58.635627     0.152 >> Model instance registered, version=39
# 2026.09.09-22:13:58.650418     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch39.ipynb"
# 2026.09.09-22:13:58.650746     0.007 >> 1.8 idle runners exist, submitted launch "18d_world_model_07:39"; running launches=15
# 2026.09.09-22:14:24.866716     0.181 >> Trial 11 (18d_world_model_07:27) finished with value: 0.8900072136893868 and parameters: {'batch_size': 128, 'learn_rate': 0.00958555379675654, 'info_nce_loss.temperature': 0.38608065308319733}. Best is trial 5 with value: 0.9235389614477754
# 2026.09.09-22:14:29.809329     0.002 >> Launch "18d_world_model_07:27" completed
# 2026.09.09-22:14:29.810635     0.001 >> 10 (+1) launches completed; running launches=14
# 2026.09.09-22:14:50.579070     0.117 >> Model instance registered, version=40
# 2026.09.09-22:14:50.597044     0.008 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:40"; running launches=15
# 2026.09.09-22:14:50.597196     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch40.ipynb"
# 2026.09.09-22:15:11.831047     0.647 >> Trial 16 (18d_world_model_07:32) finished with value: 0.588903060182929 and parameters: {'batch_size': 256, 'learn_rate': 0.004289279315142209, 'info_nce_loss.temperature': 0.40053617141450826}. Best is trial 5 with value: 0.9235389614477754
# 2026.09.09-22:15:16.302390     0.001 >> Launch "18d_world_model_07:32" completed
# 2026.09.09-22:15:16.303510     0.001 >> 11 (+1) launches completed; running launches=14
# 2026.09.09-22:15:21.614431     0.193 >> Model instance registered, version=41
# 2026.09.09-22:15:21.628441     0.006 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:41"; running launches=15
# 2026.09.09-22:15:21.628629     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch41.ipynb"
# 2026.09.09-22:16:32.580656     0.300 >> Trial 18 (18d_world_model_07:34) finished with value: 0.7484482219442725 and parameters: {'batch_size': 256, 'learn_rate': 0.0038336122345106432, 'info_nce_loss.temperature': 0.03873069784982055}. Best is trial 5 with value: 0.9235389614477754
# 2026.09.09-22:16:35.421017     2.840 >> Trial 13 (18d_world_model_07:29) finished with value: 0.9251743583008647 and parameters: {'batch_size': 128, 'learn_rate': 0.0014192833041708015, 'info_nce_loss.temperature': 0.2921068587917522}. Best is trial 13 with value: 0.9251743583008647
# 2026.09.09-22:16:37.806271     0.002 >> Launch "18d_world_model_07:29" completed
# 2026.09.09-22:16:37.806783     0.001 >> Launch "18d_world_model_07:34" completed
# 2026.09.09-22:16:37.807200     0.000 >> 13 (+2) launches completed; running launches=13
# 2026.09.09-22:16:48.356956     0.330 >> Model instance registered, version=42
# 2026.09.09-22:16:48.379334     0.010 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:42"; running launches=14
# 2026.09.09-22:16:48.379499     0.010 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch42.ipynb"
# 2026.09.09-22:16:49.257934     0.878 >> Trial 4 (18d_world_model_07:20) finished with value: 0.514061214402318 and parameters: {'batch_size': 128, 'learn_rate': 0.000698194677644167, 'info_nce_loss.temperature': 0.41424491824306386}. Best is trial 13 with value: 0.9251743583008647
# 2026.09.09-22:16:53.159104     3.901 >> Trial 17 (18d_world_model_07:33) finished with value: 0.7592662684619427 and parameters: {'batch_size': 256, 'learn_rate': 0.005374411724707671, 'info_nce_loss.temperature': 0.26585349625235954}. Best is trial 13 with value: 0.9251743583008647
# 2026.09.09-22:16:53.607462     0.001 >> Launch "18d_world_model_07:33" completed
# 2026.09.09-22:16:53.607956     0.000 >> Launch "18d_world_model_07:20" completed
# 2026.09.09-22:16:53.608246     0.000 >> 15 (+2) launches completed; running launches=12
# 2026.09.09-22:17:19.363453     0.199 >> Model instance registered, version=43
# 2026.09.09-22:17:19.373438     0.005 >> 4.0 idle runners exist, submitted launch "18d_world_model_07:43"; running launches=13
# 2026.09.09-22:17:19.373555     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch43.ipynb"
# 2026.09.09-22:17:54.391531     0.268 >> Model instance registered, version=44
# 2026.09.09-22:17:54.402114     0.004 >> 2.7 idle runners exist, submitted launch "18d_world_model_07:44"; running launches=14
# 2026.09.09-22:17:54.402235     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch44.ipynb"
# 2026.09.09-22:19:17.081026     0.419 >> Trial 7 (18d_world_model_07:23) finished with value: 0.8772439055610448 and parameters: {'batch_size': 64, 'learn_rate': 0.004569738867636124, 'info_nce_loss.temperature': 0.40292621967174697}. Best is trial 13 with value: 0.9251743583008647
# 2026.09.09-22:19:21.781316     0.001 >> Launch "18d_world_model_07:23" completed
# 2026.09.09-22:19:21.782136     0.001 >> 16 (+1) launches completed; running launches=13
# 2026.09.09-22:19:42.384533     0.164 >> Model instance registered, version=45
# 2026.09.09-22:19:42.398393     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:45"; running launches=14
# 2026.09.09-22:19:42.398552     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch45.ipynb"
# 2026.09.09-22:19:47.758794     0.251 >> Trial 22 (18d_world_model_07:38) finished with value: 0.927907049190253 and parameters: {'batch_size': 128, 'learn_rate': 0.0017728410259359208, 'info_nce_loss.temperature': 0.1822801464493423}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:19:52.626650     0.002 >> Launch "18d_world_model_07:38" completed
# 2026.09.09-22:19:52.628339     0.002 >> 17 (+1) launches completed; running launches=13
# 2026.09.09-22:20:13.679768     0.177 >> Model instance registered, version=46
# 2026.09.09-22:20:13.694465     0.006 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:46"; running launches=14
# 2026.09.09-22:20:13.694622     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch46.ipynb"
# 2026.09.09-22:20:58.452465     2.834 >> Trial 14 (18d_world_model_07:30) finished with value: 0.892325516557321 and parameters: {'batch_size': 64, 'learn_rate': 0.009054959303132907, 'info_nce_loss.temperature': 0.33812609202219285}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:21:00.732395     0.001 >> Launch "18d_world_model_07:30" completed
# 2026.09.09-22:21:00.733177     0.001 >> 18 (+1) launches completed; running launches=13
# 2026.09.09-22:21:04.776984     4.044 >> Trial 24 (18d_world_model_07:40) finished with value: 0.7603983720764518 and parameters: {'batch_size': 128, 'learn_rate': 0.003531074992248988, 'info_nce_loss.temperature': 0.46050965805152155}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:21:05.933605     0.002 >> Launch "18d_world_model_07:40" completed
# 2026.09.09-22:21:05.934557     0.001 >> 19 (+1) launches completed; running launches=12
# 2026.09.09-22:21:11.205915     0.158 >> Model instance registered, version=47
# 2026.09.09-22:21:11.223023     0.008 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:47"; running launches=13
# 2026.09.09-22:21:11.223389     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch47.ipynb"
# 2026.09.09-22:21:42.607212     0.263 >> Model instance registered, version=48
# 2026.09.09-22:21:42.618679     0.004 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:48"; running launches=14
# 2026.09.09-22:21:42.618840     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch48.ipynb"
# 2026.09.09-22:21:44.595548     1.977 >> Trial 19 (18d_world_model_07:35) finished with value: 0.8630246385000646 and parameters: {'batch_size': 64, 'learn_rate': 0.007945837698943201, 'info_nce_loss.temperature': 0.39514936907251413}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:21:47.733600     0.001 >> Launch "18d_world_model_07:35" completed
# 2026.09.09-22:21:47.734387     0.001 >> 20 (+1) launches completed; running launches=13
# 2026.09.09-22:22:13.459788     0.170 >> Model instance registered, version=49
# 2026.09.09-22:22:13.479467     0.009 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:49"; running launches=14
# 2026.09.09-22:22:13.479615     0.009 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch49.ipynb"
# 2026.09.09-22:22:44.241486     0.090 >> Model instance registered, version=50
# 2026.09.09-22:22:44.255645     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:50"; running launches=15
# 2026.09.09-22:22:44.255774     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch50.ipynb"
# 2026.09.09-22:22:45.044593     0.789 >> Trial 26 (18d_world_model_07:42) finished with value: 0.901519282720983 and parameters: {'batch_size': 128, 'learn_rate': 0.002776326727160613, 'info_nce_loss.temperature': 0.4946883154102546}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:22:49.365426     0.001 >> Launch "18d_world_model_07:42" completed
# 2026.09.09-22:22:49.365975     0.001 >> 21 (+1) launches completed; running launches=14
# 2026.09.09-22:23:36.841078     0.393 >> Trial 20 (18d_world_model_07:36) finished with value: 0.8359507280401886 and parameters: {'batch_size': 64, 'learn_rate': 0.002531426148283881, 'info_nce_loss.temperature': 0.17849903768681225}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:23:41.560314     0.001 >> Launch "18d_world_model_07:36" completed
# 2026.09.09-22:23:41.561143     0.001 >> 22 (+1) launches completed; running launches=13
# 2026.09.09-22:23:55.027871     3.240 >> Trial 21 (18d_world_model_07:37) finished with value: 0.8365806075744331 and parameters: {'batch_size': 128, 'learn_rate': 0.004971862468145915, 'info_nce_loss.temperature': 0.23302140388237158}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:23:57.191729     0.195 >> Model instance registered, version=51
# 2026.09.09-22:23:57.202111     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:51"; running launches=14
# 2026.09.09-22:23:57.202253     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch51.ipynb"
# 2026.09.09-22:23:57.202684     0.001 >> Launch "18d_world_model_07:37" completed
# 2026.09.09-22:23:57.203648     0.001 >> 23 (+1) launches completed; running launches=13
# 2026.09.09-22:24:15.870459     3.322 >> Trial 12 (18d_world_model_07:28) finished with value: 0.7741142362356186 and parameters: {'batch_size': 256, 'learn_rate': 0.009674353489400798, 'info_nce_loss.temperature': 0.03391841978937931}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:24:17.658538     0.001 >> Launch "18d_world_model_07:28" completed
# 2026.09.09-22:24:17.659151     0.001 >> 24 (+1) launches completed; running launches=12
# 2026.09.09-22:24:28.122376     0.245 >> Model instance registered, version=52
# 2026.09.09-22:24:28.136425     0.006 >> 2.3 idle runners exist, submitted launch "18d_world_model_07:52"; running launches=13
# 2026.09.09-22:24:28.136583     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch52.ipynb"
# 2026.09.09-22:24:30.022385     1.886 >> Trial 23 (18d_world_model_07:39) finished with value: 0.8868815056048334 and parameters: {'batch_size': 128, 'learn_rate': 0.0028638170458805115, 'info_nce_loss.temperature': 0.19609407766508838}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:24:33.253226     0.001 >> Launch "18d_world_model_07:39" completed
# 2026.09.09-22:24:33.253842     0.001 >> 25 (+1) launches completed; running launches=12
# 2026.09.09-22:24:41.219541     2.857 >> Trial 27 (18d_world_model_07:43) finished with value: 0.7958289221860468 and parameters: {'batch_size': 128, 'learn_rate': 0.0029812379865874084, 'info_nce_loss.temperature': 0.4902655879407605}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:24:43.472599     0.001 >> Launch "18d_world_model_07:43" completed
# 2026.09.09-22:24:43.473121     0.001 >> 26 (+1) launches completed; running launches=11
# 2026.09.09-22:24:59.003460     0.187 >> Model instance registered, version=53
# 2026.09.09-22:24:59.017776     0.006 >> 3.7 idle runners exist, submitted launch "18d_world_model_07:53"; running launches=12
# 2026.09.09-22:24:59.018015     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch53.ipynb"
# 2026.09.09-22:25:09.333829     0.014 >> Trial 28 (18d_world_model_07:44) finished with value: 0.9046406224370003 and parameters: {'batch_size': 128, 'learn_rate': 0.002757998081459767, 'info_nce_loss.temperature': 0.48656205720738965}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:25:09.334743     0.001 >> Launch "18d_world_model_07:44" completed
# 2026.09.09-22:25:09.335077     0.000 >> 27 (+1) launches completed; running launches=11
# 2026.09.09-22:25:29.964163     0.176 >> Model instance registered, version=54
# 2026.09.09-22:25:29.974781     0.004 >> 3.8 idle runners exist, submitted launch "18d_world_model_07:54"; running launches=12
# 2026.09.09-22:25:29.974888     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch54.ipynb"
# 2026.09.09-22:26:01.722729     0.172 >> Model instance registered, version=55
# 2026.09.09-22:26:01.735467     0.005 >> 3.3 idle runners exist, submitted launch "18d_world_model_07:55"; running launches=13
# 2026.09.09-22:26:01.735632     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch55.ipynb"
# 2026.09.09-22:26:33.375269     0.198 >> Model instance registered, version=56
# 2026.09.09-22:26:33.391418     0.007 >> 2.8 idle runners exist, submitted launch "18d_world_model_07:56"; running launches=14
# 2026.09.09-22:26:33.391678     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch56.ipynb"
# 2026.09.09-22:27:04.955674     0.183 >> Model instance registered, version=57
# 2026.09.09-22:27:04.967852     0.004 >> 2.0 idle runners exist, submitted launch "18d_world_model_07:57"; running launches=15
# 2026.09.09-22:27:04.967956     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch57.ipynb"
# 2026.09.09-22:27:12.123541     2.049 >> Trial 30 (18d_world_model_07:46) finished with value: 0.8216928103938699 and parameters: {'batch_size': 128, 'learn_rate': 0.00320497385285218, 'info_nce_loss.temperature': 0.4986137995749961}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:27:15.181545     0.001 >> Launch "18d_world_model_07:46" completed
# 2026.09.09-22:27:15.182027     0.000 >> 28 (+1) launches completed; running launches=14
# 2026.09.09-22:27:36.960419     0.156 >> Model instance registered, version=58
# 2026.09.09-22:27:36.974518     0.005 >> 2.3 idle runners exist, submitted launch "18d_world_model_07:58"; running launches=15
# 2026.09.09-22:27:36.974734     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch58.ipynb"
# 2026.09.09-22:28:08.818747     0.096 >> Model instance registered, version=59
# 2026.09.09-22:28:08.828506     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch59.ipynb"
# 2026.09.09-22:28:08.828739     0.005 >> 1.8 idle runners exist, submitted launch "18d_world_model_07:59"; running launches=16
# 2026.09.09-22:28:18.114480     4.172 >> Trial 31 (18d_world_model_07:47) finished with value: 0.8845495306886733 and parameters: {'batch_size': 128, 'learn_rate': 0.002603893342070857, 'info_nce_loss.temperature': 0.20890776779515535}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:28:19.335423     0.003 >> Launch "18d_world_model_07:47" completed
# 2026.09.09-22:28:19.336659     0.001 >> 29 (+1) launches completed; running launches=15
# 2026.09.09-22:28:47.821530     2.809 >> Trial 32 (18d_world_model_07:48) finished with value: 0.8640812947414815 and parameters: {'batch_size': 128, 'learn_rate': 0.00278007937148673, 'info_nce_loss.temperature': 0.22440042478235994}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:28:50.732573     0.002 >> Launch "18d_world_model_07:48" completed
# 2026.09.09-22:28:50.733028     0.000 >> 30 (+1) launches completed; running launches=14
# 2026.09.09-22:29:16.615929     0.081 >> Model instance registered, version=60
# 2026.09.09-22:29:16.630293     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:60"; running launches=15
# 2026.09.09-22:29:16.630439     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch60.ipynb"
# 2026.09.09-22:29:18.963871     2.333 >> Trial 33 (18d_world_model_07:49) finished with value: 0.8736427403055131 and parameters: {'batch_size': 128, 'learn_rate': 0.002826418939823293, 'info_nce_loss.temperature': 0.21457645871384065}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:29:21.739283     0.001 >> Launch "18d_world_model_07:49" completed
# 2026.09.09-22:29:21.740028     0.001 >> 31 (+1) launches completed; running launches=14
# 2026.09.09-22:29:38.639891     1.117 >> Trial 34 (18d_world_model_07:50) finished with value: 0.8754581431858242 and parameters: {'batch_size': 128, 'learn_rate': 0.0028217313941932233, 'info_nce_loss.temperature': 0.2207859909277349}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:29:42.634019     0.001 >> Launch "18d_world_model_07:50" completed
# 2026.09.09-22:29:42.634780     0.001 >> 32 (+1) launches completed; running launches=13
# 2026.09.09-22:29:47.909543     0.168 >> Model instance registered, version=61
# 2026.09.09-22:29:47.920833     0.005 >> 1.8 idle runners exist, submitted launch "18d_world_model_07:61"; running launches=14
# 2026.09.09-22:29:47.921079     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch61.ipynb"
# 2026.09.09-22:30:19.351756     0.186 >> Model instance registered, version=62
# 2026.09.09-22:30:19.366210     0.006 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:62"; running launches=15
# 2026.09.09-22:30:19.366429     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch62.ipynb"
# 2026.09.09-22:30:26.099316     1.619 >> Trial 29 (18d_world_model_07:45) finished with value: 0.9002277189865708 and parameters: {'batch_size': 128, 'learn_rate': 0.0027004949851798373, 'info_nce_loss.temperature': 0.49069875868489804}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:30:29.589483     0.001 >> Launch "18d_world_model_07:45" completed
# 2026.09.09-22:30:29.589943     0.000 >> 33 (+1) launches completed; running launches=14
# 2026.09.09-22:30:50.390811     0.160 >> Model instance registered, version=63
# 2026.09.09-22:30:50.403348     0.004 >> 1.8 idle runners exist, submitted launch "18d_world_model_07:63"; running launches=15
# 2026.09.09-22:30:50.403498     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch63.ipynb"
# 2026.09.09-22:31:22.132520     0.178 >> Model instance registered, version=64
# 2026.09.09-22:31:22.142079     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:64"; running launches=16
# 2026.09.09-22:31:22.142225     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch64.ipynb"
# 2026.09.09-22:32:52.998287     2.921 >> Trial 38 (18d_world_model_07:54) finished with value: 0.9268017401918769 and parameters: {'batch_size': 128, 'learn_rate': 0.0018104655991304406, 'info_nce_loss.temperature': 0.29214655783658783}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:32:55.213054     0.003 >> Launch "18d_world_model_07:54" completed
# 2026.09.09-22:32:55.214020     0.001 >> 34 (+1) launches completed; running launches=15
# 2026.09.09-22:33:05.036850     4.716 >> Trial 25 (18d_world_model_07:41) finished with value: 0.8675643543247133 and parameters: {'batch_size': 64, 'learn_rate': 0.0027729221670343166, 'info_nce_loss.temperature': 0.4564060688703699}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:33:05.436262     0.002 >> Launch "18d_world_model_07:41" completed
# 2026.09.09-22:33:05.437229     0.001 >> 35 (+1) launches completed; running launches=14
# 2026.09.09-22:33:07.485754     2.049 >> Trial 40 (18d_world_model_07:56) finished with value: 0.48622972099110484 and parameters: {'batch_size': 128, 'learn_rate': 0.00022157224856519204, 'info_nce_loss.temperature': 0.3167809171612568}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:33:10.788702     0.003 >> Launch "18d_world_model_07:56" completed
# 2026.09.09-22:33:10.789796     0.001 >> 36 (+1) launches completed; running launches=13
# 2026.09.09-22:33:21.185587     0.164 >> Model instance registered, version=65
# 2026.09.09-22:33:21.196315     0.005 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:65"; running launches=14
# 2026.09.09-22:33:21.196664     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch65.ipynb"
# 2026.09.09-22:33:54.637990     0.180 >> Model instance registered, version=66
# 2026.09.09-22:33:54.652411     0.006 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:66"; running launches=15
# 2026.09.09-22:33:54.652567     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch66.ipynb"
# 2026.09.09-22:34:25.693195     0.226 >> Model instance registered, version=67
# 2026.09.09-22:34:25.712425     0.008 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:67"; running launches=16
# 2026.09.09-22:34:25.712562     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch67.ipynb"
# 2026.09.09-22:34:30.992964     0.157 >> Trial 43 (18d_world_model_07:59) finished with value: 0.9184602750465274 and parameters: {'batch_size': 128, 'learn_rate': 0.001964602387992704, 'info_nce_loss.temperature': 0.3017664962289083}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:34:35.952294     0.002 >> Launch "18d_world_model_07:59" completed
# 2026.09.09-22:34:35.953353     0.001 >> 37 (+1) launches completed; running launches=15
# 2026.09.09-22:34:57.227143     0.250 >> Model instance registered, version=68
# 2026.09.09-22:34:57.239444     0.006 >> 2.0 idle runners exist, submitted launch "18d_world_model_07:68"; running launches=16
# 2026.09.09-22:34:57.240014     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch68.ipynb"
# 2026.09.09-22:35:02.929916     0.496 >> Trial 42 (18d_world_model_07:58) finished with value: 0.9121148274280131 and parameters: {'batch_size': 128, 'learn_rate': 0.0018703577547666019, 'info_nce_loss.temperature': 0.29498883143219207}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:35:02.945996     0.016 >> Trial 41 (18d_world_model_07:57) finished with value: 0.6340908329002559 and parameters: {'batch_size': 128, 'learn_rate': 0.00011468038160812838, 'info_nce_loss.temperature': 0.3061209816304998}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:35:07.544689     0.001 >> Launch "18d_world_model_07:58" completed
# 2026.09.09-22:35:07.545123     0.000 >> Launch "18d_world_model_07:57" completed
# 2026.09.09-22:35:07.545501     0.000 >> 39 (+2) launches completed; running launches=14
# 2026.09.09-22:35:22.280386     4.512 >> Trial 44 (18d_world_model_07:60) finished with value: 0.8983520013280213 and parameters: {'batch_size': 128, 'learn_rate': 0.001831840824922564, 'info_nce_loss.temperature': 0.2987682413141556}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:35:23.156557     0.002 >> Launch "18d_world_model_07:60" completed
# 2026.09.09-22:35:23.157661     0.001 >> 40 (+1) launches completed; running launches=13
# 2026.09.09-22:35:28.493986     0.224 >> Model instance registered, version=69
# 2026.09.09-22:35:28.503683     0.004 >> 3.5 idle runners exist, submitted launch "18d_world_model_07:69"; running launches=14
# 2026.09.09-22:35:28.503936     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch69.ipynb"
# 2026.09.09-22:35:32.649190     4.145 >> Trial 36 (18d_world_model_07:52) finished with value: 0.9038095399737358 and parameters: {'batch_size': 128, 'learn_rate': 0.0018615422220793882, 'info_nce_loss.temperature': 0.2950662927033644}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:35:34.046309     0.001 >> Launch "18d_world_model_07:52" completed
# 2026.09.09-22:35:34.046809     0.001 >> 41 (+1) launches completed; running launches=13
# 2026.09.09-22:35:59.838165     0.211 >> Model instance registered, version=70
# 2026.09.09-22:35:59.851216     0.004 >> 3.7 idle runners exist, submitted launch "18d_world_model_07:70"; running launches=14
# 2026.09.09-22:35:59.851793     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch70.ipynb"
# 2026.09.09-22:36:31.646646     0.221 >> Model instance registered, version=71
# 2026.09.09-22:36:31.660557     0.005 >> 2.8 idle runners exist, submitted launch "18d_world_model_07:71"; running launches=15
# 2026.09.09-22:36:31.660957     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch71.ipynb"
# 2026.09.09-22:37:02.723928     0.195 >> Model instance registered, version=72
# 2026.09.09-22:37:02.740393     0.006 >> 1.8 idle runners exist, submitted launch "18d_world_model_07:72"; running launches=16
# 2026.09.09-22:37:02.741051     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch72.ipynb"
# 2026.09.09-22:37:28.625153     0.053 >> Trial 37 (18d_world_model_07:53) finished with value: 0.9275282113812864 and parameters: {'batch_size': 128, 'learn_rate': 0.0017021622459852334, 'info_nce_loss.temperature': 0.24172814180223837}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:37:28.626118     0.001 >> Launch "18d_world_model_07:53" completed
# 2026.09.09-22:37:28.626686     0.001 >> 42 (+1) launches completed; running launches=15
# 2026.09.09-22:37:33.916436     0.174 >> Model instance registered, version=73
# 2026.09.09-22:37:33.925547     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:73"; running launches=16
# 2026.09.09-22:37:33.925691     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch73.ipynb"
# 2026.09.09-22:38:04.946250     0.193 >> Model instance registered, version=74
# 2026.09.09-22:38:04.958419     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch74.ipynb"
# 2026.09.09-22:38:04.958641     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:74"; running launches=17
# 2026.09.09-22:39:12.242817     0.144 >> Trial 45 (18d_world_model_07:61) finished with value: 0.9189421583432704 and parameters: {'batch_size': 64, 'learn_rate': 0.0015843428194524268, 'info_nce_loss.temperature': 0.31165972923670826}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:39:17.213420     0.001 >> Launch "18d_world_model_07:61" completed
# 2026.09.09-22:39:17.214321     0.001 >> 43 (+1) launches completed; running launches=16
# 2026.09.09-22:39:20.893482     3.679 >> Trial 49 (18d_world_model_07:65) finished with value: 0.8966014347970486 and parameters: {'batch_size': 128, 'learn_rate': 0.0019098503563821016, 'info_nce_loss.temperature': 0.29157252129276257}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:39:22.331604     0.001 >> Launch "18d_world_model_07:65" completed
# 2026.09.09-22:39:22.332323     0.001 >> 44 (+1) launches completed; running launches=15
# 2026.09.09-22:39:48.042825     0.083 >> Model instance registered, version=75
# 2026.09.09-22:39:48.056971     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:75"; running launches=16
# 2026.09.09-22:39:48.057149     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch75.ipynb"
# 2026.09.09-22:40:20.522531     0.185 >> Model instance registered, version=76
# 2026.09.09-22:40:20.537604     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:76"; running launches=17
# 2026.09.09-22:40:20.537792     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch76.ipynb"
# 2026.09.09-22:41:15.638332     3.788 >> Trial 52 (18d_world_model_07:68) finished with value: 0.8921671560965478 and parameters: {'batch_size': 128, 'learn_rate': 0.0012610529932270886, 'info_nce_loss.temperature': 0.26331690139893915}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:41:16.967585     0.002 >> Launch "18d_world_model_07:68" completed
# 2026.09.09-22:41:16.968380     0.001 >> 45 (+1) launches completed; running launches=16
# 2026.09.09-22:42:05.519623     2.522 >> Trial 47 (18d_world_model_07:63) finished with value: 0.8929221394937485 and parameters: {'batch_size': 64, 'learn_rate': 0.001574043411288735, 'info_nce_loss.temperature': 0.3174493891731903}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:42:07.077373     1.558 >> Trial 51 (18d_world_model_07:67) finished with value: 0.9015318308956921 and parameters: {'batch_size': 128, 'learn_rate': 0.001758417206359669, 'info_nce_loss.temperature': 0.2837128312369242}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:42:08.110736     0.001 >> Launch "18d_world_model_07:63" completed
# 2026.09.09-22:42:08.111674     0.001 >> Launch "18d_world_model_07:67" completed
# 2026.09.09-22:42:08.113176     0.002 >> 47 (+2) launches completed; running launches=14
# 2026.09.09-22:42:15.663697     2.145 >> Trial 54 (18d_world_model_07:70) finished with value: 0.8550346624106169 and parameters: {'batch_size': 128, 'learn_rate': 0.0010611310717140482, 'info_nce_loss.temperature': 0.34591912419906823}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:42:18.823805     0.192 >> Model instance registered, version=77
# 2026.09.09-22:42:18.841922     0.008 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:77"; running launches=15
# 2026.09.09-22:42:18.842202     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch77.ipynb"
# 2026.09.09-22:42:18.842707     0.001 >> Launch "18d_world_model_07:70" completed
# 2026.09.09-22:42:18.843750     0.001 >> 48 (+1) launches completed; running launches=14
# 2026.09.09-22:42:50.294832     0.193 >> Model instance registered, version=78
# 2026.09.09-22:42:50.304484     0.004 >> 2.7 idle runners exist, submitted launch "18d_world_model_07:78"; running launches=15
# 2026.09.09-22:42:50.304631     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch78.ipynb"
# 2026.09.09-22:43:22.114659     0.246 >> Model instance registered, version=79
# 2026.09.09-22:43:22.130673     0.008 >> 2.0 idle runners exist, submitted launch "18d_world_model_07:79"; running launches=16
# 2026.09.09-22:43:22.130805     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch79.ipynb"
# 2026.09.09-22:43:28.340349     1.103 >> Trial 48 (18d_world_model_07:64) finished with value: 0.9060231035109609 and parameters: {'batch_size': 64, 'learn_rate': 0.0017321018350412718, 'info_nce_loss.temperature': 0.31402337663553115}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:43:32.352749     0.003 >> Launch "18d_world_model_07:64" completed
# 2026.09.09-22:43:32.354223     0.001 >> 49 (+1) launches completed; running launches=15
# 2026.09.09-22:43:40.012244     2.547 >> Trial 15 (18d_world_model_07:31) finished with value: 0.8779497174546123 and parameters: {'batch_size': 64, 'learn_rate': 0.008802054940163763, 'info_nce_loss.temperature': 0.36857874805763363}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:43:42.579630     0.001 >> Launch "18d_world_model_07:31" completed
# 2026.09.09-22:43:42.580286     0.001 >> 50 (+1) launches completed; running launches=14
# 2026.09.09-22:43:46.967540     4.387 >> Trial 55 (18d_world_model_07:71) finished with value: 0.8653390412218869 and parameters: {'batch_size': 128, 'learn_rate': 0.0010876438997815404, 'info_nce_loss.temperature': 0.25999915792420886}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:43:47.810381     0.002 >> Launch "18d_world_model_07:71" completed
# 2026.09.09-22:43:47.811237     0.001 >> 51 (+1) launches completed; running launches=13
# 2026.09.09-22:43:53.128633     0.205 >> Model instance registered, version=80
# 2026.09.09-22:43:53.141928     0.005 >> 2.7 idle runners exist, submitted launch "18d_world_model_07:80"; running launches=14
# 2026.09.09-22:43:53.142058     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch80.ipynb"
# 2026.09.09-22:44:16.913569     2.031 >> Trial 35 (18d_world_model_07:51) finished with value: 0.9243269003927708 and parameters: {'batch_size': 128, 'learn_rate': 0.0022257104698213143, 'info_nce_loss.temperature': 0.22753230053380052}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:44:19.989927     0.001 >> Launch "18d_world_model_07:51" completed
# 2026.09.09-22:44:19.990572     0.001 >> 52 (+1) launches completed; running launches=13
# 2026.09.09-22:44:25.311318     0.203 >> Model instance registered, version=81
# 2026.09.09-22:44:25.325630     0.004 >> 3.3 idle runners exist, submitted launch "18d_world_model_07:81"; running launches=14
# 2026.09.09-22:44:25.325810     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch81.ipynb"
# 2026.09.09-22:44:56.494896     0.199 >> Model instance registered, version=82
# 2026.09.09-22:44:56.509647     0.006 >> 3.5 idle runners exist, submitted launch "18d_world_model_07:82"; running launches=15
# 2026.09.09-22:44:56.509764     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch82.ipynb"
# 2026.09.09-22:45:26.676551     4.605 >> Trial 58 (18d_world_model_07:74) finished with value: 0.8666826053522527 and parameters: {'batch_size': 128, 'learn_rate': 0.0009875339669540842, 'info_nce_loss.temperature': 0.26127455070017114}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:45:28.014667     0.196 >> Model instance registered, version=83
# 2026.09.09-22:45:28.027852     0.005 >> 2.2 idle runners exist, submitted launch "18d_world_model_07:83"; running launches=16
# 2026.09.09-22:45:28.027949     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch83.ipynb"
# 2026.09.09-22:45:28.028392     0.001 >> Launch "18d_world_model_07:74" completed
# 2026.09.09-22:45:28.029406     0.001 >> 53 (+1) launches completed; running launches=15
# 2026.09.09-22:46:00.121063     0.192 >> Model instance registered, version=84
# 2026.09.09-22:46:00.131575     0.005 >> 2.8 idle runners exist, submitted launch "18d_world_model_07:84"; running launches=16
# 2026.09.09-22:46:00.131728     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch84.ipynb"
# 2026.09.09-22:46:25.179225     4.598 >> Trial 53 (18d_world_model_07:69) finished with value: 0.9068814548663795 and parameters: {'batch_size': 128, 'learn_rate': 0.0009461990909012646, 'info_nce_loss.temperature': 0.11900958291780771}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:46:25.697077     0.002 >> Launch "18d_world_model_07:69" completed
# 2026.09.09-22:46:25.698077     0.001 >> 54 (+1) launches completed; running launches=15
# 2026.09.09-22:46:30.984191     0.175 >> Model instance registered, version=85
# 2026.09.09-22:46:30.999341     0.007 >> 1.3 idle runners exist, submitted launch "18d_world_model_07:85"; running launches=16
# 2026.09.09-22:46:30.999520     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch85.ipynb"
# 2026.09.09-22:46:45.341285     4.084 >> Trial 59 (18d_world_model_07:75) finished with value: 0.7340192813426256 and parameters: {'batch_size': 128, 'learn_rate': 0.0009920808184852726, 'info_nce_loss.temperature': 0.2555984509753572}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:46:46.372951     0.001 >> Launch "18d_world_model_07:75" completed
# 2026.09.09-22:46:46.373656     0.001 >> 55 (+1) launches completed; running launches=15
# 2026.09.09-22:47:02.878955     0.317 >> Model instance registered, version=86
# 2026.09.09-22:47:02.888656     0.004 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:86"; running launches=16
# 2026.09.09-22:47:02.888758     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch86.ipynb"
# ...
# 2026.09.09-22:50:31.707143     4.793 >> Trial 62 (18d_world_model_07:78) finished with value: 0.9091019630432129 and parameters: {'batch_size': 128, 'learn_rate': 0.0007199443337453013, 'info_nce_loss.temperature': 0.12131809749898284}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:50:32.030173     0.001 >> Launch "18d_world_model_07:78" completed
# 2026.09.09-22:50:32.031016     0.001 >> 61 (+1) launches completed; running launches=16
# 2026.09.09-22:51:00.336886     0.076 >> Model instance registered, version=93
# 2026.09.09-22:51:00.348869     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:93"; running launches=17
# 2026.09.09-22:51:00.349005     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch93.ipynb"
# 2026.09.09-22:51:22.083304     0.329 >> Trial 63 (18d_world_model_07:79) finished with value: 0.7616540938615799 and parameters: {'batch_size': 128, 'learn_rate': 0.0006542348162033131, 'info_nce_loss.temperature': 0.14131688220958305}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:51:26.866435     0.001 >> Launch "18d_world_model_07:79" completed
# 2026.09.09-22:51:26.867063     0.001 >> 62 (+1) launches completed; running launches=16
# 2026.09.09-22:51:47.604065     0.165 >> Model instance registered, version=94
# 2026.09.09-22:51:47.619617     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:94"; running launches=17
# 2026.09.09-22:51:47.619718     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch94.ipynb"
# 2026.09.09-22:52:03.274545     0.318 >> Trial 67 (18d_world_model_07:83) finished with value: 0.6601204928010702 and parameters: {'batch_size': 256, 'learn_rate': 0.0005762604368124429, 'info_nce_loss.temperature': 0.1413186215553358}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:52:08.069842     0.002 >> Launch "18d_world_model_07:83" completed
# 2026.09.09-22:52:08.070745     0.001 >> 63 (+1) launches completed; running launches=16
# 2026.09.09-22:52:18.698599     0.187 >> Model instance registered, version=95
# 2026.09.09-22:52:18.711470     0.005 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:95"; running launches=17
# 2026.09.09-22:52:18.711594     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch95.ipynb"
# 2026.09.09-22:52:28.399307     4.082 >> Trial 69 (18d_world_model_07:85) finished with value: 0.6044611260294914 and parameters: {'batch_size': 256, 'learn_rate': 0.000558317606739652, 'info_nce_loss.temperature': 0.1678226479958205}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:52:29.428424     0.001 >> Launch "18d_world_model_07:85" completed
# 2026.09.09-22:52:29.428942     0.001 >> 64 (+1) launches completed; running launches=16
# 2026.09.09-22:52:59.690962     4.283 >> Trial 66 (18d_world_model_07:82) finished with value: 0.9065053085796535 and parameters: {'batch_size': 128, 'learn_rate': 0.002314808390209566, 'info_nce_loss.temperature': 0.1368593447813248}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:53:00.524548     0.001 >> Launch "18d_world_model_07:82" completed
# 2026.09.09-22:53:00.525575     0.001 >> 65 (+1) launches completed; running launches=15
# 2026.09.09-22:53:14.490617     3.738 >> Trial 70 (18d_world_model_07:86) finished with value: 0.9007450193166733 and parameters: {'batch_size': 256, 'learn_rate': 0.0022794436457996797, 'info_nce_loss.temperature': 0.17026248876291472}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:53:15.868060     0.001 >> Launch "18d_world_model_07:86" completed
# 2026.09.09-22:53:15.869045     0.001 >> 66 (+1) launches completed; running launches=14
# 2026.09.09-22:53:21.160804     0.175 >> Model instance registered, version=96
# 2026.09.09-22:53:21.175277     0.005 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:96"; running launches=15
# 2026.09.09-22:53:21.175434     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch96.ipynb"
# 2026.09.09-22:53:52.260396     0.169 >> Model instance registered, version=97
# 2026.09.09-22:53:52.269744     0.004 >> 1.8 idle runners exist, submitted launch "18d_world_model_07:97"; running launches=16
# 2026.09.09-22:53:52.269967     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch97.ipynb"
# 2026.09.09-22:54:03.837882     1.344 >> Trial 71 (18d_world_model_07:87) finished with value: 0.908024181611836 and parameters: {'batch_size': 256, 'learn_rate': 0.0022362031069499263, 'info_nce_loss.temperature': 0.16496409129685968}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:54:07.605006     0.001 >> Launch "18d_world_model_07:87" completed
# 2026.09.09-22:54:07.605610     0.001 >> 67 (+1) launches completed; running launches=15
# 2026.09.09-22:54:19.783976     1.949 >> Trial 68 (18d_world_model_07:84) finished with value: 0.8969722911715508 and parameters: {'batch_size': 256, 'learn_rate': 0.002259488133251294, 'info_nce_loss.temperature': 0.15444117364824997}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:54:23.697253     0.186 >> Model instance registered, version=98
# 2026.09.09-22:54:23.712017     0.005 >> 1.5 idle runners exist, submitted launch "18d_world_model_07:98"; running launches=16
# 2026.09.09-22:54:23.712202     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch98.ipynb"
# 2026.09.09-22:54:23.712898     0.001 >> Launch "18d_world_model_07:84" completed
# 2026.09.09-22:54:23.713785     0.001 >> 68 (+1) launches completed; running launches=15
# 2026.09.09-22:54:41.790701     2.751 >> Trial 39 (18d_world_model_07:55) finished with value: 0.9241956225596368 and parameters: {'batch_size': 128, 'learn_rate': 0.0019268663534094117, 'info_nce_loss.temperature': 0.2918824241982132}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:54:44.618485     0.001 >> Launch "18d_world_model_07:55" completed
# 2026.09.09-22:54:44.618944     0.000 >> 69 (+1) launches completed; running launches=14
# 2026.09.09-22:54:54.959451     0.113 >> Model instance registered, version=99
# 2026.09.09-22:54:54.970903     0.005 >> 2.2 idle runners exist, submitted launch "18d_world_model_07:99"; running launches=15
# 2026.09.09-22:54:54.971036     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch99.ipynb"
# 2026.09.09-22:55:04.023667     3.941 >> Trial 74 (18d_world_model_07:90) finished with value: 0.5695730391889811 and parameters: {'batch_size': 256, 'learn_rate': 0.00043890257392293144, 'info_nce_loss.temperature': 0.1804734556718922}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:55:05.282302     0.003 >> Launch "18d_world_model_07:90" completed
# 2026.09.09-22:55:05.283500     0.001 >> 70 (+1) launches completed; running launches=14
# 2026.09.09-22:55:26.375919     0.172 >> Model instance registered, version=100
# 2026.09.09-22:55:26.389450     0.006 >> 2.8 idle runners exist, submitted launch "18d_world_model_07:100"; running launches=15
# 2026.09.09-22:55:26.389633     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch100.ipynb"
# 2026.09.09-22:55:32.796620     1.292 >> Trial 50 (18d_world_model_07:66) finished with value: 0.9256047997623682 and parameters: {'batch_size': 128, 'learn_rate': 0.0018221220888885513, 'info_nce_loss.temperature': 0.2950791709691544}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:55:37.027623     0.003 >> Launch "18d_world_model_07:66" completed
# 2026.09.09-22:55:37.028845     0.001 >> 71 (+1) launches completed; running launches=14
# 2026.09.09-22:55:57.655733     0.165 >> Model instance registered, version=101
# 2026.09.09-22:55:57.673662     0.010 >> 3.0 idle runners exist, submitted launch "18d_world_model_07:101"; running launches=15
# 2026.09.09-22:55:57.674034     0.010 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch101.ipynb"
# 2026.09.09-22:56:28.859260     0.170 >> Model instance registered, version=102
# 2026.09.09-22:56:28.873998     0.007 >> 2.2 idle runners exist, submitted launch "18d_world_model_07:102"; running launches=16
# 2026.09.09-22:56:28.874269     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch102.ipynb"
# 2026.09.09-22:57:00.543020     0.164 >> Model instance registered, version=103
# 2026.09.09-22:57:00.554514     0.004 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:103"; running launches=17
# 2026.09.09-22:57:00.554609     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch103.ipynb"
# 2026.09.09-22:57:17.310450     0.229 >> Trial 76 (18d_world_model_07:92) finished with value: 0.8354291375726461 and parameters: {'batch_size': 256, 'learn_rate': 0.006568457841202847, 'info_nce_loss.temperature': 0.16687986637944957}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:57:22.196428     0.001 >> Launch "18d_world_model_07:92" completed
# 2026.09.09-22:57:22.197250     0.001 >> 72 (+1) launches completed; running launches=16
# 2026.09.09-22:58:16.575352     2.933 >> Trial 77 (18d_world_model_07:93) finished with value: 0.8781320536509156 and parameters: {'batch_size': 256, 'learn_rate': 0.0021656954206167992, 'info_nce_loss.temperature': 0.17178796189501677}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:58:18.754414     0.001 >> Launch "18d_world_model_07:93" completed
# 2026.09.09-22:58:18.755230     0.001 >> 73 (+1) launches completed; running launches=15
# 2026.09.09-22:58:33.764072     4.786 >> Trial 75 (18d_world_model_07:91) finished with value: 0.9121407764032483 and parameters: {'batch_size': 256, 'learn_rate': 0.002197349493656994, 'info_nce_loss.temperature': 0.16994362365594662}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:58:34.095500     0.002 >> Launch "18d_world_model_07:91" completed
# 2026.09.09-22:58:34.096391     0.001 >> 74 (+1) launches completed; running launches=14
# 2026.09.09-22:58:36.378463     2.282 >> Trial 78 (18d_world_model_07:94) finished with value: 0.8581481985747814 and parameters: {'batch_size': 256, 'learn_rate': 0.0021952893547257375, 'info_nce_loss.temperature': 0.23555628354337416}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:58:39.505041     0.294 >> Model instance registered, version=104
# 2026.09.09-22:58:39.526162     0.009 >> 1.3 idle runners exist, submitted launch "18d_world_model_07:104"; running launches=15
# 2026.09.09-22:58:39.526946     0.010 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch104.ipynb"
# 2026.09.09-22:58:39.527487     0.001 >> Launch "18d_world_model_07:94" completed
# 2026.09.09-22:58:39.529370     0.002 >> 75 (+1) launches completed; running launches=14
# 2026.09.09-22:58:54.588189     4.830 >> Trial 73 (18d_world_model_07:89) finished with value: 0.5827584788203239 and parameters: {'batch_size': 256, 'learn_rate': 0.0004800536050078251, 'info_nce_loss.temperature': 0.17301740867110754}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-22:58:54.878250     0.001 >> Launch "18d_world_model_07:89" completed
# 2026.09.09-22:58:54.879133     0.001 >> 76 (+1) launches completed; running launches=13
# 2026.09.09-22:59:10.337549     0.123 >> Model instance registered, version=105
# 2026.09.09-22:59:10.350764     0.005 >> 3.3 idle runners exist, submitted launch "18d_world_model_07:105"; running launches=14
# 2026.09.09-22:59:10.350887     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch105.ipynb"
# 2026.09.09-22:59:41.700975     0.176 >> Model instance registered, version=106
# 2026.09.09-22:59:41.713975     0.005 >> 2.7 idle runners exist, submitted launch "18d_world_model_07:106"; running launches=15
# 2026.09.09-22:59:41.714213     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch106.ipynb"
# 2026.09.09-23:00:30.289712     2.212 >> Trial 72 (18d_world_model_07:88) finished with value: 0.849274349398911 and parameters: {'batch_size': 128, 'learn_rate': 0.00398965542991057, 'info_nce_loss.temperature': 0.19035379455939355}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-23:00:33.192657     0.001 >> Launch "18d_world_model_07:88" completed
# 2026.09.09-23:00:33.193505     0.001 >> 77 (+1) launches completed; running launches=14
# 2026.09.09-23:05:24.187814     3.230 >> Trial 65 (18d_world_model_07:81) finished with value: 0.9015527502633631 and parameters: {'batch_size': 128, 'learn_rate': 0.0006175835799228074, 'info_nce_loss.temperature': 0.11482107591907491}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-23:05:26.174998     0.003 >> Launch "18d_world_model_07:81" completed
# 2026.09.09-23:05:26.175965     0.001 >> 78 (+1) launches completed; running launches=13
# 2026.09.09-23:07:29.996237     2.133 >> Trial 85 (18d_world_model_07:101) finished with value: 0.7814908372238278 and parameters: {'batch_size': 128, 'learn_rate': 0.004249074769698766, 'info_nce_loss.temperature': 0.42749242743614074}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-23:07:32.972203     0.001 >> Launch "18d_world_model_07:101" completed
# 2026.09.09-23:07:32.972702     0.000 >> 79 (+1) launches completed; running launches=12
# 2026.09.09-23:09:38.560476     1.654 >> Trial 88 (18d_world_model_07:104) finished with value: 0.8376815835945308 and parameters: {'batch_size': 128, 'learn_rate': 0.003233323499111136, 'info_nce_loss.temperature': 0.2409014658430164}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-23:09:42.027697     0.002 >> Launch "18d_world_model_07:104" completed
# 2026.09.09-23:09:42.028530     0.001 >> 80 (+1) launches completed; running launches=11
# 2026.09.09-23:12:56.495903     4.872 >> Trial 64 (18d_world_model_07:80) finished with value: 0.8918491285294294 and parameters: {'batch_size': 64, 'learn_rate': 0.0007211056519269024, 'info_nce_loss.temperature': 0.13854390422452595}. Best is trial 22 with value: 0.927907049190253
# 2026.09.09-23:12:56.741104     0.002 >> Launch "18d_world_model_07:80" completed
# 2026.09.09-23:12:56.741863     0.001 >> 81 (+1) launches completed; running launches=10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 54
#      52     pass
# ---> 54 time.sleep(5)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 12
#       9 completed_launches_count = 0
#      11 with LOG.auto_log_level(logging.INFO):
# ---> 12     with cf.ThreadPoolExecutor(max_workers=32) as executor:
#      13         futures = {}
#      14         idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
#
# File ~/anaconda3/envs/mine/lib/python3.12/concurrent/futures/_base.py:647, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     646 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647     self.shutdown(wait=True)
#     648     return False
#
# File ~/anaconda3/envs/mine/lib/python3.12/concurrent/futures/thread.py:239, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     237 if wait:
#     238     for t in self._threads:
# --> 239         t.join()
#
# File ~/anaconda3/envs/mine/lib/python3.12/threading.py:1149, in Thread.join(self, timeout)
#    1146     raise RuntimeError("cannot join current thread")
#    1148 if timeout is None:
# -> 1149     self._wait_for_tstate_lock()
#    1150 else:
#    1151     # the behavior of a negative timeout isn't documented, but
#    1152     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1153     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/anaconda3/envs/mine/lib/python3.12/threading.py:1169, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1166     return
#    1168 try:
# -> 1169     if lock.acquire(block, timeout):
#    1170         lock.release()
#    1171         self._stop()
#
# KeyboardInterrupt:
