# %% [markdown]
# # Goal
#
# Продолжение `18d_study_16.1`. Что можно выжать из простого `MSE` при `launch_goal=train_predictor`? Тестируем гиперпараметры:
# - `struct_projector=dict(type='Identity')`
# - `learn_rate`

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18d_world_model_07.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.launch_goal = 'train_predictor'
    
    HP.general.comment = None
    HP.general.random_seed = random.randint(0, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.dataset.train = [
        'train_dataset_seq_eq_5_max_eq_0:101',
        'train_dataset_seq_eq_5_max_eq_0:102',
        'train_dataset_seq_eq_5_max_eq_0:103',
        'train_dataset_seq_eq_5_max_eq_0:104',
        'train_dataset_seq_eq_5_max_eq_0:105',
        'train_dataset_seq_eq_5_max_eq_0:106',
        'train_dataset_seq_eq_5_max_eq_0:107',
        'train_dataset_seq_eq_5_max_eq_0:108',
        'train_dataset_seq_eq_5_max_eq_0:109',
        'train_dataset_seq_eq_5_max_eq_0:110',
    ]
    HP.dataset.test = 'test_dataset_seq_eq_5_max_eq_0:101'

    HP.model.parent = '18d_world_model_07:8'
    HP.model.sequence_length = 4
    HP.model.actions_count = 6
    HP.model.ob_shape = (1, 178, 152)
    HP.model.d_model = 256
    HP.model.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.model.encoder = dict(
        is_trainable=HP.launch_goal in ('train_encoder', 'train_all', None),
        vision_head=dict(grid=(6,6), features_counts=(16, 32, 64, 128)),
    )
    HP.model.predictor = dict(
        is_trainable=HP.launch_goal in ('train_predictor', 'train_all', None),
        down_translator=None,
        parent=None, # do not load from HP.model.parent
    )
    HP.model.renderer = dict(
        is_trainable=HP.launch_goal in ('train_encoder', 'train_all', None),
        projector=dict(type='linear'), 
        render_engine=dict(
            type='layer', 
            layers_count=4, 
            features_counts=(96, 64, 32, 16),
        ),
    )
    HP.model.struct_projector = dict(
        is_trainable=HP.launch_goal in ('train_predictor', 'train_all', None),
        type='Identity',
        parent=None, # do not load from HP.model.parent
    )
    
    HP.train.epochs_count = 100
    HP.train.batch_size = 128
    HP.train.optimizer = 'AdamW'
    HP.train.max_grad_norm = 1.0
    HP.train.learn_rate = f'const({optuna_trial.suggest_float('learn_rate', 0.0001, 0.01)})'
    HP.train.bce_loss_coef = 'const(1.0)'
    HP.train.edge_loss_coef = 'const(1.0)'
    HP.train.recon_loss_coef = 'const(0.0)'
    HP.train.pred_loss = dict(
        type='MSE', 
        loss_coef='const(1.0)', 
    )
    
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Тут уже веселее. Лучший `ssim=0.9761` у запуска `18d_world_model_07:258`. Это даже лучше, чем у `InfoNCE` и даже лучше, чем когда просто скопировали латент (см. `18d_world_model_07:193`).
#
# Посмотрел, картинки, которые сгенерил `18d_world_model_07:258` - в целом неплохо. Видно, что это не просто копирование. Передвижения игрока переданы правильно.
#
# <img src="./img/ssim.png">
#
# **Выводы**
# 1) всё надо перепроверять: случае с `InfoNCE` прожектор работает (`18d_study_15.1` vs `18d_study_15a.1`), а с `MSE` не работает (`18d_study_16.1` vs `18d_study_17.1`). Наперёд вообще непонятно, что полезно, а что нет =(
# 2) правда, значение `ssim=0.9761` не супер высокое, хз можно его использовать для опоры?
# 3) кажется, всё таки надо попробоывать предсказывать более дальнее будущее

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18d_world_model_07.ipynb',
#  'target_notebook_name': '18d_world_model_07',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18d_study_17.1/18d_study_17.1.ipynb',
#  'optuna_study_name': '18d_study_17.1',
#  'optuna_study_serial': '17.1',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18d_study_17.1/18d_study_17.1.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 100
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-10 19:03:15,212] Using an existing study with name '18d_study_17.1' instead of creating a new one.
# 2026.09.10-19:03:15.406240     0.162 >> Model instance registered, version=238
# 2026.09.10-19:03:15.416008     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch238.ipynb"
# 2026.09.10-19:03:15.416221     0.004 >> 10.0 idle runners exist, submitted launch "18d_world_model_07:238"; running launches=1
# 2026.09.10-19:03:46.298332     0.167 >> Model instance registered, version=239
# 2026.09.10-19:03:46.313315     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch239.ipynb"
# 2026.09.10-19:03:46.313998     0.007 >> 9.5 idle runners exist, submitted launch "18d_world_model_07:239"; running launches=2
# 2026.09.10-19:04:17.178051     0.174 >> Model instance registered, version=240
# 2026.09.10-19:04:17.191664     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch240.ipynb"
# 2026.09.10-19:04:17.191880     0.005 >> 8.3 idle runners exist, submitted launch "18d_world_model_07:240"; running launches=3
# 2026.09.10-19:04:48.594968     0.387 >> Model instance registered, version=241
# 2026.09.10-19:04:48.607963     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch241.ipynb"
# 2026.09.10-19:04:48.608232     0.005 >> 7.0 idle runners exist, submitted launch "18d_world_model_07:241"; running launches=4
# 2026.09.10-19:05:20.081441     0.209 >> Model instance registered, version=242
# 2026.09.10-19:05:20.095140     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch242.ipynb"
# 2026.09.10-19:05:20.095468     0.006 >> 6.7 idle runners exist, submitted launch "18d_world_model_07:242"; running launches=5
# 2026.09.10-19:05:50.973247     0.183 >> Model instance registered, version=243
# 2026.09.10-19:05:50.983550     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch243.ipynb"
# 2026.09.10-19:05:50.983988     0.005 >> 5.8 idle runners exist, submitted launch "18d_world_model_07:243"; running launches=6
# 2026.09.10-19:06:21.956649     0.193 >> Model instance registered, version=244
# 2026.09.10-19:06:21.968390     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch244.ipynb"
# 2026.09.10-19:06:21.968845     0.005 >> 4.5 idle runners exist, submitted launch "18d_world_model_07:244"; running launches=7
# 2026.09.10-19:06:53.564107     0.203 >> Model instance registered, version=245
# 2026.09.10-19:06:53.580817     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch245.ipynb"
# 2026.09.10-19:06:53.581088     0.007 >> 3.5 idle runners exist, submitted launch "18d_world_model_07:245"; running launches=8
# 2026.09.10-19:07:24.539621     0.162 >> Model instance registered, version=246
# 2026.09.10-19:07:24.549948     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch246.ipynb"
# 2026.09.10-19:07:24.550895     0.001 >> 2.7 idle runners exist, submitted launch "18d_world_model_07:246"; running launches=9
# 2026.09.10-19:07:56.452013     0.181 >> Model instance registered, version=247
# 2026.09.10-19:07:56.462164     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch247.ipynb"
# 2026.09.10-19:07:56.462420     0.005 >> 1.3 idle runners exist, submitted launch "18d_world_model_07:247"; running launches=10
# 2026.09.10-19:09:22.807009     4.428 >> Trial 3 (18d_world_model_07:238) finished with value: 0.9655950064770877 and parameters: {'learn_rate': 0.00550559151230636}. Best is trial 3 with value: 0.9655950064770877
# 2026.09.10-19:09:23.486910     0.001 >> Launch "18d_world_model_07:238" completed
# 2026.09.10-19:09:23.487353     0.000 >> 1 (+1) launches completed; running launches=9
# 2026.09.10-19:09:49.599948     0.181 >> Model instance registered, version=248
# 2026.09.10-19:09:49.614207     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:248"; running launches=10
# 2026.09.10-19:09:49.614348     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch248.ipynb"
# 2026.09.10-19:12:13.763158     0.335 >> Trial 7 (18d_world_model_07:242) finished with value: 0.9689706512726843 and parameters: {'learn_rate': 0.002397366801020104}. Best is trial 7 with value: 0.9689706512726843
# 2026.09.10-19:12:18.808724     0.001 >> Launch "18d_world_model_07:242" completed
# 2026.09.10-19:12:18.809177     0.000 >> 2 (+1) launches completed; running launches=9
# 2026.09.10-19:12:39.658954     0.156 >> Model instance registered, version=249
# 2026.09.10-19:12:39.669544     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:249"; running launches=10
# 2026.09.10-19:12:39.669700     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch249.ipynb"
# 2026.09.10-19:14:00.127401     3.566 >> Trial 10 (18d_world_model_07:245) finished with value: 0.9674077806994319 and parameters: {'learn_rate': 0.005905785869996629}. Best is trial 7 with value: 0.9689706512726843
# 2026.09.10-19:14:01.679164     0.002 >> Launch "18d_world_model_07:245" completed
# 2026.09.10-19:14:01.680238     0.001 >> 3 (+1) launches completed; running launches=9
# 2026.09.10-19:14:27.645408     0.167 >> Model instance registered, version=250
# 2026.09.10-19:14:27.659941     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:250"; running launches=10
# 2026.09.10-19:14:27.660125     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch250.ipynb"
# 2026.09.10-19:15:00.335668     1.936 >> Trial 12 (18d_world_model_07:247) finished with value: 0.9664102145470679 and parameters: {'learn_rate': 0.004438620304589036}. Best is trial 7 with value: 0.9689706512726843
# 2026.09.10-19:15:03.507811     0.001 >> Launch "18d_world_model_07:247" completed
# 2026.09.10-19:15:03.508358     0.001 >> 4 (+1) launches completed; running launches=9
# 2026.09.10-19:15:29.247708     0.173 >> Model instance registered, version=251
# 2026.09.10-19:15:29.263406     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:251"; running launches=10
# 2026.09.10-19:15:29.263585     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch251.ipynb"
# 2026.09.10-19:16:37.559425     0.311 >> Trial 13 (18d_world_model_07:248) finished with value: 0.9708936656825244 and parameters: {'learn_rate': 0.00020047363038403865}. Best is trial 13 with value: 0.9708936656825244
# 2026.09.10-19:16:42.361713     0.002 >> Launch "18d_world_model_07:248" completed
# 2026.09.10-19:16:42.362396     0.001 >> 5 (+1) launches completed; running launches=9
# 2026.09.10-19:16:56.821012     4.236 >> Trial 4 (18d_world_model_07:239) finished with value: 0.9699681038036942 and parameters: {'learn_rate': 0.007125239781210466}. Best is trial 13 with value: 0.9708936656825244
# 2026.09.10-19:16:57.912138     0.168 >> Model instance registered, version=252
# 2026.09.10-19:16:57.923782     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:252"; running launches=10
# 2026.09.10-19:16:57.923883     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch252.ipynb"
# 2026.09.10-19:16:57.924342     0.001 >> Launch "18d_world_model_07:239" completed
# 2026.09.10-19:16:57.925334     0.001 >> 6 (+1) launches completed; running launches=9
# 2026.09.10-19:17:28.942021     0.174 >> Model instance registered, version=253
# 2026.09.10-19:17:28.954535     0.004 >> 1.5 idle runners exist, submitted launch "18d_world_model_07:253"; running launches=10
# 2026.09.10-19:17:28.954694     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch253.ipynb"
# 2026.09.10-19:18:32.623645     1.724 >> Trial 5 (18d_world_model_07:240) finished with value: 0.9664515480399132 and parameters: {'learn_rate': 0.0023074078557060113}. Best is trial 13 with value: 0.9708936656825244
# 2026.09.10-19:18:36.014998     0.001 >> Launch "18d_world_model_07:240" completed
# 2026.09.10-19:18:36.015971     0.001 >> 7 (+1) launches completed; running launches=9
# 2026.09.10-19:19:01.789838     0.191 >> Model instance registered, version=254
# 2026.09.10-19:19:01.801361     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:254"; running launches=10
# 2026.09.10-19:19:01.801478     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch254.ipynb"
# 2026.09.10-19:19:24.056444     1.681 >> Trial 6 (18d_world_model_07:241) finished with value: 0.9688375825062394 and parameters: {'learn_rate': 0.001992311947679323}. Best is trial 13 with value: 0.9708936656825244
# 2026.09.10-19:19:27.660063     0.001 >> Launch "18d_world_model_07:241" completed
# 2026.09.10-19:19:27.660511     0.000 >> 8 (+1) launches completed; running launches=9
# 2026.09.10-19:19:27.899662     0.239 >> Trial 14 (18d_world_model_07:249) finished with value: 0.9720595763064921 and parameters: {'learn_rate': 0.0012725679010835277}. Best is trial 14 with value: 0.9720595763064921
# 2026.09.10-19:19:32.938169     0.171 >> Model instance registered, version=255
# 2026.09.10-19:19:32.952997     0.006 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:255"; running launches=10
# 2026.09.10-19:19:32.953612     0.001 >> Launch "18d_world_model_07:249" completed
# 2026.09.10-19:19:32.953981     0.000 >> 9 (+1) launches completed; running launches=9
# 2026.09.10-19:19:32.953176     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch255.ipynb"
# 2026.09.10-19:20:04.768926     0.229 >> Model instance registered, version=256
# 2026.09.10-19:20:04.779642     0.005 >> 2.0 idle runners exist, submitted launch "18d_world_model_07:256"; running launches=10
# 2026.09.10-19:20:04.779785     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch256.ipynb"
# 2026.09.10-19:20:13.031322     3.139 >> Trial 8 (18d_world_model_07:243) finished with value: 0.9682213012129068 and parameters: {'learn_rate': 0.0035192877744521962}. Best is trial 14 with value: 0.9720595763064921
# 2026.09.10-19:20:15.010200     0.002 >> Launch "18d_world_model_07:243" completed
# 2026.09.10-19:20:15.011346     0.001 >> 10 (+1) launches completed; running launches=9
# 2026.09.10-19:20:24.634170     4.510 >> Trial 9 (18d_world_model_07:244) finished with value: 0.9686246416531503 and parameters: {'learn_rate': 0.007098353182947325}. Best is trial 14 with value: 0.9720595763064921
# 2026.09.10-19:20:25.238220     0.001 >> Launch "18d_world_model_07:244" completed
# 2026.09.10-19:20:25.238969     0.001 >> 11 (+1) launches completed; running launches=8
# 2026.09.10-19:20:35.681996     0.210 >> Model instance registered, version=257
# 2026.09.10-19:20:35.693345     0.005 >> 2.0 idle runners exist, submitted launch "18d_world_model_07:257"; running launches=9
# 2026.09.10-19:20:35.693472     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch257.ipynb"
# 2026.09.10-19:20:58.149889     1.944 >> Trial 11 (18d_world_model_07:246) finished with value: 0.9742526821792126 and parameters: {'learn_rate': 0.00041791395596811446}. Best is trial 11 with value: 0.9742526821792126
# 2026.09.10-19:21:01.448445     0.002 >> Launch "18d_world_model_07:246" completed
# 2026.09.10-19:21:01.449514     0.001 >> 12 (+1) launches completed; running launches=8
# 2026.09.10-19:21:06.752114     0.189 >> Model instance registered, version=258
# 2026.09.10-19:21:06.762146     0.004 >> 2.2 idle runners exist, submitted launch "18d_world_model_07:258"; running launches=9
# 2026.09.10-19:21:06.762282     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch258.ipynb"
# 2026.09.10-19:21:34.882245     1.793 >> Trial 15 (18d_world_model_07:250) finished with value: 0.9702995656989515 and parameters: {'learn_rate': 0.0019548100445621963}. Best is trial 11 with value: 0.9742526821792126
# 2026.09.10-19:21:38.395319     0.190 >> Model instance registered, version=259
# 2026.09.10-19:21:38.409969     0.006 >> 2.2 idle runners exist, submitted launch "18d_world_model_07:259"; running launches=10
# 2026.09.10-19:21:38.410144     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch259.ipynb"
# 2026.09.10-19:21:38.410610     0.001 >> Launch "18d_world_model_07:250" completed
# 2026.09.10-19:21:38.411628     0.001 >> 13 (+1) launches completed; running launches=9
# 2026.09.10-19:22:10.255708     0.182 >> Model instance registered, version=260
# 2026.09.10-19:22:10.269818     0.006 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:260"; running launches=10
# 2026.09.10-19:22:10.270387     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch260.ipynb"
# 2026.09.10-19:22:44.378602     2.833 >> Trial 16 (18d_world_model_07:251) finished with value: 0.9677942902781069 and parameters: {'learn_rate': 0.001961558287797292}. Best is trial 11 with value: 0.9742526821792126
# 2026.09.10-19:22:49.414481     0.003 >> Launch "18d_world_model_07:251" completed
# 2026.09.10-19:22:49.415354     0.001 >> 14 (+1) launches completed; running launches=9
# 2026.09.10-19:23:15.398478     0.190 >> Model instance registered, version=261
# 2026.09.10-19:23:15.413808     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:261"; running launches=10
# 2026.09.10-19:23:15.413937     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch261.ipynb"
# 2026.09.10-19:23:52.352332     1.116 >> Trial 17 (18d_world_model_07:252) finished with value: 0.9674411029554904 and parameters: {'learn_rate': 0.00423904578410231}. Best is trial 11 with value: 0.9742526821792126
# 2026.09.10-19:23:56.352266     0.002 >> Launch "18d_world_model_07:252" completed
# 2026.09.10-19:23:56.353211     0.001 >> 15 (+1) launches completed; running launches=9
# 2026.09.10-19:24:22.483537     0.170 >> Model instance registered, version=262
# 2026.09.10-19:24:22.496461     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:262"; running launches=10
# 2026.09.10-19:24:22.496838     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch262.ipynb"
# 2026.09.10-19:26:37.845132     0.808 >> Trial 20 (18d_world_model_07:255) finished with value: 0.9694193159230053 and parameters: {'learn_rate': 0.00200977051253818}. Best is trial 11 with value: 0.9742526821792126
# 2026.09.10-19:26:42.236123     0.003 >> Launch "18d_world_model_07:255" completed
# 2026.09.10-19:26:42.236820     0.001 >> 16 (+1) launches completed; running launches=9
# 2026.09.10-19:27:08.480772     0.199 >> Model instance registered, version=263
# 2026.09.10-19:27:08.492389     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:263"; running launches=10
# 2026.09.10-19:27:08.492485     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch263.ipynb"
# 2026.09.10-19:28:09.597708     4.323 >> Trial 23 (18d_world_model_07:258) finished with value: 0.9760677004233003 and parameters: {'learn_rate': 0.00044333075424127195}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:28:10.762274     0.002 >> Launch "18d_world_model_07:258" completed
# 2026.09.10-19:28:10.763201     0.001 >> 17 (+1) launches completed; running launches=9
# 2026.09.10-19:28:36.506979     0.163 >> Model instance registered, version=264
# 2026.09.10-19:28:36.516605     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:264"; running launches=10
# 2026.09.10-19:28:36.516699     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch264.ipynb"
# 2026.09.10-19:29:20.464573     3.041 >> Trial 18 (18d_world_model_07:253) finished with value: 0.9681857950054109 and parameters: {'learn_rate': 0.009405823306412677}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:29:22.532384     0.001 >> Launch "18d_world_model_07:253" completed
# 2026.09.10-19:29:22.532814     0.000 >> 18 (+1) launches completed; running launches=9
# 2026.09.10-19:29:48.255833     0.168 >> Model instance registered, version=265
# 2026.09.10-19:29:48.267193     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:265"; running launches=10
# 2026.09.10-19:29:48.267329     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch265.ipynb"
# 2026.09.10-19:30:27.723001     3.445 >> Trial 26 (18d_world_model_07:261) finished with value: 0.9685708051547408 and parameters: {'learn_rate': 0.009056221569871487}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:30:29.386510     0.001 >> Launch "18d_world_model_07:261" completed
# 2026.09.10-19:30:29.387196     0.001 >> 19 (+1) launches completed; running launches=9
# 2026.09.10-19:30:55.128717     0.173 >> Model instance registered, version=266
# 2026.09.10-19:30:55.141535     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:266"; running launches=10
# 2026.09.10-19:30:55.141736     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch266.ipynb"
# 2026.09.10-19:31:17.378099     1.705 >> Trial 27 (18d_world_model_07:262) finished with value: 0.9727233960293233 and parameters: {'learn_rate': 0.00017810352799054266}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:31:20.866244     0.003 >> Launch "18d_world_model_07:262" completed
# 2026.09.10-19:31:20.867387     0.001 >> 20 (+1) launches completed; running launches=9
# 2026.09.10-19:31:46.632334     0.186 >> Model instance registered, version=267
# 2026.09.10-19:31:46.647889     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:267"; running launches=10
# 2026.09.10-19:31:46.648077     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch267.ipynb"
# 2026.09.10-19:32:19.632502     1.679 >> Trial 19 (18d_world_model_07:254) finished with value: 0.967700766865164 and parameters: {'learn_rate': 0.0022617015032693534}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:32:23.073158     0.001 >> Launch "18d_world_model_07:254" completed
# 2026.09.10-19:32:23.074036     0.001 >> 21 (+1) launches completed; running launches=9
# 2026.09.10-19:32:49.033152     0.215 >> Model instance registered, version=268
# 2026.09.10-19:32:49.047855     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:268"; running launches=10
# 2026.09.10-19:32:49.047965     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch268.ipynb"
# 2026.09.10-19:33:56.160001     0.382 >> Trial 21 (18d_world_model_07:256) finished with value: 0.9579184264875948 and parameters: {'learn_rate': 0.009607552080458675}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:34:00.895494     0.003 >> Launch "18d_world_model_07:256" completed
# 2026.09.10-19:34:00.896444     0.001 >> 22 (+1) launches completed; running launches=9
# 2026.09.10-19:34:12.640877     1.525 >> Trial 28 (18d_world_model_07:263) finished with value: 0.9655187814496458 and parameters: {'learn_rate': 0.009995411110872278}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:34:16.401815     0.170 >> Model instance registered, version=269
# 2026.09.10-19:34:16.417189     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:269"; running launches=10
# 2026.09.10-19:34:16.417286     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch269.ipynb"
# 2026.09.10-19:34:16.417699     0.001 >> Launch "18d_world_model_07:263" completed
# 2026.09.10-19:34:16.418569     0.001 >> 23 (+1) launches completed; running launches=9
# 2026.09.10-19:34:38.510518     1.559 >> Trial 22 (18d_world_model_07:257) finished with value: 0.9723642664030194 and parameters: {'learn_rate': 0.00013507843969218298}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:34:42.068907     0.002 >> Launch "18d_world_model_07:257" completed
# 2026.09.10-19:34:42.070157     0.001 >> 24 (+1) launches completed; running launches=8
# 2026.09.10-19:34:47.388396     0.201 >> Model instance registered, version=270
# 2026.09.10-19:34:47.404166     0.006 >> 1.8 idle runners exist, submitted launch "18d_world_model_07:270"; running launches=9
# 2026.09.10-19:34:47.404316     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch270.ipynb"
# 2026.09.10-19:35:18.381987     0.186 >> Model instance registered, version=271
# 2026.09.10-19:35:18.397330     0.005 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:271"; running launches=10
# 2026.09.10-19:35:18.397426     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch271.ipynb"
# 2026.09.10-19:35:23.410256     5.013 >> Trial 29 (18d_world_model_07:264) finished with value: 0.9639951419085264 and parameters: {'learn_rate': 0.009758645304856615}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:35:23.511678     0.001 >> Launch "18d_world_model_07:264" completed
# 2026.09.10-19:35:23.512419     0.001 >> 25 (+1) launches completed; running launches=9
# 2026.09.10-19:35:33.533632     4.908 >> Trial 24 (18d_world_model_07:259) finished with value: 0.9748761062510312 and parameters: {'learn_rate': 0.000546620292613881}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:35:33.738326     0.001 >> Launch "18d_world_model_07:259" completed
# 2026.09.10-19:35:33.738809     0.000 >> 26 (+1) launches completed; running launches=8
# 2026.09.10-19:35:49.285429     0.211 >> Model instance registered, version=272
# 2026.09.10-19:35:49.296049     0.005 >> 2.5 idle runners exist, submitted launch "18d_world_model_07:272"; running launches=9
# 2026.09.10-19:35:49.296445     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch272.ipynb"
# 2026.09.10-19:36:04.750776     0.120 >> Trial 25 (18d_world_model_07:260) finished with value: 0.975142577663064 and parameters: {'learn_rate': 0.00029179750910692936}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:36:10.097978     0.002 >> Launch "18d_world_model_07:260" completed
# 2026.09.10-19:36:10.099077     0.001 >> 27 (+1) launches completed; running launches=8
# 2026.09.10-19:36:20.499184     0.175 >> Model instance registered, version=273
# 2026.09.10-19:36:20.512380     0.005 >> 2.2 idle runners exist, submitted launch "18d_world_model_07:273"; running launches=9
# 2026.09.10-19:36:20.512553     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch273.ipynb"
# 2026.09.10-19:36:51.556084     0.178 >> Model instance registered, version=274
# 2026.09.10-19:36:51.568845     0.005 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:274"; running launches=10
# 2026.09.10-19:36:51.568949     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch274.ipynb"
# 2026.09.10-19:37:52.599777     4.268 >> Trial 31 (18d_world_model_07:266) finished with value: 0.9757500607520342 and parameters: {'learn_rate': 0.00035087448149372785}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:37:53.449277     0.002 >> Launch "18d_world_model_07:266" completed
# 2026.09.10-19:37:53.450191     0.001 >> 28 (+1) launches completed; running launches=9
# 2026.09.10-19:38:19.994064     0.185 >> Model instance registered, version=275
# 2026.09.10-19:38:20.008319     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:275"; running launches=10
# 2026.09.10-19:38:20.008443     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch275.ipynb"
# 2026.09.10-19:38:42.726757     2.203 >> Trial 32 (18d_world_model_07:267) finished with value: 0.9669928210787475 and parameters: {'learn_rate': 0.0032627620480412704}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:38:45.639290     0.002 >> Launch "18d_world_model_07:267" completed
# 2026.09.10-19:38:45.640099     0.001 >> 29 (+1) launches completed; running launches=9
# 2026.09.10-19:39:11.472563     0.182 >> Model instance registered, version=276
# 2026.09.10-19:39:11.485057     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:276"; running launches=10
# 2026.09.10-19:39:11.485173     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch276.ipynb"
# 2026.09.10-19:40:59.562215     4.520 >> Trial 30 (18d_world_model_07:265) finished with value: 0.9723048014566302 and parameters: {'learn_rate': 0.00019892386417266154}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:41:00.156868     0.003 >> Launch "18d_world_model_07:265" completed
# 2026.09.10-19:41:00.157573     0.001 >> 30 (+1) launches completed; running launches=9
# 2026.09.10-19:41:05.525027     0.259 >> Trial 34 (18d_world_model_07:269) finished with value: 0.9715385683812201 and parameters: {'learn_rate': 0.00013405608249254293}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:41:10.386088     0.002 >> Launch "18d_world_model_07:269" completed
# 2026.09.10-19:41:10.387106     0.001 >> 31 (+1) launches completed; running launches=8
# 2026.09.10-19:41:15.668457     0.168 >> Model instance registered, version=277
# 2026.09.10-19:41:15.684040     0.006 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:277"; running launches=9
# 2026.09.10-19:41:15.684141     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch277.ipynb"
# 2026.09.10-19:41:46.534899     0.171 >> Model instance registered, version=278
# 2026.09.10-19:41:46.544663     0.004 >> 1.5 idle runners exist, submitted launch "18d_world_model_07:278"; running launches=10
# 2026.09.10-19:41:46.544807     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch278.ipynb"
# 2026.09.10-19:42:28.133248     0.281 >> Trial 37 (18d_world_model_07:272) finished with value: 0.9711494105868042 and parameters: {'learn_rate': 0.001005123841612361}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:42:32.961012     0.001 >> Launch "18d_world_model_07:272" completed
# 2026.09.10-19:42:32.961611     0.001 >> 32 (+1) launches completed; running launches=9
# 2026.09.10-19:42:53.610047     0.195 >> Model instance registered, version=279
# 2026.09.10-19:42:53.624477     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:279"; running launches=10
# 2026.09.10-19:42:53.624628     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch279.ipynb"
# 2026.09.10-19:44:51.865748     0.087 >> Trial 33 (18d_world_model_07:268) finished with value: 0.9725067429244518 and parameters: {'learn_rate': 0.0001693379337351646}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:44:51.866489     0.001 >> Launch "18d_world_model_07:268" completed
# 2026.09.10-19:44:51.866976     0.000 >> 33 (+1) launches completed; running launches=9
# 2026.09.10-19:45:16.268723     3.941 >> Trial 40 (18d_world_model_07:275) finished with value: 0.9690770916640759 and parameters: {'learn_rate': 0.001141787692350538}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:45:17.615613     0.174 >> Model instance registered, version=280
# 2026.09.10-19:45:17.627199     0.004 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:280"; running launches=10
# 2026.09.10-19:45:17.627295     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch280.ipynb"
# 2026.09.10-19:45:17.627842     0.001 >> Launch "18d_world_model_07:275" completed
# 2026.09.10-19:45:17.629331     0.001 >> 34 (+1) launches completed; running launches=9
# 2026.09.10-19:45:48.827569     0.179 >> Model instance registered, version=281
# 2026.09.10-19:45:48.840877     0.005 >> 1.5 idle runners exist, submitted launch "18d_world_model_07:281"; running launches=10
# 2026.09.10-19:45:48.841022     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch281.ipynb"
# 2026.09.10-19:45:57.021825     3.074 >> Trial 41 (18d_world_model_07:276) finished with value: 0.9714823053218424 and parameters: {'learn_rate': 0.001305631469660144}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:45:59.063289     0.001 >> Launch "18d_world_model_07:276" completed
# 2026.09.10-19:45:59.064330     0.001 >> 35 (+1) launches completed; running launches=9
# 2026.09.10-19:46:20.380151     0.170 >> Model instance registered, version=282
# 2026.09.10-19:46:20.394326     0.004 >> 1.8 idle runners exist, submitted launch "18d_world_model_07:282"; running launches=10
# 2026.09.10-19:46:20.394415     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch282.ipynb"
# 2026.09.10-19:48:20.073956     1.774 >> Trial 42 (18d_world_model_07:277) finished with value: 0.9704886395484209 and parameters: {'learn_rate': 0.0011998929131476054}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:48:23.409048     0.001 >> Launch "18d_world_model_07:277" completed
# 2026.09.10-19:48:23.409766     0.001 >> 36 (+1) launches completed; running launches=9
# 2026.09.10-19:48:43.478289     4.729 >> Trial 35 (18d_world_model_07:270) finished with value: 0.9735595411621034 and parameters: {'learn_rate': 0.0009197534738551376}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:48:44.050478     0.185 >> Model instance registered, version=283
# 2026.09.10-19:48:44.064118     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:283"; running launches=10
# 2026.09.10-19:48:44.064203     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch283.ipynb"
# 2026.09.10-19:48:44.064919     0.001 >> Launch "18d_world_model_07:270" completed
# 2026.09.10-19:48:44.065725     0.001 >> 37 (+1) launches completed; running launches=9
# 2026.09.10-19:49:15.074582     0.317 >> Model instance registered, version=284
# 2026.09.10-19:49:15.090132     0.007 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:284"; running launches=10
# 2026.09.10-19:49:15.090265     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch284.ipynb"
# 2026.09.10-19:49:30.614904     0.188 >> Trial 44 (18d_world_model_07:279) finished with value: 0.9712221040390432 and parameters: {'learn_rate': 0.0011022641748748138}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:49:34.067889     3.453 >> Trial 36 (18d_world_model_07:271) finished with value: 0.9739078413695097 and parameters: {'learn_rate': 0.000788220544055199}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:49:35.535377     0.001 >> Launch "18d_world_model_07:271" completed
# 2026.09.10-19:49:35.535817     0.000 >> Launch "18d_world_model_07:279" completed
# 2026.09.10-19:49:35.536045     0.000 >> 39 (+2) launches completed; running launches=8
# 2026.09.10-19:49:46.121860     0.363 >> Model instance registered, version=285
# 2026.09.10-19:49:46.144455     0.009 >> 1.8 idle runners exist, submitted launch "18d_world_model_07:285"; running launches=9
# 2026.09.10-19:49:46.144757     0.009 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch285.ipynb"
# 2026.09.10-19:50:17.122099     0.106 >> Model instance registered, version=286
# 2026.09.10-19:50:17.134655     0.004 >> 2.0 idle runners exist, submitted launch "18d_world_model_07:286"; running launches=10
# 2026.09.10-19:50:17.134812     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch286.ipynb"
# 2026.09.10-19:50:31.441977     3.985 >> Trial 38 (18d_world_model_07:273) finished with value: 0.9721249178983271 and parameters: {'learn_rate': 0.001085959783321185}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:50:32.564604     0.001 >> Launch "18d_world_model_07:273" completed
# 2026.09.10-19:50:32.565007     0.000 >> 40 (+1) launches completed; running launches=9
# 2026.09.10-19:50:48.084870     0.179 >> Model instance registered, version=287
# 2026.09.10-19:50:48.094053     0.004 >> 1.2 idle runners exist, submitted launch "18d_world_model_07:287"; running launches=10
# 2026.09.10-19:50:48.094210     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch287.ipynb"
# 2026.09.10-19:50:57.033851     3.828 >> Trial 39 (18d_world_model_07:274) finished with value: 0.973668560385704 and parameters: {'learn_rate': 0.001112356738391715}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:50:58.322577     0.002 >> Launch "18d_world_model_07:274" completed
# 2026.09.10-19:50:58.323350     0.001 >> 41 (+1) launches completed; running launches=9
# 2026.09.10-19:51:20.154786     0.175 >> Model instance registered, version=288
# 2026.09.10-19:51:20.167309     0.004 >> 1.3 idle runners exist, submitted launch "18d_world_model_07:288"; running launches=10
# 2026.09.10-19:51:20.167435     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch288.ipynb"
# 2026.09.10-19:52:59.478407     1.692 >> Trial 46 (18d_world_model_07:281) finished with value: 0.9704244211316109 and parameters: {'learn_rate': 0.001063062464582269}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:53:02.907587     0.004 >> Launch "18d_world_model_07:281" completed
# 2026.09.10-19:53:02.909472     0.002 >> 42 (+1) launches completed; running launches=9
# 2026.09.10-19:53:20.554025     2.307 >> Trial 47 (18d_world_model_07:282) finished with value: 0.9731013337150216 and parameters: {'learn_rate': 0.0008475202601447778}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:53:23.559596     0.201 >> Model instance registered, version=289
# 2026.09.10-19:53:23.580624     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:289"; running launches=10
# 2026.09.10-19:53:23.580824     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch289.ipynb"
# 2026.09.10-19:53:23.581362     0.001 >> Launch "18d_world_model_07:282" completed
# 2026.09.10-19:53:23.582608     0.001 >> 43 (+1) launches completed; running launches=9
# 2026.09.10-19:53:54.657133     0.391 >> Model instance registered, version=290
# 2026.09.10-19:53:54.677274     0.008 >> 1.7 idle runners exist, submitted launch "18d_world_model_07:290"; running launches=10
# 2026.09.10-19:53:54.677521     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch290.ipynb"
# 2026.09.10-19:54:09.444782     4.535 >> Trial 43 (18d_world_model_07:278) finished with value: 0.971880191937089 and parameters: {'learn_rate': 0.001037913084059454}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:54:10.227059     0.001 >> Launch "18d_world_model_07:278" completed
# 2026.09.10-19:54:10.227668     0.001 >> 44 (+1) launches completed; running launches=9
# 2026.09.10-19:54:25.789779     0.216 >> Model instance registered, version=291
# 2026.09.10-19:54:25.803515     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:291"; running launches=10
# 2026.09.10-19:54:25.803660     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch291.ipynb"
# 2026.09.10-19:55:43.361254     0.796 >> Trial 48 (18d_world_model_07:283) finished with value: 0.9693059115670621 and parameters: {'learn_rate': 0.0026458595342353165}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:55:47.684870     0.002 >> Launch "18d_world_model_07:283" completed
# 2026.09.10-19:55:47.685999     0.001 >> 45 (+1) launches completed; running launches=9
# 2026.09.10-19:56:13.613436     0.225 >> Model instance registered, version=292
# 2026.09.10-19:56:13.628434     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:292"; running launches=10
# 2026.09.10-19:56:13.628634     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch292.ipynb"
# 2026.09.10-19:56:43.945159     4.662 >> Trial 51 (18d_world_model_07:286) finished with value: 0.9672558000311255 and parameters: {'learn_rate': 0.002766691158625151}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:56:44.391887     0.001 >> Launch "18d_world_model_07:286" completed
# 2026.09.10-19:56:44.392330     0.000 >> 46 (+1) launches completed; running launches=9
# 2026.09.10-19:57:11.462841     0.214 >> Model instance registered, version=293
# 2026.09.10-19:57:11.475026     0.005 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:293"; running launches=10
# 2026.09.10-19:57:11.475154     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch293.ipynb"
# 2026.09.10-19:57:59.681411     2.170 >> Trial 45 (18d_world_model_07:280) finished with value: 0.9721181350760162 and parameters: {'learn_rate': 0.0010533655447560516}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-19:58:02.683981     0.003 >> Launch "18d_world_model_07:280" completed
# 2026.09.10-19:58:02.685061     0.001 >> 47 (+1) launches completed; running launches=9
# 2026.09.10-19:58:30.953661     0.180 >> Model instance registered, version=294
# 2026.09.10-19:58:30.963613     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:294"; running launches=10
# 2026.09.10-19:58:30.963741     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch294.ipynb"
# 2026.09.10-20:03:01.304246     0.048 >> Trial 49 (18d_world_model_07:284) finished with value: 0.9681062479503453 and parameters: {'learn_rate': 0.003030894434466327}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-20:03:01.305276     0.001 >> Launch "18d_world_model_07:284" completed
# 2026.09.10-20:03:01.305819     0.001 >> 48 (+1) launches completed; running launches=9
# 2026.09.10-20:03:44.281632     1.549 >> Trial 50 (18d_world_model_07:285) finished with value: 0.9661289253272116 and parameters: {'learn_rate': 0.0029376982805242764}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-20:03:47.849497     0.001 >> Launch "18d_world_model_07:285" completed
# 2026.09.10-20:03:47.850818     0.001 >> 49 (+1) launches completed; running launches=8
# 2026.09.10-20:04:47.887071     3.779 >> Trial 52 (18d_world_model_07:287) finished with value: 0.9662496619857848 and parameters: {'learn_rate': 0.0029382400857264385}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-20:04:49.216899     0.001 >> Launch "18d_world_model_07:287" completed
# 2026.09.10-20:04:49.217446     0.001 >> 50 (+1) launches completed; running launches=7
# 2026.09.10-20:05:27.597430     2.211 >> Trial 53 (18d_world_model_07:288) finished with value: 0.9718465334735811 and parameters: {'learn_rate': 0.0016240602009665785}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-20:05:30.944709     0.002 >> Launch "18d_world_model_07:288" completed
# 2026.09.10-20:05:30.945741     0.001 >> 51 (+1) launches completed; running launches=6
# 2026.09.10-20:07:13.278434     0.349 >> Trial 55 (18d_world_model_07:290) finished with value: 0.9660465591587126 and parameters: {'learn_rate': 0.002646742485780818}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-20:07:18.051938     0.003 >> Launch "18d_world_model_07:290" completed
# 2026.09.10-20:07:18.053506     0.002 >> 52 (+1) launches completed; running launches=5
# 2026.09.10-20:07:39.082864     0.243 >> Model instance registered, version=295
# 2026.09.10-20:07:39.095001     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:295"; running launches=6
# 2026.09.10-20:07:39.095126     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch295.ipynb"
# 2026.09.10-20:11:19.791241     0.388 >> Trial 59 (18d_world_model_07:294) finished with value: 0.9680131413042545 and parameters: {'learn_rate': 0.001644837850372676}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-20:11:24.516451     0.001 >> Launch "18d_world_model_07:294" completed
# 2026.09.10-20:11:24.517169     0.001 >> 53 (+1) launches completed; running launches=5
# 2026.09.10-20:11:45.372242     0.245 >> Model instance registered, version=296
# 2026.09.10-20:11:45.387143     0.004 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:296"; running launches=6
# 2026.09.10-20:11:45.387273     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch296.ipynb"
# 2026.09.10-20:16:05.250170     3.151 >> Trial 54 (18d_world_model_07:289) finished with value: 0.9699410381726921 and parameters: {'learn_rate': 0.0017394428229166319}. Best is trial 23 with value: 0.9760677004233003
# 2026.09.10-20:16:07.219550     0.002 >> Launch "18d_world_model_07:289" completed
# 2026.09.10-20:16:07.220815     0.001 >> 54 (+1) launches completed; running launches=5
# 2026.09.10-20:16:32.965248     0.163 >> Model instance registered, version=297
# 2026.09.10-20:16:32.979381     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_07:297"; running launches=6
# 2026.09.10-20:16:32.979546     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_07-launch297.ipynb"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 54
#      51 except TimeoutError as e:
#      52     pass
# ---> 54 time.sleep(5)
#
# KeyboardInterrupt:

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
