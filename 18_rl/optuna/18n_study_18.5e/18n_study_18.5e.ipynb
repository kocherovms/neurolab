# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 5 поколений по 6 млн шагов с последующим отбором чемпионов. Наследники этих чемпионов будут использоваться на следующем шаге.
#
# Данный эксперимент - это пятый шаг шаг. Берём `18n_ppo_tr_frostbite:335` и просто натаскиваем его через train RAM-ы.

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    generations_count = 5
    generation_ind = 4
    generation_steps_count = 6_000_000
    all_generations_steps_count = generation_steps_count * generations_count
    learn_rate_range = (0.00025, 0.00025 * 0.1)
    ent_coef_range = (0.05, 0.05 * 0.1)
    ####
    
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False

    parent = '18n_ppo_tr_frostbite_06:335'
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights=parent)
    HP.encoder.is_trainable = True

    HP.agent.parent = parent 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(500000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = None
    HP.video.capture_env_ram_patches = None
    HP.video.break_on_level_passed = False
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = generation_steps_count # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = [
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=train1',
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=train2',
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=train3',
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=train4',
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=train5',

        'com.develorium.neurolab.frostbite_ram:level2:1:cls=train1',
        'com.develorium.neurolab.frostbite_ram:level2:1:cls=train2',
        'com.develorium.neurolab.frostbite_ram:level2:1:cls=train3',
        'com.develorium.neurolab.frostbite_ram:level2:1:cls=train4',
        'com.develorium.neurolab.frostbite_ram:level2:1:cls=train5',

        'com.develorium.neurolab.frostbite_ram:level3:1:cls=train1',
        'com.develorium.neurolab.frostbite_ram:level3:1:cls=train2',
        'com.develorium.neurolab.frostbite_ram:level3:1:cls=train3',
        'com.develorium.neurolab.frostbite_ram:level3:1:cls=train4',
        'com.develorium.neurolab.frostbite_ram:level3:1:cls=train5',

        'com.develorium.neurolab.frostbite_ram:level4:1:cls=train1',
        'com.develorium.neurolab.frostbite_ram:level4:1:cls=train2',
        'com.develorium.neurolab.frostbite_ram:level4:1:cls=train3',
        'com.develorium.neurolab.frostbite_ram:level4:1:cls=train4',
        'com.develorium.neurolab.frostbite_ram:level4:1:cls=train5',

        'com.develorium.neurolab.frostbite_ram:level5:1:cls=train1',
        'com.develorium.neurolab.frostbite_ram:level5:1:cls=train2',
        'com.develorium.neurolab.frostbite_ram:level5:1:cls=train3',
        'com.develorium.neurolab.frostbite_ram:level5:1:cls=train4',
        'com.develorium.neurolab.frostbite_ram:level5:1:cls=train5',
    ]
    HP.ppo.rollout_env_ram_patches = [
        ['no_score', 'last_life', 'no_igloo', 'temperature_45', 'bailey_safe_random_spawn'],
    ]
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    learn_rate_change_speed = (learn_rate_range[1] - learn_rate_range[0]) / generations_count
    learn_rate_a = learn_rate_range[0] + learn_rate_change_speed * generation_ind
    learn_rate_b = learn_rate_a + learn_rate_change_speed
    HP.ppo.learn_rate = f'linear({learn_rate_a}, {learn_rate_b})'
    # HP.ppo.learn_rate = 'linear(0.00025, 0.00015)'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    ent_coef_change_speed = (ent_coef_range[1] - ent_coef_range[0]) / generations_count
    ent_coef_a = ent_coef_range[0] + ent_coef_change_speed * generation_ind
    ent_coef_b = ent_coef_a + ent_coef_change_speed
    HP.ppo.ent_coef = f'linear({ent_coef_a}, {ent_coef_b})' # coefficient of the entropy member within loss function
    # HP.ppo.ent_coef = 'linear(0.05, 0.03)' # coefficient of the entropy member within loss function
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Ну что, вот он долгожданный момент!!! Несколько агентов коснулись планки "пройдено 5 уровней":
# - `18n_ppo_tr_frostbite_06:355`
# - `18n_ppo_tr_frostbite_06:359`
# - `18n_ppo_tr_frostbite_06:369`
#
# Обидно только, что это случилось в самом начале или в середине, а ближе к концу агенты даже немного деградировали. Но сам факт, что агент смог пройти 5 уровней - это то, над чем я бился несколько месяцев. Получается, что ставка на декомпозиацию моделей, на заморозку `VisionHead` была правильная.
#
# Теперь уже можно заняться оптимизацией пути обучения: как быстрее достичь состояния "5 уровней пройдено" и сделать это стабильным. Также можно посмотреть, что работает, а что можно выкинуть. Например, нужен ли action planing? Что можно использовать для других игр? И т.д.
#
# <img src="./img/score.png">
# <img src="./img/episode_r.png">
#
# **Выводы**
# 1) успех окрыляет на дальнейшие оптимизации

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_18.5e/18n_study_18.5e.ipynb',
#  'optuna_study_name': '18n_study_18.5e',
#  'optuna_study_serial': '18.5e',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_18.5e/18n_study_18.5e.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-21 22:49:02,272] A new study created in Journal with name: 18n_study_18.5e
# 2026.09.21-22:49:02.661453     0.232 >> Model instance registered, version=351
# 2026.09.21-22:49:02.677927     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch351.ipynb"
# 2026.09.21-22:49:02.678721     0.001 >> 6.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:351"; running launches=1
# 2026.09.21-22:49:34.160489     0.202 >> Model instance registered, version=352
# 2026.09.21-22:49:34.174730     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch352.ipynb"
# 2026.09.21-22:49:34.175055     0.007 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:352"; running launches=2
# 2026.09.21-22:50:06.654899     0.226 >> Model instance registered, version=353
# 2026.09.21-22:50:06.670666     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch353.ipynb"
# 2026.09.21-22:50:06.671404     0.007 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:353"; running launches=3
# 2026.09.21-22:50:37.600039     0.213 >> Model instance registered, version=354
# 2026.09.21-22:50:37.613871     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch354.ipynb"
# 2026.09.21-22:50:37.614128     0.006 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:354"; running launches=4
# 2026.09.21-22:51:08.511385     0.200 >> Model instance registered, version=355
# 2026.09.21-22:51:08.525837     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch355.ipynb"
# 2026.09.21-22:51:08.526531     0.007 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:355"; running launches=5
# 2026.09.21-22:51:39.426994     0.215 >> Model instance registered, version=356
# 2026.09.21-22:51:39.441958     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch356.ipynb"
# 2026.09.21-22:51:39.442883     0.008 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:356"; running launches=6
# 2026.09.22-00:19:53.145558     1.283 >> Trial 2 (18n_ppo_tr_frostbite_06:353) finished with value: 20302.00022243247 and parameters: {}. Best is trial 2 with value: 20302.00022243247
# 2026.09.22-00:19:57.061406     0.002 >> Launch "18n_ppo_tr_frostbite_06:353" completed
# 2026.09.22-00:19:57.061883     0.000 >> 1 (+1) launches completed; running launches=5
# 2026.09.22-00:20:17.710504     0.196 >> Model instance registered, version=357
# 2026.09.22-00:20:17.723695     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:357"; running launches=6
# 2026.09.22-00:20:17.723825     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch357.ipynb"
# 2026.09.22-00:20:24.029385     1.199 >> Trial 3 (18n_ppo_tr_frostbite_06:354) finished with value: 40303.000208501304 and parameters: {}. Best is trial 3 with value: 40303.000208501304
# 2026.09.22-00:20:27.945436     0.001 >> Launch "18n_ppo_tr_frostbite_06:354" completed
# 2026.09.22-00:20:27.946161     0.001 >> 2 (+1) launches completed; running launches=5
# 2026.09.22-00:20:48.607597     0.198 >> Model instance registered, version=358
# 2026.09.22-00:20:48.620812     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:358"; running launches=6
# 2026.09.22-00:20:48.620914     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch358.ipynb"
# 2026.09.22-00:21:33.269342     3.381 >> Trial 5 (18n_ppo_tr_frostbite_06:356) finished with value: 20303.000196818866 and parameters: {}. Best is trial 3 with value: 40303.000208501304
# 2026.09.22-00:21:35.002393     0.001 >> Launch "18n_ppo_tr_frostbite_06:356" completed
# 2026.09.22-00:21:35.003271     0.001 >> 3 (+1) launches completed; running launches=5
# 2026.09.22-00:22:00.810757     0.202 >> Model instance registered, version=359
# 2026.09.22-00:22:00.821795     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:359"; running launches=6
# 2026.09.22-00:22:00.821922     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch359.ipynb"
# 2026.09.22-00:25:36.575920     3.000 >> Trial 0 (18n_ppo_tr_frostbite_06:351) finished with value: 30302.000213135885 and parameters: {}. Best is trial 3 with value: 40303.000208501304
# 2026.09.22-00:25:39.520899     0.002 >> Launch "18n_ppo_tr_frostbite_06:351" completed
# 2026.09.22-00:25:39.521423     0.001 >> 4 (+1) launches completed; running launches=5
# 2026.09.22-00:25:39.750726     0.229 >> Trial 1 (18n_ppo_tr_frostbite_06:352) finished with value: 30002.000230001373 and parameters: {}. Best is trial 3 with value: 40303.000208501304
# 2026.09.22-00:25:44.636839     0.001 >> Launch "18n_ppo_tr_frostbite_06:352" completed
# 2026.09.22-00:25:44.637674     0.001 >> 5 (+1) launches completed; running launches=4
# 2026.09.22-00:25:50.179826     0.215 >> Model instance registered, version=360
# 2026.09.22-00:25:50.190042     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:360"; running launches=5
# 2026.09.22-00:25:50.190121     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch360.ipynb"
# 2026.09.22-00:26:16.444345     4.897 >> Trial 4 (18n_ppo_tr_frostbite_06:355) finished with value: 30202.000196572055 and parameters: {}. Best is trial 3 with value: 40303.000208501304
# 2026.09.22-00:26:16.659398     0.001 >> Launch "18n_ppo_tr_frostbite_06:355" completed
# 2026.09.22-00:26:16.659916     0.001 >> 6 (+1) launches completed; running launches=4
# 2026.09.22-00:26:21.974819     0.200 >> Model instance registered, version=361
# 2026.09.22-00:26:21.986975     0.005 >> 1.7 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:361"; running launches=5
# 2026.09.22-00:26:21.987588     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch361.ipynb"
# 2026.09.22-00:26:52.985733     0.213 >> Model instance registered, version=362
# 2026.09.22-00:26:52.998791     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:362"; running launches=6
# 2026.09.22-00:26:52.998886     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch362.ipynb"
# 2026.09.22-01:48:56.718152     1.559 >> Trial 6 (18n_ppo_tr_frostbite_06:357) finished with value: 40404.0002171123 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-01:49:00.596446     0.002 >> Launch "18n_ppo_tr_frostbite_06:357" completed
# 2026.09.22-01:49:00.597478     0.001 >> 7 (+1) launches completed; running launches=5
# 2026.09.22-01:49:19.484971     2.847 >> Trial 7 (18n_ppo_tr_frostbite_06:358) finished with value: 30203.0002194433 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-01:49:22.197037     0.202 >> Model instance registered, version=363
# 2026.09.22-01:49:22.207327     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:363"; running launches=6
# 2026.09.22-01:49:22.207433     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch363.ipynb"
# 2026.09.22-01:49:22.207787     0.000 >> Launch "18n_ppo_tr_frostbite_06:358" completed
# 2026.09.22-01:49:22.208903     0.001 >> 8 (+1) launches completed; running launches=5
# 2026.09.22-01:49:53.565773     0.235 >> Model instance registered, version=364
# 2026.09.22-01:49:53.578731     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:364"; running launches=6
# 2026.09.22-01:49:53.578879     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch364.ipynb"
# 2026.09.22-01:50:53.048503     1.965 >> Trial 8 (18n_ppo_tr_frostbite_06:359) finished with value: 20303.00025534074 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-01:50:56.199860     0.001 >> Launch "18n_ppo_tr_frostbite_06:359" completed
# 2026.09.22-01:50:56.200771     0.001 >> 9 (+1) launches completed; running launches=5
# 2026.09.22-01:51:22.013637     0.217 >> Model instance registered, version=365
# 2026.09.22-01:51:22.027838     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:365"; running launches=6
# 2026.09.22-01:51:22.027969     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch365.ipynb"
# 2026.09.22-02:03:28.764524     0.229 >> Trial 9 (18n_ppo_tr_frostbite_06:360) finished with value: 20303.00020894008 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-02:03:33.963475     0.002 >> Launch "18n_ppo_tr_frostbite_06:360" completed
# 2026.09.22-02:03:33.964382     0.001 >> 10 (+1) launches completed; running launches=5
# 2026.09.22-02:03:55.253025     0.196 >> Model instance registered, version=366
# 2026.09.22-02:03:55.265837     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:366"; running launches=6
# 2026.09.22-02:03:55.265939     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch366.ipynb"
# 2026.09.22-02:04:15.805843     0.101 >> Trial 10 (18n_ppo_tr_frostbite_06:361) finished with value: 20404.000223008363 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-02:04:20.822689     0.002 >> Launch "18n_ppo_tr_frostbite_06:361" completed
# 2026.09.22-02:04:20.823734     0.001 >> 11 (+1) launches completed; running launches=5
# 2026.09.22-02:04:41.504964     0.220 >> Model instance registered, version=367
# 2026.09.22-02:04:41.517864     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:367"; running launches=6
# 2026.09.22-02:04:41.517964     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch367.ipynb"
# 2026.09.22-02:04:53.931530     2.178 >> Trial 11 (18n_ppo_tr_frostbite_06:362) finished with value: 40304.000220869326 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-02:04:56.871723     0.001 >> Launch "18n_ppo_tr_frostbite_06:362" completed
# 2026.09.22-02:04:56.872529     0.001 >> 12 (+1) launches completed; running launches=5
# 2026.09.22-02:05:12.403506     0.192 >> Model instance registered, version=368
# 2026.09.22-02:05:12.411549     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:368"; running launches=6
# 2026.09.22-02:05:12.411698     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch368.ipynb"
# 2026.09.22-03:19:25.292190     2.596 >> Trial 12 (18n_ppo_tr_frostbite_06:363) finished with value: 204.00019829973948 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-03:19:27.812514     0.001 >> Launch "18n_ppo_tr_frostbite_06:363" completed
# 2026.09.22-03:19:27.813396     0.001 >> 13 (+1) launches completed; running launches=5
# 2026.09.22-03:19:53.653905     4.939 >> Trial 13 (18n_ppo_tr_frostbite_06:364) finished with value: 30303.000219635265 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-03:19:54.054353     0.220 >> Model instance registered, version=369
# 2026.09.22-03:19:54.066954     0.004 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:369"; running launches=6
# 2026.09.22-03:19:54.067122     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch369.ipynb"
# 2026.09.22-03:19:54.067801     0.001 >> Launch "18n_ppo_tr_frostbite_06:364" completed
# 2026.09.22-03:19:54.069177     0.001 >> 14 (+1) launches completed; running launches=5
# 2026.09.22-03:20:25.279277     0.205 >> Model instance registered, version=370
# 2026.09.22-03:20:25.287223     0.003 >> 1.5 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:370"; running launches=6
# 2026.09.22-03:20:25.287302     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch370.ipynb"
# 2026.09.22-03:21:58.172464     4.596 >> Trial 14 (18n_ppo_tr_frostbite_06:365) finished with value: 30303.000186617304 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-03:21:58.692146     0.001 >> Launch "18n_ppo_tr_frostbite_06:365" completed
# 2026.09.22-03:21:58.693004     0.001 >> 15 (+1) launches completed; running launches=5
# 2026.09.22-03:22:24.859624     0.193 >> Model instance registered, version=371
# 2026.09.22-03:22:24.871783     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:371"; running launches=6
# 2026.09.22-03:22:24.871921     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch371.ipynb"
# 2026.09.22-03:42:36.840445     1.401 >> Trial 16 (18n_ppo_tr_frostbite_06:367) finished with value: 30300.00020238585 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-03:42:40.555175     0.002 >> Launch "18n_ppo_tr_frostbite_06:367" completed
# 2026.09.22-03:42:40.556019     0.001 >> 16 (+1) launches completed; running launches=5
# 2026.09.22-03:42:46.663298     0.432 >> Trial 17 (18n_ppo_tr_frostbite_06:368) finished with value: 40304.000271602905 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-03:42:48.305131     1.642 >> Trial 15 (18n_ppo_tr_frostbite_06:366) finished with value: 30303.00023090635 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-03:42:51.553662     0.204 >> Model instance registered, version=372
# 2026.09.22-03:42:51.567053     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:372"; running launches=6
# 2026.09.22-03:42:51.567696     0.001 >> Launch "18n_ppo_tr_frostbite_06:368" completed
# 2026.09.22-03:42:51.568069     0.000 >> Launch "18n_ppo_tr_frostbite_06:366" completed
# 2026.09.22-03:42:51.568440     0.000 >> 18 (+2) launches completed; running launches=4
# 2026.09.22-03:42:51.567210     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch372.ipynb"
# 2026.09.22-03:43:22.970341     0.196 >> Model instance registered, version=373
# 2026.09.22-03:43:22.979940     0.003 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:373"; running launches=5
# 2026.09.22-03:43:22.980098     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch373.ipynb"
# 2026.09.22-03:43:54.227808     0.211 >> Model instance registered, version=374
# 2026.09.22-03:43:54.240878     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:374"; running launches=6
# 2026.09.22-03:43:54.241030     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch374.ipynb"
# 2026.09.22-04:51:52.081819     3.166 >> Trial 19 (18n_ppo_tr_frostbite_06:370) finished with value: 40403.0002708899 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-04:51:54.035585     0.001 >> Launch "18n_ppo_tr_frostbite_06:370" completed
# 2026.09.22-04:51:54.036525     0.001 >> 19 (+1) launches completed; running launches=5
# 2026.09.22-04:52:15.124796     0.222 >> Model instance registered, version=375
# 2026.09.22-04:52:15.137771     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:375"; running launches=6
# 2026.09.22-04:52:15.137897     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch375.ipynb"
# 2026.09.22-04:52:15.340040     0.202 >> Trial 18 (18n_ppo_tr_frostbite_06:369) finished with value: 20403.000253613052 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-04:52:20.282635     0.003 >> Launch "18n_ppo_tr_frostbite_06:369" completed
# 2026.09.22-04:52:20.283642     0.001 >> 20 (+1) launches completed; running launches=5
# 2026.09.22-04:52:46.627240     0.194 >> Model instance registered, version=376
# 2026.09.22-04:52:46.635286     0.003 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:376"; running launches=6
# 2026.09.22-04:52:46.635420     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch376.ipynb"
# 2026.09.22-04:52:49.653866     3.018 >> Trial 20 (18n_ppo_tr_frostbite_06:371) finished with value: 30402.00018752228 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-04:52:51.753489     0.002 >> Launch "18n_ppo_tr_frostbite_06:371" completed
# 2026.09.22-04:52:51.754055     0.001 >> 21 (+1) launches completed; running launches=5
# 2026.09.22-04:53:18.513120     0.207 >> Model instance registered, version=377
# 2026.09.22-04:53:18.521674     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:377"; running launches=6
# 2026.09.22-04:53:18.522241     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch377.ipynb"
# 2026.09.22-05:21:54.489176     2.913 >> Trial 22 (18n_ppo_tr_frostbite_06:373) finished with value: 40304.0002146716 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-05:21:56.691440     0.001 >> Launch "18n_ppo_tr_frostbite_06:373" completed
# 2026.09.22-05:21:56.692267     0.001 >> 22 (+1) launches completed; running launches=5
# 2026.09.22-05:22:22.462535     0.200 >> Model instance registered, version=378
# 2026.09.22-05:22:22.476377     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:378"; running launches=6
# 2026.09.22-05:22:22.476510     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch378.ipynb"
# 2026.09.22-05:22:24.805115     2.329 >> Trial 23 (18n_ppo_tr_frostbite_06:374) finished with value: 30304.00021502811 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-05:22:27.584294     0.001 >> Launch "18n_ppo_tr_frostbite_06:374" completed
# 2026.09.22-05:22:27.584872     0.001 >> 23 (+1) launches completed; running launches=5
# 2026.09.22-05:22:53.363185     0.207 >> Model instance registered, version=379
# 2026.09.22-05:22:53.371182     0.003 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:379"; running launches=6
# 2026.09.22-05:22:53.371321     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch379.ipynb"
# 2026.09.22-05:22:54.049649     0.678 >> Trial 21 (18n_ppo_tr_frostbite_06:372) finished with value: 20304.000230412723 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-05:22:58.477576     0.001 >> Launch "18n_ppo_tr_frostbite_06:372" completed
# 2026.09.22-05:22:58.478127     0.001 >> 24 (+1) launches completed; running launches=5
# 2026.09.22-05:23:24.260397     0.200 >> Model instance registered, version=380
# 2026.09.22-05:23:24.270950     0.003 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:380"; running launches=6
# 2026.09.22-05:23:24.271068     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch380.ipynb"
# 2026.09.22-06:22:15.253036     0.312 >> Trial 24 (18n_ppo_tr_frostbite_06:375) finished with value: 30303.00023507473 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-06:22:20.059040     0.002 >> Launch "18n_ppo_tr_frostbite_06:375" completed
# 2026.09.22-06:22:20.059877     0.001 >> 25 (+1) launches completed; running launches=5
# 2026.09.22-06:23:19.108979     2.526 >> Trial 25 (18n_ppo_tr_frostbite_06:376) finished with value: 30303.00023063211 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-06:23:21.698456     0.001 >> Launch "18n_ppo_tr_frostbite_06:376" completed
# 2026.09.22-06:23:21.699284     0.001 >> 26 (+1) launches completed; running launches=4
# 2026.09.22-06:23:31.603464     4.790 >> Trial 26 (18n_ppo_tr_frostbite_06:377) finished with value: 30402.00021812697 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-06:23:31.930730     0.001 >> Launch "18n_ppo_tr_frostbite_06:377" completed
# 2026.09.22-06:23:31.931619     0.001 >> 27 (+1) launches completed; running launches=3
# 2026.09.22-07:00:18.662126     2.290 >> Trial 27 (18n_ppo_tr_frostbite_06:378) finished with value: 40402.00025503908 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-07:00:21.486477     0.001 >> Launch "18n_ppo_tr_frostbite_06:378" completed
# 2026.09.22-07:00:21.487323     0.001 >> 28 (+1) launches completed; running launches=2
# 2026.09.22-07:00:53.189968     0.999 >> Trial 29 (18n_ppo_tr_frostbite_06:380) finished with value: 40402.000233593855 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-07:00:57.307396     0.001 >> Launch "18n_ppo_tr_frostbite_06:380" completed
# 2026.09.22-07:00:57.308511     0.001 >> 29 (+1) launches completed; running launches=1
# 2026.09.22-07:01:25.221310     2.139 >> Trial 28 (18n_ppo_tr_frostbite_06:379) finished with value: 30303.000236829837 and parameters: {}. Best is trial 6 with value: 40404.0002171123
# 2026.09.22-07:01:28.199994     0.001 >> Launch "18n_ppo_tr_frostbite_06:379" completed
# 2026.09.22-07:01:28.200828     0.001 >> 30 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-22 07:01:33,228] Using an existing study with name '18n_study_18.5e' instead of creating a new one.
# 2026.09.22-07:01:33.231623     5.031 >> Study statistics:
# 2026.09.22-07:01:33.234815     0.003 >> 	Number of finished trials: 30
# 2026.09.22-07:01:33.235980     0.001 >> 	Number of pruned trials: 0
# 2026.09.22-07:01:33.236689     0.001 >> 	Number of complete trials: 30
# 2026.09.22-07:01:33.237845     0.001 >> Best trial:
# 2026.09.22-07:01:33.239387     0.002 >> 	Value: 40404.0002171123
# 2026.09.22-07:01:33.240055     0.001 >> 	Model version: 357
# 2026.09.22-07:01:33.240769     0.001 >> 	Params:
