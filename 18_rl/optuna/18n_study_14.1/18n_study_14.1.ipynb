# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 5 поколений по 6 млн шагов с последующим отбором чемпионов. Наследники этих чемпионов будут использоваться на следующем шаге.
#
# Данный эксперимент - это первый шаг. Здесь агент должен научиться заходить в иглу = прорыв.
#
# Особенности:
# - энкодер из `18d_world_model_08`
# - механика повторяет 17-ых агентов
# - `prediction_coef=0.1`
# - `sequence_length=10`

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_04.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    generations_count = 5
    generation_ind = 0
    generation_steps_count = 6_000_000
    all_generations_steps_count = generation_steps_count * generations_count
    learn_rate_range = (0.00025, 0.00025 * 0.1)
    ent_coef_range = (0.05, 0.05 * 0.1)
    ####
    
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.agent.parent = None 
    HP.agent.ob_shape = (1, 178, 152)
    HP.agent.sequence_length = 10
    HP.agent.action_plan_length = 10 
    HP.agent.encoder = dict(source='18d_world_model_08:217', is_trainable=False)
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    
    # Video params
    HP.video.capture_policy = 'every(500000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = None
    HP.video.capture_env_ram_patches = None
    HP.video.break_on_level_passed = False
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = generation_steps_count # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = None
    HP.ppo.rollout_env_ram_patches = [
        ['last_life', 'full_igloo', 'bailey_right_at_the_igloo_door', 'temperature_10'],
        ['last_life', 'full_igloo', 'bailey_very_near_igloo_door', 'temperature_10'],  
        ['last_life', 'full_igloo', 'bailey_near_center', 'temperature_10'],
        ['last_life', 'one_remaining_igloo', 'bailey_near_center', 'temperature_10'],
        ['last_life', 'three_remaining_igloo', 'bailey_near_center', 'temperature_20'],
        ['last_life', 'half_igloo', 'bailey_near_center'],
        ['last_life', 'half_igloo'],
        ['last_life'],
    ]
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 256 
    learn_rate_change_speed = (learn_rate_range[1] - learn_rate_range[0]) / generations_count
    learn_rate_a = learn_rate_range[0] + learn_rate_change_speed * generation_ind
    learn_rate_b = learn_rate_a + learn_rate_change_speed
    HP.ppo.learn_rate = f'linear({learn_rate_a}, {learn_rate_b})'
    # HP.ppo.learn_rate = 'linear(0.00025, 0.00015)'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.5 # coefficient of the value function within loss function
    ent_coef_change_speed = (ent_coef_range[1] - ent_coef_range[0]) / generations_count
    ent_coef_a = ent_coef_range[0] + ent_coef_change_speed * generation_ind
    ent_coef_b = ent_coef_a + ent_coef_change_speed
    HP.ppo.ent_coef = f'linear({ent_coef_a}, {ent_coef_b})' # coefficient of the entropy member within loss function
    # HP.ppo.ent_coef = 'linear(0.05, 0.03)' # coefficient of the entropy member within loss function
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Особой разницы этого исследований и `18n_study_13.1` не заметно.
#
# Походу дополнительным фактором является то, что энкодер заморожен. Т.е. имеем следующую картину:
# |фактор|17|18|
# |---|---|---|
# |ob_shape|(3,84,84)|(1,178,152)|
# |цветность ob|полная|чб|
# |max_pooling|+|-|
# |rollout|одна история для всех reset|разные истории для reset|
# |pred_loss|MSE(latents)|MSE(normalize(latents))|
# |batch_size|1024|256|
# |энкодер|обучаемый|замороженный|
#
# <img src="./img/levels_passed.png">
# <img src="./img/reward.png">
# <img src="./img/episode_r.png">
# <img src="./img/value_mean.png">
# <img src="./img/value_loss.png">
#
# **Выводы**
# 1) посмотреть глазами на цепочки, когда value был огромным - есть ли проблема с тем, чтобы разобраться
# 2) думать в сторону сближения по факторам

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_04.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_04',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_14.1/18n_study_14.1.ipynb',
#  'optuna_study_name': '18n_study_14.1',
#  'optuna_study_serial': '14.1',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_14.1/18n_study_14.1.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-15 14:32:03,277] A new study created in Journal with name: 18n_study_14.1
# 2026.09.15-14:32:03.497854     0.193 >> Model instance registered, version=29
# 2026.09.15-14:32:03.512388     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch29.ipynb"
# 2026.09.15-14:32:03.513483     0.001 >> 6.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:29"; running launches=1
# 2026.09.15-14:32:34.746624     0.176 >> Model instance registered, version=30
# 2026.09.15-14:32:34.759458     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch30.ipynb"
# 2026.09.15-14:32:34.759911     0.005 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:30"; running launches=2
# 2026.09.15-14:33:05.778680     0.176 >> Model instance registered, version=31
# 2026.09.15-14:33:05.789604     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch31.ipynb"
# 2026.09.15-14:33:05.789866     0.005 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:31"; running launches=3
# 2026.09.15-14:33:37.758708     0.205 >> Model instance registered, version=32
# 2026.09.15-14:33:37.772055     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch32.ipynb"
# 2026.09.15-14:33:37.772557     0.006 >> 3.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:32"; running launches=4
# 2026.09.15-14:34:08.869350     0.184 >> Model instance registered, version=33
# 2026.09.15-14:34:08.880602     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch33.ipynb"
# 2026.09.15-14:34:08.881600     0.007 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:33"; running launches=5
# 2026.09.15-14:34:39.992906     0.183 >> Model instance registered, version=34
# 2026.09.15-14:34:40.006022     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch34.ipynb"
# 2026.09.15-14:34:40.006543     0.006 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:34"; running launches=6
# 2026.09.15-14:35:10.972606     0.193 >> Model instance registered, version=35
# 2026.09.15-14:35:10.986029     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch35.ipynb"
# 2026.09.15-14:35:10.986872     0.006 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:35"; running launches=7
# 2026.09.15-14:35:41.884470     0.175 >> Model instance registered, version=36
# 2026.09.15-14:35:41.894232     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch36.ipynb"
# 2026.09.15-14:35:41.894507     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:36"; running launches=8
# 2026.09.15-15:22:55.146687     0.200 >> Model instance registered, version=37
# 2026.09.15-15:22:55.155079     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch37.ipynb"
# 2026.09.15-15:22:55.155290     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:37"; running launches=9
# 2026.09.15-15:23:26.095040     0.253 >> Model instance registered, version=38
# 2026.09.15-15:23:26.111556     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch38.ipynb"
# 2026.09.15-15:23:26.112212     0.008 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:38"; running launches=10
# 2026.09.15-15:23:57.596147     0.182 >> Model instance registered, version=39
# 2026.09.15-15:23:57.611756     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch39.ipynb"
# 2026.09.15-15:23:57.612335     0.007 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:39"; running launches=11
# 2026.09.15-15:24:28.858103     0.223 >> Model instance registered, version=40
# 2026.09.15-15:24:28.867162     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch40.ipynb"
# 2026.09.15-15:24:28.867868     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:40"; running launches=12
# 2026.09.15-15:28:40.655175     0.206 >> Model instance registered, version=41
# 2026.09.15-15:28:40.664424     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch41.ipynb"
# 2026.09.15-15:28:40.664863     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:41"; running launches=13
# 2026.09.15-15:41:46.204952     0.177 >> Model instance registered, version=42
# 2026.09.15-15:41:46.214640     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch42.ipynb"
# 2026.09.15-15:41:46.214832     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:42"; running launches=14
# 2026.09.15-15:43:18.974794     0.204 >> Model instance registered, version=43
# 2026.09.15-15:43:18.988593     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch43.ipynb"
# 2026.09.15-15:43:18.988826     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:43"; running launches=15
# 2026.09.15-15:43:50.320917     0.196 >> Model instance registered, version=44
# 2026.09.15-15:43:50.329728     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch44.ipynb"
# 2026.09.15-15:43:50.330311     0.004 >> 3.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:44"; running launches=16
# 2026.09.15-15:44:22.000956     0.186 >> Model instance registered, version=45
# 2026.09.15-15:44:22.012745     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch45.ipynb"
# 2026.09.15-15:44:22.012940     0.005 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:45"; running launches=17
# 2026.09.15-15:44:53.083476     0.254 >> Model instance registered, version=46
# 2026.09.15-15:44:53.096431     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch46.ipynb"
# 2026.09.15-15:44:53.096742     0.005 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:46"; running launches=18
# 2026.09.15-15:45:23.979505     0.196 >> Model instance registered, version=47
# 2026.09.15-15:45:23.992744     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch47.ipynb"
# 2026.09.15-15:45:23.993014     0.006 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:47"; running launches=19
# 2026.09.15-15:45:54.886870     0.198 >> Model instance registered, version=48
# 2026.09.15-15:45:54.899103     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch48.ipynb"
# 2026.09.15-15:45:54.899709     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:48"; running launches=20
# 2026.09.15-15:49:46.719186     0.180 >> Model instance registered, version=49
# 2026.09.15-15:49:46.728581     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch49.ipynb"
# 2026.09.15-15:49:46.728825     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:49"; running launches=21
# 2026.09.15-16:11:34.101161     0.200 >> Model instance registered, version=50
# 2026.09.15-16:11:34.110577     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch50.ipynb"
# 2026.09.15-16:11:34.110782     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:50"; running launches=22
# 2026.09.15-16:36:37.958904     5.009 >> Trial 8 (18n_ppo_tr_frostbite_04:37) finished with value: 226.92307692307693 and parameters: {}. Best is trial 8 with value: 226.92307692307693
# 2026.09.15-16:36:38.075407     0.003 >> Launch "18n_ppo_tr_frostbite_04:37" completed
# 2026.09.15-16:36:38.076529     0.001 >> 1 (+1) launches completed; running launches=21
# 2026.09.15-16:37:03.938716     0.292 >> Model instance registered, version=51
# 2026.09.15-16:37:03.959122     0.008 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:51"; running launches=22
# 2026.09.15-16:37:03.959298     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch51.ipynb"
# 2026.09.15-16:37:28.804849     4.397 >> Trial 11 (18n_ppo_tr_frostbite_04:40) finished with value: 1627.6923076923076 and parameters: {}. Best is trial 11 with value: 1627.6923076923076
# 2026.09.15-16:37:29.525472     0.001 >> Launch "18n_ppo_tr_frostbite_04:40" completed
# 2026.09.15-16:37:29.526559     0.001 >> 2 (+1) launches completed; running launches=21
# 2026.09.15-16:37:49.245991     4.344 >> Trial 10 (18n_ppo_tr_frostbite_04:39) finished with value: 219.23076923076923 and parameters: {}. Best is trial 11 with value: 1627.6923076923076
# 2026.09.15-16:37:50.079224     0.001 >> Launch "18n_ppo_tr_frostbite_04:39" completed
# 2026.09.15-16:37:50.079914     0.001 >> 3 (+1) launches completed; running launches=20
# 2026.09.15-16:38:16.155044     0.200 >> Model instance registered, version=52
# 2026.09.15-16:38:16.166329     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:52"; running launches=21
# 2026.09.15-16:38:16.166497     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch52.ipynb"
# 2026.09.15-16:38:49.068284     2.181 >> Trial 9 (18n_ppo_tr_frostbite_04:38) finished with value: 517.6923076923077 and parameters: {}. Best is trial 11 with value: 1627.6923076923076
# 2026.09.15-16:38:52.021914     0.003 >> Launch "18n_ppo_tr_frostbite_04:38" completed
# 2026.09.15-16:38:52.023169     0.001 >> 4 (+1) launches completed; running launches=20
# 2026.09.15-16:39:17.801472     0.194 >> Model instance registered, version=53
# 2026.09.15-16:39:17.812590     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:53"; running launches=21
# 2026.09.15-16:39:17.812711     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch53.ipynb"
# 2026.09.15-16:41:20.396743     4.418 >> Trial 12 (18n_ppo_tr_frostbite_04:41) finished with value: 568.4615384615385 and parameters: {}. Best is trial 11 with value: 1627.6923076923076
# 2026.09.15-16:41:21.094585     0.001 >> Launch "18n_ppo_tr_frostbite_04:41" completed
# 2026.09.15-16:41:21.095768     0.001 >> 5 (+1) launches completed; running launches=20
# 2026.09.15-16:50:38.251509     2.748 >> Trial 13 (18n_ppo_tr_frostbite_04:42) finished with value: 245.3846153846154 and parameters: {}. Best is trial 11 with value: 1627.6923076923076
# 2026.09.15-16:50:40.628558     0.004 >> Launch "18n_ppo_tr_frostbite_04:42" completed
# 2026.09.15-16:50:40.629410     0.001 >> 6 (+1) launches completed; running launches=19
# 2026.09.15-16:53:34.111944     2.894 >> Trial 14 (18n_ppo_tr_frostbite_04:43) finished with value: 202.30769230769232 and parameters: {}. Best is trial 11 with value: 1627.6923076923076
# 2026.09.15-16:53:36.338526     0.002 >> Launch "18n_ppo_tr_frostbite_04:43" completed
# 2026.09.15-16:53:36.339802     0.001 >> 7 (+1) launches completed; running launches=18
# 2026.09.15-16:54:00.237279     3.372 >> Trial 16 (18n_ppo_tr_frostbite_04:45) finished with value: 220.0 and parameters: {}. Best is trial 11 with value: 1627.6923076923076
# 2026.09.15-16:54:01.986978     0.002 >> Launch "18n_ppo_tr_frostbite_04:45" completed
# 2026.09.15-16:54:01.988072     0.001 >> 8 (+1) launches completed; running launches=17
# 2026.09.15-16:54:49.937149     1.883 >> Trial 17 (18n_ppo_tr_frostbite_04:46) finished with value: 231.53846153846155 and parameters: {}. Best is trial 11 with value: 1627.6923076923076
# 2026.09.15-16:54:53.171830     0.001 >> Launch "18n_ppo_tr_frostbite_04:46" completed
# 2026.09.15-16:54:53.172751     0.001 >> 9 (+1) launches completed; running launches=16
# 2026.09.15-16:55:19.046764     0.226 >> Model instance registered, version=54
# 2026.09.15-16:55:19.057882     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:54"; running launches=17
# 2026.09.15-16:55:19.058058     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch54.ipynb"
# 2026.09.15-16:56:04.933000     4.811 >> Trial 15 (18n_ppo_tr_frostbite_04:44) finished with value: 230.76923076923077 and parameters: {}. Best is trial 11 with value: 1627.6923076923076
# 2026.09.15-16:56:05.240704     0.002 >> Launch "18n_ppo_tr_frostbite_04:44" completed
# 2026.09.15-16:56:05.242183     0.001 >> 10 (+1) launches completed; running launches=16
# 2026.09.15-16:56:31.115469     0.280 >> Model instance registered, version=55
# 2026.09.15-16:56:31.125652     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:55"; running launches=17
# 2026.09.15-16:56:31.125850     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch55.ipynb"
# 2026.09.15-16:57:02.010001     0.091 >> Trial 18 (18n_ppo_tr_frostbite_04:47) finished with value: 486.9230769230769 and parameters: {}. Best is trial 11 with value: 1627.6923076923076
# 2026.09.15-16:57:02.010986     0.001 >> Launch "18n_ppo_tr_frostbite_04:47" completed
# 2026.09.15-16:57:02.011503     0.001 >> 11 (+1) launches completed; running launches=16
# 2026.09.15-16:57:15.049118     2.807 >> Trial 19 (18n_ppo_tr_frostbite_04:48) finished with value: 234.6153846153846 and parameters: {}. Best is trial 11 with value: 1627.6923076923076
# 2026.09.15-16:57:17.356890     0.001 >> Launch "18n_ppo_tr_frostbite_04:48" completed
# 2026.09.15-16:57:17.357430     0.001 >> 12 (+1) launches completed; running launches=15
# 2026.09.15-16:57:22.662136     0.192 >> Model instance registered, version=56
# 2026.09.15-16:57:22.672193     0.003 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:56"; running launches=16
# 2026.09.15-16:57:22.672278     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch56.ipynb"
# 2026.09.15-16:57:53.573292     0.200 >> Model instance registered, version=57
# 2026.09.15-16:57:53.585473     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:57"; running launches=17
# 2026.09.15-16:57:53.585625     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch57.ipynb"
# 2026.09.15-16:58:15.431921     1.397 >> Trial 21 (18n_ppo_tr_frostbite_04:50) finished with value: 223.84615384615384 and parameters: {}. Best is trial 11 with value: 1627.6923076923076
# 2026.09.15-16:58:19.150944     0.001 >> Launch "18n_ppo_tr_frostbite_04:50" completed
# 2026.09.15-16:58:19.151858     0.001 >> 13 (+1) launches completed; running launches=16
# 2026.09.15-16:58:44.983964     0.228 >> Model instance registered, version=58
# 2026.09.15-16:58:44.993538     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:58"; running launches=17
# 2026.09.15-16:58:44.993663     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch58.ipynb"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 54
#      51 except TimeoutError as e:
#      52     pass
# ---> 54 time.sleep(5)
#
# KeyboardInterrupt:

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
