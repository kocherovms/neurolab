# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 5 поколений по 6 млн шагов с последующим отбором чемпионов. Наследники этих чемпионов будут использоваться на следующем шаге.
#
# Данный эксперимент - это четвёртый шаг. Даём 9 жизней и пусть играет, нарабатывает опыт. Используем чемпионов с 3-ого шага `18n_study_18.3e`.

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    generations_count = 5
    generation_ind = 3
    generation_steps_count = 6_000_000
    all_generations_steps_count = generation_steps_count * generations_count
    learn_rate_range = (0.00025, 0.00025 * 0.1)
    ent_coef_range = (0.05, 0.05 * 0.1)
    ####
    
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False

    parent = optuna_trial.suggest_categorical('parent', [
        '18n_ppo_tr_frostbite_06:331',
        '18n_ppo_tr_frostbite_06:326',
        '18n_ppo_tr_frostbite_06:319',
    ])
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights=parent)
    HP.encoder.is_trainable = True

    HP.agent.parent = parent 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(500000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = None
    HP.video.capture_env_ram_patches = None
    HP.video.break_on_level_passed = False
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = generation_steps_count # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = None
    HP.ppo.rollout_env_ram_patches = [
        ['nine_lives'],
    ]
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    learn_rate_change_speed = (learn_rate_range[1] - learn_rate_range[0]) / generations_count
    learn_rate_a = learn_rate_range[0] + learn_rate_change_speed * generation_ind
    learn_rate_b = learn_rate_a + learn_rate_change_speed
    HP.ppo.learn_rate = f'linear({learn_rate_a}, {learn_rate_b})'
    # HP.ppo.learn_rate = 'linear(0.00025, 0.00015)'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    ent_coef_change_speed = (ent_coef_range[1] - ent_coef_range[0]) / generations_count
    ent_coef_a = ent_coef_range[0] + ent_coef_change_speed * generation_ind
    ent_coef_b = ent_coef_a + ent_coef_change_speed
    HP.ppo.ent_coef = f'linear({ent_coef_a}, {ent_coef_b})' # coefficient of the entropy member within loss function
    # HP.ppo.ent_coef = 'linear(0.05, 0.03)' # coefficient of the entropy member within loss function
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Ну тут прям обилие агентов, которые уверенно доходят до 5-го уровня. И всего один агент `18n_ppo_tr_frostbite:335` (судя по `episode_r`), которые что-то такое уловил и прокачался в прохождении пятого уровня. Получается вероятность около 5% получения такого агента для данных родителей.
#
# В целом не особо рассчитывал, что тут будет прорыв и кто-то из агентов пройдёт 5 уровней. Вообще в котороый раз убеждаюсь, что `nine_lives` не даёт большого эффекта. Скорее просто фактор "низковисящих фруктов" - хочется самым простым способом проверить. А вдруг проканает.
#
# Видимо, что всё таки правильный путь идти через train RAM-ы.
#
# <img src="./img/score.png">
# <img src="./img/episode_r.png">
#
# **Выводы**
# 1) агенты из `18n_study_18.3e` в целом неплохо так прокачались
# 2) попробовать другой низковисящий фрукт - взять агента `18n_ppo_tr_frostbite:335` и просто натаскать его чере train RAM-ы

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_18.4e/18n_study_18.4e.ipynb',
#  'optuna_study_name': '18n_study_18.4e',
#  'optuna_study_serial': '18.4e',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_18.4e/18n_study_18.4e.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 18
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-21 19:21:39,533] A new study created in Journal with name: 18n_study_18.4e
# 2026.09.21-19:21:39.972488     0.290 >> Model instance registered, version=333
# 2026.09.21-19:21:39.983387     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch333.ipynb"
# 2026.09.21-19:21:39.983639     0.004 >> 6.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:333"; running launches=1
# 2026.09.21-19:22:10.908207     0.226 >> Model instance registered, version=334
# 2026.09.21-19:22:10.921732     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch334.ipynb"
# 2026.09.21-19:22:10.922886     0.007 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:334"; running launches=2
# 2026.09.21-19:22:41.870729     0.217 >> Model instance registered, version=335
# 2026.09.21-19:22:41.879710     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch335.ipynb"
# 2026.09.21-19:22:41.880006     0.004 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:335"; running launches=3
# 2026.09.21-19:23:12.927117     0.208 >> Model instance registered, version=336
# 2026.09.21-19:23:12.941269     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch336.ipynb"
# 2026.09.21-19:23:12.942238     0.001 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:336"; running launches=4
# 2026.09.21-19:23:43.873445     0.233 >> Model instance registered, version=337
# 2026.09.21-19:23:43.884604     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch337.ipynb"
# 2026.09.21-19:23:43.884888     0.004 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:337"; running launches=5
# 2026.09.21-19:24:15.120628     0.196 >> Model instance registered, version=338
# 2026.09.21-19:24:15.132197     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch338.ipynb"
# 2026.09.21-19:24:15.132443     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:338"; running launches=6
# 2026.09.21-20:11:14.322422     0.232 >> Model instance registered, version=339
# 2026.09.21-20:11:14.336178     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch339.ipynb"
# 2026.09.21-20:11:14.336437     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:339"; running launches=7
# 2026.09.21-20:11:45.388973     0.264 >> Model instance registered, version=340
# 2026.09.21-20:11:45.402432     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch340.ipynb"
# 2026.09.21-20:11:45.402878     0.005 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:340"; running launches=8
# 2026.09.21-20:12:16.340226     0.215 >> Model instance registered, version=341
# 2026.09.21-20:12:16.349751     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch341.ipynb"
# 2026.09.21-20:12:16.350050     0.004 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:341"; running launches=9
# 2026.09.21-20:12:47.436911     0.248 >> Model instance registered, version=342
# 2026.09.21-20:12:47.449169     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch342.ipynb"
# 2026.09.21-20:12:47.450148     0.001 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:342"; running launches=10
# 2026.09.21-20:49:22.474266     4.647 >> Trial 2 (18n_ppo_tr_frostbite_06:335) finished with value: 40104.00026822981 and parameters: {'parent': '18n_ppo_tr_frostbite_06:331'}. Best is trial 2 with value: 40104.00026822981
# 2026.09.21-20:49:22.953104     0.005 >> Launch "18n_ppo_tr_frostbite_06:335" completed
# 2026.09.21-20:49:22.954263     0.001 >> 1 (+1) launches completed; running launches=9
# 2026.09.21-20:49:48.988984     0.330 >> Model instance registered, version=343
# 2026.09.21-20:49:49.012695     0.009 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:343"; running launches=10
# 2026.09.21-20:49:49.012903     0.009 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch343.ipynb"
# 2026.09.21-20:51:01.933369     0.497 >> Trial 3 (18n_ppo_tr_frostbite_06:336) finished with value: 40404.00025893322 and parameters: {'parent': '18n_ppo_tr_frostbite_06:319'}. Best is trial 3 with value: 40404.00025893322
# 2026.09.21-20:51:06.549338     0.001 >> Launch "18n_ppo_tr_frostbite_06:336" completed
# 2026.09.21-20:51:06.550013     0.001 >> 2 (+1) launches completed; running launches=9
# 2026.09.21-20:51:27.203016     0.198 >> Model instance registered, version=344
# 2026.09.21-20:51:27.215057     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:344"; running launches=10
# 2026.09.21-20:51:27.215842     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch344.ipynb"
# 2026.09.21-20:51:41.972660     4.530 >> Trial 5 (18n_ppo_tr_frostbite_06:338) finished with value: 40304.00023704922 and parameters: {'parent': '18n_ppo_tr_frostbite_06:331'}. Best is trial 3 with value: 40404.00025893322
# 2026.09.21-20:51:42.734772     0.003 >> Launch "18n_ppo_tr_frostbite_06:338" completed
# 2026.09.21-20:51:42.735782     0.001 >> 3 (+1) launches completed; running launches=9
# 2026.09.21-20:51:58.334052     0.203 >> Model instance registered, version=345
# 2026.09.21-20:51:58.343501     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:345"; running launches=10
# 2026.09.21-20:51:58.343629     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch345.ipynb"
# 2026.09.21-20:55:31.897277     1.229 >> Trial 1 (18n_ppo_tr_frostbite_06:334) finished with value: 40203.00021442479 and parameters: {'parent': '18n_ppo_tr_frostbite_06:326'}. Best is trial 3 with value: 40404.00025893322
# 2026.09.21-20:55:35.790096     0.005 >> Launch "18n_ppo_tr_frostbite_06:334" completed
# 2026.09.21-20:55:35.790822     0.001 >> 4 (+1) launches completed; running launches=9
# 2026.09.21-20:55:40.307556     4.517 >> Trial 0 (18n_ppo_tr_frostbite_06:333) finished with value: 40404.00025928973 and parameters: {'parent': '18n_ppo_tr_frostbite_06:319'}. Best is trial 0 with value: 40404.00025928973
# 2026.09.21-20:55:41.228904     0.003 >> Launch "18n_ppo_tr_frostbite_06:333" completed
# 2026.09.21-20:55:41.229908     0.001 >> 5 (+1) launches completed; running launches=8
# 2026.09.21-20:55:51.729480     0.271 >> Model instance registered, version=346
# 2026.09.21-20:55:51.740453     0.004 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:346"; running launches=9
# 2026.09.21-20:55:51.740595     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch346.ipynb"
# 2026.09.21-20:56:22.857466     0.250 >> Model instance registered, version=347
# 2026.09.21-20:56:22.867887     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:347"; running launches=10
# 2026.09.21-20:56:22.868033     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch347.ipynb"
# 2026.09.21-20:56:49.721442     0.361 >> Trial 4 (18n_ppo_tr_frostbite_06:337) finished with value: 40404.000251446596 and parameters: {'parent': '18n_ppo_tr_frostbite_06:326'}. Best is trial 0 with value: 40404.00025928973
# 2026.09.21-20:56:54.492226     0.003 >> Launch "18n_ppo_tr_frostbite_06:337" completed
# 2026.09.21-20:56:54.493375     0.001 >> 6 (+1) launches completed; running launches=9
# 2026.09.21-20:57:15.224358     0.220 >> Model instance registered, version=348
# 2026.09.21-20:57:15.236853     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:348"; running launches=10
# 2026.09.21-20:57:15.236973     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch348.ipynb"
# 2026.09.21-21:33:56.416671     3.353 >> Trial 6 (18n_ppo_tr_frostbite_06:339) finished with value: 30403.0002237488 and parameters: {'parent': '18n_ppo_tr_frostbite_06:326'}. Best is trial 0 with value: 40404.00025928973
# 2026.09.21-21:33:58.336769     0.003 >> Launch "18n_ppo_tr_frostbite_06:339" completed
# 2026.09.21-21:33:58.337814     0.001 >> 7 (+1) launches completed; running launches=9
# 2026.09.21-21:34:24.112996     0.206 >> Model instance registered, version=349
# 2026.09.21-21:34:24.125333     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:349"; running launches=10
# 2026.09.21-21:34:24.125465     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch349.ipynb"
# 2026.09.21-21:35:06.262796     1.094 >> Trial 7 (18n_ppo_tr_frostbite_06:340) finished with value: 40404.00025882353 and parameters: {'parent': '18n_ppo_tr_frostbite_06:326'}. Best is trial 0 with value: 40404.00025928973
# 2026.09.21-21:35:10.285214     0.001 >> Launch "18n_ppo_tr_frostbite_06:340" completed
# 2026.09.21-21:35:10.286377     0.001 >> 8 (+1) launches completed; running launches=9
# 2026.09.21-21:35:36.275314     0.280 >> Model instance registered, version=350
# 2026.09.21-21:35:36.286403     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:350"; running launches=10
# 2026.09.21-21:35:36.286542     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch350.ipynb"
# 2026.09.21-21:36:17.827093     0.259 >> Trial 8 (18n_ppo_tr_frostbite_06:341) finished with value: 30303.00023746058 and parameters: {'parent': '18n_ppo_tr_frostbite_06:326'}. Best is trial 0 with value: 40404.00025928973
# 2026.09.21-21:36:22.685359     0.002 >> Launch "18n_ppo_tr_frostbite_06:341" completed
# 2026.09.21-21:36:22.686260     0.001 >> 9 (+1) launches completed; running launches=9
# 2026.09.21-21:37:01.187108     2.530 >> Trial 9 (18n_ppo_tr_frostbite_06:342) finished with value: 40303.00028081722 and parameters: {'parent': '18n_ppo_tr_frostbite_06:326'}. Best is trial 0 with value: 40404.00025928973
# 2026.09.21-21:37:03.775574     0.001 >> Launch "18n_ppo_tr_frostbite_06:342" completed
# 2026.09.21-21:37:03.776808     0.001 >> 10 (+1) launches completed; running launches=8
# 2026.09.21-22:15:21.980766     1.089 >> Trial 10 (18n_ppo_tr_frostbite_06:343) finished with value: 40403.00027456465 and parameters: {'parent': '18n_ppo_tr_frostbite_06:331'}. Best is trial 0 with value: 40404.00025928973
# 2026.09.21-22:15:26.006960     0.001 >> Launch "18n_ppo_tr_frostbite_06:343" completed
# 2026.09.21-22:15:26.007716     0.001 >> 11 (+1) launches completed; running launches=7
# 2026.09.21-22:18:10.238015     4.919 >> Trial 12 (18n_ppo_tr_frostbite_06:345) finished with value: 40404.0002541341 and parameters: {'parent': '18n_ppo_tr_frostbite_06:326'}. Best is trial 0 with value: 40404.00025928973
# 2026.09.21-22:18:10.435496     0.002 >> Launch "18n_ppo_tr_frostbite_06:345" completed
# 2026.09.21-22:18:10.436299     0.001 >> 12 (+1) launches completed; running launches=6
# 2026.09.21-22:18:14.301995     3.866 >> Trial 11 (18n_ppo_tr_frostbite_06:344) finished with value: 40404.000277828054 and parameters: {'parent': '18n_ppo_tr_frostbite_06:319'}. Best is trial 11 with value: 40404.000277828054
# 2026.09.21-22:18:15.612860     0.002 >> Launch "18n_ppo_tr_frostbite_06:344" completed
# 2026.09.21-22:18:15.614064     0.001 >> 13 (+1) launches completed; running launches=5
# 2026.09.21-22:30:32.943413     1.203 >> Trial 13 (18n_ppo_tr_frostbite_06:346) finished with value: 40404.00025248869 and parameters: {'parent': '18n_ppo_tr_frostbite_06:326'}. Best is trial 11 with value: 40404.000277828054
# 2026.09.21-22:30:36.857492     0.002 >> Launch "18n_ppo_tr_frostbite_06:346" completed
# 2026.09.21-22:30:36.858571     0.001 >> 14 (+1) launches completed; running launches=4
# 2026.09.21-22:30:44.511899     2.543 >> Trial 14 (18n_ppo_tr_frostbite_06:347) finished with value: 40404.000283230496 and parameters: {'parent': '18n_ppo_tr_frostbite_06:331'}. Best is trial 14 with value: 40404.000283230496
# 2026.09.21-22:30:47.086453     0.001 >> Launch "18n_ppo_tr_frostbite_06:347" completed
# 2026.09.21-22:30:47.087181     0.001 >> 15 (+1) launches completed; running launches=3
# 2026.09.21-22:31:19.865712     1.810 >> Trial 15 (18n_ppo_tr_frostbite_06:348) finished with value: 40203.00023617167 and parameters: {'parent': '18n_ppo_tr_frostbite_06:326'}. Best is trial 14 with value: 40404.000283230496
# 2026.09.21-22:31:23.176039     0.002 >> Launch "18n_ppo_tr_frostbite_06:348" completed
# 2026.09.21-22:31:23.176954     0.001 >> 16 (+1) launches completed; running launches=2
# 2026.09.21-22:35:33.000624     2.454 >> Trial 16 (18n_ppo_tr_frostbite_06:349) finished with value: 40403.00028534211 and parameters: {'parent': '18n_ppo_tr_frostbite_06:326'}. Best is trial 14 with value: 40404.000283230496
# 2026.09.21-22:35:35.660198     0.002 >> Launch "18n_ppo_tr_frostbite_06:349" completed
# 2026.09.21-22:35:35.661036     0.001 >> 17 (+1) launches completed; running launches=1
# 2026.09.21-22:36:53.465573     0.258 >> Trial 17 (18n_ppo_tr_frostbite_06:350) finished with value: 20403.000264664748 and parameters: {'parent': '18n_ppo_tr_frostbite_06:331'}. Best is trial 14 with value: 40404.000283230496
# 2026.09.21-22:36:58.334204     0.002 >> Launch "18n_ppo_tr_frostbite_06:350" completed
# 2026.09.21-22:36:58.335625     0.001 >> 18 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-21 22:37:03,369] Using an existing study with name '18n_study_18.4e' instead of creating a new one.
# 2026.09.21-22:37:03.373232     5.038 >> Study statistics:
# 2026.09.21-22:37:03.375463     0.002 >> 	Number of finished trials: 18
# 2026.09.21-22:37:03.375842     0.000 >> 	Number of pruned trials: 0
# 2026.09.21-22:37:03.376268     0.000 >> 	Number of complete trials: 18
# 2026.09.21-22:37:03.376860     0.001 >> Best trial:
# 2026.09.21-22:37:03.377703     0.001 >> 	Value: 40404.000283230496
# 2026.09.21-22:37:03.378273     0.001 >> 	Model version: 347
# 2026.09.21-22:37:03.378726     0.000 >> 	Params:
# 2026.09.21-22:37:03.379205     0.000 >> 		parent: 18n_ppo_tr_frostbite_06:331
