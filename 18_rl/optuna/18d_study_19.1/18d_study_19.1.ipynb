# %% [markdown]
# # Goal
#
# **Перезапуск `18d_study_18.1`**, в котором выяснилось, что и для обучения, и для теста использовался один и тот же датасет. Причём для все 12 датасетов для обучения были одинаковыми =)
#
# Продолжение `18d_study_17.1`, но с новым `18d_world_model_08`, который умеет предсказывать любой горизонт. Тестируем гиперпараметры:
# - `struct_projector=dict(type='Identity')`
# - `pred_latents_source`
# - `learn_rate`
# - `pred_loss_type='MSE'`

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18d_world_model_08.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.launch_goal = 'train_predictor'
    
    HP.general.comment = None
    HP.general.random_seed = random.randint(0, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True

    HP.dataset.train = [
        '18b_dataset_02:7:cls=train,no=1,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=2,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=3,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=4,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=5,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=6,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=7,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=8,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=9,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=10,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=11,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=12,seq=8,mp=0',
    ]
    HP.dataset.test = '18b_dataset_02:7:cls=test,no=1,seq=8,mp=0'

    HP.model.parent = '18d_world_model_07:8'
    # Give 4 obs, predict next 4 obs
    HP.model.input_sequence_length = 4
    HP.model.actions_count = 6
    HP.model.ob_shape = (1, 178, 152)
    HP.model.d_model = 256
    HP.model.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.model.encoder = dict(
        is_trainable=HP.launch_goal in ('train_encoder', 'train_all', None),
        vision_head=dict(grid=(6,6), features_counts=(16, 32, 64, 128)),
    )
    HP.model.predictor = dict(
        is_trainable=HP.launch_goal in ('train_predictor', 'train_all', None),
        pred_latents_source=optuna_trial.suggest_categorical('pred_latents_source', ['actions', 'separate']),
        parent=None, # do not load from HP.model.parent
    )
    HP.model.renderer = dict(
        is_trainable=HP.launch_goal in ('train_encoder', 'train_all', None),
        projector=dict(type='linear'), 
        render_engine=dict(
            type='layer', 
            layers_count=4, 
            features_counts=(96, 64, 32, 16),
        ),
    )
    HP.model.struct_projector = dict(
        is_trainable=HP.launch_goal in ('train_predictor', 'train_all', None),
        type='Identity',
        parent=None, # do not load from HP.model.parent
    )
    
    HP.train.epochs_count = 100
    HP.train.batch_size = 128
    HP.train.optimizer = 'AdamW'
    HP.train.max_grad_norm = 1.0
    HP.train.learn_rate = f'const({optuna_trial.suggest_float('learn_rate', 0.0001, 0.01)})'
    HP.train.bce_loss_coef = 'const(1.0)'
    HP.train.edge_loss_coef = 'const(1.0)'
    HP.train.recon_loss_coef = 'const(0.0)'
    HP.train.pred_loss = dict(
        type='MSE', 
        loss_coef='const(1.0)', 
    )
    
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Ну вот тут уже более честные результаты, и они ближе к ожидаемым. Как никак, когда нужно предсказывать более длинный горизонт, то точность будет неизбежно снижаться.
#
# <img src="./img/ssim.png">
#
# При изучении рендера чемпиона `18d_world_model_08/opt_19.1/60` пришла мысль, что будет полезным все экшны обрабатывать, а не только те, которые в предикшне. Это из-за того, что бывают ситуации, когда игрок уже получил ускорение, и это можно увидеть только по прошедшим действиям.
#
# Гипотеза подтвердилась - специальный запуск 72, показал стабильно лучшие результаты.
#
# <img src="./img/60-vs-72.png">
#
# Реализация 72-го запуска также выявила проблематику - на входящие латенты НЕ накидывался `input_temporal_encoding`. Т.е. мы по факту работали с мешком входящих латентов, а не с последовательностью.
#
# **Выводы**
# 1) использовать все экшны
# 2) перезапустить исследование с исправленным багом, когда не использовался `input_temporal_encoding`

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18d_world_model_08.ipynb',
#  'target_notebook_name': '18d_world_model_08',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18d_study_19.1/18d_study_19.1.ipynb',
#  'optuna_study_name': '18d_study_19.1',
#  'optuna_study_serial': '19.1',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18d_study_19.1/18d_study_19.1.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-14 12:06:18,998] A new study created in Journal with name: 18d_study_19.1
# 2026.09.14-12:06:19.233025     0.212 >> Model instance registered, version=42
# 2026.09.14-12:06:19.255710     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch42.ipynb"
# 2026.09.14-12:06:19.256080     0.008 >> 6.0 idle runners exist, submitted launch "18d_world_model_08:42"; running launches=1
# 2026.09.14-12:06:50.503524     0.190 >> Model instance registered, version=43
# 2026.09.14-12:06:50.521134     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch43.ipynb"
# 2026.09.14-12:06:50.521514     0.007 >> 5.5 idle runners exist, submitted launch "18d_world_model_08:43"; running launches=2
# 2026.09.14-12:07:21.433187     0.218 >> Model instance registered, version=44
# 2026.09.14-12:07:21.453042     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch44.ipynb"
# 2026.09.14-12:07:21.453989     0.008 >> 4.5 idle runners exist, submitted launch "18d_world_model_08:44"; running launches=3
# 2026.09.14-12:07:52.424903     0.192 >> Model instance registered, version=45
# 2026.09.14-12:07:52.444587     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch45.ipynb"
# 2026.09.14-12:07:52.444915     0.009 >> 3.7 idle runners exist, submitted launch "18d_world_model_08:45"; running launches=4
# 2026.09.14-12:08:23.511969     0.171 >> Model instance registered, version=46
# 2026.09.14-12:08:23.531510     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch46.ipynb"
# 2026.09.14-12:08:23.531755     0.008 >> 2.7 idle runners exist, submitted launch "18d_world_model_08:46"; running launches=5
# 2026.09.14-12:08:55.035833     0.185 >> Model instance registered, version=47
# 2026.09.14-12:08:55.054925     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch47.ipynb"
# 2026.09.14-12:08:55.055161     0.007 >> 1.7 idle runners exist, submitted launch "18d_world_model_08:47"; running launches=6
# 2026.09.14-12:19:24.095241     1.085 >> Trial 0 (18d_world_model_08:42) finished with value: 0.944231549431296 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.008588841377347181}. Best is trial 0 with value: 0.944231549431296
# 2026.09.14-12:19:28.131502     0.002 >> Launch "18d_world_model_08:42" completed
# 2026.09.14-12:19:28.132736     0.001 >> 1 (+1) launches completed; running launches=5
# 2026.09.14-12:19:54.620141     0.175 >> Model instance registered, version=48
# 2026.09.14-12:19:54.642404     0.010 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:48"; running launches=6
# 2026.09.14-12:19:54.642569     0.010 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch48.ipynb"
# 2026.09.14-12:20:51.101762     4.836 >> Trial 2 (18d_world_model_08:44) finished with value: 0.9516514421659505 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.002868259875368851}. Best is trial 2 with value: 0.9516514421659505
# 2026.09.14-12:20:51.381548     0.003 >> Launch "18d_world_model_08:44" completed
# 2026.09.14-12:20:51.382604     0.001 >> 2 (+1) launches completed; running launches=5
# 2026.09.14-12:21:17.772590     0.172 >> Model instance registered, version=49
# 2026.09.14-12:21:17.787291     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:49"; running launches=6
# 2026.09.14-12:21:17.787409     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch49.ipynb"
# 2026.09.14-12:21:19.878931     2.092 >> Trial 3 (18d_world_model_08:45) finished with value: 0.9573789760994459 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0015751491659214802}. Best is trial 3 with value: 0.9573789760994459
# 2026.09.14-12:21:22.898521     0.001 >> Launch "18d_world_model_08:45" completed
# 2026.09.14-12:21:22.899405     0.001 >> 3 (+1) launches completed; running launches=5
# 2026.09.14-12:21:48.729130     0.188 >> Model instance registered, version=50
# 2026.09.14-12:21:48.742150     0.006 >> 1.5 idle runners exist, submitted launch "18d_world_model_08:50"; running launches=6
# 2026.09.14-12:21:48.742344     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch50.ipynb"
# 2026.09.14-12:23:37.962593     0.280 >> Trial 1 (18d_world_model_08:43) finished with value: 0.9471268953952023 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.007298038483629671}. Best is trial 3 with value: 0.9573789760994459
# 2026.09.14-12:23:43.011380     0.002 >> Launch "18d_world_model_08:43" completed
# 2026.09.14-12:23:43.012588     0.001 >> 4 (+1) launches completed; running launches=5
# 2026.09.14-12:24:04.260433     0.169 >> Model instance registered, version=51
# 2026.09.14-12:24:04.281862     0.009 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:51"; running launches=6
# 2026.09.14-12:24:04.281970     0.009 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch51.ipynb"
# 2026.09.14-12:25:26.265256     4.310 >> Trial 4 (18d_world_model_08:46) finished with value: 0.9452988179049832 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.007351370089391553}. Best is trial 3 with value: 0.9573789760994459
# 2026.09.14-12:25:27.255031     0.003 >> Launch "18d_world_model_08:46" completed
# 2026.09.14-12:25:27.255916     0.001 >> 5 (+1) launches completed; running launches=5
# 2026.09.14-12:25:53.343214     0.214 >> Model instance registered, version=52
# 2026.09.14-12:25:53.361055     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:52"; running launches=6
# 2026.09.14-12:25:53.361175     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch52.ipynb"
# 2026.09.14-12:26:02.927117     4.446 >> Trial 5 (18d_world_model_08:47) finished with value: 0.9458253814763753 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.008345664228155568}. Best is trial 3 with value: 0.9573789760994459
# 2026.09.14-12:26:03.597205     0.002 >> Launch "18d_world_model_08:47" completed
# 2026.09.14-12:26:03.597966     0.001 >> 6 (+1) launches completed; running launches=5
# 2026.09.14-12:26:24.606698     0.203 >> Model instance registered, version=53
# 2026.09.14-12:26:24.622802     0.006 >> 1.3 idle runners exist, submitted launch "18d_world_model_08:53"; running launches=6
# 2026.09.14-12:26:24.622898     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch53.ipynb"
# 2026.09.14-12:32:44.641855     0.990 >> Trial 6 (18d_world_model_08:48) finished with value: 0.9502958039498351 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0018083517869536083}. Best is trial 3 with value: 0.9573789760994459
# 2026.09.14-12:32:48.769749     0.002 >> Launch "18d_world_model_08:48" completed
# 2026.09.14-12:32:48.770686     0.001 >> 7 (+1) launches completed; running launches=5
# 2026.09.14-12:33:14.680526     0.205 >> Model instance registered, version=54
# 2026.09.14-12:33:14.702333     0.008 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:54"; running launches=6
# 2026.09.14-12:33:14.702574     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch54.ipynb"
# 2026.09.14-12:34:36.353672     4.571 >> Trial 7 (18d_world_model_08:49) finished with value: 0.9537505676098564 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.000681743532170605}. Best is trial 3 with value: 0.9573789760994459
# 2026.09.14-12:34:36.901221     0.002 >> Launch "18d_world_model_08:49" completed
# 2026.09.14-12:34:36.902090     0.001 >> 8 (+1) launches completed; running launches=5
# 2026.09.14-12:35:01.444359     4.088 >> Trial 8 (18d_world_model_08:50) finished with value: 0.9517801284196404 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.0034203059600146236}. Best is trial 3 with value: 0.9573789760994459
# 2026.09.14-12:35:02.667125     0.192 >> Model instance registered, version=55
# 2026.09.14-12:35:02.683890     0.007 >> 1.2 idle runners exist, submitted launch "18d_world_model_08:55"; running launches=6
# 2026.09.14-12:35:02.684739     0.001 >> Launch "18d_world_model_08:50" completed
# 2026.09.14-12:35:02.685242     0.001 >> 9 (+1) launches completed; running launches=5
# 2026.09.14-12:35:02.684115     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch55.ipynb"
# 2026.09.14-12:35:33.646752     0.209 >> Model instance registered, version=56
# 2026.09.14-12:35:33.664225     0.006 >> 1.5 idle runners exist, submitted launch "18d_world_model_08:56"; running launches=6
# 2026.09.14-12:35:33.664418     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch56.ipynb"
# 2026.09.14-12:40:54.026316     1.605 >> Trial 9 (18d_world_model_08:51) finished with value: 0.9496595594618056 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0025163644695606955}. Best is trial 3 with value: 0.9573789760994459
# 2026.09.14-12:40:57.541499     0.003 >> Launch "18d_world_model_08:51" completed
# 2026.09.14-12:40:57.542384     0.001 >> 10 (+1) launches completed; running launches=5
# 2026.09.14-12:41:23.307549     0.196 >> Model instance registered, version=57
# 2026.09.14-12:41:23.327685     0.008 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:57"; running launches=6
# 2026.09.14-12:41:23.327811     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch57.ipynb"
# 2026.09.14-12:42:53.769160     3.369 >> Trial 10 (18d_world_model_08:52) finished with value: 0.9536721137836645 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0002745963145435318}. Best is trial 3 with value: 0.9573789760994459
# 2026.09.14-12:42:55.536665     0.003 >> Launch "18d_world_model_08:52" completed
# 2026.09.14-12:42:55.537632     0.001 >> 11 (+1) launches completed; running launches=5
# 2026.09.14-12:43:21.493020     0.181 >> Model instance registered, version=58
# 2026.09.14-12:43:21.505801     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:58"; running launches=6
# 2026.09.14-12:43:21.505949     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch58.ipynb"
# 2026.09.14-12:43:27.326947     0.715 >> Trial 11 (18d_world_model_08:53) finished with value: 0.9464717372273345 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0039667840672961705}. Best is trial 3 with value: 0.9573789760994459
# 2026.09.14-12:43:31.720299     0.001 >> Launch "18d_world_model_08:53" completed
# 2026.09.14-12:43:31.720716     0.000 >> 12 (+1) launches completed; running launches=5
# 2026.09.14-12:43:52.466355     0.200 >> Model instance registered, version=59
# 2026.09.14-12:43:52.484702     0.007 >> 1.2 idle runners exist, submitted launch "18d_world_model_08:59"; running launches=6
# 2026.09.14-12:43:52.484792     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch59.ipynb"
# 2026.09.14-12:46:12.487769     1.697 >> Trial 12 (18d_world_model_08:54) finished with value: 0.9450297493671947 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.00872778479336268}. Best is trial 3 with value: 0.9573789760994459
# 2026.09.14-12:46:15.908255     0.002 >> Launch "18d_world_model_08:54" completed
# 2026.09.14-12:46:15.909106     0.001 >> 13 (+1) launches completed; running launches=5
# 2026.09.14-12:46:42.305739     0.167 >> Model instance registered, version=60
# 2026.09.14-12:46:42.322915     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:60"; running launches=6
# 2026.09.14-12:46:42.323007     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch60.ipynb"
# 2026.09.14-12:48:22.153068     2.458 >> Trial 13 (18d_world_model_08:55) finished with value: 0.9486100254717773 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.0026779270724081286}. Best is trial 3 with value: 0.9573789760994459
# 2026.09.14-12:48:24.810494     0.002 >> Launch "18d_world_model_08:55" completed
# 2026.09.14-12:48:24.811560     0.001 >> 14 (+1) launches completed; running launches=5
# 2026.09.14-12:48:34.872581     4.945 >> Trial 14 (18d_world_model_08:56) finished with value: 0.9462056905281644 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.006870638323106836}. Best is trial 3 with value: 0.9573789760994459
# 2026.09.14-12:48:35.044881     0.002 >> Launch "18d_world_model_08:56" completed
# 2026.09.14-12:48:35.045866     0.001 >> 15 (+1) launches completed; running launches=4
# 2026.09.14-12:48:40.404876     0.178 >> Model instance registered, version=61
# 2026.09.14-12:48:40.426121     0.010 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:61"; running launches=5
# 2026.09.14-12:48:40.426302     0.010 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch61.ipynb"
# 2026.09.14-12:49:11.271710     0.171 >> Model instance registered, version=62
# 2026.09.14-12:49:11.288847     0.006 >> 1.5 idle runners exist, submitted launch "18d_world_model_08:62"; running launches=6
# 2026.09.14-12:49:11.288989     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch62.ipynb"
# 2026.09.14-12:57:27.891997     4.598 >> Trial 15 (18d_world_model_08:57) finished with value: 0.948109734277283 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.004936303455721611}. Best is trial 3 with value: 0.9573789760994459
# 2026.09.14-12:57:28.411238     0.002 >> Launch "18d_world_model_08:57" completed
# 2026.09.14-12:57:28.412192     0.001 >> 16 (+1) launches completed; running launches=5
# 2026.09.14-12:57:54.163580     0.178 >> Model instance registered, version=63
# 2026.09.14-12:57:54.176360     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:63"; running launches=6
# 2026.09.14-12:57:54.176513     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch63.ipynb"
# 2026.09.14-12:59:08.924387     2.501 >> Trial 18 (18d_world_model_08:60) finished with value: 0.9581508989093684 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.00032738295953039435}. Best is trial 18 with value: 0.9581508989093684
# 2026.09.14-12:59:11.540638     0.002 >> Launch "18d_world_model_08:60" completed
# 2026.09.14-12:59:11.541614     0.001 >> 17 (+1) launches completed; running launches=5
# 2026.09.14-12:59:37.392183     0.175 >> Model instance registered, version=64
# 2026.09.14-12:59:37.405488     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:64"; running launches=6
# 2026.09.14-12:59:37.405660     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch64.ipynb"
# 2026.09.14-13:00:27.243480     3.022 >> Trial 16 (18d_world_model_08:58) finished with value: 0.957335613213927 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.000550662585239223}. Best is trial 18 with value: 0.9581508989093684
# 2026.09.14-13:00:29.336083     0.001 >> Launch "18d_world_model_08:58" completed
# 2026.09.14-13:00:29.337137     0.001 >> 18 (+1) launches completed; running launches=5
# 2026.09.14-13:00:55.109095     0.180 >> Model instance registered, version=65
# 2026.09.14-13:00:55.122654     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:65"; running launches=6
# 2026.09.14-13:00:55.122819     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch65.ipynb"
# 2026.09.14-13:01:05.618033     0.275 >> Trial 17 (18d_world_model_08:59) finished with value: 0.9535440952504048 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0004352147712041461}. Best is trial 18 with value: 0.9581508989093684
# 2026.09.14-13:01:10.462290     0.002 >> Launch "18d_world_model_08:59" completed
# 2026.09.14-13:01:10.463103     0.001 >> 19 (+1) launches completed; running launches=5
# 2026.09.14-13:01:25.997367     0.188 >> Model instance registered, version=66
# 2026.09.14-13:01:26.013101     0.006 >> 1.2 idle runners exist, submitted launch "18d_world_model_08:66"; running launches=6
# 2026.09.14-13:01:26.013199     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch66.ipynb"
# 2026.09.14-13:01:52.870346     1.011 >> Trial 19 (18d_world_model_08:61) finished with value: 0.953888800935956 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0001435630747436559}. Best is trial 18 with value: 0.9581508989093684
# 2026.09.14-13:01:56.976387     0.001 >> Launch "18d_world_model_08:61" completed
# 2026.09.14-13:01:56.977463     0.001 >> 20 (+1) launches completed; running launches=5
# 2026.09.14-13:02:15.706678     3.389 >> Trial 20 (18d_world_model_08:62) finished with value: 0.9544321164066755 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.00030112092292644007}. Best is trial 18 with value: 0.9581508989093684
# 2026.09.14-13:02:17.605764     0.174 >> Model instance registered, version=67
# 2026.09.14-13:02:17.623969     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:67"; running launches=6
# 2026.09.14-13:02:17.624774     0.001 >> Launch "18d_world_model_08:62" completed
# 2026.09.14-13:02:17.624096     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch67.ipynb"
# 2026.09.14-13:02:17.625049     0.000 >> 21 (+1) launches completed; running launches=5
# 2026.09.14-13:02:48.497626     0.175 >> Model instance registered, version=68
# 2026.09.14-13:02:48.515389     0.007 >> 1.5 idle runners exist, submitted launch "18d_world_model_08:68"; running launches=6
# 2026.09.14-13:02:48.515536     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch68.ipynb"
# 2026.09.14-13:11:59.709088     1.601 >> Trial 22 (18d_world_model_08:64) finished with value: 0.9564575636976796 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0016401697744238945}. Best is trial 18 with value: 0.9581508989093684
# 2026.09.14-13:12:03.234092     0.002 >> Launch "18d_world_model_08:64" completed
# 2026.09.14-13:12:03.235512     0.001 >> 22 (+1) launches completed; running launches=5
# 2026.09.14-13:14:01.900142     0.237 >> Trial 21 (18d_world_model_08:63) finished with value: 0.9548025122321064 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0002217094541459648}. Best is trial 18 with value: 0.9581508989093684
# 2026.09.14-13:14:06.779765     0.002 >> Launch "18d_world_model_08:63" completed
# 2026.09.14-13:14:06.780908     0.001 >> 23 (+1) launches completed; running launches=4
# 2026.09.14-13:14:27.694443     0.179 >> Model instance registered, version=69
# 2026.09.14-13:14:27.717140     0.011 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:69"; running launches=5
# 2026.09.14-13:14:27.717389     0.011 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch69.ipynb"
# 2026.09.14-13:15:18.653364     4.870 >> Trial 25 (18d_world_model_08:67) finished with value: 0.9533272247836851 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0015700813195427868}. Best is trial 18 with value: 0.9581508989093684
# 2026.09.14-13:15:18.903044     0.002 >> Launch "18d_world_model_08:67" completed
# 2026.09.14-13:15:18.903873     0.001 >> 24 (+1) launches completed; running launches=4
# 2026.09.14-13:15:44.763634     0.142 >> Model instance registered, version=70
# 2026.09.14-13:15:44.787845     0.011 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:70"; running launches=5
# 2026.09.14-13:15:44.787994     0.011 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch70.ipynb"
# 2026.09.14-13:15:57.432355     2.428 >> Trial 26 (18d_world_model_08:68) finished with value: 0.9547377723197569 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0014465276358196593}. Best is trial 18 with value: 0.9581508989093684
# 2026.09.14-13:16:00.122420     0.001 >> Launch "18d_world_model_08:68" completed
# 2026.09.14-13:16:00.123527     0.001 >> 25 (+1) launches completed; running launches=4
# 2026.09.14-13:16:15.740870     0.200 >> Model instance registered, version=71
# 2026.09.14-13:16:15.759902     0.008 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:71"; running launches=5
# 2026.09.14-13:16:15.760092     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch71.ipynb"
# 2026.09.14-13:17:49.314817     0.956 >> Trial 23 (18d_world_model_08:65) finished with value: 0.9570598845685192 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0016524227970257975}. Best is trial 18 with value: 0.9581508989093684
# 2026.09.14-13:17:53.556100     0.003 >> Launch "18d_world_model_08:65" completed
# 2026.09.14-13:17:53.557417     0.001 >> 26 (+1) launches completed; running launches=4
# 2026.09.14-13:24:10.780149     2.784 >> Trial 24 (18d_world_model_08:66) finished with value: 0.9533409111528726 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0015549296309648438}. Best is trial 18 with value: 0.9581508989093684
# 2026.09.14-13:24:13.113979     0.001 >> Launch "18d_world_model_08:66" completed
# 2026.09.14-13:24:13.114791     0.001 >> 27 (+1) launches completed; running launches=3
# 2026.09.14-13:26:11.057888     4.819 >> Trial 27 (18d_world_model_08:69) finished with value: 0.9533334859687147 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0015128439608684814}. Best is trial 18 with value: 0.9581508989093684
# 2026.09.14-13:26:11.352796     0.002 >> Launch "18d_world_model_08:69" completed
# 2026.09.14-13:26:11.353712     0.001 >> 28 (+1) launches completed; running launches=2
# 2026.09.14-13:28:14.085077     4.963 >> Trial 28 (18d_world_model_08:70) finished with value: 0.9540182451425666 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0012868544699348554}. Best is trial 18 with value: 0.9581508989093684
# 2026.09.14-13:28:14.241185     0.002 >> Launch "18d_world_model_08:70" completed
# 2026.09.14-13:28:14.242216     0.001 >> 29 (+1) launches completed; running launches=1
# 2026.09.14-13:28:36.423635     1.736 >> Trial 29 (18d_world_model_08:71) finished with value: 0.949530654750507 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.004402307879155802}. Best is trial 18 with value: 0.9581508989093684
# 2026.09.14-13:28:39.805893     0.002 >> Launch "18d_world_model_08:71" completed
# 2026.09.14-13:28:39.806779     0.001 >> 30 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-14 13:28:44,838] Using an existing study with name '18d_study_19.1' instead of creating a new one.
# 2026.09.14-13:28:44.839607     5.033 >> Study statistics:
# 2026.09.14-13:28:44.840980     0.001 >> 	Number of finished trials: 30
# 2026.09.14-13:28:44.841328     0.000 >> 	Number of pruned trials: 0
# 2026.09.14-13:28:44.841750     0.000 >> 	Number of complete trials: 30
# 2026.09.14-13:28:44.842183     0.000 >> Best trial:
# 2026.09.14-13:28:44.842842     0.001 >> 	Value: 0.9581508989093684
# 2026.09.14-13:28:44.843558     0.001 >> 	Model version: 60
# 2026.09.14-13:28:44.844115     0.001 >> 	Params:
# 2026.09.14-13:28:44.844694     0.001 >> 		pred_latents_source: separate
# 2026.09.14-13:28:44.845456     0.001 >> 		learn_rate: 0.00032738295953039435
