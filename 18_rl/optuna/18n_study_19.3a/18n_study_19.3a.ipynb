# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 6 шагов. На каждом шаге отбираем чемпионов для продолжения след. шага.
#
# Данный эксперимент - это третий шаг. Здесь агент 80% играет на втором уровне с train RAM-ами, 20% времени играет с первого уровня.

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False

    parent = optuna_trial.suggest_categorical('parent', [
        '18n_ppo_tr_frostbite_06:439',
        '18n_ppo_tr_frostbite_06:428',
        '18n_ppo_tr_frostbite_06:436',
        '18n_ppo_tr_frostbite_06:440',
        '18n_ppo_tr_frostbite_06:445',
    ])
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights=parent)
    HP.encoder.is_trainable = True

    HP.agent.parent = parent 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(200000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = None
    HP.video.capture_env_ram_patches = None
    HP.video.break_on_level_passed = False
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = 3_000_000 # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = [
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=none', # 0
        
        'com.develorium.neurolab.frostbite_ram:level2:1:cls=train1', # 1
        'com.develorium.neurolab.frostbite_ram:level2:1:cls=train2', # 2
        'com.develorium.neurolab.frostbite_ram:level2:1:cls=train3', # 3
        'com.develorium.neurolab.frostbite_ram:level2:1:cls=train4', # 4
        'com.develorium.neurolab.frostbite_ram:level2:1:cls=train5', # 5
    ]
    HP.ppo.rollout_env_ram_patches = [
        ['no_score', 'three_lives', 'no_igloo', 'temperature_45', 'bailey_safe_random_spawn'], # 0
        ['no_score', 'last_life', 'no_igloo', 'temperature_45', 'bailey_safe_random_spawn'], # 1
    ]
    HP.ppo.rollout_env_stories = [
        '0;0',   # level 1 - 20% time
        '1:6;1', # level 2 - 80% time
        '1:6;1', # level 2 - 80% time
        '1:6;1', # level 2 - 80% time
        '1:6;1', # level 2 - 80% time
    ]
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    HP.ppo.learn_rate = f'const({0.00025 - 0.0002 / 6 * 2})'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    HP.ppo.ent_coef = f'const({0.05 - 0.04 / 6 * 2})'
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Некоторое кол-во агентов даже до 5-го уровня дошло, хотя разброс (дисперсия) по `score` большой.
#
# Чемпионы:
# - `18n_ppo_tr_frostbite_06:458`
# - `18n_ppo_tr_frostbite_06:464`
# - `18n_ppo_tr_frostbite_06:465`
#
# <img src="./img/score.png">
# <img src="./img/episode_r.png">
#
# **Выводы**
# 1) делает следующий шаг

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.3a/18n_study_19.3a.ipynb',
#  'optuna_study_name': '18n_study_19.3a',
#  'optuna_study_serial': '19.3a',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.3a/18n_study_19.3a.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 20
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-22 20:17:51,907] Using an existing study with name '18n_study_19.3a' instead of creating a new one.
# 2026.09.22-20:17:52.170372     0.231 >> Model instance registered, version=450
# 2026.09.22-20:17:52.185344     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch450.ipynb"
# 2026.09.22-20:17:52.186060     0.007 >> 10.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:450"; running launches=1
# 2026.09.22-20:18:23.451477     0.207 >> Model instance registered, version=451
# 2026.09.22-20:18:23.465258     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch451.ipynb"
# 2026.09.22-20:18:23.465540     0.006 >> 9.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:451"; running launches=2
# 2026.09.22-20:18:54.773760     0.202 >> Model instance registered, version=452
# 2026.09.22-20:18:54.784972     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch452.ipynb"
# 2026.09.22-20:18:54.785570     0.005 >> 8.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:452"; running launches=3
# 2026.09.22-20:19:25.734424     0.202 >> Model instance registered, version=453
# 2026.09.22-20:19:25.747319     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch453.ipynb"
# 2026.09.22-20:19:25.747616     0.005 >> 7.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:453"; running launches=4
# 2026.09.22-20:19:56.907421     0.203 >> Model instance registered, version=454
# 2026.09.22-20:19:56.920675     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch454.ipynb"
# 2026.09.22-20:19:56.921200     0.006 >> 6.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:454"; running launches=5
# 2026.09.22-20:20:28.309625     0.241 >> Model instance registered, version=455
# 2026.09.22-20:20:28.323688     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch455.ipynb"
# 2026.09.22-20:20:28.324595     0.007 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:455"; running launches=6
# 2026.09.22-20:20:59.250281     0.238 >> Model instance registered, version=456
# 2026.09.22-20:20:59.265637     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch456.ipynb"
# 2026.09.22-20:20:59.265870     0.005 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:456"; running launches=7
# 2026.09.22-20:21:30.312155     0.217 >> Model instance registered, version=457
# 2026.09.22-20:21:30.325455     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch457.ipynb"
# 2026.09.22-20:21:30.325678     0.006 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:457"; running launches=8
# 2026.09.22-20:22:01.337396     0.204 >> Model instance registered, version=458
# 2026.09.22-20:22:01.345775     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch458.ipynb"
# 2026.09.22-20:22:01.345997     0.004 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:458"; running launches=9
# 2026.09.22-20:22:32.269605     0.245 >> Model instance registered, version=459
# 2026.09.22-20:22:32.284051     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch459.ipynb"
# 2026.09.22-20:22:32.284309     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:459"; running launches=10
# 2026.09.22-21:02:17.727153     2.696 >> Trial 7 (18n_ppo_tr_frostbite_06:453) finished with value: 30303.00018054813 and parameters: {'parent': '18n_ppo_tr_frostbite_06:436'}. Best is trial 7 with value: 30303.00018054813
# 2026.09.22-21:02:20.462810     0.002 >> Launch "18n_ppo_tr_frostbite_06:453" completed
# 2026.09.22-21:02:20.463811     0.001 >> 1 (+1) launches completed; running launches=9
# 2026.09.22-21:02:46.714234     0.242 >> Model instance registered, version=460
# 2026.09.22-21:02:46.724518     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:460"; running launches=10
# 2026.09.22-21:02:46.724628     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch460.ipynb"
# 2026.09.22-21:02:49.470603     2.746 >> Trial 8 (18n_ppo_tr_frostbite_06:454) finished with value: 30303.000168449198 and parameters: {'parent': '18n_ppo_tr_frostbite_06:428'}. Best is trial 7 with value: 30303.00018054813
# 2026.09.22-21:02:51.836664     0.001 >> Launch "18n_ppo_tr_frostbite_06:454" completed
# 2026.09.22-21:02:51.837309     0.001 >> 2 (+1) launches completed; running launches=9
# 2026.09.22-21:03:18.721863     0.295 >> Model instance registered, version=461
# 2026.09.22-21:03:18.732645     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:461"; running launches=10
# 2026.09.22-21:03:18.732789     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch461.ipynb"
# 2026.09.22-21:04:13.092498     2.376 >> Trial 5 (18n_ppo_tr_frostbite_06:451) finished with value: 30303.000169674688 and parameters: {'parent': '18n_ppo_tr_frostbite_06:428'}. Best is trial 7 with value: 30303.00018054813
# 2026.09.22-21:04:16.176336     0.003 >> Launch "18n_ppo_tr_frostbite_06:451" completed
# 2026.09.22-21:04:16.177584     0.001 >> 3 (+1) launches completed; running launches=9
# 2026.09.22-21:04:42.433591     0.251 >> Model instance registered, version=462
# 2026.09.22-21:04:42.448072     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:462"; running launches=10
# 2026.09.22-21:04:42.448206     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch462.ipynb"
# 2026.09.22-21:04:59.232349     0.462 >> Trial 10 (18n_ppo_tr_frostbite_06:456) finished with value: 10201.000044050803 and parameters: {'parent': '18n_ppo_tr_frostbite_06:439'}. Best is trial 7 with value: 30303.00018054813
# 2026.09.22-21:05:03.893827     0.002 >> Launch "18n_ppo_tr_frostbite_06:456" completed
# 2026.09.22-21:05:03.895388     0.002 >> 4 (+1) launches completed; running launches=9
# 2026.09.22-21:05:12.784194     3.774 >> Trial 6 (18n_ppo_tr_frostbite_06:452) finished with value: 30303.000180793228 and parameters: {'parent': '18n_ppo_tr_frostbite_06:440'}. Best is trial 6 with value: 30303.000180793228
# 2026.09.22-21:05:14.801475     0.263 >> Model instance registered, version=463
# 2026.09.22-21:05:14.815973     0.005 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:463"; running launches=10
# 2026.09.22-21:05:14.816382     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch463.ipynb"
# 2026.09.22-21:05:14.816613     0.001 >> Launch "18n_ppo_tr_frostbite_06:452" completed
# 2026.09.22-21:05:14.817095     0.000 >> 5 (+1) launches completed; running launches=9
# 2026.09.22-21:05:46.026575     0.259 >> Model instance registered, version=464
# 2026.09.22-21:05:46.040518     0.006 >> 1.5 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:464"; running launches=10
# 2026.09.22-21:05:46.040817     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch464.ipynb"
# 2026.09.22-21:06:22.471704     4.713 >> Trial 4 (18n_ppo_tr_frostbite_06:450) finished with value: 300.0001415552585 and parameters: {'parent': '18n_ppo_tr_frostbite_06:440'}. Best is trial 6 with value: 30303.000180793228
# 2026.09.22-21:06:22.880018     0.002 >> Launch "18n_ppo_tr_frostbite_06:450" completed
# 2026.09.22-21:06:22.881103     0.001 >> 6 (+1) launches completed; running launches=9
# 2026.09.22-21:06:41.555114     2.841 >> Trial 12 (18n_ppo_tr_frostbite_06:458) finished with value: 30304.000203877007 and parameters: {'parent': '18n_ppo_tr_frostbite_06:440'}. Best is trial 12 with value: 30304.000203877007
# 2026.09.22-21:06:44.040144     0.217 >> Model instance registered, version=465
# 2026.09.22-21:06:44.049701     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:465"; running launches=10
# 2026.09.22-21:06:44.050321     0.001 >> Launch "18n_ppo_tr_frostbite_06:458" completed
# 2026.09.22-21:06:44.050438     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch465.ipynb"
# 2026.09.22-21:06:44.050823     0.001 >> 7 (+1) launches completed; running launches=9
# 2026.09.22-21:07:15.909970     0.227 >> Model instance registered, version=466
# 2026.09.22-21:07:15.919885     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:466"; running launches=10
# 2026.09.22-21:07:15.920168     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch466.ipynb"
# 2026.09.22-21:09:17.710203     2.818 >> Trial 13 (18n_ppo_tr_frostbite_06:459) finished with value: 30302.00015256239 and parameters: {'parent': '18n_ppo_tr_frostbite_06:445'}. Best is trial 12 with value: 30304.000203877007
# 2026.09.22-21:09:20.010881     0.002 >> Launch "18n_ppo_tr_frostbite_06:459" completed
# 2026.09.22-21:09:20.011869     0.001 >> 8 (+1) launches completed; running launches=9
# 2026.09.22-21:09:47.505892     0.228 >> Model instance registered, version=467
# 2026.09.22-21:09:47.519984     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:467"; running launches=10
# 2026.09.22-21:09:47.520170     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch467.ipynb"
# 2026.09.22-21:09:49.703672     2.183 >> Trial 9 (18n_ppo_tr_frostbite_06:455) finished with value: 30203.000169741532 and parameters: {'parent': '18n_ppo_tr_frostbite_06:428'}. Best is trial 12 with value: 30304.000203877007
# 2026.09.22-21:09:52.709547     0.003 >> Launch "18n_ppo_tr_frostbite_06:455" completed
# 2026.09.22-21:09:52.710381     0.001 >> 9 (+1) launches completed; running launches=9
# 2026.09.22-21:10:19.419919     0.214 >> Model instance registered, version=468
# 2026.09.22-21:10:19.430291     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:468"; running launches=10
# 2026.09.22-21:10:19.430398     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch468.ipynb"
# 2026.09.22-21:11:20.020237     4.288 >> Trial 11 (18n_ppo_tr_frostbite_06:457) finished with value: 20303.000168003564 and parameters: {'parent': '18n_ppo_tr_frostbite_06:436'}. Best is trial 12 with value: 30304.000203877007
# 2026.09.22-21:11:21.889530     0.003 >> Launch "18n_ppo_tr_frostbite_06:457" completed
# 2026.09.22-21:11:21.890888     0.001 >> 10 (+1) launches completed; running launches=9
# 2026.09.22-21:11:48.221769     0.207 >> Model instance registered, version=469
# 2026.09.22-21:11:48.234510     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:469"; running launches=10
# 2026.09.22-21:11:48.234609     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch469.ipynb"
# 2026.09.22-21:44:55.979686     4.350 >> Trial 14 (18n_ppo_tr_frostbite_06:460) finished with value: 30303.000180525847 and parameters: {'parent': '18n_ppo_tr_frostbite_06:428'}. Best is trial 12 with value: 30304.000203877007
# 2026.09.22-21:44:56.749151     0.002 >> Launch "18n_ppo_tr_frostbite_06:460" completed
# 2026.09.22-21:44:56.750342     0.001 >> 11 (+1) launches completed; running launches=9
# 2026.09.22-21:46:36.172052     2.067 >> Trial 15 (18n_ppo_tr_frostbite_06:461) finished with value: 30302.000152094475 and parameters: {'parent': '18n_ppo_tr_frostbite_06:445'}. Best is trial 12 with value: 30304.000203877007
# 2026.09.22-21:46:39.297971     0.004 >> Launch "18n_ppo_tr_frostbite_06:461" completed
# 2026.09.22-21:46:39.299486     0.002 >> 12 (+1) launches completed; running launches=8
# 2026.09.22-21:48:37.184840     4.612 >> Trial 20 (18n_ppo_tr_frostbite_06:466) finished with value: 20201.000055882352 and parameters: {'parent': '18n_ppo_tr_frostbite_06:439'}. Best is trial 12 with value: 30304.000203877007
# 2026.09.22-21:48:37.229370     0.045 >> Trial 17 (18n_ppo_tr_frostbite_06:463) finished with value: 30302.000168426915 and parameters: {'parent': '18n_ppo_tr_frostbite_06:436'}. Best is trial 12 with value: 30304.000203877007
# 2026.09.22-21:48:37.967170     0.003 >> Launch "18n_ppo_tr_frostbite_06:466" completed
# 2026.09.22-21:48:37.968116     0.001 >> Launch "18n_ppo_tr_frostbite_06:463" completed
# 2026.09.22-21:48:37.968834     0.001 >> 14 (+2) launches completed; running launches=6
# 2026.09.22-21:50:40.342626     4.325 >> Trial 16 (18n_ppo_tr_frostbite_06:462) finished with value: 30002.00017337344 and parameters: {'parent': '18n_ppo_tr_frostbite_06:440'}. Best is trial 12 with value: 30304.000203877007
# 2026.09.22-21:50:41.127040     0.001 >> Launch "18n_ppo_tr_frostbite_06:462" completed
# 2026.09.22-21:50:41.127591     0.001 >> 15 (+1) launches completed; running launches=5
# 2026.09.22-21:51:58.085328     4.904 >> Trial 18 (18n_ppo_tr_frostbite_06:464) finished with value: 30303.00017702763 and parameters: {'parent': '18n_ppo_tr_frostbite_06:428'}. Best is trial 12 with value: 30304.000203877007
# 2026.09.22-21:51:58.304029     0.003 >> Launch "18n_ppo_tr_frostbite_06:464" completed
# 2026.09.22-21:51:58.306091     0.002 >> 16 (+1) launches completed; running launches=4
# 2026.09.22-21:55:36.946837     2.689 >> Trial 22 (18n_ppo_tr_frostbite_06:468) finished with value: 20300.000133622994 and parameters: {'parent': '18n_ppo_tr_frostbite_06:445'}. Best is trial 12 with value: 30304.000203877007
# 2026.09.22-21:55:39.370970     0.002 >> Launch "18n_ppo_tr_frostbite_06:468" completed
# 2026.09.22-21:55:39.371765     0.001 >> 17 (+1) launches completed; running launches=3
# 2026.09.22-21:57:20.050403     3.220 >> Trial 19 (18n_ppo_tr_frostbite_06:465) finished with value: 30303.0002008467 and parameters: {'parent': '18n_ppo_tr_frostbite_06:440'}. Best is trial 12 with value: 30304.000203877007
# 2026.09.22-21:57:21.950465     0.003 >> Launch "18n_ppo_tr_frostbite_06:465" completed
# 2026.09.22-21:57:21.951154     0.001 >> 18 (+1) launches completed; running launches=2
# 2026.09.22-21:59:23.059306     2.690 >> Trial 21 (18n_ppo_tr_frostbite_06:467) finished with value: 30203.000156818183 and parameters: {'parent': '18n_ppo_tr_frostbite_06:445'}. Best is trial 12 with value: 30304.000203877007
# 2026.09.22-21:59:25.489327     0.002 >> Launch "18n_ppo_tr_frostbite_06:467" completed
# 2026.09.22-21:59:25.490632     0.001 >> 19 (+1) launches completed; running launches=1
# 2026.09.22-22:01:27.072689     2.873 >> Trial 23 (18n_ppo_tr_frostbite_06:469) finished with value: 30303.00017878788 and parameters: {'parent': '18n_ppo_tr_frostbite_06:440'}. Best is trial 12 with value: 30304.000203877007
# 2026.09.22-22:01:29.327119     0.006 >> Launch "18n_ppo_tr_frostbite_06:469" completed
# 2026.09.22-22:01:29.328560     0.001 >> 20 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-22 22:01:34,357] Using an existing study with name '18n_study_19.3a' instead of creating a new one.
# 2026.09.22-22:01:34.360346     5.032 >> Study statistics:
# 2026.09.22-22:01:34.362598     0.002 >> 	Number of finished trials: 24
# 2026.09.22-22:01:34.363731     0.001 >> 	Number of pruned trials: 0
# 2026.09.22-22:01:34.365344     0.002 >> 	Number of complete trials: 20
# 2026.09.22-22:01:34.367114     0.002 >> Best trial:
# 2026.09.22-22:01:34.368287     0.001 >> 	Value: 30304.000203877007
# 2026.09.22-22:01:34.368866     0.001 >> 	Model version: 458
# 2026.09.22-22:01:34.369467     0.001 >> 	Params:
# 2026.09.22-22:01:34.370698     0.001 >> 		parent: 18n_ppo_tr_frostbite_06:440
