# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 6 шагов. На каждом шаге отбираем чемпионов для продолжения след. шага.
#
# Данный эксперимент - это четвёртый шаг. Здесь агент 80% играет на третьем уровне с train RAM-ами, 10% времени играет с первого уровня, 10%  со второго.

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False

    parent = optuna_trial.suggest_categorical('parent', [
        '18n_ppo_tr_frostbite_06:458',
        '18n_ppo_tr_frostbite_06:464',
        '18n_ppo_tr_frostbite_06:465',
    ])
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights=parent)
    HP.encoder.is_trainable = True

    HP.agent.parent = parent 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(200000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = None
    HP.video.capture_env_ram_patches = None
    HP.video.break_on_level_passed = False
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = 3_000_000 # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = [
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=none', # 0
        'com.develorium.neurolab.frostbite_ram:level2:1:cls=none', # 1
        
        'com.develorium.neurolab.frostbite_ram:level3:1:cls=train1', # 2
        'com.develorium.neurolab.frostbite_ram:level3:1:cls=train2', # 3
        'com.develorium.neurolab.frostbite_ram:level3:1:cls=train3', # 4
        'com.develorium.neurolab.frostbite_ram:level3:1:cls=train4', # 5
        'com.develorium.neurolab.frostbite_ram:level3:1:cls=train5', # 6
    ]
    HP.ppo.rollout_env_ram_patches = [
        ['no_score', 'three_lives', 'no_igloo', 'temperature_45', 'bailey_safe_random_spawn'], # 0
        ['no_score', 'last_life', 'no_igloo', 'temperature_45', 'bailey_safe_random_spawn'], # 1
    ]
    HP.ppo.rollout_env_stories = [
        '0;0',   # level 1 - 10% time
        '1;0',   # level 2 - 10% time
        '2:7;1', # level 3 - 80% time
        '2:7;1', # level 3 - 80% time
        '2:7;1', # level 3 - 80% time
        '2:7;1', # level 3 - 80% time
        '2:7;1', # level 3 - 80% time
        '2:7;1', # level 3 - 80% time
        '2:7;1', # level 3 - 80% time
        '2:7;1', # level 3 - 80% time
    ]
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    HP.ppo.learn_rate = f'const({0.00025 - 0.0002 / 6 * 3})'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    HP.ppo.ent_coef = f'const({0.05 - 0.04 / 6 * 3})'
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Чемпионы:
# - `18n_ppo_tr_frostbite_06:476`
# - `18n_ppo_tr_frostbite_06:471`
# - `18n_ppo_tr_frostbite_06:473`
# - `18n_ppo_tr_frostbite_06:477`
# - `18n_ppo_tr_frostbite_06:478`
# - `18n_ppo_tr_frostbite_06:475`
#
# <img src="./img/score.png">
# <img src="./img/episode_r.png">
#
# **Выводы**
# 1) делаем следующий шаг на чемпионах

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.4a/18n_study_19.4a.ipynb',
#  'optuna_study_name': '18n_study_19.4a',
#  'optuna_study_serial': '19.4a',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.4a/18n_study_19.4a.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 20
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-22 22:09:15,580] A new study created in Journal with name: 18n_study_19.4a
# 2026.09.22-22:09:15.828630     0.216 >> Model instance registered, version=470
# 2026.09.22-22:09:15.838433     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch470.ipynb"
# 2026.09.22-22:09:15.838693     0.004 >> 10.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:470"; running launches=1
# 2026.09.22-22:09:47.024577     0.218 >> Model instance registered, version=471
# 2026.09.22-22:09:47.035679     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch471.ipynb"
# 2026.09.22-22:09:47.036376     0.001 >> 9.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:471"; running launches=2
# 2026.09.22-22:10:18.134542     0.228 >> Model instance registered, version=472
# 2026.09.22-22:10:18.146237     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch472.ipynb"
# 2026.09.22-22:10:18.147370     0.005 >> 8.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:472"; running launches=3
# 2026.09.22-22:10:49.101297     0.216 >> Model instance registered, version=473
# 2026.09.22-22:10:49.115093     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch473.ipynb"
# 2026.09.22-22:10:49.115454     0.006 >> 7.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:473"; running launches=4
# 2026.09.22-22:11:20.223000     0.303 >> Model instance registered, version=474
# 2026.09.22-22:11:20.235297     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch474.ipynb"
# 2026.09.22-22:11:20.235525     0.004 >> 6.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:474"; running launches=5
# 2026.09.22-22:11:51.343644     0.273 >> Model instance registered, version=475
# 2026.09.22-22:11:51.356167     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch475.ipynb"
# 2026.09.22-22:11:51.356785     0.005 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:475"; running launches=6
# 2026.09.22-22:12:22.318599     0.240 >> Model instance registered, version=476
# 2026.09.22-22:12:22.332159     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch476.ipynb"
# 2026.09.22-22:12:22.332392     0.006 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:476"; running launches=7
# 2026.09.22-22:12:53.406156     0.362 >> Model instance registered, version=477
# 2026.09.22-22:12:53.417036     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch477.ipynb"
# 2026.09.22-22:12:53.417520     0.004 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:477"; running launches=8
# 2026.09.22-22:13:24.770981     0.326 >> Model instance registered, version=478
# 2026.09.22-22:13:24.785328     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch478.ipynb"
# 2026.09.22-22:13:24.785648     0.005 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:478"; running launches=9
# 2026.09.22-22:13:55.877879     0.281 >> Model instance registered, version=479
# 2026.09.22-22:13:55.889117     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch479.ipynb"
# 2026.09.22-22:13:55.889719     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:479"; running launches=10
# 2026.09.22-22:54:23.849925     3.593 >> Trial 3 (18n_ppo_tr_frostbite_06:473) finished with value: 40404.00024456328 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 3 with value: 40404.00024456328
# 2026.09.22-22:54:25.375325     0.002 >> Launch "18n_ppo_tr_frostbite_06:473" completed
# 2026.09.22-22:54:25.376328     0.001 >> 1 (+1) launches completed; running launches=9
# 2026.09.22-22:54:51.297858     0.349 >> Model instance registered, version=480
# 2026.09.22-22:54:51.310370     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:480"; running launches=10
# 2026.09.22-22:54:51.310536     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch480.ipynb"
# 2026.09.22-22:55:14.395910     2.630 >> Trial 4 (18n_ppo_tr_frostbite_06:474) finished with value: 30202.00006579768 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 3 with value: 40404.00024456328
# 2026.09.22-22:55:16.884516     0.001 >> Launch "18n_ppo_tr_frostbite_06:474" completed
# 2026.09.22-22:55:16.885351     0.001 >> 2 (+1) launches completed; running launches=9
# 2026.09.22-22:55:42.683925     0.204 >> Model instance registered, version=481
# 2026.09.22-22:55:42.695002     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:481"; running launches=10
# 2026.09.22-22:55:42.695164     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch481.ipynb"
# 2026.09.22-22:56:07.608235     4.450 >> Trial 1 (18n_ppo_tr_frostbite_06:471) finished with value: 40404.000239616755 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 3 with value: 40404.00024456328
# 2026.09.22-22:56:08.441235     0.001 >> Launch "18n_ppo_tr_frostbite_06:471" completed
# 2026.09.22-22:56:08.441685     0.000 >> 3 (+1) launches completed; running launches=9
# 2026.09.22-22:56:13.544846     5.103 >> Trial 6 (18n_ppo_tr_frostbite_06:476) finished with value: 40404.000250334226 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-22:56:13.549804     0.001 >> Launch "18n_ppo_tr_frostbite_06:476" completed
# 2026.09.22-22:56:13.550240     0.000 >> 4 (+1) launches completed; running launches=8
# 2026.09.22-22:56:18.870400     0.207 >> Model instance registered, version=482
# 2026.09.22-22:56:18.878695     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:482"; running launches=9
# 2026.09.22-22:56:18.878797     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch482.ipynb"
# 2026.09.22-22:56:49.892146     0.240 >> Model instance registered, version=483
# 2026.09.22-22:56:49.905639     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:483"; running launches=10
# 2026.09.22-22:56:49.905797     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch483.ipynb"
# 2026.09.22-22:57:03.955843     3.590 >> Trial 8 (18n_ppo_tr_frostbite_06:478) finished with value: 40404.000182040996 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-22:57:05.473281     0.001 >> Launch "18n_ppo_tr_frostbite_06:478" completed
# 2026.09.22-22:57:05.473739     0.000 >> 5 (+1) launches completed; running launches=9
# 2026.09.22-22:57:21.085317     0.209 >> Model instance registered, version=484
# 2026.09.22-22:57:21.094306     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:484"; running launches=10
# 2026.09.22-22:57:21.094464     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch484.ipynb"
# 2026.09.22-22:57:55.369855     3.596 >> Trial 2 (18n_ppo_tr_frostbite_06:472) finished with value: 40303.00011958556 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-22:57:56.891099     0.001 >> Launch "18n_ppo_tr_frostbite_06:472" completed
# 2026.09.22-22:57:56.891793     0.001 >> 6 (+1) launches completed; running launches=9
# 2026.09.22-22:58:22.672535     0.208 >> Model instance registered, version=485
# 2026.09.22-22:58:22.686634     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:485"; running launches=10
# 2026.09.22-22:58:22.686749     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch485.ipynb"
# 2026.09.22-22:59:07.669245     3.870 >> Trial 9 (18n_ppo_tr_frostbite_06:479) finished with value: 40403.00012704991 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-22:59:08.920302     0.002 >> Launch "18n_ppo_tr_frostbite_06:479" completed
# 2026.09.22-22:59:08.921201     0.001 >> 7 (+1) launches completed; running launches=9
# 2026.09.22-22:59:34.713460     0.217 >> Model instance registered, version=486
# 2026.09.22-22:59:34.726204     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:486"; running launches=10
# 2026.09.22-22:59:34.726373     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch486.ipynb"
# 2026.09.22-22:59:39.366446     4.640 >> Trial 0 (18n_ppo_tr_frostbite_06:470) finished with value: 30303.000154723708 and parameters: {'parent': '18n_ppo_tr_frostbite_06:465'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-22:59:39.840793     0.002 >> Launch "18n_ppo_tr_frostbite_06:470" completed
# 2026.09.22-22:59:39.842015     0.001 >> 8 (+1) launches completed; running launches=9
# 2026.09.22-23:00:05.794037     0.228 >> Model instance registered, version=487
# 2026.09.22-23:00:05.807253     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:487"; running launches=10
# 2026.09.22-23:00:05.807386     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch487.ipynb"
# 2026.09.22-23:02:02.551398     4.087 >> Trial 5 (18n_ppo_tr_frostbite_06:475) finished with value: 40300.000196880574 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-23:02:03.581593     0.001 >> Launch "18n_ppo_tr_frostbite_06:475" completed
# 2026.09.22-23:02:03.582429     0.001 >> 9 (+1) launches completed; running launches=9
# 2026.09.22-23:02:29.384989     0.232 >> Model instance registered, version=488
# 2026.09.22-23:02:29.398860     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:488"; running launches=10
# 2026.09.22-23:02:29.399496     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch488.ipynb"
# 2026.09.22-23:04:44.829712     1.871 >> Trial 7 (18n_ppo_tr_frostbite_06:477) finished with value: 40404.000242959 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-23:04:48.078345     0.002 >> Launch "18n_ppo_tr_frostbite_06:477" completed
# 2026.09.22-23:04:48.079218     0.001 >> 10 (+1) launches completed; running launches=9
# 2026.09.22-23:05:14.234571     0.241 >> Model instance registered, version=489
# 2026.09.22-23:05:14.246597     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:489"; running launches=10
# 2026.09.22-23:05:14.246720     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch489.ipynb"
# 2026.09.22-23:38:52.191533     1.540 >> Trial 10 (18n_ppo_tr_frostbite_06:480) finished with value: 40403.00018803476 and parameters: {'parent': '18n_ppo_tr_frostbite_06:465'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-23:38:55.766039     0.001 >> Launch "18n_ppo_tr_frostbite_06:480" completed
# 2026.09.22-23:38:55.766573     0.001 >> 11 (+1) launches completed; running launches=9
# 2026.09.22-23:39:53.138231     0.716 >> Trial 11 (18n_ppo_tr_frostbite_06:481) finished with value: 30302.000117758467 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-23:39:57.639635     0.004 >> Launch "18n_ppo_tr_frostbite_06:481" completed
# 2026.09.22-23:39:57.641228     0.002 >> 12 (+1) launches completed; running launches=8
# 2026.09.22-23:40:24.622604     0.800 >> Trial 13 (18n_ppo_tr_frostbite_06:483) finished with value: 40304.00022502228 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-23:40:28.941003     0.001 >> Launch "18n_ppo_tr_frostbite_06:483" completed
# 2026.09.22-23:40:28.941840     0.001 >> 13 (+1) launches completed; running launches=7
# 2026.09.22-23:41:04.592006     4.878 >> Trial 14 (18n_ppo_tr_frostbite_06:484) finished with value: 30303.00016209893 and parameters: {'parent': '18n_ppo_tr_frostbite_06:465'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-23:41:04.839259     0.002 >> Launch "18n_ppo_tr_frostbite_06:484" completed
# 2026.09.22-23:41:04.840166     0.001 >> 14 (+1) launches completed; running launches=6
# 2026.09.22-23:43:00.747951     1.732 >> Trial 12 (18n_ppo_tr_frostbite_06:482) finished with value: 30303.000169006238 and parameters: {'parent': '18n_ppo_tr_frostbite_06:465'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-23:43:04.140724     0.002 >> Launch "18n_ppo_tr_frostbite_06:482" completed
# 2026.09.22-23:43:04.141654     0.001 >> 15 (+1) launches completed; running launches=5
# 2026.09.22-23:45:40.421083     2.342 >> Trial 15 (18n_ppo_tr_frostbite_06:485) finished with value: 40303.000141733515 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-23:45:43.207945     0.006 >> Launch "18n_ppo_tr_frostbite_06:485" completed
# 2026.09.22-23:45:43.209207     0.001 >> 16 (+1) launches completed; running launches=4
# 2026.09.22-23:47:19.482338     3.561 >> Trial 17 (18n_ppo_tr_frostbite_06:487) finished with value: 30403.000116198753 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-23:47:21.133407     0.003 >> Launch "18n_ppo_tr_frostbite_06:487" completed
# 2026.09.22-23:47:21.134855     0.001 >> 17 (+1) launches completed; running launches=3
# 2026.09.22-23:51:18.364746     0.297 >> Trial 16 (18n_ppo_tr_frostbite_06:486) finished with value: 30404.000171524065 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-23:51:23.185970     0.001 >> Launch "18n_ppo_tr_frostbite_06:486" completed
# 2026.09.22-23:51:23.187084     0.001 >> 18 (+1) launches completed; running launches=2
# 2026.09.22-23:53:05.036184     4.034 >> Trial 18 (18n_ppo_tr_frostbite_06:488) finished with value: 40403.00018952763 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-23:53:06.124534     0.003 >> Launch "18n_ppo_tr_frostbite_06:488" completed
# 2026.09.22-23:53:06.125380     0.001 >> 19 (+1) launches completed; running launches=1
# 2026.09.22-23:56:09.372187     2.869 >> Trial 19 (18n_ppo_tr_frostbite_06:489) finished with value: 40203.000202540105 and parameters: {'parent': '18n_ppo_tr_frostbite_06:465'}. Best is trial 6 with value: 40404.000250334226
# 2026.09.22-23:56:11.624605     0.002 >> Launch "18n_ppo_tr_frostbite_06:489" completed
# 2026.09.22-23:56:11.625571     0.001 >> 20 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-22 23:56:16,664] Using an existing study with name '18n_study_19.4a' instead of creating a new one.
# 2026.09.22-23:56:16.671903     5.046 >> Study statistics:
# 2026.09.22-23:56:16.674768     0.003 >> 	Number of finished trials: 20
# 2026.09.22-23:56:16.675975     0.001 >> 	Number of pruned trials: 0
# 2026.09.22-23:56:16.676743     0.001 >> 	Number of complete trials: 20
# 2026.09.22-23:56:16.677877     0.001 >> Best trial:
# 2026.09.22-23:56:16.679150     0.001 >> 	Value: 40404.000250334226
# 2026.09.22-23:56:16.679630     0.000 >> 	Model version: 476
# 2026.09.22-23:56:16.680048     0.000 >> 	Params:
# 2026.09.22-23:56:16.680447     0.000 >> 		parent: 18n_ppo_tr_frostbite_06:464
