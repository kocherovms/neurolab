# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 5 поколений по 6 млн шагов с последующим отбором чемпионов. Наследники этих чемпионов будут использоваться на следующем шаге.
#
# Данный эксперимент - это третий шаг. Здесь уже без спец. условий агент играет либо с 1, либо с 4-го, либо с 5-го уровней. Используем чемпионов со 2-ого шага `18n_study_18.2c`. Используем стохастичность `bailey_safe_random_spawn` для ресетов!!!
#
# Особенности:
# - `vision_head` из `18d_world_model_09`
# - **`vision_head.is_trainable=False`**
# - энкодер из чемпионов `18n_study_18.2`
# - **`encoder.is_trainable=True`**
# - механика повторяет 17-ых агентов
# - `prediction_coef=0.1`
# - `sequence_length=10`
# - `batch_size=128`
# - `vf_coef=0.2`

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    generations_count = 5
    generation_ind = 2
    generation_steps_count = 8_000_000
    all_generations_steps_count = generation_steps_count * generations_count
    learn_rate_range = (0.00025, 0.00025 * 0.1)
    ent_coef_range = (0.05, 0.05 * 0.1)
    ####
    
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False

    parent = optuna_trial.suggest_categorical('parent', [
        '18n_ppo_tr_frostbite_06:210',
        '18n_ppo_tr_frostbite_06:203',
        '18n_ppo_tr_frostbite_06:208',
    ])
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights=parent)
    HP.encoder.is_trainable = True

    HP.agent.parent = parent 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(500000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = None
    HP.video.capture_env_ram_patches = None
    HP.video.break_on_level_passed = False
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = generation_steps_count # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = None
    HP.ppo.rollout_env_rams = [
        'com.develorium.neurolab.frostbite_ram:level1_101:1', 
        'com.develorium.neurolab.frostbite_ram:level4_101:1', # bear level, day
        'com.develorium.neurolab.frostbite_ram:level5_101:1', # bear level, night
    ]
    HP.ppo.rollout_env_ram_patches = [
        ['no_score', 'three_lives', 'no_igloo', 'bailey_safe_random_spawn'],
    ]
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    learn_rate_change_speed = (learn_rate_range[1] - learn_rate_range[0]) / generations_count
    learn_rate_a = learn_rate_range[0] + learn_rate_change_speed * generation_ind
    learn_rate_b = learn_rate_a + learn_rate_change_speed
    HP.ppo.learn_rate = f'linear({learn_rate_a}, {learn_rate_b})'
    # HP.ppo.learn_rate = 'linear(0.00025, 0.00015)'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    ent_coef_change_speed = (ent_coef_range[1] - ent_coef_range[0]) / generations_count
    ent_coef_a = ent_coef_range[0] + ent_coef_change_speed * generation_ind
    ent_coef_b = ent_coef_a + ent_coef_change_speed
    HP.ppo.ent_coef = f'linear({ent_coef_a}, {ent_coef_b})' # coefficient of the entropy member within loss function
    # HP.ppo.ent_coef = 'linear(0.05, 0.03)' # coefficient of the entropy member within loss function
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Как-то вяло. По сравнению с `18n_study_18.3b` тут нет ни одного агента, который бы добрался до того, чтобы уверенно проходить 4 уровня. Еле-еле 2 агента коснулись этой отметки и потом откалились. Единственная разница - это стохастичность при ресете. Неужели это так влияет?
#
# Из просмотра видео заметно, что агенты часто совершают тупую ошибку - шагают в воду. Кажется, что можно предсказывать смерть на определённом горизонте событий и это может помочь агентам лучше действовать.
#
# Чемпионы:
# - `18n_ppo_tr_frostbite_06:232`
# - `18n_ppo_tr_frostbite_06:238`
#
# <img src="./img/score.png">
# <img src="./img/episode_r.png">
#
# **Выводы*
# 1) выполнить четвёртый шаг исключительно ради того, чтобы закрыть гештальт
# 2) думать

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_18.3c/18n_study_18.3c.ipynb',
#  'optuna_study_name': '18n_study_18.3c',
#  'optuna_study_serial': '18.3c',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_18.3c/18n_study_18.3c.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-20 17:25:43,360] A new study created in Journal with name: 18n_study_18.3c
# 2026.09.20-17:25:43.648220     0.250 >> Model instance registered, version=229
# 2026.09.20-17:25:43.658431     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch229.ipynb"
# 2026.09.20-17:25:43.658657     0.004 >> 14.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:229"; running launches=1
# 2026.09.20-17:26:14.981154     0.199 >> Model instance registered, version=230
# 2026.09.20-17:26:14.991580     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch230.ipynb"
# 2026.09.20-17:26:14.992446     0.005 >> 13.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:230"; running launches=2
# 2026.09.20-17:26:45.976525     0.193 >> Model instance registered, version=231
# 2026.09.20-17:26:45.989226     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch231.ipynb"
# 2026.09.20-17:26:45.990115     0.007 >> 12.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:231"; running launches=3
# 2026.09.20-17:27:16.877708     0.203 >> Model instance registered, version=232
# 2026.09.20-17:27:16.889990     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch232.ipynb"
# 2026.09.20-17:27:16.890389     0.005 >> 11.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:232"; running launches=4
# 2026.09.20-17:27:47.919309     0.197 >> Model instance registered, version=233
# 2026.09.20-17:27:47.928376     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch233.ipynb"
# 2026.09.20-17:27:47.928844     0.005 >> 10.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:233"; running launches=5
# 2026.09.20-17:28:18.810211     0.206 >> Model instance registered, version=234
# 2026.09.20-17:28:18.823380     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch234.ipynb"
# 2026.09.20-17:28:18.824149     0.006 >> 9.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:234"; running launches=6
# 2026.09.20-17:28:49.772790     0.200 >> Model instance registered, version=235
# 2026.09.20-17:28:49.783924     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch235.ipynb"
# 2026.09.20-17:28:49.784135     0.004 >> 8.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:235"; running launches=7
# 2026.09.20-17:29:21.641568     0.213 >> Model instance registered, version=236
# 2026.09.20-17:29:21.656060     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch236.ipynb"
# 2026.09.20-17:29:21.656642     0.007 >> 7.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:236"; running launches=8
# 2026.09.20-17:29:52.706255     0.214 >> Model instance registered, version=237
# 2026.09.20-17:29:52.718768     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch237.ipynb"
# 2026.09.20-17:29:52.719060     0.005 >> 6.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:237"; running launches=9
# 2026.09.20-17:30:23.852800     0.232 >> Model instance registered, version=238
# 2026.09.20-17:30:23.880105     0.016 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch238.ipynb"
# 2026.09.20-17:30:23.881363     0.017 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:238"; running launches=10
# 2026.09.20-17:30:54.788822     0.206 >> Model instance registered, version=239
# 2026.09.20-17:30:54.801401     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch239.ipynb"
# 2026.09.20-17:30:54.801649     0.004 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:239"; running launches=11
# 2026.09.20-17:31:25.719769     0.223 >> Model instance registered, version=240
# 2026.09.20-17:31:25.732994     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch240.ipynb"
# 2026.09.20-17:31:25.733306     0.006 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:240"; running launches=12
# 2026.09.20-17:31:56.634624     0.201 >> Model instance registered, version=241
# 2026.09.20-17:31:56.643013     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch241.ipynb"
# 2026.09.20-17:31:56.643220     0.004 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:241"; running launches=13
# 2026.09.20-17:32:27.708428     0.192 >> Model instance registered, version=242
# 2026.09.20-17:32:27.720276     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch242.ipynb"
# 2026.09.20-17:32:27.720580     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:242"; running launches=14
# 2026.09.20-18:58:50.364537     4.504 >> Trial 1 (18n_ppo_tr_frostbite_06:230) finished with value: 20202.00012913914 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 1 with value: 20202.00012913914
# 2026.09.20-18:58:50.978021     0.002 >> Launch "18n_ppo_tr_frostbite_06:230" completed
# 2026.09.20-18:58:50.978908     0.001 >> 1 (+1) launches completed; running launches=13
# 2026.09.20-18:59:09.498452     3.176 >> Trial 2 (18n_ppo_tr_frostbite_06:231) finished with value: 10101.000132452553 and parameters: {'parent': '18n_ppo_tr_frostbite_06:208'}. Best is trial 1 with value: 20202.00012913914
# 2026.09.20-18:59:11.643415     0.206 >> Model instance registered, version=243
# 2026.09.20-18:59:11.656155     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:243"; running launches=14
# 2026.09.20-18:59:11.656297     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch243.ipynb"
# 2026.09.20-18:59:11.657074     0.001 >> Launch "18n_ppo_tr_frostbite_06:231" completed
# 2026.09.20-18:59:11.658174     0.001 >> 2 (+1) launches completed; running launches=13
# 2026.09.20-18:59:42.954003     0.237 >> Model instance registered, version=244
# 2026.09.20-18:59:42.963682     0.003 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:244"; running launches=14
# 2026.09.20-18:59:42.964428     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch244.ipynb"
# 2026.09.20-19:00:10.456959     1.894 >> Trial 3 (18n_ppo_tr_frostbite_06:232) finished with value: 30402.0001802873 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-19:00:13.679962     0.001 >> Launch "18n_ppo_tr_frostbite_06:232" completed
# 2026.09.20-19:00:13.680862     0.001 >> 3 (+1) launches completed; running launches=13
# 2026.09.20-19:00:39.566329     0.189 >> Model instance registered, version=245
# 2026.09.20-19:00:39.578485     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:245"; running launches=14
# 2026.09.20-19:00:39.578594     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch245.ipynb"
# 2026.09.20-19:01:19.153573     3.447 >> Trial 5 (18n_ppo_tr_frostbite_06:234) finished with value: 10102.000147153192 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-19:01:20.817884     0.001 >> Launch "18n_ppo_tr_frostbite_06:234" completed
# 2026.09.20-19:01:20.818464     0.001 >> 4 (+1) launches completed; running launches=13
# 2026.09.20-19:01:46.591281     0.204 >> Model instance registered, version=246
# 2026.09.20-19:01:46.603627     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:246"; running launches=14
# 2026.09.20-19:01:46.603746     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch246.ipynb"
# 2026.09.20-19:04:00.404098     4.937 >> Trial 9 (18n_ppo_tr_frostbite_06:238) finished with value: 10202.00015476565 and parameters: {'parent': '18n_ppo_tr_frostbite_06:203'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-19:04:00.586011     0.002 >> Launch "18n_ppo_tr_frostbite_06:238" completed
# 2026.09.20-19:04:00.587094     0.001 >> 5 (+1) launches completed; running launches=13
# 2026.09.20-19:04:09.252557     3.551 >> Trial 8 (18n_ppo_tr_frostbite_06:237) finished with value: 20102.000139058404 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-19:04:10.818897     0.002 >> Launch "18n_ppo_tr_frostbite_06:237" completed
# 2026.09.20-19:04:10.819717     0.001 >> 6 (+1) launches completed; running launches=12
# 2026.09.20-19:04:16.137530     0.204 >> Model instance registered, version=247
# 2026.09.20-19:04:16.149599     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:247"; running launches=13
# 2026.09.20-19:04:16.149738     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch247.ipynb"
# 2026.09.20-19:04:47.031901     0.198 >> Model instance registered, version=248
# 2026.09.20-19:04:47.045161     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:248"; running launches=14
# 2026.09.20-19:04:47.045291     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch248.ipynb"
# 2026.09.20-19:05:55.088167     1.340 >> Trial 11 (18n_ppo_tr_frostbite_06:240) finished with value: 10201.000133375275 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-19:05:58.867997     0.003 >> Launch "18n_ppo_tr_frostbite_06:240" completed
# 2026.09.20-19:05:58.868884     0.001 >> 7 (+1) launches completed; running launches=13
# 2026.09.20-19:06:24.672972     0.198 >> Model instance registered, version=249
# 2026.09.20-19:06:24.682200     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:249"; running launches=14
# 2026.09.20-19:06:24.682314     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch249.ipynb"
# 2026.09.20-19:07:04.327548     3.849 >> Trial 12 (18n_ppo_tr_frostbite_06:241) finished with value: 20201.000155856138 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-19:07:05.594310     0.002 >> Launch "18n_ppo_tr_frostbite_06:241" completed
# 2026.09.20-19:07:05.595413     0.001 >> 8 (+1) launches completed; running launches=13
# 2026.09.20-19:07:31.722777     0.214 >> Model instance registered, version=250
# 2026.09.20-19:07:31.734676     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:250"; running launches=14
# 2026.09.20-19:07:31.734836     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch250.ipynb"
# 2026.09.20-19:17:38.358581     4.714 >> Trial 0 (18n_ppo_tr_frostbite_06:229) finished with value: 10201.000145160951 and parameters: {'parent': '18n_ppo_tr_frostbite_06:208'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-19:17:38.760604     0.002 >> Launch "18n_ppo_tr_frostbite_06:229" completed
# 2026.09.20-19:17:38.761434     0.001 >> 9 (+1) launches completed; running launches=13
# 2026.09.20-19:18:04.738486     0.194 >> Model instance registered, version=251
# 2026.09.20-19:18:04.751299     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:251"; running launches=14
# 2026.09.20-19:18:04.751407     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch251.ipynb"
# 2026.09.20-19:25:10.823910     4.220 >> Trial 10 (18n_ppo_tr_frostbite_06:239) finished with value: 10101.000127377582 and parameters: {'parent': '18n_ppo_tr_frostbite_06:208'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-19:25:11.718480     0.001 >> Launch "18n_ppo_tr_frostbite_06:239" completed
# 2026.09.20-19:25:11.719544     0.001 >> 10 (+1) launches completed; running launches=13
# 2026.09.20-19:25:37.506413     0.187 >> Model instance registered, version=252
# 2026.09.20-19:25:37.515468     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:252"; running launches=14
# 2026.09.20-19:25:37.515611     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch252.ipynb"
# 2026.09.20-19:26:29.825531     0.956 >> Trial 13 (18n_ppo_tr_frostbite_06:242) finished with value: 20201.000153926812 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-19:26:33.991737     0.002 >> Launch "18n_ppo_tr_frostbite_06:242" completed
# 2026.09.20-19:26:33.992546     0.001 >> 11 (+1) launches completed; running launches=13
# 2026.09.20-19:26:54.784893     0.196 >> Model instance registered, version=253
# 2026.09.20-19:26:54.798477     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:253"; running launches=14
# 2026.09.20-19:26:54.798619     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch253.ipynb"
# 2026.09.20-19:30:49.155255     2.524 >> Trial 4 (18n_ppo_tr_frostbite_06:233) finished with value: 20202.000118255215 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-19:30:51.750005     0.002 >> Launch "18n_ppo_tr_frostbite_06:233" completed
# 2026.09.20-19:30:51.750947     0.001 >> 12 (+1) launches completed; running launches=13
# 2026.09.20-19:31:17.689390     0.193 >> Model instance registered, version=254
# 2026.09.20-19:31:17.699251     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:254"; running launches=14
# 2026.09.20-19:31:17.699404     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch254.ipynb"
# 2026.09.20-19:32:38.817325     4.047 >> Trial 6 (18n_ppo_tr_frostbite_06:235) finished with value: 10101.00015365419 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-19:32:39.887353     0.001 >> Launch "18n_ppo_tr_frostbite_06:235" completed
# 2026.09.20-19:32:39.888345     0.001 >> 13 (+1) launches completed; running launches=13
# 2026.09.20-19:33:05.659158     0.201 >> Model instance registered, version=255
# 2026.09.20-19:33:05.672741     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:255"; running launches=14
# 2026.09.20-19:33:05.672899     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch255.ipynb"
# 2026.09.20-19:33:10.083963     4.411 >> Trial 7 (18n_ppo_tr_frostbite_06:236) finished with value: 20102.00014597882 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-19:33:10.939157     0.002 >> Launch "18n_ppo_tr_frostbite_06:236" completed
# 2026.09.20-19:33:10.939850     0.001 >> 14 (+1) launches completed; running launches=13
# 2026.09.20-19:33:36.885108     0.206 >> Model instance registered, version=256
# 2026.09.20-19:33:36.897308     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:256"; running launches=14
# 2026.09.20-19:33:36.897425     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch256.ipynb"
# 2026.09.20-19:56:20.947651     2.992 >> Trial 16 (18n_ppo_tr_frostbite_06:245) finished with value: 10101.000125062388 and parameters: {'parent': '18n_ppo_tr_frostbite_06:208'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-19:56:23.263149     0.002 >> Launch "18n_ppo_tr_frostbite_06:245" completed
# 2026.09.20-19:56:23.263647     0.001 >> 15 (+1) launches completed; running launches=13
# 2026.09.20-19:57:34.819281     4.339 >> Trial 15 (18n_ppo_tr_frostbite_06:244) finished with value: 10101.000141532977 and parameters: {'parent': '18n_ppo_tr_frostbite_06:208'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-19:57:35.593219     0.002 >> Launch "18n_ppo_tr_frostbite_06:244" completed
# 2026.09.20-19:57:35.593936     0.001 >> 16 (+1) launches completed; running launches=12
# 2026.09.20-19:57:35.995610     0.402 >> Trial 14 (18n_ppo_tr_frostbite_06:243) finished with value: 10000.000079403662 and parameters: {'parent': '18n_ppo_tr_frostbite_06:208'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-19:57:40.723557     0.002 >> Launch "18n_ppo_tr_frostbite_06:243" completed
# 2026.09.20-19:57:40.724404     0.001 >> 17 (+1) launches completed; running launches=11
# 2026.09.20-19:58:50.914688     3.543 >> Trial 17 (18n_ppo_tr_frostbite_06:246) finished with value: 10202.000149149246 and parameters: {'parent': '18n_ppo_tr_frostbite_06:210'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-19:58:52.493443     0.001 >> Launch "18n_ppo_tr_frostbite_06:246" completed
# 2026.09.20-19:58:52.494781     0.001 >> 18 (+1) launches completed; running launches=10
# 2026.09.20-20:08:18.268561     1.849 >> Trial 22 (18n_ppo_tr_frostbite_06:251) finished with value: 20202.000124369748 and parameters: {'parent': '18n_ppo_tr_frostbite_06:203'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-20:08:21.379648     3.111 >> Trial 23 (18n_ppo_tr_frostbite_06:252) finished with value: 20202.000128877004 and parameters: {'parent': '18n_ppo_tr_frostbite_06:203'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-20:08:21.540139     0.002 >> Launch "18n_ppo_tr_frostbite_06:252" completed
# 2026.09.20-20:08:21.541287     0.001 >> Launch "18n_ppo_tr_frostbite_06:251" completed
# 2026.09.20-20:08:21.541993     0.001 >> 20 (+2) launches completed; running launches=8
# 2026.09.20-20:20:32.964335     5.499 >> Trial 27 (18n_ppo_tr_frostbite_06:256) finished with value: 20202.00013731432 and parameters: {'parent': '18n_ppo_tr_frostbite_06:203'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-20:20:33.049446     0.002 >> Launch "18n_ppo_tr_frostbite_06:256" completed
# 2026.09.20-20:20:33.050245     0.001 >> 21 (+1) launches completed; running launches=7
# 2026.09.20-20:20:41.227212     3.061 >> Trial 26 (18n_ppo_tr_frostbite_06:255) finished with value: 20202.00013915627 and parameters: {'parent': '18n_ppo_tr_frostbite_06:203'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-20:20:43.275519     0.001 >> Launch "18n_ppo_tr_frostbite_06:255" completed
# 2026.09.20-20:20:43.276007     0.000 >> 22 (+1) launches completed; running launches=6
# 2026.09.20-20:20:45.621483     2.345 >> Trial 25 (18n_ppo_tr_frostbite_06:254) finished with value: 20202.00012900433 and parameters: {'parent': '18n_ppo_tr_frostbite_06:203'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-20:20:48.393320     0.002 >> Launch "18n_ppo_tr_frostbite_06:254" completed
# 2026.09.20-20:20:48.394206     0.001 >> 23 (+1) launches completed; running launches=5
# 2026.09.20-20:20:51.081194     2.687 >> Trial 24 (18n_ppo_tr_frostbite_06:253) finished with value: 20202.00014104278 and parameters: {'parent': '18n_ppo_tr_frostbite_06:203'}. Best is trial 3 with value: 30402.0001802873
# 2026.09.20-20:20:53.516991     0.001 >> Launch "18n_ppo_tr_frostbite_06:253" completed
# 2026.09.20-20:20:53.517906     0.001 >> 24 (+1) launches completed; running launches=4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 54
#      51 except TimeoutError as e:
#      52     pass
# ---> 54 time.sleep(5)
#
# KeyboardInterrupt:

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-20 20:24:38,460] Using an existing study with name '18n_study_18.3c' instead of creating a new one.
# 2026.09.20-20:24:38.462651     7.638 >> Study statistics:
# 2026.09.20-20:24:38.464630     0.002 >> 	Number of finished trials: 28
# 2026.09.20-20:24:38.465156     0.001 >> 	Number of pruned trials: 0
# 2026.09.20-20:24:38.465609     0.000 >> 	Number of complete trials: 24
# 2026.09.20-20:24:38.466456     0.001 >> Best trial:
# 2026.09.20-20:24:38.467253     0.001 >> 	Value: 30402.0001802873
# 2026.09.20-20:24:38.467633     0.000 >> 	Model version: 232
# 2026.09.20-20:24:38.468072     0.000 >> 	Params:
# 2026.09.20-20:24:38.468435     0.000 >> 		parent: 18n_ppo_tr_frostbite_06:210
