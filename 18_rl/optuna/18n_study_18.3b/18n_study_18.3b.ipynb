# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 5 поколений по 6 млн шагов с последующим отбором чемпионов. Наследники этих чемпионов будут использоваться на следующем шаге.
#
# Данный эксперимент - это третий шаг. Здесь уже без спец. условий агент играет либо с 1, либо с 4-го, либо с 5-го уровней. Используем чемпионов со 2-ого шага `18n_study_18.2b`.
#
# Особенности:
# - `vision_head` из `18d_world_model_09`
# - **`vision_head.is_trainable=False`**
# - энкодер из чемпионов `18n_study_18.2`
# - **`encoder.is_trainable=True`**
# - механика повторяет 17-ых агентов
# - `prediction_coef=0.1`
# - `sequence_length=10`
# - `batch_size=128`
# - `vf_coef=0.2`

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    generations_count = 5
    generation_ind = 2
    generation_steps_count = 8_000_000
    all_generations_steps_count = generation_steps_count * generations_count
    learn_rate_range = (0.00025, 0.00025 * 0.1)
    ent_coef_range = (0.05, 0.05 * 0.1)
    ####
    
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False

    parent = optuna_trial.suggest_categorical('parent', [
        '18n_ppo_tr_frostbite_06:112',
        '18n_ppo_tr_frostbite_06:85',
        '18n_ppo_tr_frostbite_06:95',
        '18n_ppo_tr_frostbite_06:107',
    ])
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights=parent)
    HP.encoder.is_trainable = True

    HP.agent.parent = parent 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(500000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = None
    HP.video.capture_env_ram_patches = None
    HP.video.break_on_level_passed = False
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = generation_steps_count # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = None
    HP.ppo.rollout_env_rams = [
        'com.develorium.neurolab.frostbite_ram:level1_101:1', 
        'com.develorium.neurolab.frostbite_ram:level4_101:1', # bear level, day
        'com.develorium.neurolab.frostbite_ram:level5_101:1', # bear level, night
    ]
    HP.ppo.rollout_env_ram_patches = [
        ['no_score', 'three_lives', 'no_igloo'],
    ]
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    learn_rate_change_speed = (learn_rate_range[1] - learn_rate_range[0]) / generations_count
    learn_rate_a = learn_rate_range[0] + learn_rate_change_speed * generation_ind
    learn_rate_b = learn_rate_a + learn_rate_change_speed
    HP.ppo.learn_rate = f'linear({learn_rate_a}, {learn_rate_b})'
    # HP.ppo.learn_rate = 'linear(0.00025, 0.00015)'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    ent_coef_change_speed = (ent_coef_range[1] - ent_coef_range[0]) / generations_count
    ent_coef_a = ent_coef_range[0] + ent_coef_change_speed * generation_ind
    ent_coef_b = ent_coef_a + ent_coef_change_speed
    HP.ppo.ent_coef = f'linear({ent_coef_a}, {ent_coef_b})' # coefficient of the entropy member within loss function
    # HP.ppo.ent_coef = 'linear(0.05, 0.03)' # coefficient of the entropy member within loss function
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Итак, мы прошли следующий путь:
# - на первом шаге агент учился на закондишном 1-ом уровне и учился заходить в иглу. В результате отдельные агенты прошли пару уровней самостоятельно
# - на втором шаге агент учился на закондишном 4-ом и 5-ом уровнях, познакомился с медведями на дневном и ночном уровнях, научился научился заходить в иглу
# - на этом (третьем) шаге агенты тренились безо всяких кондишнов с 1-го, 4-го или 5-го уровней. В результате отдельные агенты умудряются самостоятельно проходить 4-е уровня (достигают 5-го, ночного с медведями).
#
# Чемпионы:
# - **`18n_ppo_tr_frostbite_06:117`**
# - **`18n_ppo_tr_frostbite_06:162`**
# - `18n_ppo_tr_frostbite_06:172`
# - `18n_ppo_tr_frostbite_06:124`
#
# Просмотр видео показал, что до 5-го уровня они доходит с 1-ой жизнью и им тупо её не хватает. Если бы у них было больше жизней, то м.б. они бы и преодолели 5-ый уровень. Получается, что здесь вопрос эффективности прохождения 1-4 уровней.
#
# Либо по-другому. Надо научиться проходить 5-ый уровнеь с одной жизнью, типа супер эффективность.
#
# Также был проведен эксперимент через `18n_explore_02`- смогут ли чемпионы пройти 5-ый уровень. Оказалось, что `18n_ppo_tr_frostbite_06:117` и `18n_ppo_tr_frostbite_06:162` проходят, тогда как `18n_ppo_tr_frostbite_06:172` и `18n_ppo_tr_frostbite_06:124` не очень. Это отличается от 17-ых агентов, которые не либо умели проходить 5-ый уровень, либо первые 4, но ни то ни другое. Здесь же агент умеет проходить 1-4 и 5, если есть достаточно жизней.
#
# Самый простая мысль - а если дать агенту 9 жизней, то сможет ли он пройти 5 уровней самостоятельно?
#
# <img src="./img/levels_passed.png">
# <img src="./img/reward.png">
# <img src="./img/episode_r.png">
#
# **Выводы**
# 1) дать чемпионам по 9 жизней и пусть играют с первого уровня

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_18.3b/18n_study_18.3b.ipynb',
#  'optuna_study_name': '18n_study_18.3b',
#  'optuna_study_serial': '18.3b',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_18.3b/18n_study_18.3b.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-19 22:09:11,322] A new study created in Journal with name: 18n_study_18.3b
# 2026.09.19-22:09:11.539577     0.190 >> Model instance registered, version=143
# 2026.09.19-22:09:11.554586     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch143.ipynb"
# 2026.09.19-22:09:11.555451     0.001 >> 6.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:143"; running launches=1
# 2026.09.19-22:09:42.455222     0.226 >> Model instance registered, version=144
# 2026.09.19-22:09:42.470139     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch144.ipynb"
# 2026.09.19-22:09:42.470604     0.006 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:144"; running launches=2
# 2026.09.19-22:10:13.389774     0.199 >> Model instance registered, version=145
# 2026.09.19-22:10:13.402246     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch145.ipynb"
# 2026.09.19-22:10:13.402515     0.005 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:145"; running launches=3
# 2026.09.19-22:10:44.437350     0.339 >> Model instance registered, version=146
# 2026.09.19-22:10:44.455536     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch146.ipynb"
# 2026.09.19-22:10:44.457520     0.002 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:146"; running launches=4
# 2026.09.19-22:11:15.376127     0.231 >> Model instance registered, version=147
# 2026.09.19-22:11:15.390199     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch147.ipynb"
# 2026.09.19-22:11:15.390742     0.006 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:147"; running launches=5
# 2026.09.19-22:11:46.604997     0.208 >> Model instance registered, version=148
# 2026.09.19-22:11:46.614184     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch148.ipynb"
# 2026.09.19-22:11:46.614459     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:148"; running launches=6
# 2026.09.20-00:01:52.044531     3.554 >> Trial 2 (18n_ppo_tr_frostbite_06:145) finished with value: 3671.764705882353 and parameters: {'parent': '18n_ppo_tr_frostbite_06:112'}. Best is trial 2 with value: 3671.764705882353
# 2026.09.20-00:01:53.609521     0.002 >> Launch "18n_ppo_tr_frostbite_06:145" completed
# 2026.09.20-00:01:53.610488     0.001 >> 1 (+1) launches completed; running launches=5
# 2026.09.20-00:02:19.417195     0.192 >> Model instance registered, version=149
# 2026.09.20-00:02:19.431087     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:149"; running launches=6
# 2026.09.20-00:02:19.431266     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch149.ipynb"
# 2026.09.20-00:04:55.505979     1.256 >> Trial 5 (18n_ppo_tr_frostbite_06:148) finished with value: 3746.470588235294 and parameters: {'parent': '18n_ppo_tr_frostbite_06:107'}. Best is trial 5 with value: 3746.470588235294
# 2026.09.20-00:04:59.367648     0.002 >> Launch "18n_ppo_tr_frostbite_06:148" completed
# 2026.09.20-00:04:59.368659     0.001 >> 2 (+1) launches completed; running launches=5
# 2026.09.20-00:05:20.253844     0.220 >> Model instance registered, version=150
# 2026.09.20-00:05:20.266988     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:150"; running launches=6
# 2026.09.20-00:05:20.267124     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch150.ipynb"
# 2026.09.20-00:06:15.625216     3.567 >> Trial 4 (18n_ppo_tr_frostbite_06:147) finished with value: 4911.764705882353 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 4 with value: 4911.764705882353
# 2026.09.20-00:06:17.174566     0.002 >> Launch "18n_ppo_tr_frostbite_06:147" completed
# 2026.09.20-00:06:17.175402     0.001 >> 3 (+1) launches completed; running launches=5
# 2026.09.20-00:06:42.988022     0.203 >> Model instance registered, version=151
# 2026.09.20-00:06:43.001744     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:151"; running launches=6
# 2026.09.20-00:06:43.001907     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch151.ipynb"
# 2026.09.20-00:14:23.560380     3.369 >> Trial 0 (18n_ppo_tr_frostbite_06:143) finished with value: 3312.3529411764707 and parameters: {'parent': '18n_ppo_tr_frostbite_06:112'}. Best is trial 4 with value: 4911.764705882353
# 2026.09.20-00:14:25.306633     0.001 >> Launch "18n_ppo_tr_frostbite_06:143" completed
# 2026.09.20-00:14:25.307407     0.001 >> 4 (+1) launches completed; running launches=5
# 2026.09.20-00:14:32.779125     2.360 >> Trial 1 (18n_ppo_tr_frostbite_06:144) finished with value: 3751.176470588235 and parameters: {'parent': '18n_ppo_tr_frostbite_06:107'}. Best is trial 4 with value: 4911.764705882353
# 2026.09.20-00:14:35.532864     0.001 >> Launch "18n_ppo_tr_frostbite_06:144" completed
# 2026.09.20-00:14:35.533633     0.001 >> 5 (+1) launches completed; running launches=4
# 2026.09.20-00:14:40.869072     0.222 >> Model instance registered, version=152
# 2026.09.20-00:14:40.882934     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:152"; running launches=5
# 2026.09.20-00:14:40.883087     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch152.ipynb"
# 2026.09.20-00:15:11.758418     0.195 >> Model instance registered, version=153
# 2026.09.20-00:15:11.766739     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:153"; running launches=6
# 2026.09.20-00:15:11.767419     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch153.ipynb"
# 2026.09.20-00:16:23.690165     0.100 >> Trial 3 (18n_ppo_tr_frostbite_06:146) finished with value: 4593.529411764706 and parameters: {'parent': '18n_ppo_tr_frostbite_06:107'}. Best is trial 4 with value: 4911.764705882353
# 2026.09.20-00:16:23.690847     0.001 >> Launch "18n_ppo_tr_frostbite_06:146" completed
# 2026.09.20-00:16:23.691424     0.001 >> 6 (+1) launches completed; running launches=5
# 2026.09.20-00:16:49.467160     0.190 >> Model instance registered, version=154
# 2026.09.20-00:16:49.482107     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:154"; running launches=6
# 2026.09.20-00:16:49.482314     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch154.ipynb"
# 2026.09.20-01:57:17.213156     3.809 >> Trial 6 (18n_ppo_tr_frostbite_06:149) finished with value: 4247.058823529412 and parameters: {'parent': '18n_ppo_tr_frostbite_06:85'}. Best is trial 4 with value: 4911.764705882353
# 2026.09.20-01:57:18.518742     0.002 >> Launch "18n_ppo_tr_frostbite_06:149" completed
# 2026.09.20-01:57:18.519499     0.001 >> 7 (+1) launches completed; running launches=5
# 2026.09.20-01:57:44.295934     0.187 >> Model instance registered, version=155
# 2026.09.20-01:57:44.310068     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:155"; running launches=6
# 2026.09.20-01:57:44.310214     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch155.ipynb"
# 2026.09.20-02:00:49.724534     3.891 >> Trial 7 (18n_ppo_tr_frostbite_06:150) finished with value: 5043.529411764706 and parameters: {'parent': '18n_ppo_tr_frostbite_06:85'}. Best is trial 7 with value: 5043.529411764706
# 2026.09.20-02:00:50.955519     0.002 >> Launch "18n_ppo_tr_frostbite_06:150" completed
# 2026.09.20-02:00:50.956511     0.001 >> 8 (+1) launches completed; running launches=5
# 2026.09.20-02:01:16.775389     0.218 >> Model instance registered, version=156
# 2026.09.20-02:01:16.790307     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:156"; running launches=6
# 2026.09.20-02:01:16.790522     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch156.ipynb"
# 2026.09.20-02:02:35.519311     1.368 >> Trial 8 (18n_ppo_tr_frostbite_06:151) finished with value: 4564.705882352941 and parameters: {'parent': '18n_ppo_tr_frostbite_06:85'}. Best is trial 7 with value: 5043.529411764706
# 2026.09.20-02:02:39.267141     0.002 >> Launch "18n_ppo_tr_frostbite_06:151" completed
# 2026.09.20-02:02:39.267989     0.001 >> 9 (+1) launches completed; running launches=5
# 2026.09.20-02:03:06.642248     0.204 >> Model instance registered, version=157
# 2026.09.20-02:03:06.655219     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:157"; running launches=6
# 2026.09.20-02:03:06.655385     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch157.ipynb"
# 2026.09.20-02:19:08.656944     3.885 >> Trial 10 (18n_ppo_tr_frostbite_06:153) finished with value: 4363.529411764706 and parameters: {'parent': '18n_ppo_tr_frostbite_06:85'}. Best is trial 7 with value: 5043.529411764706
# 2026.09.20-02:19:09.889789     0.002 >> Launch "18n_ppo_tr_frostbite_06:153" completed
# 2026.09.20-02:19:09.890729     0.001 >> 10 (+1) launches completed; running launches=5
# 2026.09.20-02:19:19.524559     4.438 >> Trial 9 (18n_ppo_tr_frostbite_06:152) finished with value: 3886.470588235294 and parameters: {'parent': '18n_ppo_tr_frostbite_06:107'}. Best is trial 7 with value: 5043.529411764706
# 2026.09.20-02:19:20.571044     0.002 >> Launch "18n_ppo_tr_frostbite_06:152" completed
# 2026.09.20-02:19:20.571876     0.001 >> 11 (+1) launches completed; running launches=4
# 2026.09.20-02:19:28.171152     0.215 >> Model instance registered, version=158
# 2026.09.20-02:19:28.184584     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:158"; running launches=5
# 2026.09.20-02:19:28.184710     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch158.ipynb"
# 2026.09.20-02:19:59.461776     0.188 >> Model instance registered, version=159
# 2026.09.20-02:19:59.474100     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:159"; running launches=6
# 2026.09.20-02:19:59.474311     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch159.ipynb"
# 2026.09.20-02:20:41.017981     0.416 >> Trial 11 (18n_ppo_tr_frostbite_06:154) finished with value: 5862.941176470588 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-02:20:45.721990     0.002 >> Launch "18n_ppo_tr_frostbite_06:154" completed
# 2026.09.20-02:20:45.722938     0.001 >> 12 (+1) launches completed; running launches=5
# 2026.09.20-02:21:06.492300     0.197 >> Model instance registered, version=160
# 2026.09.20-02:21:06.502380     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:160"; running launches=6
# 2026.09.20-02:21:06.502460     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch160.ipynb"
# 2026.09.20-03:51:09.162140     3.756 >> Trial 12 (18n_ppo_tr_frostbite_06:155) finished with value: 4618.235294117647 and parameters: {'parent': '18n_ppo_tr_frostbite_06:85'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-03:51:10.521378     0.001 >> Launch "18n_ppo_tr_frostbite_06:155" completed
# 2026.09.20-03:51:10.522467     0.001 >> 13 (+1) launches completed; running launches=5
# 2026.09.20-03:51:36.354182     0.186 >> Model instance registered, version=161
# 2026.09.20-03:51:36.366781     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:161"; running launches=6
# 2026.09.20-03:51:36.366994     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch161.ipynb"
# 2026.09.20-03:54:27.920408     2.505 >> Trial 13 (18n_ppo_tr_frostbite_06:156) finished with value: 3897.0588235294117 and parameters: {'parent': '18n_ppo_tr_frostbite_06:112'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-03:54:30.531458     0.001 >> Launch "18n_ppo_tr_frostbite_06:156" completed
# 2026.09.20-03:54:30.532331     0.001 >> 14 (+1) launches completed; running launches=5
# 2026.09.20-03:54:56.469420     0.207 >> Model instance registered, version=162
# 2026.09.20-03:54:56.482429     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:162"; running launches=6
# 2026.09.20-03:54:56.483329     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch162.ipynb"
# 2026.09.20-03:56:34.080557     0.165 >> Trial 14 (18n_ppo_tr_frostbite_06:157) finished with value: 4674.705882352941 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-03:56:39.035093     0.002 >> Launch "18n_ppo_tr_frostbite_06:157" completed
# 2026.09.20-03:56:39.036059     0.001 >> 15 (+1) launches completed; running launches=5
# 2026.09.20-03:56:59.777516     0.213 >> Model instance registered, version=163
# 2026.09.20-03:56:59.791263     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:163"; running launches=6
# 2026.09.20-03:56:59.791456     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch163.ipynb"
# 2026.09.20-04:24:42.426762     4.368 >> Trial 16 (18n_ppo_tr_frostbite_06:159) finished with value: 5142.941176470588 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-04:24:42.495664     0.069 >> Trial 15 (18n_ppo_tr_frostbite_06:158) finished with value: 4711.764705882353 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-04:24:43.176543     0.002 >> Launch "18n_ppo_tr_frostbite_06:159" completed
# 2026.09.20-04:24:43.177351     0.001 >> Launch "18n_ppo_tr_frostbite_06:158" completed
# 2026.09.20-04:24:43.178111     0.001 >> 17 (+2) launches completed; running launches=4
# 2026.09.20-04:24:53.601789     0.195 >> Model instance registered, version=164
# 2026.09.20-04:24:53.615211     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:164"; running launches=5
# 2026.09.20-04:24:53.615394     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch164.ipynb"
# 2026.09.20-04:25:24.605365     0.211 >> Model instance registered, version=165
# 2026.09.20-04:25:24.619277     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:165"; running launches=6
# 2026.09.20-04:25:24.619523     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch165.ipynb"
# 2026.09.20-04:25:53.823083     3.221 >> Trial 17 (18n_ppo_tr_frostbite_06:160) finished with value: 4479.411764705882 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-04:25:55.840929     0.002 >> Launch "18n_ppo_tr_frostbite_06:160" completed
# 2026.09.20-04:25:55.841892     0.001 >> 18 (+1) launches completed; running launches=5
# 2026.09.20-04:26:21.741550     0.200 >> Model instance registered, version=166
# 2026.09.20-04:26:21.755975     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:166"; running launches=6
# 2026.09.20-04:26:21.756227     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch166.ipynb"
# 2026.09.20-05:46:36.358375     4.689 >> Trial 18 (18n_ppo_tr_frostbite_06:161) finished with value: 4755.294117647059 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-05:46:36.786946     0.002 >> Launch "18n_ppo_tr_frostbite_06:161" completed
# 2026.09.20-05:46:36.787860     0.001 >> 19 (+1) launches completed; running launches=5
# 2026.09.20-05:47:02.593236     0.199 >> Model instance registered, version=167
# 2026.09.20-05:47:02.611236     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:167"; running launches=6
# 2026.09.20-05:47:02.611433     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch167.ipynb"
# 2026.09.20-05:49:13.245512     2.553 >> Trial 19 (18n_ppo_tr_frostbite_06:162) finished with value: 5395.882352941177 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-05:49:15.810375     0.001 >> Launch "18n_ppo_tr_frostbite_06:162" completed
# 2026.09.20-05:49:15.811379     0.001 >> 20 (+1) launches completed; running launches=5
# 2026.09.20-05:49:41.588720     0.204 >> Model instance registered, version=168
# 2026.09.20-05:49:41.597734     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:168"; running launches=6
# 2026.09.20-05:49:41.597949     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch168.ipynb"
# 2026.09.20-05:51:39.927290     0.224 >> Trial 20 (18n_ppo_tr_frostbite_06:163) finished with value: 4315.882352941177 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-05:51:44.819932     0.001 >> Launch "18n_ppo_tr_frostbite_06:163" completed
# 2026.09.20-05:51:44.820951     0.001 >> 21 (+1) launches completed; running launches=5
# 2026.09.20-05:52:05.479402     0.197 >> Model instance registered, version=169
# 2026.09.20-05:52:05.489062     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:169"; running launches=6
# 2026.09.20-05:52:05.489197     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch169.ipynb"
# 2026.09.20-06:31:06.283039     4.797 >> Trial 23 (18n_ppo_tr_frostbite_06:166) finished with value: 4090.0 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-06:31:06.605391     0.002 >> Launch "18n_ppo_tr_frostbite_06:166" completed
# 2026.09.20-06:31:06.606254     0.001 >> 22 (+1) launches completed; running launches=5
# 2026.09.20-06:31:26.997251     5.047 >> Trial 22 (18n_ppo_tr_frostbite_06:165) finished with value: 4968.235294117647 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-06:31:26.998148     0.001 >> Trial 21 (18n_ppo_tr_frostbite_06:164) finished with value: 3944.1176470588234 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-06:31:27.267385     0.199 >> Model instance registered, version=170
# 2026.09.20-06:31:27.282444     0.006 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:170"; running launches=6
# 2026.09.20-06:31:27.283347     0.001 >> Launch "18n_ppo_tr_frostbite_06:164" completed
# 2026.09.20-06:31:27.282572     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch170.ipynb"
# 2026.09.20-06:31:27.283673     0.000 >> Launch "18n_ppo_tr_frostbite_06:165" completed
# 2026.09.20-06:31:27.284951     0.001 >> 24 (+2) launches completed; running launches=4
# 2026.09.20-06:31:58.210778     0.184 >> Model instance registered, version=171
# 2026.09.20-06:31:58.224639     0.006 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:171"; running launches=5
# 2026.09.20-06:31:58.224861     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch171.ipynb"
# 2026.09.20-06:32:29.150808     0.224 >> Model instance registered, version=172
# 2026.09.20-06:32:29.163037     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:172"; running launches=6
# 2026.09.20-06:32:29.163168     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch172.ipynb"
# 2026.09.20-07:42:03.499800     0.085 >> Trial 24 (18n_ppo_tr_frostbite_06:167) finished with value: 5002.941176470588 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-07:42:03.500832     0.001 >> Launch "18n_ppo_tr_frostbite_06:167" completed
# 2026.09.20-07:42:03.501279     0.000 >> 25 (+1) launches completed; running launches=5
# 2026.09.20-07:43:42.307869     1.451 >> Trial 25 (18n_ppo_tr_frostbite_06:168) finished with value: 5043.529411764706 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-07:43:45.971531     0.001 >> Launch "18n_ppo_tr_frostbite_06:168" completed
# 2026.09.20-07:43:45.972371     0.001 >> 26 (+1) launches completed; running launches=4
# 2026.09.20-07:46:19.493993     4.428 >> Trial 26 (18n_ppo_tr_frostbite_06:169) finished with value: 5286.470588235294 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-07:46:20.183222     0.003 >> Launch "18n_ppo_tr_frostbite_06:169" completed
# 2026.09.20-07:46:20.184048     0.001 >> 27 (+1) launches completed; running launches=3
# 2026.09.20-08:34:26.175300     2.553 >> Trial 27 (18n_ppo_tr_frostbite_06:170) finished with value: 5062.35294117647 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-08:34:28.743221     0.003 >> Launch "18n_ppo_tr_frostbite_06:170" completed
# 2026.09.20-08:34:28.744179     0.001 >> 28 (+1) launches completed; running launches=2
# 2026.09.20-08:35:00.939366     1.509 >> Trial 29 (18n_ppo_tr_frostbite_06:172) finished with value: 4887.64705882353 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 11 with value: 5862.941176470588
# 2026.09.20-08:35:04.545614     0.002 >> Launch "18n_ppo_tr_frostbite_06:172" completed
# 2026.09.20-08:35:04.546518     0.001 >> 29 (+1) launches completed; running launches=1
# 2026.09.20-08:35:22.845486     2.929 >> Trial 28 (18n_ppo_tr_frostbite_06:171) finished with value: 5872.35294117647 and parameters: {'parent': '18n_ppo_tr_frostbite_06:95'}. Best is trial 28 with value: 5872.35294117647
# 2026.09.20-08:35:25.035338     0.002 >> Launch "18n_ppo_tr_frostbite_06:171" completed
# 2026.09.20-08:35:25.036318     0.001 >> 30 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-20 08:35:30,071] Using an existing study with name '18n_study_18.3b' instead of creating a new one.
# 2026.09.20-08:35:30.073312     5.037 >> Study statistics:
# 2026.09.20-08:35:30.075997     0.003 >> 	Number of finished trials: 30
# 2026.09.20-08:35:30.077123     0.001 >> 	Number of pruned trials: 0
# 2026.09.20-08:35:30.078154     0.001 >> 	Number of complete trials: 30
# 2026.09.20-08:35:30.079298     0.001 >> Best trial:
# 2026.09.20-08:35:30.080641     0.001 >> 	Value: 5872.35294117647
# 2026.09.20-08:35:30.081117     0.000 >> 	Model version: 171
# 2026.09.20-08:35:30.081550     0.000 >> 	Params:
# 2026.09.20-08:35:30.081973     0.000 >> 		parent: 18n_ppo_tr_frostbite_06:95
