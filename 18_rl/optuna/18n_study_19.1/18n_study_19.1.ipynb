# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 6 шагов. На каждом шаге отбираем чемпионов для продолжения след. шага.
#
# Данный эксперимент - это первый шаг. Здесь агент должен научиться заходить в иглу = прорыв. Дневой и ночной уровни.

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.encoder.is_trainable = True

    HP.agent.parent = None 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(500000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = [
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=none',
        'com.develorium.neurolab.frostbite_ram:level5:1:cls=none',
    ]
    HP.video.capture_env_ram_patches = [
        ['no_score', 'last_life', 'full_igloo', 'temperature_10', 'bailey_to_the_right_of_igloo', 'bear_to_the_left_of_igloo'],
        ['no_score', 'last_life', 'full_igloo', 'temperature_10', 'bailey_to_the_left_of_igloo', 'bear_to_the_left_of_igloo'],
        ['no_score', 'last_life', 'full_igloo', 'temperature_10', 'bear_chases_bailey_to_the_right_of_igloo'],
        ['no_score', 'last_life', 'full_igloo', 'temperature_10', 'bear_chases_bailey_to_the_left_of_igloo'],
        ['no_score', 'last_life', 'full_igloo', 'temperature_20', 'bailey_near_center'], # *
    ]
    HP.video.break_on_level_passed = True
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = 3_000_000 # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = [
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=none',
        'com.develorium.neurolab.frostbite_ram:level5:1:cls=none',
    ]
    HP.ppo.rollout_env_ram_patches = [
        ['no_score', 'last_life', 'full_igloo',            'temperature_10', 'bailey_right_at_the_igloo_door'], # 0 
        ['no_score', 'last_life', 'full_igloo',            'temperature_10', 'bailey_very_near_igloo_door'], # 1
        ['no_score', 'last_life', 'full_igloo',            'temperature_10', 'bailey_near_center'], # 2
        ['no_score', 'last_life', 'one_remaining_igloo',   'temperature_10', 'bailey_near_center'], # 3
        ['no_score', 'last_life', 'three_remaining_igloo', 'temperature_20', 'bailey_near_center', ], # 4
        ['no_score', 'last_life', 'half_igloo', 'bailey_near_center'], # 5
        ['no_score', 'last_life', 'half_igloo'], # 6

        ['no_score', 'last_life', 'full_igloo', 'temperature_10', 'bailey_to_the_right_of_igloo', 'bear_to_the_left_of_igloo'], # 7
        ['no_score', 'last_life', 'full_igloo', 'temperature_10', 'bailey_to_the_left_of_igloo', 'bear_to_the_left_of_igloo'], # 8
        ['no_score', 'last_life', 'full_igloo', 'temperature_10', 'bear_chases_bailey_to_the_right_of_igloo'], # 9
        ['no_score', 'last_life', 'full_igloo', 'temperature_10', 'bear_chases_bailey_to_the_left_of_igloo'], # 10
        ['no_score', 'last_life', 'full_igloo', 'temperature_20', 'bailey_near_center'], # 11
    ]
    HP.ppo.rollout_env_stories = [
        '0;0:7',  # level 1 - teach agent to enter complete igloo
        '1;7:12', # level 5 - teach agent to enter complete blinking igloo
    ]
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    HP.ppo.learn_rate = 'const(0.00025)'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    HP.ppo.ent_coef = 'const(0.05)'
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Максимльно один из агентов 8 экзаменов сдал.
#
# Чемпионы:
# - `18n_ppo_tr_frostbite_06:388`
# - `18n_ppo_tr_frostbite_06:396`
# - `18n_ppo_tr_frostbite_06:412`
#
# <img src="./img/score.png">
# <img src="./img/episode_r.png">
#
# **Выводы**
# 1) едем дальше на чемпионах

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.1/18n_study_19.1.ipynb',
#  'optuna_study_name': '18n_study_19.1',
#  'optuna_study_serial': '19.1',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.1/18n_study_19.1.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-22 11:15:47,500] A new study created in Journal with name: 18n_study_19.1
# 2026.09.22-11:15:47.861276     0.332 >> Model instance registered, version=385
# 2026.09.22-11:15:47.875033     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch385.ipynb"
# 2026.09.22-11:15:47.876676     0.006 >> 6.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:385"; running launches=1
# 2026.09.22-11:16:18.811407     0.224 >> Model instance registered, version=386
# 2026.09.22-11:16:18.825427     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch386.ipynb"
# 2026.09.22-11:16:18.826698     0.001 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:386"; running launches=2
# 2026.09.22-11:16:49.740751     0.215 >> Model instance registered, version=387
# 2026.09.22-11:16:49.754343     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch387.ipynb"
# 2026.09.22-11:16:49.754612     0.006 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:387"; running launches=3
# 2026.09.22-11:17:22.241792     0.248 >> Model instance registered, version=388
# 2026.09.22-11:17:22.260891     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch388.ipynb"
# 2026.09.22-11:17:22.262050     0.007 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:388"; running launches=4
# 2026.09.22-11:17:53.382005     0.220 >> Model instance registered, version=389
# 2026.09.22-11:17:53.395822     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch389.ipynb"
# 2026.09.22-11:17:53.396422     0.001 >> 2.5 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:389"; running launches=5
# 2026.09.22-11:18:25.163825     0.246 >> Model instance registered, version=390
# 2026.09.22-11:18:25.174174     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch390.ipynb"
# 2026.09.22-11:18:25.174429     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:390"; running launches=6
# 2026.09.22-12:06:53.354269     0.282 >> Model instance registered, version=391
# 2026.09.22-12:06:53.370300     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch391.ipynb"
# 2026.09.22-12:06:53.370677     0.007 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:391"; running launches=7
# 2026.09.22-12:07:24.264500     0.207 >> Model instance registered, version=392
# 2026.09.22-12:07:24.274602     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch392.ipynb"
# 2026.09.22-12:07:24.274928     0.004 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:392"; running launches=8
# 2026.09.22-12:07:39.039880     4.543 >> Trial 2 (18n_ppo_tr_frostbite_06:387) finished with value: 50605.000113521775 and parameters: {}. Best is trial 2 with value: 50605.000113521775
# 2026.09.22-12:07:39.615597     0.002 >> Launch "18n_ppo_tr_frostbite_06:387" completed
# 2026.09.22-12:07:39.616794     0.001 >> 1 (+1) launches completed; running launches=7
# 2026.09.22-12:07:55.383272     0.219 >> Model instance registered, version=393
# 2026.09.22-12:07:55.391808     0.003 >> 3.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:393"; running launches=8
# 2026.09.22-12:07:55.391943     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch393.ipynb"
# 2026.09.22-12:08:03.815619     3.317 >> Trial 3 (18n_ppo_tr_frostbite_06:388) finished with value: 70605.00010455819 and parameters: {}. Best is trial 3 with value: 70605.00010455819
# 2026.09.22-12:08:05.616954     0.002 >> Launch "18n_ppo_tr_frostbite_06:388" completed
# 2026.09.22-12:08:05.618029     0.001 >> 2 (+1) launches completed; running launches=7
# 2026.09.22-12:08:26.292669     0.207 >> Model instance registered, version=394
# 2026.09.22-12:08:26.305589     0.005 >> 3.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:394"; running launches=8
# 2026.09.22-12:08:26.305729     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch394.ipynb"
# 2026.09.22-12:08:57.191127     0.204 >> Model instance registered, version=395
# 2026.09.22-12:08:57.204032     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch395.ipynb"
# 2026.09.22-12:08:57.204745     0.006 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:395"; running launches=9
# 2026.09.22-12:09:28.105423     0.214 >> Model instance registered, version=396
# 2026.09.22-12:09:28.119167     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch396.ipynb"
# 2026.09.22-12:09:28.119441     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:396"; running launches=10
# 2026.09.22-12:09:57.532812     3.788 >> Trial 5 (18n_ppo_tr_frostbite_06:390) finished with value: 60606.00011998981 and parameters: {}. Best is trial 3 with value: 70605.00010455819
# 2026.09.22-12:09:58.862501     0.002 >> Launch "18n_ppo_tr_frostbite_06:390" completed
# 2026.09.22-12:09:58.863392     0.001 >> 3 (+1) launches completed; running launches=9
# 2026.09.22-12:10:24.632072     0.200 >> Model instance registered, version=397
# 2026.09.22-12:10:24.644115     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:397"; running launches=10
# 2026.09.22-12:10:24.644210     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch397.ipynb"
# 2026.09.22-12:10:47.436399     2.338 >> Trial 1 (18n_ppo_tr_frostbite_06:386) finished with value: 60606.00012156863 and parameters: {}. Best is trial 3 with value: 70605.00010455819
# 2026.09.22-12:10:50.217604     0.002 >> Launch "18n_ppo_tr_frostbite_06:386" completed
# 2026.09.22-12:10:50.218393     0.001 >> 4 (+1) launches completed; running launches=9
# 2026.09.22-12:11:16.017401     0.208 >> Model instance registered, version=398
# 2026.09.22-12:11:16.030443     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:398"; running launches=10
# 2026.09.22-12:11:16.030568     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch398.ipynb"
# 2026.09.22-12:11:17.936474     1.906 >> Trial 0 (18n_ppo_tr_frostbite_06:385) finished with value: 60505.000100636615 and parameters: {}. Best is trial 3 with value: 70605.00010455819
# 2026.09.22-12:11:21.146157     0.002 >> Launch "18n_ppo_tr_frostbite_06:385" completed
# 2026.09.22-12:11:21.147110     0.001 >> 5 (+1) launches completed; running launches=9
# 2026.09.22-12:11:47.032231     0.247 >> Model instance registered, version=399
# 2026.09.22-12:11:47.044792     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:399"; running launches=10
# 2026.09.22-12:11:47.044917     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch399.ipynb"
# 2026.09.22-12:12:25.969239     3.124 >> Trial 4 (18n_ppo_tr_frostbite_06:389) finished with value: 50605.00009844665 and parameters: {}. Best is trial 3 with value: 70605.00010455819
# 2026.09.22-12:12:28.157856     0.002 >> Launch "18n_ppo_tr_frostbite_06:389" completed
# 2026.09.22-12:12:28.158909     0.001 >> 6 (+1) launches completed; running launches=9
# 2026.09.22-12:12:54.051262     0.205 >> Model instance registered, version=400
# 2026.09.22-12:12:54.059659     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:400"; running launches=10
# 2026.09.22-12:12:54.059840     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch400.ipynb"
# 2026.09.22-12:53:28.155611     1.964 >> Trial 6 (18n_ppo_tr_frostbite_06:391) finished with value: 50606.000146371276 and parameters: {}. Best is trial 3 with value: 70605.00010455819
# 2026.09.22-12:53:31.309584     0.001 >> Launch "18n_ppo_tr_frostbite_06:391" completed
# 2026.09.22-12:53:31.310191     0.001 >> 7 (+1) launches completed; running launches=9
# 2026.09.22-12:53:57.848400     0.213 >> Model instance registered, version=401
# 2026.09.22-12:53:57.859487     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:401"; running launches=10
# 2026.09.22-12:53:57.859630     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch401.ipynb"
# 2026.09.22-12:54:27.987165     4.565 >> Trial 7 (18n_ppo_tr_frostbite_06:392) finished with value: 50605.00011678126 and parameters: {}. Best is trial 3 with value: 70605.00010455819
# 2026.09.22-12:54:28.740064     0.002 >> Launch "18n_ppo_tr_frostbite_06:392" completed
# 2026.09.22-12:54:28.740887     0.001 >> 8 (+1) launches completed; running launches=9
# 2026.09.22-12:54:54.524256     0.206 >> Model instance registered, version=402
# 2026.09.22-12:54:54.533148     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:402"; running launches=10
# 2026.09.22-12:54:54.533243     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch402.ipynb"
# 2026.09.22-12:55:18.803329     3.808 >> Trial 8 (18n_ppo_tr_frostbite_06:393) finished with value: 50506.000101094985 and parameters: {}. Best is trial 3 with value: 70605.00010455819
# 2026.09.22-12:55:20.110899     0.001 >> Launch "18n_ppo_tr_frostbite_06:393" completed
# 2026.09.22-12:55:20.111751     0.001 >> 9 (+1) launches completed; running launches=9
# 2026.09.22-12:55:45.892998     0.200 >> Model instance registered, version=403
# 2026.09.22-12:55:45.906623     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:403"; running launches=10
# 2026.09.22-12:55:45.906724     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch403.ipynb"
# 2026.09.22-12:56:30.557323     3.725 >> Trial 11 (18n_ppo_tr_frostbite_06:396) finished with value: 70807.00011769799 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-12:56:31.949507     0.001 >> Launch "18n_ppo_tr_frostbite_06:396" completed
# 2026.09.22-12:56:31.950174     0.001 >> 10 (+1) launches completed; running launches=9
# 2026.09.22-12:56:57.823970     0.198 >> Model instance registered, version=404
# 2026.09.22-12:56:57.833460     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:404"; running launches=10
# 2026.09.22-12:56:57.833607     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch404.ipynb"
# 2026.09.22-12:59:26.786140     0.312 >> Trial 9 (18n_ppo_tr_frostbite_06:394) finished with value: 60606.00012319837 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-12:59:31.590079     0.002 >> Launch "18n_ppo_tr_frostbite_06:394" completed
# 2026.09.22-12:59:31.591169     0.001 >> 11 (+1) launches completed; running launches=9
# 2026.09.22-12:59:52.318855     0.275 >> Model instance registered, version=405
# 2026.09.22-12:59:52.330891     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:405"; running launches=10
# 2026.09.22-12:59:52.331109     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch405.ipynb"
# 2026.09.22-13:00:02.418913     4.981 >> Trial 10 (18n_ppo_tr_frostbite_06:395) finished with value: 60505.00011413293 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-13:00:02.557705     0.002 >> Launch "18n_ppo_tr_frostbite_06:395" completed
# 2026.09.22-13:00:02.558594     0.001 >> 12 (+1) launches completed; running launches=9
# 2026.09.22-13:00:23.223060     0.209 >> Model instance registered, version=406
# 2026.09.22-13:00:23.236856     0.006 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:406"; running launches=10
# 2026.09.22-13:00:23.237509     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch406.ipynb"
# 2026.09.22-13:01:24.351640     4.497 >> Trial 12 (18n_ppo_tr_frostbite_06:397) finished with value: 50706.00011566081 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-13:01:24.968924     0.001 >> Launch "18n_ppo_tr_frostbite_06:397" completed
# 2026.09.22-13:01:24.969754     0.001 >> 13 (+1) launches completed; running launches=9
# 2026.09.22-13:01:50.766340     0.226 >> Model instance registered, version=407
# 2026.09.22-13:01:50.775502     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:407"; running launches=10
# 2026.09.22-13:01:50.775614     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch407.ipynb"
# 2026.09.22-13:05:55.343434     3.577 >> Trial 14 (18n_ppo_tr_frostbite_06:399) finished with value: 60606.000124522536 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-13:05:56.880534     0.001 >> Launch "18n_ppo_tr_frostbite_06:399" completed
# 2026.09.22-13:05:56.881282     0.001 >> 14 (+1) launches completed; running launches=9
# 2026.09.22-13:05:57.567619     0.686 >> Trial 13 (18n_ppo_tr_frostbite_06:398) finished with value: 50505.00010634072 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-13:06:01.999019     0.002 >> Launch "18n_ppo_tr_frostbite_06:398" completed
# 2026.09.22-13:06:02.000112     0.001 >> 15 (+1) launches completed; running launches=8
# 2026.09.22-13:06:12.443806     0.217 >> Model instance registered, version=408
# 2026.09.22-13:06:12.457987     0.005 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:408"; running launches=9
# 2026.09.22-13:06:12.458161     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch408.ipynb"
# 2026.09.22-13:06:43.387270     0.215 >> Model instance registered, version=409
# 2026.09.22-13:06:43.397287     0.003 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:409"; running launches=10
# 2026.09.22-13:06:43.397419     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch409.ipynb"
# 2026.09.22-13:07:57.858801     2.705 >> Trial 15 (18n_ppo_tr_frostbite_06:400) finished with value: 70606.00010863255 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-13:08:00.269110     0.001 >> Launch "18n_ppo_tr_frostbite_06:400" completed
# 2026.09.22-13:08:00.269812     0.001 >> 16 (+1) launches completed; running launches=9
# 2026.09.22-13:08:26.057074     0.206 >> Model instance registered, version=410
# 2026.09.22-13:08:26.070042     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:410"; running launches=10
# 2026.09.22-13:08:26.070663     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch410.ipynb"
# 2026.09.22-13:40:02.109054     3.548 >> Trial 16 (18n_ppo_tr_frostbite_06:401) finished with value: 60606.000123503945 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-13:40:03.676339     0.001 >> Launch "18n_ppo_tr_frostbite_06:401" completed
# 2026.09.22-13:40:03.677184     0.001 >> 17 (+1) launches completed; running launches=9
# 2026.09.22-13:40:29.484316     0.237 >> Model instance registered, version=411
# 2026.09.22-13:40:29.493541     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:411"; running launches=10
# 2026.09.22-13:40:29.493630     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch411.ipynb"
# 2026.09.22-13:41:11.731448     1.186 >> Trial 17 (18n_ppo_tr_frostbite_06:402) finished with value: 60605.000107715816 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-13:41:15.655421     0.001 >> Launch "18n_ppo_tr_frostbite_06:402" completed
# 2026.09.22-13:41:15.655866     0.000 >> 18 (+1) launches completed; running launches=9
# 2026.09.22-13:41:41.463243     0.219 >> Model instance registered, version=412
# 2026.09.22-13:41:41.473130     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:412"; running launches=10
# 2026.09.22-13:41:41.473305     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch412.ipynb"
# 2026.09.22-13:42:01.637929     4.824 >> Trial 18 (18n_ppo_tr_frostbite_06:403) finished with value: 50606.00013180545 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-13:42:01.931087     0.001 >> Launch "18n_ppo_tr_frostbite_06:403" completed
# 2026.09.22-13:42:01.932246     0.001 >> 19 (+1) launches completed; running launches=9
# 2026.09.22-13:42:27.729060     0.209 >> Model instance registered, version=413
# 2026.09.22-13:42:27.743164     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:413"; running launches=10
# 2026.09.22-13:42:27.743373     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch413.ipynb"
# 2026.09.22-13:42:42.254476     4.293 >> Trial 19 (18n_ppo_tr_frostbite_06:404) finished with value: 50605.000116068244 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-13:42:43.072104     0.001 >> Launch "18n_ppo_tr_frostbite_06:404" completed
# 2026.09.22-13:42:43.072630     0.001 >> 20 (+1) launches completed; running launches=9
# 2026.09.22-13:42:58.677649     0.260 >> Model instance registered, version=414
# 2026.09.22-13:42:58.687186     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:414"; running launches=10
# 2026.09.22-13:42:58.687343     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch414.ipynb"
# 2026.09.22-13:51:36.987825     2.690 >> Trial 20 (18n_ppo_tr_frostbite_06:405) finished with value: 60706.00011418386 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-13:51:39.412726     0.001 >> Launch "18n_ppo_tr_frostbite_06:405" completed
# 2026.09.22-13:51:39.413301     0.001 >> 21 (+1) launches completed; running launches=9
# 2026.09.22-13:52:50.508308     3.922 >> Trial 21 (18n_ppo_tr_frostbite_06:406) finished with value: 50505.00010053476 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-13:52:51.704865     0.002 >> Launch "18n_ppo_tr_frostbite_06:406" completed
# 2026.09.22-13:52:51.705659     0.001 >> 22 (+1) launches completed; running launches=8
# 2026.09.22-13:52:58.277823     1.456 >> Trial 22 (18n_ppo_tr_frostbite_06:407) finished with value: 70506.00011398013 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-13:53:01.960505     0.003 >> Launch "18n_ppo_tr_frostbite_06:407" completed
# 2026.09.22-13:53:01.961564     0.001 >> 23 (+1) launches completed; running launches=7
# 2026.09.22-14:00:51.426776     1.841 >> Trial 24 (18n_ppo_tr_frostbite_06:409) finished with value: 50605.000125744846 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-14:00:54.703045     0.002 >> Launch "18n_ppo_tr_frostbite_06:409" completed
# 2026.09.22-14:00:54.703888     0.001 >> 24 (+1) launches completed; running launches=6
# 2026.09.22-14:01:24.057644     3.781 >> Trial 23 (18n_ppo_tr_frostbite_06:408) finished with value: 40605.000108479755 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-14:01:25.392132     0.002 >> Launch "18n_ppo_tr_frostbite_06:408" completed
# 2026.09.22-14:01:25.392926     0.001 >> 25 (+1) launches completed; running launches=5
# 2026.09.22-14:03:16.607697     3.029 >> Trial 25 (18n_ppo_tr_frostbite_06:410) finished with value: 60505.000106137 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-14:03:18.698537     0.002 >> Launch "18n_ppo_tr_frostbite_06:410" completed
# 2026.09.22-14:03:18.699399     0.001 >> 26 (+1) launches completed; running launches=4
# 2026.09.22-14:26:43.960027     1.352 >> Trial 26 (18n_ppo_tr_frostbite_06:411) finished with value: 60604.00009192768 and parameters: {}. Best is trial 11 with value: 70807.00011769799
# 2026.09.22-14:26:47.725138     0.002 >> Launch "18n_ppo_tr_frostbite_06:411" completed
# 2026.09.22-14:26:47.725975     0.001 >> 27 (+1) launches completed; running launches=3
# 2026.09.22-14:27:53.101908     3.531 >> Trial 27 (18n_ppo_tr_frostbite_06:412) finished with value: 80506.00011469315 and parameters: {}. Best is trial 27 with value: 80506.00011469315
# 2026.09.22-14:27:54.688963     0.002 >> Launch "18n_ppo_tr_frostbite_06:412" completed
# 2026.09.22-14:27:54.690014     0.001 >> 28 (+1) launches completed; running launches=2
# 2026.09.22-14:28:24.359393     4.093 >> Trial 28 (18n_ppo_tr_frostbite_06:413) finished with value: 60506.00011265597 and parameters: {}. Best is trial 27 with value: 80506.00011469315
# 2026.09.22-14:28:25.382793     0.001 >> Launch "18n_ppo_tr_frostbite_06:413" completed
# 2026.09.22-14:28:25.383871     0.001 >> 29 (+1) launches completed; running launches=1
# 2026.09.22-14:28:45.293796     4.401 >> Trial 29 (18n_ppo_tr_frostbite_06:414) finished with value: 60404.00009090909 and parameters: {}. Best is trial 27 with value: 80506.00011469315
# 2026.09.22-14:28:46.011716     0.001 >> Launch "18n_ppo_tr_frostbite_06:414" completed
# 2026.09.22-14:28:46.012561     0.001 >> 30 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-22 14:28:51,045] Using an existing study with name '18n_study_19.1' instead of creating a new one.
# 2026.09.22-14:28:51.047620     5.035 >> Study statistics:
# 2026.09.22-14:28:51.049039     0.001 >> 	Number of finished trials: 30
# 2026.09.22-14:28:51.049471     0.000 >> 	Number of pruned trials: 0
# 2026.09.22-14:28:51.049862     0.000 >> 	Number of complete trials: 30
# 2026.09.22-14:28:51.050366     0.001 >> Best trial:
# 2026.09.22-14:28:51.051118     0.001 >> 	Value: 80506.00011469315
# 2026.09.22-14:28:51.051408     0.000 >> 	Model version: 412
# 2026.09.22-14:28:51.051754     0.000 >> 	Params:
