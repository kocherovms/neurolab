# %% [markdown]
# # Goal
#
# Дообучение чемпов `18d_study_21.1`. Тестируем гиперпараметры:
# - `struct_projector=dict(type='Identity')`
# - `pred_latents_source='separate'`
# - `learn_rate`
# - `pred_loss_type='MSE'`
# - **учёт всех экшнов**

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18d_world_model_08.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.launch_goal = 'train_predictor'
    
    HP.general.comment = None
    HP.general.random_seed = random.randint(0, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True

    HP.dataset.train = [
        '18b_dataset_02:7:cls=train,no=1,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=2,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=3,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=4,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=5,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=6,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=7,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=8,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=9,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=10,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=11,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=12,seq=8,mp=0',
    ]
    HP.dataset.test = '18b_dataset_02:7:cls=test,no=1,seq=8,mp=0'

    parent = optuna_trial.suggest_categorical('parent', [
        '18d_world_model_08:169',
        '18d_world_model_08:148',
        '18d_world_model_08:145',
    ])
    HP.model.parent = parent
    # Give 4 obs, predict next 4 obs
    HP.model.input_sequence_length = 4
    HP.model.actions_count = 6
    HP.model.ob_shape = (1, 178, 152)
    HP.model.d_model = 256
    HP.model.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.model.encoder = dict(
        is_trainable=HP.launch_goal in ('train_encoder', 'train_all', None),
        vision_head=dict(grid=(6,6), features_counts=(16, 32, 64, 128)),
    )
    HP.model.predictor = dict(
        is_trainable=HP.launch_goal in ('train_predictor', 'train_all', None),
        pred_latents_source='separate',
    )
    HP.model.renderer = dict(
        is_trainable=HP.launch_goal in ('train_encoder', 'train_all', None),
        projector=dict(type='linear'), 
        render_engine=dict(
            type='layer', 
            layers_count=4, 
            features_counts=(96, 64, 32, 16),
        ),
    )
    HP.model.struct_projector = dict(
        is_trainable=HP.launch_goal in ('train_predictor', 'train_all', None),
        type='Identity',
        parent=None,
    )
    
    HP.train.epochs_count = 100
    HP.train.batch_size = 128
    HP.train.optimizer = 'AdamW'
    HP.train.max_grad_norm = 1.0
    HP.train.learn_rate = 'const(0.0001)'
    HP.train.bce_loss_coef = 'const(1.0)'
    HP.train.edge_loss_coef = 'const(1.0)'
    HP.train.recon_loss_coef = 'const(0.0)'
    HP.train.pred_loss = dict(
        type='MSE', 
        loss_coef='const(1.0)', 
    )
    
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Небольшое улучшение, по сравнению с первым шагом.
#
# <img src="./img/ssim.png">
#
# **Выводы**
# 1) сделать третий шаг с `launch_goal='train_all'`, посмотреть, что получится

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18d_world_model_08.ipynb',
#  'target_notebook_name': '18d_world_model_08',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18d_study_21.2/18d_study_21.2.ipynb',
#  'optuna_study_name': '18d_study_21.2',
#  'optuna_study_serial': '21.2',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18d_study_21.2/18d_study_21.2.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-14 16:52:11,718] A new study created in Journal with name: 18d_study_21.2
# 2026.09.14-16:52:11.914262     0.177 >> Model instance registered, version=172
# 2026.09.14-16:52:11.930586     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch172.ipynb"
# 2026.09.14-16:52:11.930885     0.007 >> 9.0 idle runners exist, submitted launch "18d_world_model_08:172"; running launches=1
# 2026.09.14-16:52:42.838538     0.201 >> Model instance registered, version=173
# 2026.09.14-16:52:42.852998     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch173.ipynb"
# 2026.09.14-16:52:42.854095     0.008 >> 8.5 idle runners exist, submitted launch "18d_world_model_08:173"; running launches=2
# 2026.09.14-16:53:13.967571     0.193 >> Model instance registered, version=174
# 2026.09.14-16:53:13.992024     0.012 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch174.ipynb"
# 2026.09.14-16:53:13.992444     0.013 >> 7.7 idle runners exist, submitted launch "18d_world_model_08:174"; running launches=3
# 2026.09.14-16:53:44.881728     0.202 >> Model instance registered, version=175
# 2026.09.14-16:53:44.897375     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch175.ipynb"
# 2026.09.14-16:53:44.897740     0.008 >> 6.7 idle runners exist, submitted launch "18d_world_model_08:175"; running launches=4
# 2026.09.14-16:54:16.147801     0.202 >> Model instance registered, version=176
# 2026.09.14-16:54:16.161676     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch176.ipynb"
# 2026.09.14-16:54:16.162302     0.007 >> 5.7 idle runners exist, submitted launch "18d_world_model_08:176"; running launches=5
# 2026.09.14-16:54:47.163284     0.195 >> Model instance registered, version=177
# 2026.09.14-16:54:47.181789     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch177.ipynb"
# 2026.09.14-16:54:47.182035     0.008 >> 4.5 idle runners exist, submitted launch "18d_world_model_08:177"; running launches=6
# 2026.09.14-16:55:18.983416     0.179 >> Model instance registered, version=178
# 2026.09.14-16:55:19.001834     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch178.ipynb"
# 2026.09.14-16:55:19.002089     0.007 >> 3.7 idle runners exist, submitted launch "18d_world_model_08:178"; running launches=7
# 2026.09.14-16:55:50.119657     0.184 >> Model instance registered, version=179
# 2026.09.14-16:55:50.138775     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch179.ipynb"
# 2026.09.14-16:55:50.139011     0.007 >> 2.8 idle runners exist, submitted launch "18d_world_model_08:179"; running launches=8
# 2026.09.14-16:56:21.263192     0.197 >> Model instance registered, version=180
# 2026.09.14-16:56:21.280526     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch180.ipynb"
# 2026.09.14-16:56:21.280769     0.007 >> 1.3 idle runners exist, submitted launch "18d_world_model_08:180"; running launches=9
# 2026.09.14-17:04:06.372212     2.952 >> Trial 3 (18d_world_model_08:175) finished with value: 0.9647719382349293 and parameters: {'parent': '18d_world_model_08:145'}. Best is trial 3 with value: 0.9647719382349293
# 2026.09.14-17:04:08.619194     0.004 >> Launch "18d_world_model_08:175" completed
# 2026.09.14-17:04:08.619941     0.001 >> 1 (+1) launches completed; running launches=8
# 2026.09.14-17:04:34.369947     0.182 >> Model instance registered, version=181
# 2026.09.14-17:04:34.384890     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:181"; running launches=9
# 2026.09.14-17:04:34.385102     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch181.ipynb"
# 2026.09.14-17:04:55.667995     0.326 >> Trial 0 (18d_world_model_08:172) finished with value: 0.9678133905471911 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 0 with value: 0.9678133905471911
# 2026.09.14-17:05:00.467922     0.001 >> Launch "18d_world_model_08:172" completed
# 2026.09.14-17:05:00.468503     0.001 >> 2 (+1) launches completed; running launches=8
# 2026.09.14-17:05:05.758829     0.177 >> Model instance registered, version=182
# 2026.09.14-17:05:05.772558     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:182"; running launches=9
# 2026.09.14-17:05:05.772768     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch182.ipynb"
# 2026.09.14-17:06:37.358964     4.341 >> Trial 6 (18d_world_model_08:178) finished with value: 0.9675101419419765 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 0 with value: 0.9678133905471911
# 2026.09.14-17:06:38.217327     0.003 >> Launch "18d_world_model_08:178" completed
# 2026.09.14-17:06:38.218646     0.001 >> 3 (+1) launches completed; running launches=8
# 2026.09.14-17:07:03.988672     0.185 >> Model instance registered, version=183
# 2026.09.14-17:07:04.003920     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:183"; running launches=9
# 2026.09.14-17:07:04.004259     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch183.ipynb"
# 2026.09.14-17:07:15.771688     1.550 >> Trial 8 (18d_world_model_08:180) finished with value: 0.9678863316431173 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 8 with value: 0.9678863316431173
# 2026.09.14-17:07:19.373638     0.001 >> Launch "18d_world_model_08:180" completed
# 2026.09.14-17:07:19.374515     0.001 >> 4 (+1) launches completed; running launches=8
# 2026.09.14-17:07:34.897851     0.189 >> Model instance registered, version=184
# 2026.09.14-17:07:34.922235     0.011 >> 1.3 idle runners exist, submitted launch "18d_world_model_08:184"; running launches=9
# 2026.09.14-17:07:34.922371     0.011 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch184.ipynb"
# 2026.09.14-17:07:47.865653     2.702 >> Trial 5 (18d_world_model_08:177) finished with value: 0.9676380754667319 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 8 with value: 0.9678863316431173
# 2026.09.14-17:07:50.282758     0.002 >> Launch "18d_world_model_08:177" completed
# 2026.09.14-17:07:50.283683     0.001 >> 5 (+1) launches completed; running launches=8
# 2026.09.14-17:08:06.034076     0.204 >> Model instance registered, version=185
# 2026.09.14-17:08:06.052691     0.007 >> 1.2 idle runners exist, submitted launch "18d_world_model_08:185"; running launches=9
# 2026.09.14-17:08:06.053469     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch185.ipynb"
# 2026.09.14-17:08:56.230901     3.927 >> Trial 7 (18d_world_model_08:179) finished with value: 0.964912074991672 and parameters: {'parent': '18d_world_model_08:145'}. Best is trial 8 with value: 0.9678863316431173
# 2026.09.14-17:08:57.420564     0.001 >> Launch "18d_world_model_08:179" completed
# 2026.09.14-17:08:57.421359     0.001 >> 6 (+1) launches completed; running launches=8
# 2026.09.14-17:09:23.178248     0.181 >> Model instance registered, version=186
# 2026.09.14-17:09:23.192019     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:186"; running launches=9
# 2026.09.14-17:09:23.192347     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch186.ipynb"
# 2026.09.14-17:10:31.995173     1.975 >> Trial 1 (18d_world_model_08:173) finished with value: 0.9667764758084223 and parameters: {'parent': '18d_world_model_08:148'}. Best is trial 8 with value: 0.9678863316431173
# 2026.09.14-17:10:35.128334     0.001 >> Launch "18d_world_model_08:173" completed
# 2026.09.14-17:10:35.128873     0.001 >> 7 (+1) launches completed; running launches=8
# 2026.09.14-17:10:52.358024     1.894 >> Trial 2 (18d_world_model_08:174) finished with value: 0.9668224288413282 and parameters: {'parent': '18d_world_model_08:148'}. Best is trial 8 with value: 0.9678863316431173
# 2026.09.14-17:10:55.756539     0.180 >> Model instance registered, version=187
# 2026.09.14-17:10:55.778106     0.009 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:187"; running launches=9
# 2026.09.14-17:10:55.778783     0.001 >> Launch "18d_world_model_08:174" completed
# 2026.09.14-17:10:55.779016     0.000 >> 8 (+1) launches completed; running launches=8
# 2026.09.14-17:10:55.778378     0.010 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch187.ipynb"
# 2026.09.14-17:11:26.787049     0.188 >> Model instance registered, version=188
# 2026.09.14-17:11:26.809524     0.010 >> 1.5 idle runners exist, submitted launch "18d_world_model_08:188"; running launches=9
# 2026.09.14-17:11:26.809664     0.010 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch188.ipynb"
# 2026.09.14-17:12:09.736081     1.570 >> Trial 4 (18d_world_model_08:176) finished with value: 0.9669758691915351 and parameters: {'parent': '18d_world_model_08:148'}. Best is trial 8 with value: 0.9678863316431173
# 2026.09.14-17:12:13.287156     0.002 >> Launch "18d_world_model_08:176" completed
# 2026.09.14-17:12:13.287996     0.001 >> 9 (+1) launches completed; running launches=8
# 2026.09.14-17:12:39.118295     0.194 >> Model instance registered, version=189
# 2026.09.14-17:12:39.136599     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:189"; running launches=9
# 2026.09.14-17:12:39.136730     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch189.ipynb"
# 2026.09.14-17:14:20.840474     3.732 >> Trial 9 (18d_world_model_08:181) finished with value: 0.9664553431235775 and parameters: {'parent': '18d_world_model_08:148'}. Best is trial 8 with value: 0.9678863316431173
# 2026.09.14-17:14:22.223113     0.002 >> Launch "18d_world_model_08:181" completed
# 2026.09.14-17:14:22.223780     0.001 >> 10 (+1) launches completed; running launches=8
# 2026.09.14-17:14:48.024091     0.221 >> Model instance registered, version=190
# 2026.09.14-17:14:48.043595     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:190"; running launches=9
# 2026.09.14-17:14:48.043733     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch190.ipynb"
# 2026.09.14-17:17:43.178683     1.001 >> Trial 10 (18d_world_model_08:182) finished with value: 0.9661691703048407 and parameters: {'parent': '18d_world_model_08:148'}. Best is trial 8 with value: 0.9678863316431173
# 2026.09.14-17:17:47.323027     0.005 >> Launch "18d_world_model_08:182" completed
# 2026.09.14-17:17:47.324431     0.001 >> 11 (+1) launches completed; running launches=8
# 2026.09.14-17:17:52.716312     0.270 >> Trial 11 (18d_world_model_08:183) finished with value: 0.9676909046903267 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 8 with value: 0.9678863316431173
# 2026.09.14-17:17:57.564572     0.002 >> Launch "18d_world_model_08:183" completed
# 2026.09.14-17:17:57.565635     0.001 >> 12 (+1) launches completed; running launches=7
# 2026.09.14-17:18:02.903911     0.227 >> Model instance registered, version=191
# 2026.09.14-17:18:02.924487     0.008 >> 1.2 idle runners exist, submitted launch "18d_world_model_08:191"; running launches=8
# 2026.09.14-17:18:02.924588     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch191.ipynb"
# 2026.09.14-17:18:33.823161     0.192 >> Model instance registered, version=192
# 2026.09.14-17:18:33.843270     0.008 >> 1.5 idle runners exist, submitted launch "18d_world_model_08:192"; running launches=9
# 2026.09.14-17:18:33.843491     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch192.ipynb"
# 2026.09.14-17:19:11.655447     2.034 >> Trial 13 (18d_world_model_08:185) finished with value: 0.9658176183477949 and parameters: {'parent': '18d_world_model_08:148'}. Best is trial 8 with value: 0.9678863316431173
# 2026.09.14-17:19:14.729010     0.001 >> Launch "18d_world_model_08:185" completed
# 2026.09.14-17:19:14.729535     0.001 >> 13 (+1) launches completed; running launches=8
# 2026.09.14-17:19:40.492413     0.201 >> Model instance registered, version=193
# 2026.09.14-17:19:40.507381     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:193"; running launches=9
# 2026.09.14-17:19:40.507485     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch193.ipynb"
# 2026.09.14-17:20:55.093344     2.656 >> Trial 12 (18d_world_model_08:184) finished with value: 0.9677970898103165 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 8 with value: 0.9678863316431173
# 2026.09.14-17:20:57.549294     0.001 >> Launch "18d_world_model_08:184" completed
# 2026.09.14-17:20:57.549996     0.001 >> 14 (+1) launches completed; running launches=8
# 2026.09.14-17:21:23.789642     0.202 >> Model instance registered, version=194
# 2026.09.14-17:21:23.803915     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:194"; running launches=9
# 2026.09.14-17:21:23.804080     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch194.ipynb"
# 2026.09.14-17:22:17.631273     2.501 >> Trial 14 (18d_world_model_08:186) finished with value: 0.9680159857589954 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 14 with value: 0.9680159857589954
# 2026.09.14-17:22:20.253789     0.001 >> Launch "18d_world_model_08:186" completed
# 2026.09.14-17:22:20.254375     0.001 >> 15 (+1) launches completed; running launches=8
# 2026.09.14-17:22:46.031622     0.208 >> Model instance registered, version=195
# 2026.09.14-17:22:46.051722     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:195"; running launches=9
# 2026.09.14-17:22:46.051853     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch195.ipynb"
# 2026.09.14-17:24:25.266079     1.220 >> Trial 18 (18d_world_model_08:190) finished with value: 0.9681490682346072 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 18 with value: 0.9681490682346072
# 2026.09.14-17:24:29.277612     0.002 >> Launch "18d_world_model_08:190" completed
# 2026.09.14-17:24:29.278614     0.001 >> 16 (+1) launches completed; running launches=8
# 2026.09.14-17:24:55.128336     0.249 >> Model instance registered, version=196
# 2026.09.14-17:24:55.155369     0.011 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:196"; running launches=9
# 2026.09.14-17:24:55.155576     0.011 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch196.ipynb"
# 2026.09.14-17:28:27.254940     2.235 >> Trial 15 (18d_world_model_08:187) finished with value: 0.9678599666591897 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 18 with value: 0.9681490682346072
# 2026.09.14-17:28:30.148356     0.008 >> Launch "18d_world_model_08:187" completed
# 2026.09.14-17:28:30.149456     0.001 >> 17 (+1) launches completed; running launches=8
# 2026.09.14-17:28:55.961790     0.247 >> Model instance registered, version=197
# 2026.09.14-17:28:55.985598     0.008 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:197"; running launches=9
# 2026.09.14-17:28:55.985819     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch197.ipynb"
# 2026.09.14-17:29:02.743751     1.607 >> Trial 16 (18d_world_model_08:188) finished with value: 0.9660047633826752 and parameters: {'parent': '18d_world_model_08:148'}. Best is trial 18 with value: 0.9681490682346072
# 2026.09.14-17:29:06.253227     0.001 >> Launch "18d_world_model_08:188" completed
# 2026.09.14-17:29:06.253942     0.001 >> 18 (+1) launches completed; running launches=8
# 2026.09.14-17:29:27.003493     0.212 >> Model instance registered, version=198
# 2026.09.14-17:29:27.020495     0.007 >> 1.3 idle runners exist, submitted launch "18d_world_model_08:198"; running launches=9
# 2026.09.14-17:29:27.021041     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch198.ipynb"
# 2026.09.14-17:29:38.441023     0.350 >> Trial 20 (18d_world_model_08:192) finished with value: 0.9679555285655929 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 18 with value: 0.9681490682346072
# 2026.09.14-17:29:43.202064     0.001 >> Launch "18d_world_model_08:192" completed
# 2026.09.14-17:29:43.202558     0.000 >> 19 (+1) launches completed; running launches=8
# 2026.09.14-17:29:58.715512     0.185 >> Model instance registered, version=199
# 2026.09.14-17:29:58.729989     0.006 >> 1.7 idle runners exist, submitted launch "18d_world_model_08:199"; running launches=9
# 2026.09.14-17:29:58.730152     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch199.ipynb"
# 2026.09.14-17:30:02.198115     3.468 >> Trial 17 (18d_world_model_08:189) finished with value: 0.9652879061373899 and parameters: {'parent': '18d_world_model_08:145'}. Best is trial 18 with value: 0.9681490682346072
# 2026.09.14-17:30:03.838242     0.001 >> Launch "18d_world_model_08:189" completed
# 2026.09.14-17:30:03.838837     0.001 >> 20 (+1) launches completed; running launches=8
# 2026.09.14-17:30:29.944537     0.222 >> Model instance registered, version=200
# 2026.09.14-17:30:29.958048     0.007 >> 2.0 idle runners exist, submitted launch "18d_world_model_08:200"; running launches=9
# 2026.09.14-17:30:29.958185     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch200.ipynb"
# 2026.09.14-17:30:37.301472     2.161 >> Trial 21 (18d_world_model_08:193) finished with value: 0.9673604514641143 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 18 with value: 0.9681490682346072
# 2026.09.14-17:30:40.260571     0.001 >> Launch "18d_world_model_08:193" completed
# 2026.09.14-17:30:40.261401     0.001 >> 21 (+1) launches completed; running launches=8
# 2026.09.14-17:30:54.939682     4.390 >> Trial 19 (18d_world_model_08:191) finished with value: 0.9684138122615583 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 19 with value: 0.9684138122615583
# 2026.09.14-17:30:55.906368     0.002 >> Launch "18d_world_model_08:191" completed
# 2026.09.14-17:30:55.907509     0.001 >> 22 (+1) launches completed; running launches=7
# 2026.09.14-17:31:01.252441     0.236 >> Model instance registered, version=201
# 2026.09.14-17:31:01.267315     0.007 >> 2.2 idle runners exist, submitted launch "18d_world_model_08:201"; running launches=8
# 2026.09.14-17:31:01.267524     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch201.ipynb"
# 2026.09.14-17:34:04.316363     3.612 >> Trial 22 (18d_world_model_08:194) finished with value: 0.9674399600606302 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 19 with value: 0.9684138122615583
# 2026.09.14-17:34:05.823186     0.001 >> Launch "18d_world_model_08:194" completed
# 2026.09.14-17:34:05.824032     0.001 >> 23 (+1) launches completed; running launches=7
# 2026.09.14-17:34:50.572793     3.821 >> Trial 24 (18d_world_model_08:196) finished with value: 0.9677490158389744 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 19 with value: 0.9684138122615583
# 2026.09.14-17:34:51.870744     0.003 >> Launch "18d_world_model_08:196" completed
# 2026.09.14-17:34:51.871853     0.001 >> 24 (+1) launches completed; running launches=6
# 2026.09.14-17:35:35.860830     2.023 >> Trial 23 (18d_world_model_08:195) finished with value: 0.9680064329876916 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 19 with value: 0.9684138122615583
# 2026.09.14-17:35:39.162389     0.004 >> Launch "18d_world_model_08:195" completed
# 2026.09.14-17:35:39.163693     0.001 >> 25 (+1) launches completed; running launches=5
# 2026.09.14-17:40:03.798088     2.868 >> Trial 27 (18d_world_model_08:199) finished with value: 0.9649039013527503 and parameters: {'parent': '18d_world_model_08:145'}. Best is trial 19 with value: 0.9684138122615583
# 2026.09.14-17:40:06.048515     0.003 >> Launch "18d_world_model_08:199" completed
# 2026.09.14-17:40:06.049052     0.001 >> 26 (+1) launches completed; running launches=4
# 2026.09.14-17:40:41.772929     4.625 >> Trial 29 (18d_world_model_08:201) finished with value: 0.9679796467605054 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 19 with value: 0.9684138122615583
# 2026.09.14-17:40:42.274279     0.004 >> Launch "18d_world_model_08:201" completed
# 2026.09.14-17:40:42.274944     0.001 >> 27 (+1) launches completed; running launches=3
# 2026.09.14-17:41:34.085675     0.335 >> Trial 28 (18d_world_model_08:200) finished with value: 0.96808834319318 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 19 with value: 0.9684138122615583
# 2026.09.14-17:41:38.870527     0.002 >> Launch "18d_world_model_08:200" completed
# 2026.09.14-17:41:38.871585     0.001 >> 28 (+1) launches completed; running launches=2
# 2026.09.14-17:43:28.484672     1.756 >> Trial 25 (18d_world_model_08:197) finished with value: 0.9673118095029896 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 19 with value: 0.9684138122615583
# 2026.09.14-17:43:31.841633     0.001 >> Launch "18d_world_model_08:197" completed
# 2026.09.14-17:43:31.842246     0.001 >> 29 (+1) launches completed; running launches=1
# 2026.09.14-17:43:52.896936     0.395 >> Trial 26 (18d_world_model_08:198) finished with value: 0.967495845316208 and parameters: {'parent': '18d_world_model_08:169'}. Best is trial 19 with value: 0.9684138122615583
# 2026.09.14-17:43:57.617020     0.001 >> Launch "18d_world_model_08:198" completed
# 2026.09.14-17:43:57.617613     0.001 >> 30 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-14 17:44:02,639] Using an existing study with name '18d_study_21.2' instead of creating a new one.
# 2026.09.14-17:44:02.640686     5.023 >> Study statistics:
# 2026.09.14-17:44:02.642419     0.002 >> 	Number of finished trials: 30
# 2026.09.14-17:44:02.642786     0.000 >> 	Number of pruned trials: 0
# 2026.09.14-17:44:02.643089     0.000 >> 	Number of complete trials: 30
# 2026.09.14-17:44:02.643704     0.001 >> Best trial:
# 2026.09.14-17:44:02.644678     0.001 >> 	Value: 0.9684138122615583
# 2026.09.14-17:44:02.645088     0.000 >> 	Model version: 191
# 2026.09.14-17:44:02.645490     0.000 >> 	Params:
# 2026.09.14-17:44:02.645882     0.000 >> 		parent: 18d_world_model_08:169
