# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 5 поколений по 6 млн шагов с последующим отбором чемпионов. Наследники этих чемпионов будут использоваться на следующем шаге.
#
# Данный эксперимент - это первый шаг. Здесь агент должен научиться заходить в иглу = прорыв.
#
# Особенности:
# - энкодер из `18d_world_model_08`
# - механика повторяет 17-ых агентов
# - `prediction_coef=0.1`
# - `sequence_length=10`
# - `batch_size=1024`
# - `vf_coef`

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_04.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    generations_count = 5
    generation_ind = 0
    generation_steps_count = 6_000_000
    all_generations_steps_count = generation_steps_count * generations_count
    learn_rate_range = (0.00025, 0.00025 * 0.1)
    ent_coef_range = (0.05, 0.05 * 0.1)
    ####
    
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.agent.parent = None 
    HP.agent.ob_shape = (1, 178, 152)
    HP.agent.sequence_length = 10
    HP.agent.action_plan_length = 10 
    HP.agent.encoder = dict(source='18d_world_model_08:217', is_trainable=False)
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    
    # Video params
    HP.video.capture_policy = 'every(500000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = None
    HP.video.capture_env_ram_patches = None
    HP.video.break_on_level_passed = False
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = generation_steps_count # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = None
    HP.ppo.rollout_env_ram_patches = [
        ['last_life', 'full_igloo', 'bailey_right_at_the_igloo_door', 'temperature_10'],
        ['last_life', 'full_igloo', 'bailey_very_near_igloo_door', 'temperature_10'],  
        ['last_life', 'full_igloo', 'bailey_near_center', 'temperature_10'],
        ['last_life', 'one_remaining_igloo', 'bailey_near_center', 'temperature_10'],
        ['last_life', 'three_remaining_igloo', 'bailey_near_center', 'temperature_20'],
        ['last_life', 'half_igloo', 'bailey_near_center'],
        ['last_life', 'half_igloo'],
        ['last_life'],
    ]
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 1024 
    learn_rate_change_speed = (learn_rate_range[1] - learn_rate_range[0]) / generations_count
    learn_rate_a = learn_rate_range[0] + learn_rate_change_speed * generation_ind
    learn_rate_b = learn_rate_a + learn_rate_change_speed
    HP.ppo.learn_rate = f'linear({learn_rate_a}, {learn_rate_b})'
    # HP.ppo.learn_rate = 'linear(0.00025, 0.00015)'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = optuna_trial.suggest_float('vf_coef', 0.05, 0.5)
    ent_coef_change_speed = (ent_coef_range[1] - ent_coef_range[0]) / generations_count
    ent_coef_a = ent_coef_range[0] + ent_coef_change_speed * generation_ind
    ent_coef_b = ent_coef_a + ent_coef_change_speed
    HP.ppo.ent_coef = f'linear({ent_coef_a}, {ent_coef_b})' # coefficient of the entropy member within loss function
    # HP.ppo.ent_coef = 'linear(0.05, 0.03)' # coefficient of the entropy member within loss function
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# `vf_coef` влияет на градиенты - см. `total_by_value_loss`, где верхняя линия `vf_coef=0.36`, нижняя `vf_coef=0.05`. Ну это и логично, `value_loss` имеет гораздо больший мастаб, чем другие потери (легко может 20 и 30 иметь). Поэтому его надо балансировать через понижающий коэффициент, иначе система будет задавлена градиентами от `value_loss`. Кажеся, что `vf_coef=0.2` или `vf_coef=0.1` выглядит достаточно сбалансированным.
#
# В остальном без изменений. 30 запусков подарили одного агента, который прошёл два первых уровня, но это оказалось нестабильной историей.
#
# Кажется, что дело в замороженном энкодере, который не позволяет адаптировать политику.
#
# <img src="./img/levels_passed.png">
# <img src="./img/reward.png">
# <img src="./img/episode_r.png">
# <img src="./img/value_mean.png">
# <img src="./img/value_loss.png">
# <img src="./img/total_by_value_loss.png">
#
# **Выводы**
# 1) `vf_coef` можно ставить поменьше: 0.2 - 0.1
# 2) попробовать с размороженным энкодером

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_04.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_04',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_15.1/18n_study_15.1.ipynb',
#  'optuna_study_name': '18n_study_15.1',
#  'optuna_study_serial': '15.1',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_15.1/18n_study_15.1.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-15 21:48:33,736] A new study created in Journal with name: 18n_study_15.1
# 2026.09.15-21:48:33.950137     0.191 >> Model instance registered, version=63
# 2026.09.15-21:48:33.959350     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch63.ipynb"
# 2026.09.15-21:48:33.959607     0.004 >> 8.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:63"; running launches=1
# 2026.09.15-21:49:05.434124     0.198 >> Model instance registered, version=64
# 2026.09.15-21:49:05.442815     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch64.ipynb"
# 2026.09.15-21:49:05.443184     0.004 >> 7.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:64"; running launches=2
# 2026.09.15-21:49:36.376572     0.213 >> Model instance registered, version=65
# 2026.09.15-21:49:36.389764     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch65.ipynb"
# 2026.09.15-21:49:36.390601     0.006 >> 6.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:65"; running launches=3
# 2026.09.15-21:50:07.349687     0.260 >> Model instance registered, version=66
# 2026.09.15-21:50:07.362410     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch66.ipynb"
# 2026.09.15-21:50:07.362636     0.005 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:66"; running launches=4
# 2026.09.15-21:50:38.278314     0.183 >> Model instance registered, version=67
# 2026.09.15-21:50:38.288822     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch67.ipynb"
# 2026.09.15-21:50:38.289292     0.004 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:67"; running launches=5
# 2026.09.15-21:51:09.306920     0.256 >> Model instance registered, version=68
# 2026.09.15-21:51:09.321588     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch68.ipynb"
# 2026.09.15-21:51:09.321917     0.006 >> 3.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:68"; running launches=6
# 2026.09.15-21:51:40.197662     0.187 >> Model instance registered, version=69
# 2026.09.15-21:51:40.210697     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch69.ipynb"
# 2026.09.15-21:51:40.211236     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:69"; running launches=7
# 2026.09.15-22:46:09.873503     4.038 >> Trial 0 (18n_ppo_tr_frostbite_04:63) finished with value: 860.0 and parameters: {'vf_coef': 0.3600030335074391}. Best is trial 0 with value: 860.0
# 2026.09.15-22:46:10.955314     0.002 >> Launch "18n_ppo_tr_frostbite_04:63" completed
# 2026.09.15-22:46:10.956568     0.001 >> 1 (+1) launches completed; running launches=6
# 2026.09.15-22:46:24.841106     3.654 >> Trial 1 (18n_ppo_tr_frostbite_04:64) finished with value: 559.2307692307693 and parameters: {'vf_coef': 0.12394478003632545}. Best is trial 0 with value: 860.0
# 2026.09.15-22:46:26.305638     0.001 >> Launch "18n_ppo_tr_frostbite_04:64" completed
# 2026.09.15-22:46:26.307239     0.002 >> 2 (+1) launches completed; running launches=5
# 2026.09.15-22:46:31.640486     0.225 >> Model instance registered, version=70
# 2026.09.15-22:46:31.653637     0.004 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:70"; running launches=6
# 2026.09.15-22:46:31.653765     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch70.ipynb"
# 2026.09.15-22:46:43.038737     1.015 >> Trial 3 (18n_ppo_tr_frostbite_04:66) finished with value: 1091.5384615384614 and parameters: {'vf_coef': 0.3658522089719245}. Best is trial 3 with value: 1091.5384615384614
# 2026.09.15-22:46:47.143295     0.002 >> Launch "18n_ppo_tr_frostbite_04:66" completed
# 2026.09.15-22:46:47.144486     0.001 >> 3 (+1) launches completed; running launches=5
# 2026.09.15-22:47:02.675553     0.189 >> Model instance registered, version=71
# 2026.09.15-22:47:02.683361     0.003 >> 2.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:71"; running launches=6
# 2026.09.15-22:47:02.683472     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch71.ipynb"
# 2026.09.15-22:47:07.175693     4.492 >> Trial 2 (18n_ppo_tr_frostbite_04:65) finished with value: 716.1538461538462 and parameters: {'vf_coef': 0.42601527631658226}. Best is trial 3 with value: 1091.5384615384614
# 2026.09.15-22:47:07.797587     0.001 >> Launch "18n_ppo_tr_frostbite_04:65" completed
# 2026.09.15-22:47:07.798465     0.001 >> 4 (+1) launches completed; running launches=5
# 2026.09.15-22:47:33.783141     0.215 >> Model instance registered, version=72
# 2026.09.15-22:47:33.794633     0.003 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:72"; running launches=6
# 2026.09.15-22:47:33.794727     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch72.ipynb"
# 2026.09.15-22:47:38.923891     0.017 >> Trial 4 (18n_ppo_tr_frostbite_04:67) finished with value: 1163.8461538461538 and parameters: {'vf_coef': 0.09142192511005623}. Best is trial 4 with value: 1163.8461538461538
# 2026.09.15-22:47:38.925084     0.001 >> Launch "18n_ppo_tr_frostbite_04:67" completed
# 2026.09.15-22:47:38.925607     0.001 >> 5 (+1) launches completed; running launches=5
# 2026.09.15-22:47:47.431922     2.979 >> Trial 5 (18n_ppo_tr_frostbite_04:68) finished with value: 1022.3076923076923 and parameters: {'vf_coef': 0.2886669229082137}. Best is trial 4 with value: 1163.8461538461538
# 2026.09.15-22:47:49.576339     0.002 >> Launch "18n_ppo_tr_frostbite_04:68" completed
# 2026.09.15-22:47:49.577292     0.001 >> 6 (+1) launches completed; running launches=4
# 2026.09.15-22:48:05.130987     0.203 >> Model instance registered, version=73
# 2026.09.15-22:48:05.145190     0.006 >> 2.8 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:73"; running launches=5
# 2026.09.15-22:48:05.145451     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch73.ipynb"
# 2026.09.15-22:48:29.743793     4.151 >> Trial 6 (18n_ppo_tr_frostbite_04:69) finished with value: 413.0769230769231 and parameters: {'vf_coef': 0.38961284105171884}. Best is trial 4 with value: 1163.8461538461538
# 2026.09.15-22:48:31.003226     0.003 >> Launch "18n_ppo_tr_frostbite_04:69" completed
# 2026.09.15-22:48:31.004219     0.001 >> 7 (+1) launches completed; running launches=4
# 2026.09.15-22:48:36.354112     0.234 >> Model instance registered, version=74
# 2026.09.15-22:48:36.367027     0.005 >> 2.7 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:74"; running launches=5
# 2026.09.15-22:48:36.367194     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch74.ipynb"
# 2026.09.15-22:49:07.285829     0.233 >> Model instance registered, version=75
# 2026.09.15-22:49:07.298078     0.004 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:75"; running launches=6
# 2026.09.15-22:49:07.298290     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch75.ipynb"
# 2026.09.15-22:49:38.555007     0.262 >> Model instance registered, version=76
# 2026.09.15-22:49:38.567672     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:76"; running launches=7
# 2026.09.15-22:49:38.567813     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch76.ipynb"
# 2026.09.15-23:20:50.056842     0.201 >> Model instance registered, version=77
# 2026.09.15-23:20:50.070147     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch77.ipynb"
# 2026.09.15-23:20:50.070399     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:77"; running launches=8
# 2026.09.15-23:42:53.839918     3.829 >> Trial 9 (18n_ppo_tr_frostbite_04:72) finished with value: 736.9230769230769 and parameters: {'vf_coef': 0.21715432776232463}. Best is trial 4 with value: 1163.8461538461538
# 2026.09.15-23:42:55.133491     0.002 >> Launch "18n_ppo_tr_frostbite_04:72" completed
# 2026.09.15-23:42:55.135347     0.002 >> 8 (+1) launches completed; running launches=7
# 2026.09.15-23:43:20.949306     0.228 >> Model instance registered, version=78
# 2026.09.15-23:43:20.964275     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:78"; running launches=8
# 2026.09.15-23:43:20.964404     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch78.ipynb"
# 2026.09.15-23:44:01.911679     4.543 >> Trial 10 (18n_ppo_tr_frostbite_04:73) finished with value: 1404.6153846153845 and parameters: {'vf_coef': 0.050840309341729444}. Best is trial 10 with value: 1404.6153846153845
# 2026.09.15-23:44:02.705254     0.001 >> Launch "18n_ppo_tr_frostbite_04:73" completed
# 2026.09.15-23:44:02.705707     0.000 >> 9 (+1) launches completed; running launches=7
# 2026.09.15-23:44:28.577301     0.308 >> Model instance registered, version=79
# 2026.09.15-23:44:28.589334     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:79"; running launches=8
# 2026.09.15-23:44:28.590502     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch79.ipynb"
# 2026.09.15-23:46:59.357088     1.861 >> Trial 11 (18n_ppo_tr_frostbite_04:74) finished with value: 813.8461538461538 and parameters: {'vf_coef': 0.43625995812074575}. Best is trial 10 with value: 1404.6153846153845
# 2026.09.15-23:47:02.612890     0.002 >> Launch "18n_ppo_tr_frostbite_04:74" completed
# 2026.09.15-23:47:02.613780     0.001 >> 10 (+1) launches completed; running launches=7
# 2026.09.15-23:47:14.700986     1.856 >> Trial 13 (18n_ppo_tr_frostbite_04:76) finished with value: 941.5384615384615 and parameters: {'vf_coef': 0.13643379955041873}. Best is trial 10 with value: 1404.6153846153845
# 2026.09.15-23:47:18.201456     0.001 >> Launch "18n_ppo_tr_frostbite_04:76" completed
# 2026.09.15-23:47:18.202062     0.001 >> 11 (+1) launches completed; running launches=6
# 2026.09.15-23:47:23.515225     0.199 >> Model instance registered, version=80
# 2026.09.15-23:47:23.525965     0.004 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:80"; running launches=7
# 2026.09.15-23:47:23.526145     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch80.ipynb"
# 2026.09.15-23:47:34.159606     0.388 >> Trial 7 (18n_ppo_tr_frostbite_04:70) finished with value: 1442.3076923076924 and parameters: {'vf_coef': 0.39125864352303136}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.15-23:47:38.995168     0.003 >> Launch "18n_ppo_tr_frostbite_04:70" completed
# 2026.09.15-23:47:38.996257     0.001 >> 12 (+1) launches completed; running launches=6
# 2026.09.15-23:47:54.911712     0.240 >> Model instance registered, version=81
# 2026.09.15-23:47:54.926443     0.005 >> 2.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:81"; running launches=7
# 2026.09.15-23:47:54.926581     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch81.ipynb"
# 2026.09.15-23:48:25.848689     0.229 >> Model instance registered, version=82
# 2026.09.15-23:48:25.859717     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:82"; running launches=8
# 2026.09.15-23:48:25.859847     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch82.ipynb"
# 2026.09.15-23:48:45.054579     3.853 >> Trial 8 (18n_ppo_tr_frostbite_04:71) finished with value: 459.2307692307692 and parameters: {'vf_coef': 0.09890415686330764}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.15-23:48:46.320272     0.002 >> Launch "18n_ppo_tr_frostbite_04:71" completed
# 2026.09.15-23:48:46.321411     0.001 >> 13 (+1) launches completed; running launches=7
# 2026.09.15-23:49:12.822295     0.244 >> Model instance registered, version=83
# 2026.09.15-23:49:12.838563     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:83"; running launches=8
# 2026.09.15-23:49:12.838727     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch83.ipynb"
# 2026.09.15-23:51:30.283644     2.207 >> Trial 12 (18n_ppo_tr_frostbite_04:75) finished with value: 1106.1538461538462 and parameters: {'vf_coef': 0.40687275571039255}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.15-23:51:33.194879     0.002 >> Launch "18n_ppo_tr_frostbite_04:75" completed
# 2026.09.15-23:51:33.195922     0.001 >> 14 (+1) launches completed; running launches=7
# 2026.09.15-23:51:59.092518     0.202 >> Model instance registered, version=84
# 2026.09.15-23:51:59.104520     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:84"; running launches=8
# 2026.09.15-23:51:59.104647     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch84.ipynb"
# 2026.09.16-00:17:33.432284     3.302 >> Trial 14 (18n_ppo_tr_frostbite_04:77) finished with value: 1100.7692307692307 and parameters: {'vf_coef': 0.17326548997606395}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.16-00:17:35.246910     0.001 >> Launch "18n_ppo_tr_frostbite_04:77" completed
# 2026.09.16-00:17:35.247766     0.001 >> 15 (+1) launches completed; running launches=7
# 2026.09.16-00:18:01.016099     0.187 >> Model instance registered, version=85
# 2026.09.16-00:18:01.030189     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:85"; running launches=8
# 2026.09.16-00:18:01.030426     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch85.ipynb"
# 2026.09.16-00:40:56.078282     3.208 >> Trial 15 (18n_ppo_tr_frostbite_04:78) finished with value: 569.2307692307693 and parameters: {'vf_coef': 0.08085936871302744}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.16-00:40:57.990369     0.004 >> Launch "18n_ppo_tr_frostbite_04:78" completed
# 2026.09.16-00:40:57.991190     0.001 >> 16 (+1) launches completed; running launches=7
# 2026.09.16-00:41:24.022583     0.222 >> Model instance registered, version=86
# 2026.09.16-00:41:24.037746     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:86"; running launches=8
# 2026.09.16-00:41:24.037927     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch86.ipynb"
# 2026.09.16-00:41:39.616319     0.072 >> Trial 16 (18n_ppo_tr_frostbite_04:79) finished with value: 1052.3076923076924 and parameters: {'vf_coef': 0.10800851995547187}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.16-00:41:39.617096     0.001 >> Launch "18n_ppo_tr_frostbite_04:79" completed
# 2026.09.16-00:41:39.617724     0.001 >> 17 (+1) launches completed; running launches=7
# 2026.09.16-00:41:55.268584     0.190 >> Model instance registered, version=87
# 2026.09.16-00:41:55.280536     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:87"; running launches=8
# 2026.09.16-00:41:55.280715     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch87.ipynb"
# 2026.09.16-00:44:48.197228     1.836 >> Trial 18 (18n_ppo_tr_frostbite_04:81) finished with value: 766.1538461538462 and parameters: {'vf_coef': 0.4980753439958214}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.16-00:44:51.479618     0.001 >> Launch "18n_ppo_tr_frostbite_04:81" completed
# 2026.09.16-00:44:51.480416     0.001 >> 18 (+1) launches completed; running launches=7
# 2026.09.16-00:45:17.376431     0.184 >> Model instance registered, version=88
# 2026.09.16-00:45:17.386049     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:88"; running launches=8
# 2026.09.16-00:45:17.386681     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch88.ipynb"
# 2026.09.16-00:45:44.490129     1.435 >> Trial 17 (18n_ppo_tr_frostbite_04:80) finished with value: 230.76923076923077 and parameters: {'vf_coef': 0.06115379541922447}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.16-00:45:48.170429     0.001 >> Launch "18n_ppo_tr_frostbite_04:80" completed
# 2026.09.16-00:45:48.171552     0.001 >> 19 (+1) launches completed; running launches=7
# 2026.09.16-00:46:06.355973     2.526 >> Trial 20 (18n_ppo_tr_frostbite_04:83) finished with value: 1249.2307692307693 and parameters: {'vf_coef': 0.49912080733244757}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.16-00:46:09.129735     0.185 >> Model instance registered, version=89
# 2026.09.16-00:46:09.138640     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:89"; running launches=8
# 2026.09.16-00:46:09.138757     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch89.ipynb"
# 2026.09.16-00:46:09.139231     0.001 >> Launch "18n_ppo_tr_frostbite_04:83" completed
# 2026.09.16-00:46:09.140136     0.001 >> 20 (+1) launches completed; running launches=7
# 2026.09.16-00:46:41.234548     0.183 >> Model instance registered, version=90
# 2026.09.16-00:46:41.242798     0.003 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:90"; running launches=8
# 2026.09.16-00:46:41.242983     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch90.ipynb"
# 2026.09.16-00:47:41.401783     3.694 >> Trial 21 (18n_ppo_tr_frostbite_04:84) finished with value: 1211.5384615384614 and parameters: {'vf_coef': 0.4867791495255801}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.16-00:47:42.820655     0.001 >> Launch "18n_ppo_tr_frostbite_04:84" completed
# 2026.09.16-00:47:42.821413     0.001 >> 21 (+1) launches completed; running launches=7
# 2026.09.16-00:48:08.319343     5.039 >> Trial 19 (18n_ppo_tr_frostbite_04:82) finished with value: 606.1538461538462 and parameters: {'vf_coef': 0.4884257677578049}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.16-00:48:08.575716     0.178 >> Model instance registered, version=91
# 2026.09.16-00:48:08.585683     0.003 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:91"; running launches=8
# 2026.09.16-00:48:08.585794     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch91.ipynb"
# 2026.09.16-00:48:08.586493     0.001 >> Launch "18n_ppo_tr_frostbite_04:82" completed
# 2026.09.16-00:48:08.587452     0.001 >> 22 (+1) launches completed; running launches=7
# 2026.09.16-00:48:39.462289     0.192 >> Model instance registered, version=92
# 2026.09.16-00:48:39.475616     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_04:92"; running launches=8
# 2026.09.16-00:48:39.475839     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_04-launch92.ipynb"
# 2026.09.16-01:15:39.065727     0.233 >> Trial 22 (18n_ppo_tr_frostbite_04:85) finished with value: 1076.923076923077 and parameters: {'vf_coef': 0.48958304285398413}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.16-01:15:43.950745     0.001 >> Launch "18n_ppo_tr_frostbite_04:85" completed
# 2026.09.16-01:15:43.951741     0.001 >> 23 (+1) launches completed; running launches=7
# 2026.09.16-01:39:14.832502     0.319 >> Trial 23 (18n_ppo_tr_frostbite_04:86) finished with value: 815.3846153846154 and parameters: {'vf_coef': 0.4943900585458719}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.16-01:39:19.635046     0.002 >> Launch "18n_ppo_tr_frostbite_04:86" completed
# 2026.09.16-01:39:19.635972     0.001 >> 24 (+1) launches completed; running launches=6
# 2026.09.16-01:42:06.216505     4.913 >> Trial 24 (18n_ppo_tr_frostbite_04:87) finished with value: 220.0 and parameters: {'vf_coef': 0.29463557476681523}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.16-01:42:06.420769     0.002 >> Launch "18n_ppo_tr_frostbite_04:87" completed
# 2026.09.16-01:42:06.421747     0.001 >> 25 (+1) launches completed; running launches=5
# 2026.09.16-01:43:50.698898     1.474 >> Trial 25 (18n_ppo_tr_frostbite_04:88) finished with value: 240.0 and parameters: {'vf_coef': 0.29426737486487803}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.16-01:43:54.462179     0.003 >> Launch "18n_ppo_tr_frostbite_04:88" completed
# 2026.09.16-01:43:54.463185     0.001 >> 26 (+1) launches completed; running launches=4
# 2026.09.16-01:45:25.347409     2.660 >> Trial 26 (18n_ppo_tr_frostbite_04:89) finished with value: 1394.6153846153845 and parameters: {'vf_coef': 0.2979221411823195}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.16-01:45:27.809164     0.001 >> Launch "18n_ppo_tr_frostbite_04:89" completed
# 2026.09.16-01:45:27.810009     0.001 >> 27 (+1) launches completed; running launches=3
# 2026.09.16-01:45:30.951516     3.142 >> Trial 29 (18n_ppo_tr_frostbite_04:92) finished with value: 1100.0 and parameters: {'vf_coef': 0.3094891778371577}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.16-01:45:33.071554     0.002 >> Launch "18n_ppo_tr_frostbite_04:92" completed
# 2026.09.16-01:45:33.072513     0.001 >> 28 (+1) launches completed; running launches=2
# 2026.09.16-01:48:09.460834     1.053 >> Trial 27 (18n_ppo_tr_frostbite_04:90) finished with value: 815.3846153846154 and parameters: {'vf_coef': 0.30722839001552305}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.16-01:48:13.527565     0.002 >> Launch "18n_ppo_tr_frostbite_04:90" completed
# 2026.09.16-01:48:13.528511     0.001 >> 29 (+1) launches completed; running launches=1
# 2026.09.16-01:51:21.968260     2.140 >> Trial 28 (18n_ppo_tr_frostbite_04:91) finished with value: 222.30769230769232 and parameters: {'vf_coef': 0.27612268401541834}. Best is trial 7 with value: 1442.3076923076924
# 2026.09.16-01:51:24.944946     0.002 >> Launch "18n_ppo_tr_frostbite_04:91" completed
# 2026.09.16-01:51:24.945900     0.001 >> 30 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-16 01:51:29,974] Using an existing study with name '18n_study_15.1' instead of creating a new one.
# 2026.09.16-01:51:29.977725     5.032 >> Study statistics:
# 2026.09.16-01:51:29.980825     0.003 >> 	Number of finished trials: 30
# 2026.09.16-01:51:29.982018     0.001 >> 	Number of pruned trials: 0
# 2026.09.16-01:51:29.982943     0.001 >> 	Number of complete trials: 30
# 2026.09.16-01:51:29.984245     0.001 >> Best trial:
# 2026.09.16-01:51:29.985303     0.001 >> 	Value: 1442.3076923076924
# 2026.09.16-01:51:29.986095     0.001 >> 	Model version: 70
# 2026.09.16-01:51:29.986676     0.001 >> 	Params:
# 2026.09.16-01:51:29.987386     0.001 >> 		vf_coef: 0.39125864352303136
