# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 5 поколений по 6 млн шагов с последующим отбором чемпионов. Наследники этих чемпионов будут использоваться на следующем шаге.
#
# Данный эксперимент - это второй шаг. Здесь отпускаем агента в свободное плавание.
#
# Особенности:
# - `vision_head` из `18d_world_model_09`
# - **`vision_head.is_trainable=False`**
# - энкодер из чемпионов `18n_study_18.2`
# - **`encoder.is_trainable=True`**
# - механика повторяет 17-ых агентов
# - `prediction_coef=0.1`
# - `sequence_length=10`
# - `batch_size=128`
# - `vf_coef=0.2`

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    generations_count = 5
    generation_ind = 2
    generation_steps_count = 6_000_000
    all_generations_steps_count = generation_steps_count * generations_count
    learn_rate_range = (0.00025, 0.00025 * 0.1)
    ent_coef_range = (0.05, 0.05 * 0.1)
    ####
    
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False

    parent = optuna_trial.suggest_categorical('parent', [
        '18n_ppo_tr_frostbite_06:45',
        '18n_ppo_tr_frostbite_06:40',
        '18n_ppo_tr_frostbite_06:53',
    ])
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights=parent)
    HP.encoder.is_trainable = True

    HP.agent.parent = parent 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(500000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = None
    HP.video.capture_env_ram_patches = None
    HP.video.break_on_level_passed = False
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = generation_steps_count # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = None
    HP.ppo.rollout_env_ram_patches = [
        ['nine_lives'],
    ]
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    learn_rate_change_speed = (learn_rate_range[1] - learn_rate_range[0]) / generations_count
    learn_rate_a = learn_rate_range[0] + learn_rate_change_speed * generation_ind
    learn_rate_b = learn_rate_a + learn_rate_change_speed
    HP.ppo.learn_rate = f'linear({learn_rate_a}, {learn_rate_b})'
    # HP.ppo.learn_rate = 'linear(0.00025, 0.00015)'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    ent_coef_change_speed = (ent_coef_range[1] - ent_coef_range[0]) / generations_count
    ent_coef_a = ent_coef_range[0] + ent_coef_change_speed * generation_ind
    ent_coef_b = ent_coef_a + ent_coef_change_speed
    HP.ppo.ent_coef = f'linear({ent_coef_a}, {ent_coef_b})' # coefficient of the entropy member within loss function
    # HP.ppo.ent_coef = 'linear(0.05, 0.03)' # coefficient of the entropy member within loss function
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Умеренный успех, не сказать, что вау. Агенты, которые дошли до 5-го уровня:
# - `18n_ppo_tr_frostbite_06/opt_18.3a/63`
# - `18n_ppo_tr_frostbite_06/opt_18.3a/82`
#
# Есть ещё агенты, которые тоже доходили до 5-го уровня, но потом слились:
# - `18n_ppo_tr_frostbite_06/opt_18.3a/60`
# - `18n_ppo_tr_frostbite_06/opt_18.3a/72`
# - `18n_ppo_tr_frostbite_06/opt_18.3a/74`
# - `18n_ppo_tr_frostbite_06/opt_18.3a/75`
#
# Интересн агент `18n_ppo_tr_frostbite_06/opt_18.3a/62`. По графику `episode_r` видно, что он наколотил 15000 очков. Видимо он преуспел на 5-ом уровне, м.б. даже дошёл до 6-го. Больше таких экземпляров не было.
#
# Стало понятно, что просто на `reward.mean()` в оптуне смотреть менее ценно, чем на количество пройденных уровней. Подумать, как переключиться на кол-во пройденных уровней.
#
# <img src="./img/levels_passed.png">
# <img src="./img/reward.png">
# <img src="./img/episode_r.png">
#
# **Выводы**
# 1) можно сделать ещё шаг вперёд
# 2) можно вернуться на шаг назад и повторить путь 17-ых агентов

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_18.3a/18n_study_18.3a.ipynb',
#  'optuna_study_name': '18n_study_18.3a',
#  'optuna_study_serial': '18.3a',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_18.3a/18n_study_18.3a.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-19 09:52:11,854] A new study created in Journal with name: 18n_study_18.3a
# 2026.09.19-09:52:12.131343     0.253 >> Model instance registered, version=55
# 2026.09.19-09:52:12.148670     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch55.ipynb"
# 2026.09.19-09:52:12.148986     0.006 >> 4.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:55"; running launches=1
# 2026.09.19-09:52:43.582643     0.202 >> Model instance registered, version=56
# 2026.09.19-09:52:43.593242     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch56.ipynb"
# 2026.09.19-09:52:43.593885     0.004 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:56"; running launches=2
# 2026.09.19-09:53:15.028766     0.198 >> Model instance registered, version=57
# 2026.09.19-09:53:15.043864     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch57.ipynb"
# 2026.09.19-09:53:15.044249     0.007 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:57"; running launches=3
# 2026.09.19-09:53:46.752626     0.269 >> Model instance registered, version=58
# 2026.09.19-09:53:46.767364     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch58.ipynb"
# 2026.09.19-09:53:46.767619     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:58"; running launches=4
# 2026.09.19-10:07:13.418204     0.233 >> Model instance registered, version=59
# 2026.09.19-10:07:13.427727     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch59.ipynb"
# 2026.09.19-10:07:13.428106     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:59"; running launches=5
# 2026.09.19-10:07:44.675649     0.247 >> Model instance registered, version=60
# 2026.09.19-10:07:44.686101     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch60.ipynb"
# 2026.09.19-10:07:44.686858     0.007 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:60"; running launches=6
# 2026.09.19-10:08:15.814262     0.184 >> Model instance registered, version=61
# 2026.09.19-10:08:15.826580     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch61.ipynb"
# 2026.09.19-10:08:15.827004     0.005 >> 5.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:61"; running launches=7
# 2026.09.19-10:08:46.716928     0.190 >> Model instance registered, version=62
# 2026.09.19-10:08:46.728095     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch62.ipynb"
# 2026.09.19-10:08:46.728296     0.004 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:62"; running launches=8
# 2026.09.19-10:09:17.659602     0.220 >> Model instance registered, version=63
# 2026.09.19-10:09:17.673942     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch63.ipynb"
# 2026.09.19-10:09:17.674283     0.006 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:63"; running launches=9
# 2026.09.19-10:09:48.551995     0.193 >> Model instance registered, version=64
# 2026.09.19-10:09:48.563990     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch64.ipynb"
# 2026.09.19-10:09:48.564184     0.004 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:64"; running launches=10
# 2026.09.19-10:10:19.515448     0.210 >> Model instance registered, version=65
# 2026.09.19-10:10:19.529311     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch65.ipynb"
# 2026.09.19-10:10:19.529544     0.006 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:65"; running launches=11
# 2026.09.19-10:10:51.072191     0.191 >> Model instance registered, version=66
# 2026.09.19-10:10:51.086016     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch66.ipynb"
# 2026.09.19-10:10:51.086296     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:66"; running launches=12
# 2026.09.19-11:06:58.715676     1.596 >> Trial 0 (18n_ppo_tr_frostbite_06:55) finished with value: 4040.0 and parameters: {'parent': '18n_ppo_tr_frostbite_06:53'}. Best is trial 0 with value: 4040.0
# 2026.09.19-11:07:02.238203     0.002 >> Launch "18n_ppo_tr_frostbite_06:55" completed
# 2026.09.19-11:07:02.239324     0.001 >> 1 (+1) launches completed; running launches=11
# 2026.09.19-11:07:28.006826     0.186 >> Model instance registered, version=67
# 2026.09.19-11:07:28.018246     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:67"; running launches=12
# 2026.09.19-11:07:28.018394     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch67.ipynb"
# 2026.09.19-11:09:30.460066     4.419 >> Trial 3 (18n_ppo_tr_frostbite_06:58) finished with value: 4260.7692307692305 and parameters: {'parent': '18n_ppo_tr_frostbite_06:40'}. Best is trial 3 with value: 4260.7692307692305
# 2026.09.19-11:09:32.534188     0.003 >> Launch "18n_ppo_tr_frostbite_06:58" completed
# 2026.09.19-11:09:32.535235     0.001 >> 2 (+1) launches completed; running launches=11
# 2026.09.19-11:09:58.304601     0.193 >> Model instance registered, version=68
# 2026.09.19-11:09:58.313868     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:68"; running launches=12
# 2026.09.19-11:09:58.313999     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch68.ipynb"
# 2026.09.19-11:10:13.670908     0.002 >> Launch "18n_ppo_tr_frostbite_06:68" failed: Command '['papermill', '/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch68.ipynb', '/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch68.ipynb', '--no-progress-bar']' returned non-zero exit status 1.
# 2026.09.19-11:10:13.672186     0.001 >> 3 (+1) launches completed; running launches=11
# 2026.09.19-11:10:29.610770     0.188 >> Model instance registered, version=69
# 2026.09.19-11:10:29.619352     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:69"; running launches=12
# 2026.09.19-11:10:29.619504     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch69.ipynb"
# 2026.09.19-11:13:35.301718     3.810 >> Trial 2 (18n_ppo_tr_frostbite_06:57) finished with value: 5085.384615384615 and parameters: {'parent': '18n_ppo_tr_frostbite_06:53'}. Best is trial 2 with value: 5085.384615384615
# 2026.09.19-11:13:36.609557     0.002 >> Launch "18n_ppo_tr_frostbite_06:57" completed
# 2026.09.19-11:13:36.610408     0.001 >> 4 (+1) launches completed; running launches=11
# 2026.09.19-11:14:03.633479     0.189 >> Model instance registered, version=70
# 2026.09.19-11:14:03.645286     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:70"; running launches=12
# 2026.09.19-11:14:03.645407     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch70.ipynb"
# 2026.09.19-11:14:06.769046     3.124 >> Trial 1 (18n_ppo_tr_frostbite_06:56) finished with value: 5575.384615384615 and parameters: {'parent': '18n_ppo_tr_frostbite_06:45'}. Best is trial 1 with value: 5575.384615384615
# 2026.09.19-11:14:08.755488     0.001 >> Launch "18n_ppo_tr_frostbite_06:56" completed
# 2026.09.19-11:14:08.755915     0.000 >> 5 (+1) launches completed; running launches=11
# 2026.09.19-11:14:34.552429     0.213 >> Model instance registered, version=71
# 2026.09.19-11:14:34.561439     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:71"; running launches=12
# 2026.09.19-11:14:34.561570     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch71.ipynb"
# 2026.09.19-11:17:04.619269     3.634 >> Trial 5 (18n_ppo_tr_frostbite_06:60) finished with value: 4250.0 and parameters: {'parent': '18n_ppo_tr_frostbite_06:53'}. Best is trial 1 with value: 5575.384615384615
# 2026.09.19-11:17:06.105462     0.002 >> Launch "18n_ppo_tr_frostbite_06:60" completed
# 2026.09.19-11:17:06.106401     0.001 >> 6 (+1) launches completed; running launches=11
# 2026.09.19-11:17:31.868244     0.184 >> Model instance registered, version=72
# 2026.09.19-11:17:31.880069     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:72"; running launches=12
# 2026.09.19-11:17:31.880203     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch72.ipynb"
# 2026.09.19-11:17:52.117188     4.896 >> Trial 6 (18n_ppo_tr_frostbite_06:61) finished with value: 4161.538461538462 and parameters: {'parent': '18n_ppo_tr_frostbite_06:53'}. Best is trial 1 with value: 5575.384615384615
# 2026.09.19-11:17:52.337738     0.002 >> Launch "18n_ppo_tr_frostbite_06:61" completed
# 2026.09.19-11:17:52.338764     0.001 >> 7 (+1) launches completed; running launches=11
# 2026.09.19-11:18:18.175824     0.182 >> Model instance registered, version=73
# 2026.09.19-11:18:18.188670     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:73"; running launches=12
# 2026.09.19-11:18:18.188824     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch73.ipynb"
# 2026.09.19-11:20:23.784362     1.973 >> Trial 8 (18n_ppo_tr_frostbite_06:63) finished with value: 5655.384615384615 and parameters: {'parent': '18n_ppo_tr_frostbite_06:40'}. Best is trial 8 with value: 5655.384615384615
# 2026.09.19-11:20:26.930589     0.002 >> Launch "18n_ppo_tr_frostbite_06:63" completed
# 2026.09.19-11:20:26.931396     0.001 >> 8 (+1) launches completed; running launches=11
# 2026.09.19-11:20:52.786971     0.275 >> Model instance registered, version=74
# 2026.09.19-11:20:52.799686     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:74"; running launches=12
# 2026.09.19-11:20:52.799796     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch74.ipynb"
# 2026.09.19-11:20:55.166671     2.367 >> Trial 4 (18n_ppo_tr_frostbite_06:59) finished with value: 3917.6923076923076 and parameters: {'parent': '18n_ppo_tr_frostbite_06:53'}. Best is trial 8 with value: 5655.384615384615
# 2026.09.19-11:20:55.341069     0.174 >> Trial 9 (18n_ppo_tr_frostbite_06:64) finished with value: 5479.2307692307695 and parameters: {'parent': '18n_ppo_tr_frostbite_06:45'}. Best is trial 8 with value: 5655.384615384615
# 2026.09.19-11:20:57.927735     0.004 >> Launch "18n_ppo_tr_frostbite_06:64" completed
# 2026.09.19-11:20:57.928385     0.001 >> Launch "18n_ppo_tr_frostbite_06:59" completed
# 2026.09.19-11:20:57.928848     0.000 >> 10 (+2) launches completed; running launches=10
# 2026.09.19-11:21:23.690429     0.187 >> Model instance registered, version=75
# 2026.09.19-11:21:23.699940     0.003 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:75"; running launches=11
# 2026.09.19-11:21:23.700024     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch75.ipynb"
# 2026.09.19-11:21:54.891886     0.201 >> Model instance registered, version=76
# 2026.09.19-11:21:54.903932     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:76"; running launches=12
# 2026.09.19-11:21:54.904044     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch76.ipynb"
# 2026.09.19-11:23:16.127557     2.510 >> Trial 7 (18n_ppo_tr_frostbite_06:62) finished with value: 3966.153846153846 and parameters: {'parent': '18n_ppo_tr_frostbite_06:53'}. Best is trial 8 with value: 5655.384615384615
# 2026.09.19-11:23:18.736494     0.002 >> Launch "18n_ppo_tr_frostbite_06:62" completed
# 2026.09.19-11:23:18.737512     0.001 >> 11 (+1) launches completed; running launches=11
# 2026.09.19-11:23:44.547439     0.203 >> Model instance registered, version=77
# 2026.09.19-11:23:44.559593     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:77"; running launches=12
# 2026.09.19-11:23:44.559713     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch77.ipynb"
# 2026.09.19-11:24:57.594013     0.543 >> Trial 10 (18n_ppo_tr_frostbite_06:65) finished with value: 4683.846153846154 and parameters: {'parent': '18n_ppo_tr_frostbite_06:40'}. Best is trial 8 with value: 5655.384615384615
# 2026.09.19-11:25:02.168801     0.002 >> Launch "18n_ppo_tr_frostbite_06:65" completed
# 2026.09.19-11:25:02.169608     0.001 >> 12 (+1) launches completed; running launches=11
# 2026.09.19-11:25:23.662287     0.183 >> Model instance registered, version=78
# 2026.09.19-11:25:23.673378     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:78"; running launches=12
# 2026.09.19-11:25:23.673513     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch78.ipynb"
# 2026.09.19-11:26:48.929006     3.089 >> Trial 11 (18n_ppo_tr_frostbite_06:66) finished with value: 5794.615384615385 and parameters: {'parent': '18n_ppo_tr_frostbite_06:45'}. Best is trial 11 with value: 5794.615384615385
# 2026.09.19-11:26:50.958953     0.002 >> Launch "18n_ppo_tr_frostbite_06:66" completed
# 2026.09.19-11:26:50.959836     0.001 >> 13 (+1) launches completed; running launches=11
# 2026.09.19-11:27:16.913032     0.185 >> Model instance registered, version=79
# 2026.09.19-11:27:16.925794     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:79"; running launches=12
# 2026.09.19-11:27:16.926570     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch79.ipynb"
# 2026.09.19-12:21:26.502707     3.298 >> Trial 12 (18n_ppo_tr_frostbite_06:67) finished with value: 3905.3846153846152 and parameters: {'parent': '18n_ppo_tr_frostbite_06:53'}. Best is trial 11 with value: 5794.615384615385
# 2026.09.19-12:21:28.324311     0.002 >> Launch "18n_ppo_tr_frostbite_06:67" completed
# 2026.09.19-12:21:28.325094     0.001 >> 14 (+1) launches completed; running launches=11
# 2026.09.19-12:21:54.117040     0.213 >> Model instance registered, version=80
# 2026.09.19-12:21:54.130008     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:80"; running launches=12
# 2026.09.19-12:21:54.130153     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch80.ipynb"
# 2026.09.19-12:24:14.550374     0.340 >> Trial 14 (18n_ppo_tr_frostbite_06:69) finished with value: 4591.538461538462 and parameters: {'parent': '18n_ppo_tr_frostbite_06:53'}. Best is trial 11 with value: 5794.615384615385
# 2026.09.19-12:24:19.536021     0.004 >> Launch "18n_ppo_tr_frostbite_06:69" completed
# 2026.09.19-12:24:19.537117     0.001 >> 15 (+1) launches completed; running launches=11
# 2026.09.19-12:24:40.938753     0.192 >> Model instance registered, version=81
# 2026.09.19-12:24:40.948023     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:81"; running launches=12
# 2026.09.19-12:24:40.948109     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch81.ipynb"
# 2026.09.19-12:26:50.183428     4.832 >> Trial 17 (18n_ppo_tr_frostbite_06:72) finished with value: 5126.923076923077 and parameters: {'parent': '18n_ppo_tr_frostbite_06:53'}. Best is trial 11 with value: 5794.615384615385
# 2026.09.19-12:26:50.465621     0.001 >> Launch "18n_ppo_tr_frostbite_06:72" completed
# 2026.09.19-12:26:50.466531     0.001 >> 16 (+1) launches completed; running launches=11
# 2026.09.19-12:27:16.230820     0.186 >> Model instance registered, version=82
# 2026.09.19-12:27:16.243945     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:82"; running launches=12
# 2026.09.19-12:27:16.244102     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch82.ipynb"
# 2026.09.19-12:30:30.450079     4.876 >> Trial 18 (18n_ppo_tr_frostbite_06:73) finished with value: 5875.384615384615 and parameters: {'parent': '18n_ppo_tr_frostbite_06:45'}. Best is trial 18 with value: 5875.384615384615
# 2026.09.19-12:30:30.691791     0.001 >> Launch "18n_ppo_tr_frostbite_06:73" completed
# 2026.09.19-12:30:30.692809     0.001 >> 17 (+1) launches completed; running launches=11
# 2026.09.19-12:30:50.382955     4.191 >> Trial 19 (18n_ppo_tr_frostbite_06:74) finished with value: 5946.153846153846 and parameters: {'parent': '18n_ppo_tr_frostbite_06:40'}. Best is trial 19 with value: 5946.153846153846
# 2026.09.19-12:30:51.537327     0.231 >> Model instance registered, version=83
# 2026.09.19-12:30:51.551403     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:83"; running launches=12
# 2026.09.19-12:30:51.552452     0.001 >> Launch "18n_ppo_tr_frostbite_06:74" completed
# 2026.09.19-12:30:51.551587     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch83.ipynb"
# 2026.09.19-12:30:51.552868     0.000 >> 18 (+1) launches completed; running launches=11
# 2026.09.19-12:31:22.633723     0.210 >> Model instance registered, version=84
# 2026.09.19-12:31:22.641756     0.003 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:84"; running launches=12
# 2026.09.19-12:31:22.642188     0.000 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch84.ipynb"
# 2026.09.19-12:32:52.743104     2.342 >> Trial 16 (18n_ppo_tr_frostbite_06:71) finished with value: 4319.2307692307695 and parameters: {'parent': '18n_ppo_tr_frostbite_06:53'}. Best is trial 19 with value: 5946.153846153846
# 2026.09.19-12:32:52.915108     0.172 >> Trial 15 (18n_ppo_tr_frostbite_06:70) finished with value: 5752.307692307692 and parameters: {'parent': '18n_ppo_tr_frostbite_06:45'}. Best is trial 19 with value: 5946.153846153846
# 2026.09.19-12:32:55.517502     0.002 >> Launch "18n_ppo_tr_frostbite_06:71" completed
# 2026.09.19-12:32:55.518347     0.001 >> Launch "18n_ppo_tr_frostbite_06:70" completed
# 2026.09.19-12:32:55.519209     0.001 >> 20 (+2) launches completed; running launches=10
# 2026.09.19-12:35:25.415797     4.887 >> Trial 21 (18n_ppo_tr_frostbite_06:76) finished with value: 6207.692307692308 and parameters: {'parent': '18n_ppo_tr_frostbite_06:45'}. Best is trial 21 with value: 6207.692307692308
# 2026.09.19-12:35:25.646470     0.002 >> Launch "18n_ppo_tr_frostbite_06:76" completed
# 2026.09.19-12:35:25.647414     0.001 >> 21 (+1) launches completed; running launches=9
# 2026.09.19-12:36:40.533343     0.268 >> Trial 20 (18n_ppo_tr_frostbite_06:75) finished with value: 4892.307692307692 and parameters: {'parent': '18n_ppo_tr_frostbite_06:40'}. Best is trial 21 with value: 6207.692307692308
# 2026.09.19-12:36:45.523130     0.002 >> Launch "18n_ppo_tr_frostbite_06:75" completed
# 2026.09.19-12:36:45.523606     0.000 >> 22 (+1) launches completed; running launches=8
# 2026.09.19-12:38:56.603025     2.677 >> Trial 22 (18n_ppo_tr_frostbite_06:77) finished with value: 5062.307692307692 and parameters: {'parent': '18n_ppo_tr_frostbite_06:40'}. Best is trial 21 with value: 6207.692307692308
# 2026.09.19-12:38:59.036345     0.001 >> Launch "18n_ppo_tr_frostbite_06:77" completed
# 2026.09.19-12:38:59.036844     0.000 >> 23 (+1) launches completed; running launches=7
# 2026.09.19-12:40:12.604652     1.576 >> Trial 23 (18n_ppo_tr_frostbite_06:78) finished with value: 4267.692307692308 and parameters: {'parent': '18n_ppo_tr_frostbite_06:45'}. Best is trial 21 with value: 6207.692307692308
# 2026.09.19-12:40:16.146297     0.002 >> Launch "18n_ppo_tr_frostbite_06:78" completed
# 2026.09.19-12:40:16.147129     0.001 >> 24 (+1) launches completed; running launches=6
# 2026.09.19-12:42:02.761726     3.614 >> Trial 24 (18n_ppo_tr_frostbite_06:79) finished with value: 5136.923076923077 and parameters: {'parent': '18n_ppo_tr_frostbite_06:40'}. Best is trial 21 with value: 6207.692307692308
# 2026.09.19-12:42:04.266306     0.002 >> Launch "18n_ppo_tr_frostbite_06:79" completed
# 2026.09.19-12:42:04.267104     0.001 >> 25 (+1) launches completed; running launches=5
# 2026.09.19-13:25:45.563730     3.143 >> Trial 27 (18n_ppo_tr_frostbite_06:82) finished with value: 5563.076923076923 and parameters: {'parent': '18n_ppo_tr_frostbite_06:40'}. Best is trial 21 with value: 6207.692307692308
# 2026.09.19-13:25:47.538035     0.001 >> Launch "18n_ppo_tr_frostbite_06:82" completed
# 2026.09.19-13:25:47.539002     0.001 >> 26 (+1) launches completed; running launches=4
# 2026.09.19-13:28:01.926525     4.134 >> Trial 28 (18n_ppo_tr_frostbite_06:83) finished with value: 5311.538461538462 and parameters: {'parent': '18n_ppo_tr_frostbite_06:40'}. Best is trial 21 with value: 6207.692307692308
# 2026.09.19-13:28:03.122134     0.003 >> Launch "18n_ppo_tr_frostbite_06:83" completed
# 2026.09.19-13:28:03.122933     0.001 >> 27 (+1) launches completed; running launches=3
# 2026.09.19-13:28:32.084073     3.181 >> Trial 29 (18n_ppo_tr_frostbite_06:84) finished with value: 5210.7692307692305 and parameters: {'parent': '18n_ppo_tr_frostbite_06:45'}. Best is trial 21 with value: 6207.692307692308
# 2026.09.19-13:28:34.010782     0.000 >> Launch "18n_ppo_tr_frostbite_06:84" completed
# 2026.09.19-13:28:34.011171     0.000 >> 28 (+1) launches completed; running launches=2
# 2026.09.19-13:38:21.979512     4.726 >> Trial 25 (18n_ppo_tr_frostbite_06:80) finished with value: 4302.307692307692 and parameters: {'parent': '18n_ppo_tr_frostbite_06:40'}. Best is trial 21 with value: 6207.692307692308
# 2026.09.19-13:38:22.374334     0.001 >> Launch "18n_ppo_tr_frostbite_06:80" completed
# 2026.09.19-13:38:22.375200     0.001 >> 29 (+1) launches completed; running launches=1
# 2026.09.19-13:41:14.805127     0.430 >> Trial 26 (18n_ppo_tr_frostbite_06:81) finished with value: 5360.0 and parameters: {'parent': '18n_ppo_tr_frostbite_06:45'}. Best is trial 21 with value: 6207.692307692308
# 2026.09.19-13:41:19.490553     0.002 >> Launch "18n_ppo_tr_frostbite_06:81" completed
# 2026.09.19-13:41:19.491528     0.001 >> 30 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-19 13:41:24,527] Using an existing study with name '18n_study_18.3a' instead of creating a new one.
# 2026.09.19-13:41:24.530865     5.039 >> Study statistics:
# 2026.09.19-13:41:24.534151     0.003 >> 	Number of finished trials: 30
# 2026.09.19-13:41:24.535296     0.001 >> 	Number of pruned trials: 0
# 2026.09.19-13:41:24.536263     0.001 >> 	Number of complete trials: 29
# 2026.09.19-13:41:24.537158     0.001 >> Best trial:
# 2026.09.19-13:41:24.537796     0.001 >> 	Value: 6207.692307692308
# 2026.09.19-13:41:24.538245     0.000 >> 	Model version: 76
# 2026.09.19-13:41:24.538565     0.000 >> 	Params:
# 2026.09.19-13:41:24.538945     0.000 >> 		parent: 18n_ppo_tr_frostbite_06:45
