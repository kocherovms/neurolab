# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 6 шагов. На каждом шаге отбираем чемпионов для продолжения след. шага.
#
# Данный эксперимент - это пятый шаг. Здесь агент 85% играет на четвёртом уровне с train RAM-ами, 5% времени играет с первого уровня, 5% со второго, 5% с третьего.

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False

    parent = optuna_trial.suggest_categorical('parent', [
        '18n_ppo_tr_frostbite_06:476',
        '18n_ppo_tr_frostbite_06:471',
        '18n_ppo_tr_frostbite_06:473',
        '18n_ppo_tr_frostbite_06:477',
        '18n_ppo_tr_frostbite_06:478',
        '18n_ppo_tr_frostbite_06:475',
    ])
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights=parent)
    HP.encoder.is_trainable = True

    HP.agent.parent = parent 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(200000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = None
    HP.video.capture_env_ram_patches = None
    HP.video.break_on_level_passed = False
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = 3_000_000 # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = [
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=none', # 0
        'com.develorium.neurolab.frostbite_ram:level2:1:cls=none', # 1
        'com.develorium.neurolab.frostbite_ram:level3:1:cls=none', # 2
        
        'com.develorium.neurolab.frostbite_ram:level4:1:cls=train1', # 3
        'com.develorium.neurolab.frostbite_ram:level4:1:cls=train2', # 4
        'com.develorium.neurolab.frostbite_ram:level4:1:cls=train3', # 5
        'com.develorium.neurolab.frostbite_ram:level4:1:cls=train4', # 6
        'com.develorium.neurolab.frostbite_ram:level4:1:cls=train5', # 7
    ]
    HP.ppo.rollout_env_ram_patches = [
        ['no_score', 'three_lives', 'no_igloo', 'temperature_45', 'bailey_safe_random_spawn'], # 0
        ['no_score', 'last_life', 'no_igloo', 'temperature_45', 'bailey_safe_random_spawn'], # 1
    ]
    HP.ppo.rollout_env_stories = (
        ['0;0'] +      # level 1 - 5% time
        ['1;0'] +      # level 2 - 5% time
        ['2;0'] +      # level 3 - 5% time
        ['3:8;1'] * 15 # level 4 - 85% time !!! <- тут ошибка, надо умножить на 17 !!!
    )
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    HP.ppo.learn_rate = f'const({0.00025 - 0.0002 / 6 * 4})'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    HP.ppo.ent_coef = f'const({0.05 - 0.04 / 6 * 4})'
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Забавно. Видно, что как-то всё 4-ой линии подпирается и подпирается. Это если в сравнивать по скору `18n_study_19.2a` -> `18n_study_19.3a` -> `18n_study_19.4a` -> `18n_study_19.5a`. Но при это прорывов через 5-ый уровень пока нет.
#
# Чемпионы:
# - `18n_ppo_tr_frostbite_06:521`
# - `18n_ppo_tr_frostbite_06:494`
# - `18n_ppo_tr_frostbite_06:519`
#
# <img src="./img/score.png">
# <img src="./img/episode_r.png">
#
# **Выводы**
# 1) делаем на чемпионах следующий шаг

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.5a/18n_study_19.5a.ipynb',
#  'optuna_study_name': '18n_study_19.5a',
#  'optuna_study_serial': '19.5a',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.5a/18n_study_19.5a.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-22 23:59:53,767] A new study created in Journal with name: 18n_study_19.5a
# 2026.09.22-23:59:54.292490     0.218 >> Model instance registered, version=492
# 2026.09.22-23:59:54.305988     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch492.ipynb"
# 2026.09.22-23:59:54.306511     0.006 >> 6.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:492"; running launches=1
# 2026.09.23-00:00:25.731684     0.219 >> Model instance registered, version=493
# 2026.09.23-00:00:25.744913     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch493.ipynb"
# 2026.09.23-00:00:25.745698     0.006 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:493"; running launches=2
# 2026.09.23-00:00:56.705545     0.220 >> Model instance registered, version=494
# 2026.09.23-00:00:56.718040     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch494.ipynb"
# 2026.09.23-00:00:56.718323     0.005 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:494"; running launches=3
# 2026.09.23-00:01:28.020260     0.243 >> Model instance registered, version=495
# 2026.09.23-00:01:28.029255     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch495.ipynb"
# 2026.09.23-00:01:28.029456     0.004 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:495"; running launches=4
# 2026.09.23-00:01:58.931612     0.210 >> Model instance registered, version=496
# 2026.09.23-00:01:58.945917     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch496.ipynb"
# 2026.09.23-00:01:58.946528     0.007 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:496"; running launches=5
# 2026.09.23-00:02:29.928222     0.196 >> Model instance registered, version=497
# 2026.09.23-00:02:29.937746     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch497.ipynb"
# 2026.09.23-00:02:29.939198     0.001 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:497"; running launches=6
# 2026.09.23-00:50:29.180268     1.661 >> Trial 1 (18n_ppo_tr_frostbite_06:493) finished with value: 40404.00024984403 and parameters: {'parent': '18n_ppo_tr_frostbite_06:471'}. Best is trial 1 with value: 40404.00024984403
# 2026.09.23-00:50:32.634175     0.002 >> Launch "18n_ppo_tr_frostbite_06:493" completed
# 2026.09.23-00:50:32.635354     0.001 >> 1 (+1) launches completed; running launches=5
# 2026.09.23-00:50:58.649850     0.203 >> Model instance registered, version=498
# 2026.09.23-00:50:58.662322     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:498"; running launches=6
# 2026.09.23-00:50:58.662460     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch498.ipynb"
# 2026.09.23-00:51:05.333331     1.564 >> Trial 2 (18n_ppo_tr_frostbite_06:494) finished with value: 40404.00027863191 and parameters: {'parent': '18n_ppo_tr_frostbite_06:478'}. Best is trial 2 with value: 40404.00027863191
# 2026.09.23-00:51:08.884246     0.001 >> Launch "18n_ppo_tr_frostbite_06:494" completed
# 2026.09.23-00:51:08.885245     0.001 >> 2 (+1) launches completed; running launches=5
# 2026.09.23-00:51:29.566502     0.205 >> Model instance registered, version=499
# 2026.09.23-00:51:29.578437     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:499"; running launches=6
# 2026.09.23-00:51:29.578579     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch499.ipynb"
# 2026.09.23-00:52:32.844929     1.446 >> Trial 5 (18n_ppo_tr_frostbite_06:497) finished with value: 40404.00026847148 and parameters: {'parent': '18n_ppo_tr_frostbite_06:477'}. Best is trial 2 with value: 40404.00027863191
# 2026.09.23-00:52:36.513916     0.001 >> Launch "18n_ppo_tr_frostbite_06:497" completed
# 2026.09.23-00:52:36.514919     0.001 >> 3 (+1) launches completed; running launches=5
# 2026.09.23-00:52:43.230959     1.600 >> Trial 0 (18n_ppo_tr_frostbite_06:492) finished with value: 30304.00024509804 and parameters: {'parent': '18n_ppo_tr_frostbite_06:477'}. Best is trial 2 with value: 40404.00027863191
# 2026.09.23-00:52:46.746591     0.001 >> Launch "18n_ppo_tr_frostbite_06:492" completed
# 2026.09.23-00:52:46.747590     0.001 >> 4 (+1) launches completed; running launches=4
# 2026.09.23-00:52:52.841496     0.214 >> Model instance registered, version=500
# 2026.09.23-00:52:52.855412     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:500"; running launches=5
# 2026.09.23-00:52:52.855556     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch500.ipynb"
# 2026.09.23-00:53:23.895944     0.215 >> Model instance registered, version=501
# 2026.09.23-00:53:23.904905     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:501"; running launches=6
# 2026.09.23-00:53:23.905284     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch501.ipynb"
# 2026.09.23-00:55:04.057449     2.481 >> Trial 3 (18n_ppo_tr_frostbite_06:495) finished with value: 40304.0002620098 and parameters: {'parent': '18n_ppo_tr_frostbite_06:475'}. Best is trial 2 with value: 40404.00027863191
# 2026.09.23-00:55:04.253575     0.196 >> Trial 4 (18n_ppo_tr_frostbite_06:496) finished with value: 30404.000247771837 and parameters: {'parent': '18n_ppo_tr_frostbite_06:473'}. Best is trial 2 with value: 40404.00027863191
# 2026.09.23-00:55:06.776440     0.002 >> Launch "18n_ppo_tr_frostbite_06:495" completed
# 2026.09.23-00:55:06.777407     0.001 >> Launch "18n_ppo_tr_frostbite_06:496" completed
# 2026.09.23-00:55:06.778167     0.001 >> 6 (+2) launches completed; running launches=4
# 2026.09.23-00:55:17.204682     0.200 >> Model instance registered, version=502
# 2026.09.23-00:55:17.218881     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:502"; running launches=5
# 2026.09.23-00:55:17.219050     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch502.ipynb"
# 2026.09.23-00:55:48.112047     0.209 >> Model instance registered, version=503
# 2026.09.23-00:55:48.125601     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:503"; running launches=6
# 2026.09.23-00:55:48.125850     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch503.ipynb"
# 2026.09.23-01:39:37.936880     3.333 >> Trial 6 (18n_ppo_tr_frostbite_06:498) finished with value: 40404.00026167558 and parameters: {'parent': '18n_ppo_tr_frostbite_06:473'}. Best is trial 2 with value: 40404.00027863191
# 2026.09.23-01:39:39.722573     0.002 >> Launch "18n_ppo_tr_frostbite_06:498" completed
# 2026.09.23-01:39:39.723447     0.001 >> 7 (+1) launches completed; running launches=5
# 2026.09.23-01:40:06.278929     0.212 >> Model instance registered, version=504
# 2026.09.23-01:40:06.290450     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:504"; running launches=6
# 2026.09.23-01:40:06.290585     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch504.ipynb"
# 2026.09.23-01:40:37.128868     0.130 >> Trial 7 (18n_ppo_tr_frostbite_06:499) finished with value: 40303.00027627005 and parameters: {'parent': '18n_ppo_tr_frostbite_06:477'}. Best is trial 2 with value: 40404.00027863191
# 2026.09.23-01:40:42.215409     0.002 >> Launch "18n_ppo_tr_frostbite_06:499" completed
# 2026.09.23-01:40:42.215987     0.001 >> 8 (+1) launches completed; running launches=5
# 2026.09.23-01:41:03.082760     0.261 >> Model instance registered, version=505
# 2026.09.23-01:41:03.097947     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:505"; running launches=6
# 2026.09.23-01:41:03.099099     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch505.ipynb"
# 2026.09.23-01:41:42.458810     3.298 >> Trial 9 (18n_ppo_tr_frostbite_06:501) finished with value: 40404.00026454991 and parameters: {'parent': '18n_ppo_tr_frostbite_06:471'}. Best is trial 2 with value: 40404.00027863191
# 2026.09.23-01:41:44.271046     0.001 >> Launch "18n_ppo_tr_frostbite_06:501" completed
# 2026.09.23-01:41:44.271689     0.001 >> 9 (+1) launches completed; running launches=5
# 2026.09.23-01:42:10.065286     0.203 >> Model instance registered, version=506
# 2026.09.23-01:42:10.075992     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:506"; running launches=6
# 2026.09.23-01:42:10.076345     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch506.ipynb"
# 2026.09.23-01:45:52.290622     4.228 >> Trial 8 (18n_ppo_tr_frostbite_06:500) finished with value: 40304.000261653295 and parameters: {'parent': '18n_ppo_tr_frostbite_06:478'}. Best is trial 2 with value: 40404.00027863191
# 2026.09.23-01:45:53.606562     0.002 >> Launch "18n_ppo_tr_frostbite_06:500" completed
# 2026.09.23-01:45:53.607110     0.001 >> 10 (+1) launches completed; running launches=5
# 2026.09.23-01:46:19.434038     0.209 >> Model instance registered, version=507
# 2026.09.23-01:46:19.444444     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:507"; running launches=6
# 2026.09.23-01:46:19.445052     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch507.ipynb"
# 2026.09.23-01:48:09.624638     2.452 >> Trial 10 (18n_ppo_tr_frostbite_06:502) finished with value: 40304.000236185384 and parameters: {'parent': '18n_ppo_tr_frostbite_06:478'}. Best is trial 2 with value: 40404.00027863191
# 2026.09.23-01:48:12.292285     0.002 >> Launch "18n_ppo_tr_frostbite_06:502" completed
# 2026.09.23-01:48:12.293160     0.001 >> 11 (+1) launches completed; running launches=5
# 2026.09.23-01:48:38.255289     0.204 >> Model instance registered, version=508
# 2026.09.23-01:48:38.266855     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:508"; running launches=6
# 2026.09.23-01:48:38.267068     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch508.ipynb"
# 2026.09.23-01:49:10.030112     0.329 >> Trial 11 (18n_ppo_tr_frostbite_06:503) finished with value: 40404.00027090018 and parameters: {'parent': '18n_ppo_tr_frostbite_06:475'}. Best is trial 2 with value: 40404.00027863191
# 2026.09.23-01:49:14.821860     0.002 >> Launch "18n_ppo_tr_frostbite_06:503" completed
# 2026.09.23-01:49:14.822821     0.001 >> 12 (+1) launches completed; running launches=5
# 2026.09.23-01:49:36.317518     0.210 >> Model instance registered, version=509
# 2026.09.23-01:49:36.333255     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:509"; running launches=6
# 2026.09.23-01:49:36.334211     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch509.ipynb"
# 2026.09.23-02:29:12.352565     5.034 >> Trial 12 (18n_ppo_tr_frostbite_06:504) finished with value: 40404.00028360071 and parameters: {'parent': '18n_ppo_tr_frostbite_06:476'}. Best is trial 12 with value: 40404.00028360071
# 2026.09.23-02:29:12.433945     0.002 >> Launch "18n_ppo_tr_frostbite_06:504" completed
# 2026.09.23-02:29:12.434904     0.001 >> 13 (+1) launches completed; running launches=5
# 2026.09.23-02:29:38.553247     0.204 >> Model instance registered, version=510
# 2026.09.23-02:29:38.566104     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:510"; running launches=6
# 2026.09.23-02:29:38.566999     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch510.ipynb"
# 2026.09.23-02:29:55.286262     1.383 >> Trial 13 (18n_ppo_tr_frostbite_06:505) finished with value: 40404.000267825315 and parameters: {'parent': '18n_ppo_tr_frostbite_06:475'}. Best is trial 12 with value: 40404.00028360071
# 2026.09.23-02:29:59.021055     0.002 >> Launch "18n_ppo_tr_frostbite_06:505" completed
# 2026.09.23-02:29:59.021890     0.001 >> 14 (+1) launches completed; running launches=5
# 2026.09.23-02:30:24.854415     0.219 >> Model instance registered, version=511
# 2026.09.23-02:30:24.869317     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:511"; running launches=6
# 2026.09.23-02:30:24.869467     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch511.ipynb"
# 2026.09.23-02:31:36.569195     4.557 >> Trial 14 (18n_ppo_tr_frostbite_06:506) finished with value: 40404.00028540553 and parameters: {'parent': '18n_ppo_tr_frostbite_06:476'}. Best is trial 14 with value: 40404.00028540553
# 2026.09.23-02:31:37.133883     0.003 >> Launch "18n_ppo_tr_frostbite_06:506" completed
# 2026.09.23-02:31:37.134716     0.001 >> 15 (+1) launches completed; running launches=5
# 2026.09.23-02:32:03.553995     0.206 >> Model instance registered, version=512
# 2026.09.23-02:32:03.564389     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:512"; running launches=6
# 2026.09.23-02:32:03.564631     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch512.ipynb"
# 2026.09.23-02:39:54.730120     0.415 >> Trial 15 (18n_ppo_tr_frostbite_06:507) finished with value: 40404.00026526293 and parameters: {'parent': '18n_ppo_tr_frostbite_06:478'}. Best is trial 14 with value: 40404.00028540553
# 2026.09.23-02:39:59.430604     0.001 >> Launch "18n_ppo_tr_frostbite_06:507" completed
# 2026.09.23-02:39:59.431499     0.001 >> 16 (+1) launches completed; running launches=5
# 2026.09.23-02:40:20.510613     0.203 >> Model instance registered, version=513
# 2026.09.23-02:40:20.527624     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:513"; running launches=6
# 2026.09.23-02:40:20.527740     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch513.ipynb"
# 2026.09.23-02:41:12.258868     4.601 >> Trial 16 (18n_ppo_tr_frostbite_06:508) finished with value: 40304.00024175579 and parameters: {'parent': '18n_ppo_tr_frostbite_06:476'}. Best is trial 14 with value: 40404.00028540553
# 2026.09.23-02:41:12.774268     0.002 >> Launch "18n_ppo_tr_frostbite_06:508" completed
# 2026.09.23-02:41:12.775197     0.001 >> 17 (+1) launches completed; running launches=5
# 2026.09.23-02:41:38.663576     0.209 >> Model instance registered, version=514
# 2026.09.23-02:41:38.673178     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:514"; running launches=6
# 2026.09.23-02:41:38.673364     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch514.ipynb"
# 2026.09.23-02:42:48.411582     3.024 >> Trial 17 (18n_ppo_tr_frostbite_06:509) finished with value: 40403.0002594697 and parameters: {'parent': '18n_ppo_tr_frostbite_06:475'}. Best is trial 14 with value: 40404.00028540553
# 2026.09.23-02:42:50.508308     0.003 >> Launch "18n_ppo_tr_frostbite_06:509" completed
# 2026.09.23-02:42:50.509115     0.001 >> 18 (+1) launches completed; running launches=5
# 2026.09.23-02:43:16.297128     0.203 >> Model instance registered, version=515
# 2026.09.23-02:43:16.312098     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:515"; running launches=6
# 2026.09.23-02:43:16.312276     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch515.ipynb"
# 2026.09.23-03:19:02.487269     2.665 >> Trial 18 (18n_ppo_tr_frostbite_06:510) finished with value: 404.0002651515152 and parameters: {'parent': '18n_ppo_tr_frostbite_06:476'}. Best is trial 14 with value: 40404.00028540553
# 2026.09.23-03:19:05.058037     0.003 >> Launch "18n_ppo_tr_frostbite_06:510" completed
# 2026.09.23-03:19:05.059098     0.001 >> 19 (+1) launches completed; running launches=5
# 2026.09.23-03:19:32.104574     0.198 >> Model instance registered, version=516
# 2026.09.23-03:19:32.123076     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:516"; running launches=6
# 2026.09.23-03:19:32.123265     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch516.ipynb"
# 2026.09.23-03:20:05.308660     2.429 >> Trial 19 (18n_ppo_tr_frostbite_06:511) finished with value: 40404.00028752228 and parameters: {'parent': '18n_ppo_tr_frostbite_06:476'}. Best is trial 19 with value: 40404.00028752228
# 2026.09.23-03:20:08.584833     0.002 >> Launch "18n_ppo_tr_frostbite_06:511" completed
# 2026.09.23-03:20:08.585894     0.001 >> 20 (+1) launches completed; running launches=5
# 2026.09.23-03:20:34.671502     0.201 >> Model instance registered, version=517
# 2026.09.23-03:20:34.683242     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:517"; running launches=6
# 2026.09.23-03:20:34.683403     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch517.ipynb"
# 2026.09.23-03:21:40.756760     3.101 >> Trial 20 (18n_ppo_tr_frostbite_06:512) finished with value: 40304.00026495098 and parameters: {'parent': '18n_ppo_tr_frostbite_06:476'}. Best is trial 19 with value: 40404.00028752228
# 2026.09.23-03:21:42.768436     0.001 >> Launch "18n_ppo_tr_frostbite_06:512" completed
# 2026.09.23-03:21:42.769027     0.001 >> 21 (+1) launches completed; running launches=5
# 2026.09.23-03:22:08.899355     0.206 >> Model instance registered, version=518
# 2026.09.23-03:22:08.909227     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:518"; running launches=6
# 2026.09.23-03:22:08.909393     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch518.ipynb"
# 2026.09.23-03:33:13.904496     0.138 >> Trial 21 (18n_ppo_tr_frostbite_06:513) finished with value: 40401.00026544118 and parameters: {'parent': '18n_ppo_tr_frostbite_06:476'}. Best is trial 19 with value: 40404.00028752228
# 2026.09.23-03:33:18.880737     0.001 >> Launch "18n_ppo_tr_frostbite_06:513" completed
# 2026.09.23-03:33:18.881640     0.001 >> 22 (+1) launches completed; running launches=5
# 2026.09.23-03:33:40.437641     0.218 >> Model instance registered, version=519
# 2026.09.23-03:33:40.449342     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:519"; running launches=6
# 2026.09.23-03:33:40.449535     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch519.ipynb"
# 2026.09.23-03:34:22.503617     0.321 >> Trial 22 (18n_ppo_tr_frostbite_06:514) finished with value: 40404.00026566399 and parameters: {'parent': '18n_ppo_tr_frostbite_06:476'}. Best is trial 19 with value: 40404.00028752228
# 2026.09.23-03:34:27.297658     0.001 >> Launch "18n_ppo_tr_frostbite_06:514" completed
# 2026.09.23-03:34:27.298421     0.001 >> 23 (+1) launches completed; running launches=5
# 2026.09.23-03:34:48.023184     0.254 >> Model instance registered, version=520
# 2026.09.23-03:34:48.038331     0.007 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:520"; running launches=6
# 2026.09.23-03:34:48.038521     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch520.ipynb"
# 2026.09.23-03:36:22.106836     1.251 >> Trial 23 (18n_ppo_tr_frostbite_06:515) finished with value: 40403.00026292335 and parameters: {'parent': '18n_ppo_tr_frostbite_06:476'}. Best is trial 19 with value: 40404.00028752228
# 2026.09.23-03:36:25.971849     0.002 >> Launch "18n_ppo_tr_frostbite_06:515" completed
# 2026.09.23-03:36:25.972678     0.001 >> 24 (+1) launches completed; running launches=5
# 2026.09.23-03:36:52.594974     0.213 >> Model instance registered, version=521
# 2026.09.23-03:36:52.608140     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:521"; running launches=6
# 2026.09.23-03:36:52.608354     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch521.ipynb"
# 2026.09.23-04:09:11.534947     3.624 >> Trial 24 (18n_ppo_tr_frostbite_06:516) finished with value: 40404.00028694296 and parameters: {'parent': '18n_ppo_tr_frostbite_06:476'}. Best is trial 19 with value: 40404.00028752228
# 2026.09.23-04:09:13.028019     0.002 >> Launch "18n_ppo_tr_frostbite_06:516" completed
# 2026.09.23-04:09:13.028786     0.001 >> 25 (+1) launches completed; running launches=5
# 2026.09.23-04:10:31.505784     1.579 >> Trial 25 (18n_ppo_tr_frostbite_06:517) finished with value: 40404.000267713905 and parameters: {'parent': '18n_ppo_tr_frostbite_06:476'}. Best is trial 19 with value: 40404.00028752228
# 2026.09.23-04:10:35.037309     0.001 >> Launch "18n_ppo_tr_frostbite_06:517" completed
# 2026.09.23-04:10:35.037873     0.001 >> 26 (+1) launches completed; running launches=4
# 2026.09.23-04:10:44.397619     4.246 >> Trial 26 (18n_ppo_tr_frostbite_06:518) finished with value: 40404.00024048574 and parameters: {'parent': '18n_ppo_tr_frostbite_06:476'}. Best is trial 19 with value: 40404.00028752228
# 2026.09.23-04:10:45.296667     0.002 >> Launch "18n_ppo_tr_frostbite_06:518" completed
# 2026.09.23-04:10:45.297445     0.001 >> 27 (+1) launches completed; running launches=3
# 2026.09.23-04:26:15.517622     0.982 >> Trial 27 (18n_ppo_tr_frostbite_06:519) finished with value: 40404.00028794563 and parameters: {'parent': '18n_ppo_tr_frostbite_06:476'}. Best is trial 27 with value: 40404.00028794563
# 2026.09.23-04:26:19.651876     0.002 >> Launch "18n_ppo_tr_frostbite_06:519" completed
# 2026.09.23-04:26:19.652824     0.001 >> 28 (+1) launches completed; running launches=2
# 2026.09.23-04:26:29.941171     0.065 >> Trial 28 (18n_ppo_tr_frostbite_06:520) finished with value: 40404.00023627451 and parameters: {'parent': '18n_ppo_tr_frostbite_06:476'}. Best is trial 27 with value: 40404.00028794563
# 2026.09.23-04:26:29.941810     0.001 >> Launch "18n_ppo_tr_frostbite_06:520" completed
# 2026.09.23-04:26:29.942080     0.000 >> 29 (+1) launches completed; running launches=1
# 2026.09.23-04:29:35.073912     4.237 >> Trial 29 (18n_ppo_tr_frostbite_06:521) finished with value: 40404.000290753116 and parameters: {'parent': '18n_ppo_tr_frostbite_06:476'}. Best is trial 29 with value: 40404.000290753116
# 2026.09.23-04:29:36.381671     0.002 >> Launch "18n_ppo_tr_frostbite_06:521" completed
# 2026.09.23-04:29:36.382517     0.001 >> 30 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-23 04:29:41,415] Using an existing study with name '18n_study_19.5a' instead of creating a new one.
# 2026.09.23-04:29:41.418270     5.036 >> Study statistics:
# 2026.09.23-04:29:41.422249     0.004 >> 	Number of finished trials: 30
# 2026.09.23-04:29:41.423226     0.001 >> 	Number of pruned trials: 0
# 2026.09.23-04:29:41.423817     0.001 >> 	Number of complete trials: 30
# 2026.09.23-04:29:41.424646     0.001 >> Best trial:
# 2026.09.23-04:29:41.425587     0.001 >> 	Value: 40404.000290753116
# 2026.09.23-04:29:41.425963     0.000 >> 	Model version: 521
# 2026.09.23-04:29:41.426312     0.000 >> 	Params:
# 2026.09.23-04:29:41.426675     0.000 >> 		parent: 18n_ppo_tr_frostbite_06:476
