# %% [markdown]
# # Goal
#
# Продолжение `18d_study_17.1`, но с новым `18d_world_model_08`, который умеет предсказывать любой горизонт. Тестируем гиперпараметры:
# - `struct_projector=dict(type='Identity')`
# - `pred_latents_source`
# - `learn_rate`
# - `pred_loss_type='MSE'`

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18d_world_model_08.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.launch_goal = 'train_predictor'
    
    HP.general.comment = None
    HP.general.random_seed = random.randint(0, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True

    HP.dataset.train = [
        '18b_dataset_02:7:cls=train,no=1,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=2,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=3,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=4,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=5,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=6,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=7,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=8,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=9,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=10,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=11,seq=8,mp=0',
        '18b_dataset_02:7:cls=train,no=12,seq=8,mp=0',
    ]
    HP.dataset.test = '18b_dataset_02:7:cls=test,no=1,seq=8,mp=0'

    HP.model.parent = '18d_world_model_07:8'
    # Give 4 obs, predict next 4 obs
    HP.model.input_sequence_length = 4
    HP.model.actions_count = 6
    HP.model.ob_shape = (1, 178, 152)
    HP.model.d_model = 256
    HP.model.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.model.encoder = dict(
        is_trainable=HP.launch_goal in ('train_encoder', 'train_all', None),
        vision_head=dict(grid=(6,6), features_counts=(16, 32, 64, 128)),
    )
    HP.model.predictor = dict(
        is_trainable=HP.launch_goal in ('train_predictor', 'train_all', None),
        pred_latents_source=optuna_trial.suggest_categorical('pred_latents_source', ['actions', 'separate']),
        parent=None, # do not load from HP.model.parent
    )
    HP.model.renderer = dict(
        is_trainable=HP.launch_goal in ('train_encoder', 'train_all', None),
        projector=dict(type='linear'), 
        render_engine=dict(
            type='layer', 
            layers_count=4, 
            features_counts=(96, 64, 32, 16),
        ),
    )
    HP.model.struct_projector = dict(
        is_trainable=HP.launch_goal in ('train_predictor', 'train_all', None),
        type='Identity',
        parent=None, # do not load from HP.model.parent
    )
    
    HP.train.epochs_count = 100
    HP.train.batch_size = 128
    HP.train.optimizer = 'AdamW'
    HP.train.max_grad_norm = 1.0
    HP.train.learn_rate = f'const({optuna_trial.suggest_float('learn_rate', 0.0001, 0.01)})'
    HP.train.bce_loss_coef = 'const(1.0)'
    HP.train.edge_loss_coef = 'const(1.0)'
    HP.train.recon_loss_coef = 'const(0.0)'
    HP.train.pred_loss = dict(
        type='MSE', 
        loss_coef='const(1.0)', 
    )
    
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# В целом неплохо.
#
# Если только не учитывать тот факт, что все 12 датасетов, включая тестовый были одинаковыми!!! Обнаружил это по логам - для любого датасета в логи писалось, что было обработано одинаковое число батч элементов.
#
# При этом надо отметить, что на рендерах всё таки видно, что неплохо справляется с задачей.
#
# <img src="./img/ssim.png">
#
# **Выводы**
# 1) перезапустить с пофикшеной проблемой датасетов.

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18d_world_model_08.ipynb',
#  'target_notebook_name': '18d_world_model_08',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18d_study_18.1/18d_study_18.1.ipynb',
#  'optuna_study_name': '18d_study_18.1',
#  'optuna_study_serial': '18.1',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18d_study_18.1/18d_study_18.1.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 100
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-14 10:26:05,448] A new study created in Journal with name: 18d_study_18.1
# 2026.09.14-10:26:05.698407     0.226 >> Model instance registered, version=5
# 2026.09.14-10:26:05.713687     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch5.ipynb"
# 2026.09.14-10:26:05.714036     0.008 >> 6.0 idle runners exist, submitted launch "18d_world_model_08:5"; running launches=1
# 2026.09.14-10:26:36.601546     0.194 >> Model instance registered, version=6
# 2026.09.14-10:26:36.619729     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch6.ipynb"
# 2026.09.14-10:26:36.619995     0.007 >> 5.5 idle runners exist, submitted launch "18d_world_model_08:6"; running launches=2
# 2026.09.14-10:27:08.193578     0.170 >> Model instance registered, version=7
# 2026.09.14-10:27:08.209633     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch7.ipynb"
# 2026.09.14-10:27:08.209879     0.007 >> 4.7 idle runners exist, submitted launch "18d_world_model_08:7"; running launches=3
# 2026.09.14-10:27:39.067469     0.179 >> Model instance registered, version=8
# 2026.09.14-10:27:39.081478     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch8.ipynb"
# 2026.09.14-10:27:39.081717     0.007 >> 3.8 idle runners exist, submitted launch "18d_world_model_08:8"; running launches=4
# 2026.09.14-10:28:09.978297     0.194 >> Model instance registered, version=9
# 2026.09.14-10:28:10.000836     0.010 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch9.ipynb"
# 2026.09.14-10:28:10.001213     0.011 >> 2.8 idle runners exist, submitted launch "18d_world_model_08:9"; running launches=5
# 2026.09.14-10:28:41.042856     0.176 >> Model instance registered, version=10
# 2026.09.14-10:28:41.059031     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch10.ipynb"
# 2026.09.14-10:28:41.059443     0.008 >> 1.5 idle runners exist, submitted launch "18d_world_model_08:10"; running launches=6
# 2026.09.14-10:39:24.899777     4.510 >> Trial 0 (18d_world_model_08:5) finished with value: 0.9774788333696434 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0015457127498319809}. Best is trial 0 with value: 0.9774788333696434
# 2026.09.14-10:39:25.509102     0.002 >> Launch "18d_world_model_08:5" completed
# 2026.09.14-10:39:25.509935     0.001 >> 1 (+1) launches completed; running launches=5
# 2026.09.14-10:39:51.457688     0.381 >> Model instance registered, version=11
# 2026.09.14-10:39:51.474196     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:11"; running launches=6
# 2026.09.14-10:39:51.474334     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch11.ipynb"
# 2026.09.14-10:40:49.012476     0.832 >> Trial 2 (18d_world_model_08:7) finished with value: 0.9705041499145317 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.004205796457376688}. Best is trial 0 with value: 0.9774788333696434
# 2026.09.14-10:40:53.298829     0.001 >> Launch "18d_world_model_08:7" completed
# 2026.09.14-10:40:53.300088     0.001 >> 2 (+1) launches completed; running launches=5
# 2026.09.14-10:41:18.386610     4.605 >> Trial 3 (18d_world_model_08:8) finished with value: 0.9752139791646354 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.0022259912836974584}. Best is trial 0 with value: 0.9774788333696434
# 2026.09.14-10:41:19.120579     0.223 >> Model instance registered, version=12
# 2026.09.14-10:41:19.137777     0.006 >> 1.2 idle runners exist, submitted launch "18d_world_model_08:12"; running launches=6
# 2026.09.14-10:41:19.137877     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch12.ipynb"
# 2026.09.14-10:41:19.138401     0.001 >> Launch "18d_world_model_08:8" completed
# 2026.09.14-10:41:19.139593     0.001 >> 3 (+1) launches completed; running launches=5
# 2026.09.14-10:41:51.008407     0.296 >> Model instance registered, version=13
# 2026.09.14-10:41:51.027155     0.007 >> 1.5 idle runners exist, submitted launch "18d_world_model_08:13"; running launches=6
# 2026.09.14-10:41:51.029120     0.009 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch13.ipynb"
# 2026.09.14-10:43:35.228427     0.423 >> Trial 1 (18d_world_model_08:6) finished with value: 0.9720191400917756 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.0048931685758192445}. Best is trial 0 with value: 0.9774788333696434
# 2026.09.14-10:43:39.929059     0.006 >> Launch "18d_world_model_08:6" completed
# 2026.09.14-10:43:39.930302     0.001 >> 4 (+1) launches completed; running launches=5
# 2026.09.14-10:44:00.587288     0.183 >> Model instance registered, version=14
# 2026.09.14-10:44:00.602729     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:14"; running launches=6
# 2026.09.14-10:44:00.602832     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch14.ipynb"
# 2026.09.14-10:45:28.883285     4.287 >> Trial 4 (18d_world_model_08:9) finished with value: 0.9712495910358875 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.004142574032552216}. Best is trial 0 with value: 0.9774788333696434
# 2026.09.14-10:45:29.763384     0.003 >> Launch "18d_world_model_08:9" completed
# 2026.09.14-10:45:29.764385     0.001 >> 5 (+1) launches completed; running launches=5
# 2026.09.14-10:45:55.530021     0.193 >> Model instance registered, version=15
# 2026.09.14-10:45:55.548438     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:15"; running launches=6
# 2026.09.14-10:45:55.548632     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch15.ipynb"
# 2026.09.14-10:46:00.135396     4.587 >> Trial 5 (18d_world_model_08:10) finished with value: 0.9714128529374574 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.004821012297107695}. Best is trial 0 with value: 0.9774788333696434
# 2026.09.14-10:46:00.662231     0.002 >> Launch "18d_world_model_08:10" completed
# 2026.09.14-10:46:00.663051     0.001 >> 6 (+1) launches completed; running launches=5
# 2026.09.14-10:46:26.439224     0.184 >> Model instance registered, version=16
# 2026.09.14-10:46:26.455054     0.007 >> 1.5 idle runners exist, submitted launch "18d_world_model_08:16"; running launches=6
# 2026.09.14-10:46:26.455204     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch16.ipynb"
# 2026.09.14-10:53:00.800959     4.769 >> Trial 6 (18d_world_model_08:11) finished with value: 0.9713744583963047 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.009865625679293222}. Best is trial 0 with value: 0.9774788333696434
# 2026.09.14-10:53:01.147842     0.001 >> Launch "18d_world_model_08:11" completed
# 2026.09.14-10:53:01.148650     0.001 >> 7 (+1) launches completed; running launches=5
# 2026.09.14-10:53:26.920915     0.197 >> Model instance registered, version=17
# 2026.09.14-10:53:26.938144     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:17"; running launches=6
# 2026.09.14-10:53:26.938274     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch17.ipynb"
# 2026.09.14-10:54:19.586585     1.424 >> Trial 7 (18d_world_model_08:12) finished with value: 0.9731279198799788 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.008621029283007094}. Best is trial 0 with value: 0.9774788333696434
# 2026.09.14-10:54:23.281924     0.002 >> Launch "18d_world_model_08:12" completed
# 2026.09.14-10:54:23.282798     0.001 >> 8 (+1) launches completed; running launches=5
# 2026.09.14-10:54:49.011657     0.173 >> Model instance registered, version=18
# 2026.09.14-10:54:49.029442     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:18"; running launches=6
# 2026.09.14-10:54:49.029548     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch18.ipynb"
# 2026.09.14-10:54:52.927035     3.897 >> Trial 8 (18d_world_model_08:13) finished with value: 0.9750347324317777 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.0021140622753805013}. Best is trial 0 with value: 0.9774788333696434
# 2026.09.14-10:54:54.140975     0.001 >> Launch "18d_world_model_08:13" completed
# 2026.09.14-10:54:54.141700     0.001 >> 9 (+1) launches completed; running launches=5
# 2026.09.14-10:55:20.000740     0.173 >> Model instance registered, version=19
# 2026.09.14-10:55:20.018412     0.006 >> 1.5 idle runners exist, submitted launch "18d_world_model_08:19"; running launches=6
# 2026.09.14-10:55:20.018623     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch19.ipynb"
# 2026.09.14-11:00:02.400370     4.142 >> Trial 9 (18d_world_model_08:14) finished with value: 0.9713198562122173 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.004605963717943779}. Best is trial 0 with value: 0.9774788333696434
# 2026.09.14-11:00:03.520580     0.002 >> Launch "18d_world_model_08:14" completed
# 2026.09.14-11:00:03.521551     0.001 >> 10 (+1) launches completed; running launches=5
# 2026.09.14-11:00:30.590657     0.235 >> Model instance registered, version=20
# 2026.09.14-11:00:30.608102     0.008 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:20"; running launches=6
# 2026.09.14-11:00:30.608293     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch20.ipynb"
# 2026.09.14-11:02:55.175341     3.311 >> Trial 10 (18d_world_model_08:15) finished with value: 0.9716201382308222 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.0042203678697688915}. Best is trial 0 with value: 0.9774788333696434
# 2026.09.14-11:02:56.981214     0.004 >> Launch "18d_world_model_08:15" completed
# 2026.09.14-11:02:56.981954     0.001 >> 11 (+1) launches completed; running launches=5
# 2026.09.14-11:03:22.897623     0.195 >> Model instance registered, version=21
# 2026.09.14-11:03:22.913416     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:21"; running launches=6
# 2026.09.14-11:03:22.913530     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch21.ipynb"
# 2026.09.14-11:03:25.895686     2.982 >> Trial 11 (18d_world_model_08:16) finished with value: 0.9732814280588802 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.009471596301854396}. Best is trial 0 with value: 0.9774788333696434
# 2026.09.14-11:03:28.024801     0.001 >> Launch "18d_world_model_08:16" completed
# 2026.09.14-11:03:28.025477     0.001 >> 12 (+1) launches completed; running launches=5
# 2026.09.14-11:03:53.858842     0.234 >> Model instance registered, version=22
# 2026.09.14-11:03:53.883154     0.009 >> 1.5 idle runners exist, submitted launch "18d_world_model_08:22"; running launches=6
# 2026.09.14-11:03:53.883482     0.010 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch22.ipynb"
# 2026.09.14-11:06:27.405098     4.499 >> Trial 12 (18d_world_model_08:17) finished with value: 0.9744058841699371 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.008856752890612767}. Best is trial 0 with value: 0.9774788333696434
# 2026.09.14-11:06:28.267548     0.003 >> Launch "18d_world_model_08:17" completed
# 2026.09.14-11:06:28.268521     0.001 >> 13 (+1) launches completed; running launches=5
# 2026.09.14-11:06:54.290008     0.223 >> Model instance registered, version=23
# 2026.09.14-11:06:54.305772     0.008 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:23"; running launches=6
# 2026.09.14-11:06:54.305937     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch23.ipynb"
# 2026.09.14-11:07:50.295927     4.214 >> Trial 13 (18d_world_model_08:18) finished with value: 0.9730757614826078 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0065259511918536964}. Best is trial 0 with value: 0.9774788333696434
# 2026.09.14-11:07:51.192523     0.001 >> Launch "18d_world_model_08:18" completed
# 2026.09.14-11:07:51.193064     0.001 >> 14 (+1) launches completed; running launches=5
# 2026.09.14-11:08:16.994183     0.252 >> Model instance registered, version=24
# 2026.09.14-11:08:17.025138     0.015 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:24"; running launches=6
# 2026.09.14-11:08:17.025363     0.015 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch24.ipynb"
# 2026.09.14-11:08:24.050652     1.917 >> Trial 14 (18d_world_model_08:19) finished with value: 0.9726875950282152 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.009139553492199014}. Best is trial 0 with value: 0.9774788333696434
# 2026.09.14-11:08:27.245935     0.001 >> Launch "18d_world_model_08:19" completed
# 2026.09.14-11:08:27.246647     0.001 >> 15 (+1) launches completed; running launches=5
# 2026.09.14-11:08:48.112818     0.279 >> Model instance registered, version=25
# 2026.09.14-11:08:48.135275     0.010 >> 1.3 idle runners exist, submitted launch "18d_world_model_08:25"; running launches=6
# 2026.09.14-11:08:48.135427     0.010 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch25.ipynb"
# 2026.09.14-11:16:28.448200     4.977 >> Trial 15 (18d_world_model_08:20) finished with value: 0.9782650794923399 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.00039111135302076407}. Best is trial 15 with value: 0.9782650794923399
# 2026.09.14-11:16:28.598409     0.005 >> Launch "18d_world_model_08:20" completed
# 2026.09.14-11:16:28.599458     0.001 >> 16 (+1) launches completed; running launches=5
# 2026.09.14-11:16:54.696861     0.293 >> Model instance registered, version=26
# 2026.09.14-11:16:54.727437     0.011 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:26"; running launches=6
# 2026.09.14-11:16:54.727650     0.011 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch26.ipynb"
# 2026.09.14-11:20:06.344462     0.082 >> Trial 16 (18d_world_model_08:21) finished with value: 0.9793791958099223 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.0009326403841108408}. Best is trial 16 with value: 0.9793791958099223
# 2026.09.14-11:20:06.345153     0.001 >> Launch "18d_world_model_08:21" completed
# 2026.09.14-11:20:06.345674     0.001 >> 17 (+1) launches completed; running launches=5
# 2026.09.14-11:20:06.558780     0.213 >> Trial 18 (18d_world_model_08:23) finished with value: 0.9773293572245819 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0002722702679660745}. Best is trial 16 with value: 0.9793791958099223
# 2026.09.14-11:20:11.468590     0.003 >> Launch "18d_world_model_08:23" completed
# 2026.09.14-11:20:11.469585     0.001 >> 18 (+1) launches completed; running launches=4
# 2026.09.14-11:20:16.825552     0.240 >> Model instance registered, version=27
# 2026.09.14-11:20:16.847266     0.008 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:27"; running launches=5
# 2026.09.14-11:20:16.847371     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch27.ipynb"
# 2026.09.14-11:20:48.330587     0.211 >> Model instance registered, version=28
# 2026.09.14-11:20:48.348502     0.007 >> 1.3 idle runners exist, submitted launch "18d_world_model_08:28"; running launches=6
# 2026.09.14-11:20:48.348637     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch28.ipynb"
# 2026.09.14-11:20:50.195469     1.847 >> Trial 17 (18d_world_model_08:22) finished with value: 0.9757361615875768 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0002458149285683121}. Best is trial 16 with value: 0.9793791958099223
# 2026.09.14-11:20:53.458615     0.001 >> Launch "18d_world_model_08:22" completed
# 2026.09.14-11:20:53.459296     0.001 >> 19 (+1) launches completed; running launches=5
# 2026.09.14-11:21:19.300360     0.213 >> Model instance registered, version=29
# 2026.09.14-11:21:19.314787     0.006 >> 1.5 idle runners exist, submitted launch "18d_world_model_08:29"; running launches=6
# 2026.09.14-11:21:19.314924     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch29.ipynb"
# 2026.09.14-11:21:34.419369     4.877 >> Trial 19 (18d_world_model_08:24) finished with value: 0.9745439693076005 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.00013058496220498105}. Best is trial 16 with value: 0.9793791958099223
# 2026.09.14-11:21:34.660121     0.002 >> Launch "18d_world_model_08:24" completed
# 2026.09.14-11:21:34.661459     0.001 >> 20 (+1) launches completed; running launches=5
# 2026.09.14-11:21:50.195456     0.191 >> Model instance registered, version=30
# 2026.09.14-11:21:50.213325     0.007 >> 1.5 idle runners exist, submitted launch "18d_world_model_08:30"; running launches=6
# 2026.09.14-11:21:50.213502     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch30.ipynb"
# 2026.09.14-11:21:59.476899     4.158 >> Trial 20 (18d_world_model_08:25) finished with value: 0.9770004991361764 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.00026109862096006936}. Best is trial 16 with value: 0.9793791958099223
# 2026.09.14-11:22:00.435013     0.002 >> Launch "18d_world_model_08:25" completed
# 2026.09.14-11:22:00.436063     0.001 >> 21 (+1) launches completed; running launches=5
# 2026.09.14-11:22:21.193935     0.199 >> Model instance registered, version=31
# 2026.09.14-11:22:21.208700     0.007 >> 1.3 idle runners exist, submitted launch "18d_world_model_08:31"; running launches=6
# 2026.09.14-11:22:21.209006     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch31.ipynb"
# 2026.09.14-11:31:39.114966     2.784 >> Trial 21 (18d_world_model_08:26) finished with value: 0.9727354552556126 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.00010024682753402591}. Best is trial 16 with value: 0.9793791958099223
# 2026.09.14-11:31:41.449084     0.001 >> Launch "18d_world_model_08:26" completed
# 2026.09.14-11:31:41.449979     0.001 >> 22 (+1) launches completed; running launches=5
# 2026.09.14-11:32:07.595374     0.211 >> Model instance registered, version=32
# 2026.09.14-11:32:07.616697     0.011 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:32"; running launches=6
# 2026.09.14-11:32:07.616909     0.011 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch32.ipynb"
# 2026.09.14-11:33:03.006522     3.755 >> Trial 22 (18d_world_model_08:27) finished with value: 0.9754362233083074 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.00016949292800490668}. Best is trial 16 with value: 0.9793791958099223
# 2026.09.14-11:33:04.367059     0.001 >> Launch "18d_world_model_08:27" completed
# 2026.09.14-11:33:04.367529     0.000 >> 23 (+1) launches completed; running launches=5
# 2026.09.14-11:33:30.231189     0.208 >> Model instance registered, version=33
# 2026.09.14-11:33:30.246835     0.006 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:33"; running launches=6
# 2026.09.14-11:33:30.246934     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch33.ipynb"
# 2026.09.14-11:34:53.123445     0.294 >> Trial 24 (18d_world_model_08:29) finished with value: 0.9721321032162575 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.0030073340857670458}. Best is trial 16 with value: 0.9793791958099223
# 2026.09.14-11:34:57.936619     0.001 >> Launch "18d_world_model_08:29" completed
# 2026.09.14-11:34:57.937379     0.001 >> 24 (+1) launches completed; running launches=5
# 2026.09.14-11:35:18.597146     0.195 >> Model instance registered, version=34
# 2026.09.14-11:35:18.618597     0.010 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:34"; running launches=6
# 2026.09.14-11:35:18.618794     0.010 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch34.ipynb"
# 2026.09.14-11:35:20.373328     1.755 >> Trial 25 (18d_world_model_08:30) finished with value: 0.9718317459749172 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.0028285037264137924}. Best is trial 16 with value: 0.9793791958099223
# 2026.09.14-11:35:23.726312     0.001 >> Launch "18d_world_model_08:30" completed
# 2026.09.14-11:35:23.726824     0.001 >> 25 (+1) launches completed; running launches=5
# 2026.09.14-11:35:49.494886     0.204 >> Model instance registered, version=35
# 2026.09.14-11:35:49.517446     0.010 >> 1.5 idle runners exist, submitted launch "18d_world_model_08:35"; running launches=6
# 2026.09.14-11:35:49.517602     0.010 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch35.ipynb"
# 2026.09.14-11:37:29.847070     2.879 >> Trial 23 (18d_world_model_08:28) finished with value: 0.9717558110039245 and parameters: {'pred_latents_source': 'actions', 'learn_rate': 0.0030732768605953448}. Best is trial 16 with value: 0.9793791958099223
# 2026.09.14-11:37:32.079554     0.001 >> Launch "18d_world_model_08:28" completed
# 2026.09.14-11:37:32.080133     0.001 >> 26 (+1) launches completed; running launches=5
# 2026.09.14-11:37:57.955120     0.180 >> Model instance registered, version=36
# 2026.09.14-11:37:57.979153     0.009 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:36"; running launches=6
# 2026.09.14-11:37:57.979379     0.009 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch36.ipynb"
# 2026.09.14-11:39:05.881539     0.423 >> Trial 26 (18d_world_model_08:31) finished with value: 0.9762364070612629 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0018608765115056061}. Best is trial 16 with value: 0.9793791958099223
# 2026.09.14-11:39:10.583026     0.002 >> Launch "18d_world_model_08:31" completed
# 2026.09.14-11:39:10.583572     0.001 >> 27 (+1) launches completed; running launches=5
# 2026.09.14-11:39:31.295223     0.229 >> Model instance registered, version=37
# 2026.09.14-11:39:31.315654     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:37"; running launches=6
# 2026.09.14-11:39:31.316259     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch37.ipynb"
# 2026.09.14-11:46:03.311457     4.165 >> Trial 28 (18d_world_model_08:33) finished with value: 0.9771441088600575 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.001688936876427849}. Best is trial 16 with value: 0.9793791958099223
# 2026.09.14-11:46:04.264360     0.002 >> Launch "18d_world_model_08:33" completed
# 2026.09.14-11:46:04.266188     0.002 >> 28 (+1) launches completed; running launches=5
# 2026.09.14-11:46:30.204371     0.219 >> Model instance registered, version=38
# 2026.09.14-11:46:30.218745     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:38"; running launches=6
# 2026.09.14-11:46:30.218971     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch38.ipynb"
# 2026.09.14-11:47:38.695945     1.924 >> Trial 27 (18d_world_model_08:32) finished with value: 0.9756582851082598 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0017757459669128716}. Best is trial 16 with value: 0.9793791958099223
# 2026.09.14-11:47:41.996941     0.002 >> Launch "18d_world_model_08:32" completed
# 2026.09.14-11:47:41.997675     0.001 >> 29 (+1) launches completed; running launches=5
# 2026.09.14-11:48:08.000700     0.451 >> Model instance registered, version=39
# 2026.09.14-11:48:08.022618     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:39"; running launches=6
# 2026.09.14-11:48:08.022862     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch39.ipynb"
# 2026.09.14-11:48:20.153318     1.816 >> Trial 29 (18d_world_model_08:34) finished with value: 0.9783593735717202 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.001318344585648622}. Best is trial 16 with value: 0.9793791958099223
# 2026.09.14-11:48:23.451026     0.003 >> Launch "18d_world_model_08:34" completed
# 2026.09.14-11:48:23.453059     0.002 >> 30 (+1) launches completed; running launches=5
# 2026.09.14-11:48:39.015487     0.219 >> Model instance registered, version=40
# 2026.09.14-11:48:39.031936     0.007 >> 1.0 idle runners exist, submitted launch "18d_world_model_08:40"; running launches=6
# 2026.09.14-11:48:39.032047     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch40.ipynb"
# 2026.09.14-11:48:55.561813     1.041 >> Trial 30 (18d_world_model_08:35) finished with value: 0.9784980547781481 and parameters: {'pred_latents_source': 'separate', 'learn_rate': 0.0012920471712267933}. Best is trial 16 with value: 0.9793791958099223
# 2026.09.14-11:48:59.631857     0.001 >> Launch "18d_world_model_08:35" completed
# 2026.09.14-11:48:59.632414     0.001 >> 31 (+1) launches completed; running launches=5
# 2026.09.14-11:49:10.125834     0.179 >> Model instance registered, version=41
# 2026.09.14-11:49:10.148831     0.011 >> 1.2 idle runners exist, submitted launch "18d_world_model_08:41"; running launches=6
# 2026.09.14-11:49:10.149025     0.011 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18d_world_model_08-launch41.ipynb"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 54
#      52     pass
# ---> 54 time.sleep(5)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 12
#       9 completed_launches_count = 0
#      11 with LOG.auto_log_level(logging.INFO):
# ---> 12     with cf.ThreadPoolExecutor(max_workers=32) as executor:
#      13         futures = {}
#      14         idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
#
# File ~/anaconda3/envs/mine/lib/python3.12/concurrent/futures/_base.py:647, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     646 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647     self.shutdown(wait=True)
#     648     return False
#
# File ~/anaconda3/envs/mine/lib/python3.12/concurrent/futures/thread.py:239, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     237 if wait:
#     238     for t in self._threads:
# --> 239         t.join()
#
# File ~/anaconda3/envs/mine/lib/python3.12/threading.py:1149, in Thread.join(self, timeout)
#    1146     raise RuntimeError("cannot join current thread")
#    1148 if timeout is None:
# -> 1149     self._wait_for_tstate_lock()
#    1150 else:
#    1151     # the behavior of a negative timeout isn't documented, but
#    1152     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1153     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/anaconda3/envs/mine/lib/python3.12/threading.py:1169, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1166     return
#    1168 try:
# -> 1169     if lock.acquire(block, timeout):
#    1170         lock.release()
#    1171         self._stop()
#
# KeyboardInterrupt:

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-14 11:51:31,730] Using an existing study with name '18d_study_18.1' instead of creating a new one.
# 2026.09.14-11:51:31.731469     8.159 >> Study statistics:
# 2026.09.14-11:51:31.733122     0.002 >> 	Number of finished trials: 37
# 2026.09.14-11:51:31.733542     0.000 >> 	Number of pruned trials: 0
# 2026.09.14-11:51:31.733929     0.000 >> 	Number of complete trials: 31
# 2026.09.14-11:51:31.734476     0.001 >> Best trial:
# 2026.09.14-11:51:31.734902     0.000 >> 	Value: 0.9793791958099223
# 2026.09.14-11:51:31.735225     0.000 >> 	Model version: 21
# 2026.09.14-11:51:31.735592     0.000 >> 	Params:
# 2026.09.14-11:51:31.735837     0.000 >> 		pred_latents_source: actions
# 2026.09.14-11:51:31.736091     0.000 >> 		learn_rate: 0.0009326403841108408
