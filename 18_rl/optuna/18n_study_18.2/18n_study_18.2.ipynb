# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 5 поколений по 6 млн шагов с последующим отбором чемпионов. Наследники этих чемпионов будут использоваться на следующем шаге.
#
# Данный эксперимент - это второй шаг. Здесь отпускаем агента в свободное плавание.
#
# Особенности:
# - `vision_head` из `18d_world_model_09`
# - **`vision_head.is_trainable=False`**
# - энкодер из чемпионов `18n_study_18.1`
# - **`encoder.is_trainable=True`**
# - механика повторяет 17-ых агентов
# - `prediction_coef=0.1`
# - `sequence_length=10`
# - `batch_size=128`
# - `vf_coef=0.2`

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    generations_count = 5
    generation_ind = 1
    generation_steps_count = 6_000_000
    all_generations_steps_count = generation_steps_count * generations_count
    learn_rate_range = (0.00025, 0.00025 * 0.1)
    ent_coef_range = (0.05, 0.05 * 0.1)
    ####
    
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False

    parent = optuna_trial.suggest_categorical('parent', [
        '18n_ppo_tr_frostbite_06:32',
        '18n_ppo_tr_frostbite_06:26',
        '18n_ppo_tr_frostbite_06:24',
        '18n_ppo_tr_frostbite_06:21',
        '18n_ppo_tr_frostbite_06:13',
        '18n_ppo_tr_frostbite_06:11',
        '18n_ppo_tr_frostbite_06:10',
    ])
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights=parent)
    HP.encoder.is_trainable = True

    HP.agent.parent = parent 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(500000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = None
    HP.video.capture_env_ram_patches = None
    HP.video.break_on_level_passed = False
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = generation_steps_count # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = None
    HP.ppo.rollout_env_ram_patches = None
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    learn_rate_change_speed = (learn_rate_range[1] - learn_rate_range[0]) / generations_count
    learn_rate_a = learn_rate_range[0] + learn_rate_change_speed * generation_ind
    learn_rate_b = learn_rate_a + learn_rate_change_speed
    HP.ppo.learn_rate = f'linear({learn_rate_a}, {learn_rate_b})'
    # HP.ppo.learn_rate = 'linear(0.00025, 0.00015)'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    ent_coef_change_speed = (ent_coef_range[1] - ent_coef_range[0]) / generations_count
    ent_coef_a = ent_coef_range[0] + ent_coef_change_speed * generation_ind
    ent_coef_b = ent_coef_a + ent_coef_change_speed
    HP.ppo.ent_coef = f'linear({ent_coef_a}, {ent_coef_b})' # coefficient of the entropy member within loss function
    # HP.ppo.ent_coef = 'linear(0.05, 0.03)' # coefficient of the entropy member within loss function
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Агенты уверенно доходят до уровня с медведями и там мрут. Причины: обычно остаётся одна жизнь, новые враги (жёлтые моллюски). Ну т.е. новая среда, в которой у агентов мало опыта.
#
# Чемпионы:
# - `18n_ppo_tr_frostbite_06/opt_18.2/45` (mean reward, optuna)
# - `18n_ppo_tr_frostbite_06/opt_18.2/40` (last reward)
# - `18n_ppo_tr_frostbite_06/opt_18.2/53` (стабильность прхождения)
#
# <img src="./img/levels_passed.png">
# <img src="./img/reward.png">
#
# **Выводы**:
# 1) дать больше жизней, чтобы набрались опыта
# 2) делать план обучения, как в 17-ых: заставить играть на дневном и ночном уровне с медведями

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_18.2/18n_study_18.2.ipynb',
#  'optuna_study_name': '18n_study_18.2',
#  'optuna_study_serial': '18.2',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_18.2/18n_study_18.2.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 20
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-18 22:59:25,540] A new study created in Journal with name: 18n_study_18.2
# 2026.09.18-22:59:25.813181     0.249 >> Model instance registered, version=35
# 2026.09.18-22:59:25.825660     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch35.ipynb"
# 2026.09.18-22:59:25.826104     0.004 >> 0.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:35"; running launches=1
# 2026.09.18-23:03:58.377874     0.189 >> Model instance registered, version=36
# 2026.09.18-23:03:58.391456     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch36.ipynb"
# 2026.09.18-23:03:58.391686     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:36"; running launches=2
# 2026.09.18-23:04:29.351177     0.187 >> Model instance registered, version=37
# 2026.09.18-23:04:29.363485     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch37.ipynb"
# 2026.09.18-23:04:29.363961     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:37"; running launches=3
# 2026.09.18-23:05:16.218385     0.225 >> Model instance registered, version=38
# 2026.09.18-23:05:16.233954     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch38.ipynb"
# 2026.09.18-23:05:16.234364     0.007 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:38"; running launches=4
# 2026.09.19-00:16:05.749063     1.908 >> Trial 0 (18n_ppo_tr_frostbite_06:35) finished with value: 3756.923076923077 and parameters: {'parent': '18n_ppo_tr_frostbite_06:26'}. Best is trial 0 with value: 3756.923076923077
# 2026.09.19-00:16:08.958842     0.002 >> Launch "18n_ppo_tr_frostbite_06:35" completed
# 2026.09.19-00:16:08.959677     0.001 >> 1 (+1) launches completed; running launches=3
# 2026.09.19-00:16:34.728457     0.190 >> Model instance registered, version=39
# 2026.09.19-00:16:34.742687     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:39"; running launches=4
# 2026.09.19-00:16:34.743029     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch39.ipynb"
# 2026.09.19-00:19:09.857258     1.374 >> Trial 2 (18n_ppo_tr_frostbite_06:37) finished with value: 3968.4615384615386 and parameters: {'parent': '18n_ppo_tr_frostbite_06:13'}. Best is trial 2 with value: 3968.4615384615386
# 2026.09.19-00:19:13.603438     0.002 >> Launch "18n_ppo_tr_frostbite_06:37" completed
# 2026.09.19-00:19:13.604369     0.001 >> 2 (+1) launches completed; running launches=3
# 2026.09.19-00:19:39.594249     0.186 >> Model instance registered, version=40
# 2026.09.19-00:19:39.606487     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:40"; running launches=4
# 2026.09.19-00:19:39.606630     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch40.ipynb"
# 2026.09.19-00:24:30.103116     3.348 >> Trial 1 (18n_ppo_tr_frostbite_06:36) finished with value: 4233.846153846154 and parameters: {'parent': '18n_ppo_tr_frostbite_06:32'}. Best is trial 1 with value: 4233.846153846154
# 2026.09.19-00:24:31.970003     0.003 >> Launch "18n_ppo_tr_frostbite_06:36" completed
# 2026.09.19-00:24:31.971018     0.001 >> 3 (+1) launches completed; running launches=3
# 2026.09.19-00:24:57.749811     0.182 >> Model instance registered, version=41
# 2026.09.19-00:24:57.758152     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:41"; running launches=4
# 2026.09.19-00:24:57.758372     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch41.ipynb"
# 2026.09.19-00:26:15.626819     1.129 >> Trial 3 (18n_ppo_tr_frostbite_06:38) finished with value: 4440.0 and parameters: {'parent': '18n_ppo_tr_frostbite_06:24'}. Best is trial 3 with value: 4440.0
# 2026.09.19-00:26:19.615384     0.002 >> Launch "18n_ppo_tr_frostbite_06:38" completed
# 2026.09.19-00:26:19.616201     0.001 >> 4 (+1) launches completed; running launches=3
# 2026.09.19-00:26:45.417675     0.213 >> Model instance registered, version=42
# 2026.09.19-00:26:45.432238     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:42"; running launches=4
# 2026.09.19-00:26:45.432389     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch42.ipynb"
# 2026.09.19-01:32:01.925985     4.472 >> Trial 4 (18n_ppo_tr_frostbite_06:39) finished with value: 4426.153846153846 and parameters: {'parent': '18n_ppo_tr_frostbite_06:10'}. Best is trial 3 with value: 4440.0
# 2026.09.19-01:32:02.569342     0.003 >> Launch "18n_ppo_tr_frostbite_06:39" completed
# 2026.09.19-01:32:02.570148     0.001 >> 5 (+1) launches completed; running launches=3
# 2026.09.19-01:32:28.333928     0.183 >> Model instance registered, version=43
# 2026.09.19-01:32:28.344149     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:43"; running launches=4
# 2026.09.19-01:32:28.344274     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch43.ipynb"
# 2026.09.19-01:35:39.306900     0.989 >> Trial 5 (18n_ppo_tr_frostbite_06:40) finished with value: 4837.692307692308 and parameters: {'parent': '18n_ppo_tr_frostbite_06:10'}. Best is trial 5 with value: 4837.692307692308
# 2026.09.19-01:35:43.434262     0.002 >> Launch "18n_ppo_tr_frostbite_06:40" completed
# 2026.09.19-01:35:43.435521     0.001 >> 6 (+1) launches completed; running launches=3
# 2026.09.19-01:36:09.206495     0.200 >> Model instance registered, version=44
# 2026.09.19-01:36:09.219354     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:44"; running launches=4
# 2026.09.19-01:36:09.219484     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch44.ipynb"
# 2026.09.19-01:44:33.417508     0.274 >> Trial 6 (18n_ppo_tr_frostbite_06:41) finished with value: 4075.3846153846152 and parameters: {'parent': '18n_ppo_tr_frostbite_06:13'}. Best is trial 5 with value: 4837.692307692308
# 2026.09.19-01:44:38.268782     0.002 >> Launch "18n_ppo_tr_frostbite_06:41" completed
# 2026.09.19-01:44:38.269957     0.001 >> 7 (+1) launches completed; running launches=3
# 2026.09.19-01:44:58.971544     0.213 >> Model instance registered, version=45
# 2026.09.19-01:44:58.987666     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:45"; running launches=4
# 2026.09.19-01:44:58.987939     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch45.ipynb"
# 2026.09.19-01:46:26.754114     0.813 >> Trial 7 (18n_ppo_tr_frostbite_06:42) finished with value: 4106.153846153846 and parameters: {'parent': '18n_ppo_tr_frostbite_06:21'}. Best is trial 5 with value: 4837.692307692308
# 2026.09.19-01:46:31.055674     0.001 >> Launch "18n_ppo_tr_frostbite_06:42" completed
# 2026.09.19-01:46:31.056436     0.001 >> 8 (+1) launches completed; running launches=3
# 2026.09.19-01:46:56.929078     0.185 >> Model instance registered, version=46
# 2026.09.19-01:46:56.938182     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:46"; running launches=4
# 2026.09.19-01:46:56.938310     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch46.ipynb"
# 2026.09.19-02:49:15.342678     0.939 >> Trial 8 (18n_ppo_tr_frostbite_06:43) finished with value: 4363.076923076923 and parameters: {'parent': '18n_ppo_tr_frostbite_06:13'}. Best is trial 5 with value: 4837.692307692308
# 2026.09.19-02:49:19.520171     0.001 >> Launch "18n_ppo_tr_frostbite_06:43" completed
# 2026.09.19-02:49:19.520656     0.000 >> 9 (+1) launches completed; running launches=3
# 2026.09.19-02:49:45.325716     0.177 >> Model instance registered, version=47
# 2026.09.19-02:49:45.334849     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:47"; running launches=4
# 2026.09.19-02:49:45.335000     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch47.ipynb"
# 2026.09.19-02:51:20.142951     2.628 >> Trial 9 (18n_ppo_tr_frostbite_06:44) finished with value: 4961.538461538462 and parameters: {'parent': '18n_ppo_tr_frostbite_06:11'}. Best is trial 9 with value: 4961.538461538462
# 2026.09.19-02:51:22.632994     0.002 >> Launch "18n_ppo_tr_frostbite_06:44" completed
# 2026.09.19-02:51:22.634185     0.001 >> 10 (+1) launches completed; running launches=3
# 2026.09.19-02:51:48.394268     0.183 >> Model instance registered, version=48
# 2026.09.19-02:51:48.409256     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:48"; running launches=4
# 2026.09.19-02:51:48.409482     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch48.ipynb"
# 2026.09.19-03:04:58.713098     4.554 >> Trial 10 (18n_ppo_tr_frostbite_06:45) finished with value: 5326.153846153846 and parameters: {'parent': '18n_ppo_tr_frostbite_06:32'}. Best is trial 10 with value: 5326.153846153846
# 2026.09.19-03:04:59.277134     0.003 >> Launch "18n_ppo_tr_frostbite_06:45" completed
# 2026.09.19-03:04:59.277996     0.001 >> 11 (+1) launches completed; running launches=3
# 2026.09.19-03:05:25.239067     0.186 >> Model instance registered, version=49
# 2026.09.19-03:05:25.250511     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:49"; running launches=4
# 2026.09.19-03:05:25.250665     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch49.ipynb"
# 2026.09.19-03:06:04.736131     3.689 >> Trial 11 (18n_ppo_tr_frostbite_06:46) finished with value: 4009.230769230769 and parameters: {'parent': '18n_ppo_tr_frostbite_06:21'}. Best is trial 10 with value: 5326.153846153846
# 2026.09.19-03:06:06.155246     0.001 >> Launch "18n_ppo_tr_frostbite_06:46" completed
# 2026.09.19-03:06:06.155672     0.000 >> 12 (+1) launches completed; running launches=3
# 2026.09.19-03:06:32.167144     0.229 >> Model instance registered, version=50
# 2026.09.19-03:06:32.181683     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:50"; running launches=4
# 2026.09.19-03:06:32.181869     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch50.ipynb"
# 2026.09.19-04:05:48.527813     4.296 >> Trial 12 (18n_ppo_tr_frostbite_06:47) finished with value: 4437.692307692308 and parameters: {'parent': '18n_ppo_tr_frostbite_06:21'}. Best is trial 10 with value: 5326.153846153846
# 2026.09.19-04:05:49.406009     0.003 >> Launch "18n_ppo_tr_frostbite_06:47" completed
# 2026.09.19-04:05:49.406843     0.001 >> 13 (+1) launches completed; running launches=3
# 2026.09.19-04:06:15.277174     0.212 >> Model instance registered, version=51
# 2026.09.19-04:06:15.288309     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:51"; running launches=4
# 2026.09.19-04:06:15.288435     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch51.ipynb"
# 2026.09.19-04:07:51.192310     3.559 >> Trial 13 (18n_ppo_tr_frostbite_06:48) finished with value: 4558.461538461538 and parameters: {'parent': '18n_ppo_tr_frostbite_06:11'}. Best is trial 10 with value: 5326.153846153846
# 2026.09.19-04:07:52.750508     0.002 >> Launch "18n_ppo_tr_frostbite_06:48" completed
# 2026.09.19-04:07:52.751530     0.001 >> 14 (+1) launches completed; running launches=3
# 2026.09.19-04:08:18.658909     0.181 >> Model instance registered, version=52
# 2026.09.19-04:08:18.668314     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:52"; running launches=4
# 2026.09.19-04:08:18.668542     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch52.ipynb"
# 2026.09.19-04:24:06.534818     4.346 >> Trial 14 (18n_ppo_tr_frostbite_06:49) finished with value: 5008.461538461538 and parameters: {'parent': '18n_ppo_tr_frostbite_06:11'}. Best is trial 10 with value: 5326.153846153846
# 2026.09.19-04:24:07.356995     0.003 >> Launch "18n_ppo_tr_frostbite_06:49" completed
# 2026.09.19-04:24:07.358024     0.001 >> 15 (+1) launches completed; running launches=3
# 2026.09.19-04:24:33.110414     0.182 >> Model instance registered, version=53
# 2026.09.19-04:24:33.124426     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:53"; running launches=4
# 2026.09.19-04:24:33.124689     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch53.ipynb"
# 2026.09.19-04:25:07.948323     4.128 >> Trial 15 (18n_ppo_tr_frostbite_06:50) finished with value: 5016.153846153846 and parameters: {'parent': '18n_ppo_tr_frostbite_06:11'}. Best is trial 10 with value: 5326.153846153846
# 2026.09.19-04:25:08.940073     0.001 >> Launch "18n_ppo_tr_frostbite_06:50" completed
# 2026.09.19-04:25:08.941013     0.001 >> 16 (+1) launches completed; running launches=3
# 2026.09.19-04:25:34.839606     0.190 >> Model instance registered, version=54
# 2026.09.19-04:25:34.851365     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:54"; running launches=4
# 2026.09.19-04:25:34.851486     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch54.ipynb"
# 2026.09.19-05:23:11.504358     1.759 >> Trial 16 (18n_ppo_tr_frostbite_06:51) finished with value: 3894.6153846153848 and parameters: {'parent': '18n_ppo_tr_frostbite_06:11'}. Best is trial 10 with value: 5326.153846153846
# 2026.09.19-05:23:14.863471     0.002 >> Launch "18n_ppo_tr_frostbite_06:51" completed
# 2026.09.19-05:23:14.864304     0.001 >> 17 (+1) launches completed; running launches=3
# 2026.09.19-05:24:28.453472     1.881 >> Trial 17 (18n_ppo_tr_frostbite_06:52) finished with value: 4209.2307692307695 and parameters: {'parent': '18n_ppo_tr_frostbite_06:32'}. Best is trial 10 with value: 5326.153846153846
# 2026.09.19-05:24:31.691643     0.002 >> Launch "18n_ppo_tr_frostbite_06:52" completed
# 2026.09.19-05:24:31.692472     0.001 >> 18 (+1) launches completed; running launches=2
# 2026.09.19-05:43:30.387931     4.268 >> Trial 18 (18n_ppo_tr_frostbite_06:53) finished with value: 4864.615384615385 and parameters: {'parent': '18n_ppo_tr_frostbite_06:32'}. Best is trial 10 with value: 5326.153846153846
# 2026.09.19-05:43:31.237190     0.002 >> Launch "18n_ppo_tr_frostbite_06:53" completed
# 2026.09.19-05:43:31.237979     0.001 >> 19 (+1) launches completed; running launches=1
# 2026.09.19-05:44:35.100738     1.296 >> Trial 19 (18n_ppo_tr_frostbite_06:54) finished with value: 4056.923076923077 and parameters: {'parent': '18n_ppo_tr_frostbite_06:32'}. Best is trial 10 with value: 5326.153846153846
# 2026.09.19-05:44:38.924091     0.002 >> Launch "18n_ppo_tr_frostbite_06:54" completed
# 2026.09.19-05:44:38.925198     0.001 >> 20 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-19 05:44:43,949] Using an existing study with name '18n_study_18.2' instead of creating a new one.
# 2026.09.19-05:44:43.950803     5.026 >> Study statistics:
# 2026.09.19-05:44:43.952129     0.001 >> 	Number of finished trials: 20
# 2026.09.19-05:44:43.952571     0.000 >> 	Number of pruned trials: 0
# 2026.09.19-05:44:43.952848     0.000 >> 	Number of complete trials: 20
# 2026.09.19-05:44:43.953871     0.001 >> Best trial:
# 2026.09.19-05:44:43.954390     0.001 >> 	Value: 5326.153846153846
# 2026.09.19-05:44:43.954686     0.000 >> 	Model version: 45
# 2026.09.19-05:44:43.955059     0.000 >> 	Params:
# 2026.09.19-05:44:43.955354     0.000 >> 		parent: 18n_ppo_tr_frostbite_06:32
