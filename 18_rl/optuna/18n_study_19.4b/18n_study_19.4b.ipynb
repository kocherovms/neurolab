# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 6 шагов. На каждом шаге отбираем чемпионов для продолжения след. шага.
#
# Данный эксперимент - это четвёртый шаг. Здесь хотим срезать углы и сразу играть с 9-ью жизнями, чтобы пройти 5-ый уровень!

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False

    parent = optuna_trial.suggest_categorical('parent', [
        '18n_ppo_tr_frostbite_06:458',
        '18n_ppo_tr_frostbite_06:464',
        '18n_ppo_tr_frostbite_06:465',
    ])
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights=parent)
    HP.encoder.is_trainable = True

    HP.agent.parent = parent 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(300000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = None
    HP.video.capture_env_ram_patches = None
    HP.video.break_on_level_passed = False
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = 3_000_000 # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = None
    HP.ppo.rollout_env_ram_patches = [
        ['nine_lives'], 
    ]

    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    HP.ppo.learn_rate = f'const({0.00025 - 0.0002 / 6 * 3})'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    HP.ppo.ent_coef = f'const({0.05 - 0.04 / 6 * 3})'
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# Гипотеза частично подтвердилась. Пусть не очень стабильно, но 5 уровней уже можно выжать и на этом шаге! Видимо, всё таки не хватает опыта, чтобы более стабильно было.
#
# С другой стороны, мне и не нужны абсолютники. Моя цель - получить пайплайн, с которым можно быстро разные изменения модели проверять. Бенчмарк. Если стало лучше, значит, берём. Нет - копаем дальше. Поэтому в принципе и такой пайплайн сойдёт.
#
# <img src="./img/score.png">
# <img src="./img/episode_r.png">
# <img src="./img/episode_lp.png">
#
# **Выводы**
# 1) в принципе можно взять 4-х шаговку

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.4b/18n_study_19.4b.ipynb',
#  'optuna_study_name': '18n_study_19.4b',
#  'optuna_study_serial': '19.4b',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.4b/18n_study_19.4b.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 30
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-24 10:36:15,616] A new study created in Journal with name: 18n_study_19.4b
# 2026.09.24-10:36:15.978468     0.233 >> Model instance registered, version=631
# 2026.09.24-10:36:15.998800     0.008 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch631.ipynb"
# 2026.09.24-10:36:15.999793     0.009 >> 6.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:631"; running launches=1
# 2026.09.24-10:36:47.199953     0.238 >> Model instance registered, version=632
# 2026.09.24-10:36:47.214011     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch632.ipynb"
# 2026.09.24-10:36:47.214471     0.007 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:632"; running launches=2
# 2026.09.24-10:37:18.119444     0.215 >> Model instance registered, version=633
# 2026.09.24-10:37:18.133216     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch633.ipynb"
# 2026.09.24-10:37:18.134121     0.006 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:633"; running launches=3
# 2026.09.24-10:37:49.016566     0.199 >> Model instance registered, version=634
# 2026.09.24-10:37:49.026124     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch634.ipynb"
# 2026.09.24-10:37:49.026842     0.005 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:634"; running launches=4
# 2026.09.24-10:38:20.049510     0.206 >> Model instance registered, version=635
# 2026.09.24-10:38:20.059066     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch635.ipynb"
# 2026.09.24-10:38:20.059532     0.005 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:635"; running launches=5
# 2026.09.24-10:38:51.002840     0.245 >> Model instance registered, version=636
# 2026.09.24-10:38:51.016464     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch636.ipynb"
# 2026.09.24-10:38:51.017317     0.001 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:636"; running launches=6
# 2026.09.24-11:20:57.917082     3.961 >> Trial 0 (18n_ppo_tr_frostbite_06:631) finished with value: 50304.00023085399 and parameters: {'parent': '18n_ppo_tr_frostbite_06:465'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-11:20:59.071817     0.001 >> Launch "18n_ppo_tr_frostbite_06:631" completed
# 2026.09.24-11:20:59.072522     0.001 >> 1 (+1) launches completed; running launches=5
# 2026.09.24-11:21:24.856203     0.211 >> Model instance registered, version=637
# 2026.09.24-11:21:24.871162     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:637"; running launches=6
# 2026.09.24-11:21:24.871457     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch637.ipynb"
# 2026.09.24-11:21:30.394832     0.416 >> Trial 1 (18n_ppo_tr_frostbite_06:632) finished with value: 40404.000257105814 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-11:21:35.094779     0.002 >> Launch "18n_ppo_tr_frostbite_06:632" completed
# 2026.09.24-11:21:35.095957     0.001 >> 2 (+1) launches completed; running launches=5
# 2026.09.24-11:21:55.839957     0.219 >> Model instance registered, version=638
# 2026.09.24-11:21:55.848655     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:638"; running launches=6
# 2026.09.24-11:21:55.848803     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch638.ipynb"
# 2026.09.24-11:22:17.566219     1.253 >> Trial 2 (18n_ppo_tr_frostbite_06:633) finished with value: 30304.00023597472 and parameters: {'parent': '18n_ppo_tr_frostbite_06:465'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-11:22:21.428890     0.002 >> Launch "18n_ppo_tr_frostbite_06:633" completed
# 2026.09.24-11:22:21.429836     0.001 >> 3 (+1) launches completed; running launches=5
# 2026.09.24-11:22:47.379104     0.209 >> Model instance registered, version=639
# 2026.09.24-11:22:47.394346     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:639"; running launches=6
# 2026.09.24-11:22:47.394632     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch639.ipynb"
# 2026.09.24-11:26:28.364393     5.541 >> Trial 3 (18n_ppo_tr_frostbite_06:634) finished with value: 40303.00021526495 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-11:26:28.379086     0.001 >> Launch "18n_ppo_tr_frostbite_06:634" completed
# 2026.09.24-11:26:28.379738     0.001 >> 4 (+1) launches completed; running launches=5
# 2026.09.24-11:26:54.165494     0.212 >> Model instance registered, version=640
# 2026.09.24-11:26:54.177731     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:640"; running launches=6
# 2026.09.24-11:26:54.177863     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch640.ipynb"
# 2026.09.24-11:26:56.670798     2.493 >> Trial 4 (18n_ppo_tr_frostbite_06:635) finished with value: 40204.00022291363 and parameters: {'parent': '18n_ppo_tr_frostbite_06:465'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-11:26:59.285332     0.001 >> Launch "18n_ppo_tr_frostbite_06:635" completed
# 2026.09.24-11:26:59.285835     0.001 >> 5 (+1) launches completed; running launches=5
# 2026.09.24-11:27:25.311137     0.206 >> Model instance registered, version=641
# 2026.09.24-11:27:25.326439     0.007 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:641"; running launches=6
# 2026.09.24-11:27:25.326751     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch641.ipynb"
# 2026.09.24-11:27:58.756765     2.727 >> Trial 5 (18n_ppo_tr_frostbite_06:636) finished with value: 40304.00025992546 and parameters: {'parent': '18n_ppo_tr_frostbite_06:465'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-11:28:01.141010     0.001 >> Launch "18n_ppo_tr_frostbite_06:636" completed
# 2026.09.24-11:28:01.141592     0.001 >> 6 (+1) launches completed; running launches=5
# 2026.09.24-11:28:26.912857     0.205 >> Model instance registered, version=642
# 2026.09.24-11:28:26.922193     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:642"; running launches=6
# 2026.09.24-11:28:26.922814     0.001 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch642.ipynb"
# 2026.09.24-12:06:41.729010     5.041 >> Trial 6 (18n_ppo_tr_frostbite_06:637) finished with value: 40304.000248711716 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-12:06:41.806487     0.002 >> Launch "18n_ppo_tr_frostbite_06:637" completed
# 2026.09.24-12:06:41.807587     0.001 >> 7 (+1) launches completed; running launches=5
# 2026.09.24-12:07:08.001173     0.223 >> Model instance registered, version=643
# 2026.09.24-12:07:08.013239     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:643"; running launches=6
# 2026.09.24-12:07:08.013416     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch643.ipynb"
# 2026.09.24-12:07:24.951851     1.578 >> Trial 7 (18n_ppo_tr_frostbite_06:638) finished with value: 40404.00026802787 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-12:07:28.551724     0.003 >> Launch "18n_ppo_tr_frostbite_06:638" completed
# 2026.09.24-12:07:28.553068     0.001 >> 8 (+1) launches completed; running launches=5
# 2026.09.24-12:07:54.394830     0.214 >> Model instance registered, version=644
# 2026.09.24-12:07:54.403955     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:644"; running launches=6
# 2026.09.24-12:07:54.404089     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch644.ipynb"
# 2026.09.24-12:08:25.601480     0.417 >> Trial 8 (18n_ppo_tr_frostbite_06:639) finished with value: 40303.00024725328 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-12:08:30.306678     0.002 >> Launch "18n_ppo_tr_frostbite_06:639" completed
# 2026.09.24-12:08:30.307640     0.001 >> 9 (+1) launches completed; running launches=5
# 2026.09.24-12:08:50.983728     0.212 >> Model instance registered, version=645
# 2026.09.24-12:08:50.997089     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:645"; running launches=6
# 2026.09.24-12:08:50.997225     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch645.ipynb"
# 2026.09.24-12:15:32.672437     1.799 >> Trial 9 (18n_ppo_tr_frostbite_06:640) finished with value: 30404.000236655324 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-12:15:35.989949     0.002 >> Launch "18n_ppo_tr_frostbite_06:640" completed
# 2026.09.24-12:15:35.990985     0.001 >> 10 (+1) launches completed; running launches=5
# 2026.09.24-12:16:01.786986     0.216 >> Model instance registered, version=646
# 2026.09.24-12:16:01.799331     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:646"; running launches=6
# 2026.09.24-12:16:01.799497     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch646.ipynb"
# 2026.09.24-12:16:41.071397     3.483 >> Trial 10 (18n_ppo_tr_frostbite_06:641) finished with value: 40404.00025461028 and parameters: {'parent': '18n_ppo_tr_frostbite_06:465'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-12:16:42.704404     0.002 >> Launch "18n_ppo_tr_frostbite_06:641" completed
# 2026.09.24-12:16:42.705241     0.001 >> 11 (+1) launches completed; running launches=5
# 2026.09.24-12:17:08.500813     0.229 >> Model instance registered, version=647
# 2026.09.24-12:17:08.514679     0.006 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:647"; running launches=6
# 2026.09.24-12:17:08.514823     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch647.ipynb"
# 2026.09.24-12:17:15.558938     1.931 >> Trial 11 (18n_ppo_tr_frostbite_06:642) finished with value: 30203.00021063037 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-12:17:18.743282     0.001 >> Launch "18n_ppo_tr_frostbite_06:642" completed
# 2026.09.24-12:17:18.744141     0.001 >> 12 (+1) launches completed; running launches=5
# 2026.09.24-12:17:39.549831     0.286 >> Model instance registered, version=648
# 2026.09.24-12:17:39.562384     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:648"; running launches=6
# 2026.09.24-12:17:39.562759     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch648.ipynb"
# 2026.09.24-12:52:04.295681     0.293 >> Trial 12 (18n_ppo_tr_frostbite_06:643) finished with value: 30404.000267120402 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-12:52:09.119610     0.001 >> Launch "18n_ppo_tr_frostbite_06:643" completed
# 2026.09.24-12:52:09.120372     0.001 >> 13 (+1) launches completed; running launches=5
# 2026.09.24-12:52:29.855504     0.232 >> Model instance registered, version=649
# 2026.09.24-12:52:29.864092     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:649"; running launches=6
# 2026.09.24-12:52:29.864360     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch649.ipynb"
# 2026.09.24-12:53:45.757734     3.736 >> Trial 14 (18n_ppo_tr_frostbite_06:645) finished with value: 40403.000185610115 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-12:53:47.138139     0.001 >> Launch "18n_ppo_tr_frostbite_06:645" completed
# 2026.09.24-12:53:47.138810     0.001 >> 14 (+1) launches completed; running launches=5
# 2026.09.24-12:53:56.106145     3.851 >> Trial 13 (18n_ppo_tr_frostbite_06:644) finished with value: 40403.00020123157 and parameters: {'parent': '18n_ppo_tr_frostbite_06:465'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-12:53:57.376871     0.002 >> Launch "18n_ppo_tr_frostbite_06:644" completed
# 2026.09.24-12:53:57.377948     0.001 >> 15 (+1) launches completed; running launches=4
# 2026.09.24-12:54:12.964257     0.237 >> Model instance registered, version=650
# 2026.09.24-12:54:12.974052     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:650"; running launches=5
# 2026.09.24-12:54:12.974169     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch650.ipynb"
# 2026.09.24-12:54:44.472273     0.424 >> Model instance registered, version=651
# 2026.09.24-12:54:44.489128     0.007 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:651"; running launches=6
# 2026.09.24-12:54:44.489513     0.007 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch651.ipynb"
# 2026.09.24-13:05:19.650768     3.776 >> Trial 15 (18n_ppo_tr_frostbite_06:646) finished with value: 30304.000195689514 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-13:05:20.995808     0.002 >> Launch "18n_ppo_tr_frostbite_06:646" completed
# 2026.09.24-13:05:20.996664     0.001 >> 16 (+1) launches completed; running launches=5
# 2026.09.24-13:05:46.839690     0.242 >> Model instance registered, version=652
# 2026.09.24-13:05:46.849869     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:652"; running launches=6
# 2026.09.24-13:05:46.849968     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch652.ipynb"
# 2026.09.24-13:05:52.723116     0.409 >> Trial 16 (18n_ppo_tr_frostbite_06:647) finished with value: 30303.0001979906 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 0 with value: 50304.00023085399
# 2026.09.24-13:05:57.430640     0.002 >> Launch "18n_ppo_tr_frostbite_06:647" completed
# 2026.09.24-13:05:57.431434     0.001 >> 17 (+1) launches completed; running launches=5
# 2026.09.24-13:06:18.153101     0.249 >> Model instance registered, version=653
# 2026.09.24-13:06:18.166604     0.005 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:653"; running launches=6
# 2026.09.24-13:06:18.166727     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch653.ipynb"
# 2026.09.24-13:06:53.927635     5.067 >> Trial 17 (18n_ppo_tr_frostbite_06:648) finished with value: 50403.00026608329 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 17 with value: 50403.00026608329
# 2026.09.24-13:06:53.975436     0.001 >> Launch "18n_ppo_tr_frostbite_06:648" completed
# 2026.09.24-13:06:53.976128     0.001 >> 18 (+1) launches completed; running launches=5
# 2026.09.24-13:07:19.788861     0.234 >> Model instance registered, version=654
# 2026.09.24-13:07:19.801889     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:654"; running launches=6
# 2026.09.24-13:07:19.801983     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch654.ipynb"
# 2026.09.24-13:37:38.974751     2.557 >> Trial 18 (18n_ppo_tr_frostbite_06:649) finished with value: 40404.00020748663 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 17 with value: 50403.00026608329
# 2026.09.24-13:37:41.535762     0.003 >> Launch "18n_ppo_tr_frostbite_06:649" completed
# 2026.09.24-13:37:41.537670     0.002 >> 19 (+1) launches completed; running launches=5
# 2026.09.24-13:38:07.772878     0.237 >> Model instance registered, version=655
# 2026.09.24-13:38:07.783157     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:655"; running launches=6
# 2026.09.24-13:38:07.783292     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch655.ipynb"
# 2026.09.24-13:39:09.022087     4.856 >> Trial 19 (18n_ppo_tr_frostbite_06:650) finished with value: 40403.000227353754 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 17 with value: 50403.00026608329
# 2026.09.24-13:39:09.284762     0.002 >> Launch "18n_ppo_tr_frostbite_06:650" completed
# 2026.09.24-13:39:09.285690     0.001 >> 20 (+1) launches completed; running launches=5
# 2026.09.24-13:39:35.088883     0.235 >> Model instance registered, version=656
# 2026.09.24-13:39:35.097910     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:656"; running launches=6
# 2026.09.24-13:39:35.098030     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch656.ipynb"
# 2026.09.24-13:41:01.137753     4.181 >> Trial 20 (18n_ppo_tr_frostbite_06:651) finished with value: 30404.000231469778 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 17 with value: 50403.00026608329
# 2026.09.24-13:41:02.072701     0.001 >> Launch "18n_ppo_tr_frostbite_06:651" completed
# 2026.09.24-13:41:02.073726     0.001 >> 21 (+1) launches completed; running launches=5
# 2026.09.24-13:41:27.863252     0.205 >> Model instance registered, version=657
# 2026.09.24-13:41:27.874652     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:657"; running launches=6
# 2026.09.24-13:41:27.874782     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch657.ipynb"
# 2026.09.24-13:54:51.267142     0.722 >> Trial 21 (18n_ppo_tr_frostbite_06:652) finished with value: 40304.00019338843 and parameters: {'parent': '18n_ppo_tr_frostbite_06:465'}. Best is trial 17 with value: 50403.00026608329
# 2026.09.24-13:54:55.661138     0.001 >> Launch "18n_ppo_tr_frostbite_06:652" completed
# 2026.09.24-13:54:55.661869     0.001 >> 22 (+1) launches completed; running launches=5
# 2026.09.24-13:55:21.629032     0.210 >> Model instance registered, version=658
# 2026.09.24-13:55:21.642699     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:658"; running launches=6
# 2026.09.24-13:55:21.642810     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch658.ipynb"
# 2026.09.24-13:56:18.515423     0.346 >> Trial 22 (18n_ppo_tr_frostbite_06:653) finished with value: 40404.000248031116 and parameters: {'parent': '18n_ppo_tr_frostbite_06:465'}. Best is trial 17 with value: 50403.00026608329
# 2026.09.24-13:56:23.289403     0.002 >> Launch "18n_ppo_tr_frostbite_06:653" completed
# 2026.09.24-13:56:23.290291     0.001 >> 23 (+1) launches completed; running launches=5
# 2026.09.24-13:56:44.024113     0.206 >> Model instance registered, version=659
# 2026.09.24-13:56:44.036756     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:659"; running launches=6
# 2026.09.24-13:56:44.036936     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch659.ipynb"
# 2026.09.24-13:57:38.417857     3.037 >> Trial 23 (18n_ppo_tr_frostbite_06:654) finished with value: 30403.000214778804 and parameters: {'parent': '18n_ppo_tr_frostbite_06:458'}. Best is trial 17 with value: 50403.00026608329
# 2026.09.24-13:57:40.498084     0.001 >> Launch "18n_ppo_tr_frostbite_06:654" completed
# 2026.09.24-13:57:40.498831     0.001 >> 24 (+1) launches completed; running launches=5
# 2026.09.24-13:58:06.431056     0.219 >> Model instance registered, version=660
# 2026.09.24-13:58:06.444522     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:660"; running launches=6
# 2026.09.24-13:58:06.444647     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch660.ipynb"
# 2026.09.24-14:23:08.805300     2.429 >> Trial 24 (18n_ppo_tr_frostbite_06:655) finished with value: 40404.00023146978 and parameters: {'parent': '18n_ppo_tr_frostbite_06:465'}. Best is trial 17 with value: 50403.00026608329
# 2026.09.24-14:23:11.493168     0.002 >> Launch "18n_ppo_tr_frostbite_06:655" completed
# 2026.09.24-14:23:11.493984     0.001 >> 25 (+1) launches completed; running launches=5
# 2026.09.24-14:24:03.356001     0.286 >> Trial 25 (18n_ppo_tr_frostbite_06:656) finished with value: 40404.00021127856 and parameters: {'parent': '18n_ppo_tr_frostbite_06:465'}. Best is trial 17 with value: 50403.00026608329
# 2026.09.24-14:24:08.187236     0.002 >> Launch "18n_ppo_tr_frostbite_06:656" completed
# 2026.09.24-14:24:08.188041     0.001 >> 26 (+1) launches completed; running launches=4
# 2026.09.24-14:26:13.695710     2.340 >> Trial 26 (18n_ppo_tr_frostbite_06:657) finished with value: 40404.00021520013 and parameters: {'parent': '18n_ppo_tr_frostbite_06:465'}. Best is trial 17 with value: 50403.00026608329
# 2026.09.24-14:26:16.473233     0.002 >> Launch "18n_ppo_tr_frostbite_06:657" completed
# 2026.09.24-14:26:16.474175     0.001 >> 27 (+1) launches completed; running launches=3
# 2026.09.24-14:44:01.846668     1.719 >> Trial 27 (18n_ppo_tr_frostbite_06:658) finished with value: 40303.00025428618 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 17 with value: 50403.00026608329
# 2026.09.24-14:44:05.245637     0.002 >> Launch "18n_ppo_tr_frostbite_06:658" completed
# 2026.09.24-14:44:05.246427     0.001 >> 28 (+1) launches completed; running launches=2
# 2026.09.24-14:44:51.705833     0.365 >> Trial 28 (18n_ppo_tr_frostbite_06:659) finished with value: 40504.00023830822 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 17 with value: 50403.00026608329
# 2026.09.24-14:44:56.461829     0.002 >> Launch "18n_ppo_tr_frostbite_06:659" completed
# 2026.09.24-14:44:56.462713     0.001 >> 29 (+1) launches completed; running launches=1
# 2026.09.24-14:46:40.268989     1.457 >> Trial 29 (18n_ppo_tr_frostbite_06:660) finished with value: 40303.00021766326 and parameters: {'parent': '18n_ppo_tr_frostbite_06:464'}. Best is trial 17 with value: 50403.00026608329
# 2026.09.24-14:46:43.928966     0.002 >> Launch "18n_ppo_tr_frostbite_06:660" completed
# 2026.09.24-14:46:43.929909     0.001 >> 30 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-24 14:46:48,969] Using an existing study with name '18n_study_19.4b' instead of creating a new one.
# 2026.09.24-14:46:48.973290     5.043 >> Study statistics:
# 2026.09.24-14:46:48.977234     0.004 >> 	Number of finished trials: 30
# 2026.09.24-14:46:48.978286     0.001 >> 	Number of pruned trials: 0
# 2026.09.24-14:46:48.979080     0.001 >> 	Number of complete trials: 30
# 2026.09.24-14:46:48.980178     0.001 >> Best trial:
# 2026.09.24-14:46:48.981577     0.001 >> 	Value: 50403.00026608329
# 2026.09.24-14:46:48.982217     0.001 >> 	Model version: 648
# 2026.09.24-14:46:48.982970     0.001 >> 	Params:
# 2026.09.24-14:46:48.983587     0.001 >> 		parent: 18n_ppo_tr_frostbite_06:458
