# %% [markdown]
# # Goal
#
# Серия экспериментов. Треним за 6 шагов. На каждом шаге отбираем чемпионов для продолжения след. шага.
#
# Данный эксперимент - это шестой шаг. Здесь агент 80% играет на пятом уровне с train RAM-ами, и по 5% с первого/второго/третьего/четвёртого.

# %% [markdown]
# # TARGET_NOTEBOOK_FNAME

# %%
TARGET_NOTEBOOK_FNAME = '18n_ppo_tr_frostbite_06.ipynb'

# %% [markdown]
# # GRID_SEARCH_SPACE

# %%
# @launchit.collect
# GRID_SEARCH_SPACE = dict(
# )

# %% [markdown]
# # set_hyperparameters

# %%
# @launchit.collect
def set_hyperparameters(HP, optuna_study, optuna_trial):
    import random
    HP.general.random_seed = random.randint(1, 100)
    HP.general.is_torch_deterministic = True
    HP.general.is_torch_compile = True
    HP.general.is_torch_amp = True
    
    HP.env.count = 32 
    HP.env.is_episodic_life = True
    HP.env.actions_count = 6

    HP.vision_head.parent = dict(model='18d_world_model_09:40', weights='18d_world_model_09:40')
    HP.vision_head.is_trainable = False

    parent = optuna_trial.suggest_categorical('parent', [
        '18n_ppo_tr_frostbite_06:521',
        '18n_ppo_tr_frostbite_06:494',
        '18n_ppo_tr_frostbite_06:519',
    ])
    
    HP.encoder.parent = dict(model='18d_world_model_09:40', weights=parent)
    HP.encoder.is_trainable = True

    HP.agent.parent = parent 
    HP.agent.sequence_length = 4
    HP.agent.action_plan_length = 10 
    HP.agent.d_model = 256 
    HP.agent.transformer = dict(layers_count=3, heads_count=4, attention_backend=['EFFICIENT_ATTENTION', 'MATH'])
    HP.agent.is_trainable = True
    
    # Video params
    HP.video.capture_policy = 'every(200000)' # video capture policy depending on steps
    HP.video.capture_preprocessed_obs = False
    HP.video.capture_env_rams = None
    HP.video.capture_env_ram_patches = None
    HP.video.break_on_level_passed = False
    
    # Training procedure params (PPO related) 
    HP.ppo.global_steps_count = 3_000_000 # total number of steps 
    HP.ppo.rollout_steps_count = 512 # how many steps to run in a single policy rolllout
    HP.ppo.rollout_env_rams = [
        'com.develorium.neurolab.frostbite_ram:level1:1:cls=none', # 0
        'com.develorium.neurolab.frostbite_ram:level2:1:cls=none', # 1
        'com.develorium.neurolab.frostbite_ram:level3:1:cls=none', # 2
        'com.develorium.neurolab.frostbite_ram:level4:1:cls=none', # 3
        
        'com.develorium.neurolab.frostbite_ram:level5:1:cls=train1', # 4
        'com.develorium.neurolab.frostbite_ram:level5:1:cls=train2', # 5
        'com.develorium.neurolab.frostbite_ram:level5:1:cls=train3', # 6
        'com.develorium.neurolab.frostbite_ram:level5:1:cls=train4', # 7
        'com.develorium.neurolab.frostbite_ram:level5:1:cls=train5', # 8
    ]
    HP.ppo.rollout_env_ram_patches = [
        ['no_score', 'three_lives', 'no_igloo', 'temperature_45', 'bailey_safe_random_spawn'], # 0
        ['no_score', 'last_life', 'no_igloo', 'temperature_45', 'bailey_safe_random_spawn'], # 1
    ]
    HP.ppo.rollout_env_stories = (
        ['0;0'] +      # level 1 - 5% time
        ['1;0'] +      # level 2 - 5% time
        ['2;0'] +      # level 3 - 5% time
        ['3;0'] +      # level 4 - 5% time
        ['4:9;1'] * 16 # level 5 - 80% time
    )
    
    HP.ppo.epochs_count = 2 
    HP.ppo.batch_size = 512 
    HP.ppo.learn_rate = f'const({0.00025 - 0.0002 / 6 * 5})'
    HP.ppo.optimizer = 'AdamW'
    
    HP.ppo.vf_coef = 0.2
    HP.ppo.ent_coef = f'const({0.05 - 0.04 / 6 * 5})'
    HP.ppo.consistency_coef = 0.1
    HP.ppo.prediction_coef = 0.1
    
    HP.ppo.gamma = 0.997 # return discount factor gamma
    HP.ppo.gae_lambda = 0.95 # lambda for the general advantage estimation
    HP.ppo.clip_coef = 0.1 # the surrogate clipping coefficient
    HP.ppo.clip_vloss = True
    HP.ppo.max_grad_norm = 0.5 # the maximum norm for the gradient clipping
    HP.ppo.target_kl = None # the target KL divergence threshold
    HP.ppo.norm_adv = True # Toggles advantages normalization
    return HP

# %% [markdown]
# # Results

# %% [markdown]
# В итоге никто из агентов не смог пройти 5-ый уровень. При этом явление, подмеченное в `18n_study_19.5a`, подверждается. Ещё больше наблюдается "прибитие" к уровню 40000 по скору. Есть вообще агенты, которые скор постоянно держали >=40000.
#
# Подёргал несколько агентов через `18n_explore_02` против тренировнчных РАМ-ов. Выяснилось, что эти РАМ-ы слишком сложные. В итоге агент не получает положительной подпики (сигнала награды) и теряется, не понимает что делать.
#
# Короче важно, чтобы тренировочные РАМ-ы были а) разнообразны, б) проходимы. В противном случае это получается как младенца заставить решать задачи из вышки. Он не сможет решить ни одной, сколько его не тыкай носом. Он должен этот путь плавно пройти.
#
# <img src="./img/score.png">
# <img src="./img/episode_r.png">
#
# **Выводы**
# 1) тренировочные РАМ-ы не должны быть слишком сложными. Они должны быть проходимыми

# %% [markdown]
# # System

# %%
import os, sys, re, subprocess, json
import IPython 
import concurrent.futures as cf
from collections import namedtuple

import optuna
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend
from optuna.trial import TrialState

project_root_path = ! git rev-parse --show-toplevel
project_root_path = project_root_path[0]

sys.path.append(os.path.join(project_root_path, 'lib'))

from logging_utils import *
from math_utils import *
from artifact_registry import *
import launchit
import launch_dispatcher
from autoincrement import Autoincrement

# %%
CONFIG = namedtuple('CONFIG', 
                    'project_root_uri, model_group_uri, project_root_path, subproject_name, subproject_path, run_path, ' + 
                    'target_notebook_fname, target_notebook_name, ' + 
                    'optuna_study_notebook_fname, optuna_study_name, optuna_study_serial, optuna_study_fname')(
    project_root_uri=f'com.develorium.{os.path.basename(project_root_path)}',
    model_group_uri=None,
    project_root_path=project_root_path,
    subproject_name=None,
    subproject_path=os.path.abspath('../..'),
    run_path=None,
    target_notebook_fname=os.path.join(os.path.abspath('../..'), TARGET_NOTEBOOK_FNAME),
    target_notebook_name=None,
    optuna_study_notebook_fname=None,
    optuna_study_name=None,
    optuna_study_serial=None,
    optuna_study_fname=None,
)

with open(IPython.get_ipython().kernel.config['IPKernelApp']['connection_file'], 'r') as connection_file:
    optuna_study_notebook_fname = json.load(connection_file).get('jupyter_session')
    optuna_study_name, _ = os.path.splitext(os.path.basename(optuna_study_notebook_fname))
    optuna_study_serial = re.match(r'\w+_([\d\.\w]+)', optuna_study_name).group(1)
    optuna_study_fname = os.path.join(os.path.dirname(optuna_study_notebook_fname), optuna_study_name + '.optuna')
    CONFIG = CONFIG._replace(optuna_study_notebook_fname=optuna_study_notebook_fname)
    CONFIG = CONFIG._replace(optuna_study_name=optuna_study_name)
    CONFIG = CONFIG._replace(optuna_study_serial=optuna_study_serial)
    CONFIG = CONFIG._replace(optuna_study_fname=optuna_study_fname)

target_notebook_name, _ = os.path.splitext(os.path.basename(TARGET_NOTEBOOK_FNAME))
CONFIG = CONFIG._replace(subproject_name=os.path.basename(os.path.dirname(CONFIG.target_notebook_fname)))
CONFIG = CONFIG._replace(model_group_uri=f'{CONFIG.project_root_uri}.{CONFIG.subproject_name}')
CONFIG = CONFIG._replace(target_notebook_name=target_notebook_name)
CONFIG = CONFIG._replace(run_path=os.path.join(project_root_path, 'run', CONFIG.subproject_name))
CONFIG._asdict()
# Out:
# {'project_root_uri': 'com.develorium.neurolab',
#  'model_group_uri': 'com.develorium.neurolab.18_rl',
#  'project_root_path': '/home/misha/dev/mine/neurolab',
#  'subproject_name': '18_rl',
#  'subproject_path': '/home/misha/dev/mine/neurolab/18_rl',
#  'run_path': '/home/misha/dev/mine/neurolab/run/18_rl',
#  'target_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/18n_ppo_tr_frostbite_06.ipynb',
#  'target_notebook_name': '18n_ppo_tr_frostbite_06',
#  'optuna_study_notebook_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.6a/18n_study_19.6a.ipynb',
#  'optuna_study_name': '18n_study_19.6a',
#  'optuna_study_serial': '19.6a',
#  'optuna_study_fname': '/home/misha/dev/mine/neurolab/18_rl/optuna/18n_study_19.6a/18n_study_19.6a.optuna'}

# %%
LOG = Logging.get()
LOG.enable('syslog', False)
LOG.enable('stdout', False)
LOG.enable('verbose_stdout', True)

# %%
ARTIFACT_REGISTRY = ArtifactRegistry(maven_group_id=CONFIG.model_group_uri)

# %%
def create_optuna_launch():
    model_version = int(Autoincrement.get(f'{CONFIG.model_group_uri}.{CONFIG.target_notebook_name}'))
    assert model_version > 0, model_version
    ARTIFACT_REGISTRY.register_component(CONFIG.target_notebook_name, model_version)
    LOG(f'Model instance registered, version={model_version}')
    
    # Prep docker launch
    expandvars = dict(
        PROJECT_ROOT_PATH='/neurolab',
        BUILD_PROJECT_ROOT_PATH=CONFIG.project_root_path,
        MODEL_GROUP_URI=CONFIG.model_group_uri,
        MODEL_NAME=CONFIG.target_notebook_name,
        MODEL_VERSION=model_version,
        LAUNCH_GOAL='TRAIN',
        OPTUNA_STUDY_FNAME=CONFIG.optuna_study_fname,
        OPTUNA_STUDY_NAME=CONFIG.optuna_study_name,
    )
    launch_fname = launchit.launchit(
        CONFIG.target_notebook_fname, 
        launch_serial=int(model_version),
        expandvars=expandvars, 
        make_py_file=False, 
        dir_name=CONFIG.run_path,
        collect_inds=['temp_config', 'optuna', 'initrd', 'build_docker_launch', 'optuna_run_docker_launch'],
        disable_inds=[],
    )
    return f'{CONFIG.target_notebook_name}:{model_version}', launch_fname

# %%
# Executed in a separate thread with GIL locked
def run_optuna_launch(launch_fname):
    # Run launch notebook locally, the latter will:
    # 1) sample values of hyperparameters from optuna study
    # 2) pack everything to docker launch (self-contained thing)
    # 3) run "docker_launch_run" cell which in turn will dispatch launch to cloud via launch_dispatcher
    # 4) collect result of a docker launch from cloud and update optuna study
    LOG(f'Launching "{launch_fname}"')
    
    subprocess.run(
        ['papermill', launch_fname, launch_fname, '--no-progress-bar'],
        capture_output=False,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )

    if os.path.exists(launch_fname + '.out'):
        with open(launch_fname + '.out', 'rt') as f:
            LOG(f.read())
    else:
        LOG(f'"{launch_fname}" completed with no output, probably failed')

# %% [markdown]
# ## Unleash!

# %%
optuna_study = optuna.create_study(
    study_name=CONFIG.optuna_study_name,
    directions=['maximize'],
    storage=JournalStorage(JournalFileBackend(file_path=CONFIG.optuna_study_fname)),
    load_if_exists=True,
)
optuna_study.set_user_attr('STUDY_SERIAL', CONFIG.optuna_study_serial)
launches_count = 20
completed_launches_count = 0

with LOG.auto_log_level(logging.INFO):
    with cf.ThreadPoolExecutor(max_workers=32) as executor:
        futures = {}
        idle_runners_af = RecursiveMovingAverageFilter(max_n=6)
        is_first_time = True
        
        while launches_count is None or completed_launches_count < launches_count:
            runners_info = launch_dispatcher.RunnersInfo.get()
            idle_runners_af(runners_info['idle'])

            if is_first_time or (idle_runners_af.n >= idle_runners_af.max_n and idle_runners_af.v >= 1):
                if launches_count is None or (completed_launches_count + len(futures) < launches_count):
                    launch_name, launch_fname = create_optuna_launch()
                    futures.update({executor.submit(run_optuna_launch, launch_fname): launch_name})
                    LOG(f'{idle_runners_af.v:.1f} idle runners exist, submitted launch "{launch_name}"; running launches={len(futures)}')
                    idle_runners_af.reset()
                    
                is_first_time = False

            try:
                while futures:
                    completed_futures, _ = cf.wait(futures, timeout=0.1, return_when=cf.FIRST_COMPLETED)

                    if not completed_futures:
                        break
                        
                    for completed_future in completed_futures:
                        launch_name = futures[completed_future]
                        del futures[completed_future]

                        exc = completed_future.exception()
                        
                        if exc is not None:
                            LOG(f'Launch "{launch_name}" failed: {exc}')
                        else:
                            LOG(f'Launch "{launch_name}" completed')
    
                    if completed_futures:
                        completed_launches_count += len(completed_futures)
                        LOG(f'{completed_launches_count} (+{len(completed_futures)}) launches completed; running launches={len(futures)}')
            except TimeoutError as e:
                pass

            time.sleep(5)
# Out:
# [I 2026-09-23 08:38:46,292] A new study created in Journal with name: 18n_study_19.6a
# 2026.09.23-08:38:46.542654     0.226 >> Model instance registered, version=522
# 2026.09.23-08:38:46.553745     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch522.ipynb"
# 2026.09.23-08:38:46.554183     0.004 >> 6.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:522"; running launches=1
# 2026.09.23-08:39:18.022873     0.209 >> Model instance registered, version=523
# 2026.09.23-08:39:18.036218     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch523.ipynb"
# 2026.09.23-08:39:18.036766     0.006 >> 5.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:523"; running launches=2
# 2026.09.23-08:39:48.974657     0.228 >> Model instance registered, version=524
# 2026.09.23-08:39:48.984705     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch524.ipynb"
# 2026.09.23-08:39:48.985090     0.005 >> 4.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:524"; running launches=3
# 2026.09.23-08:40:20.916884     0.227 >> Model instance registered, version=525
# 2026.09.23-08:40:20.928705     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch525.ipynb"
# 2026.09.23-08:40:20.928919     0.004 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:525"; running launches=4
# 2026.09.23-08:40:51.850139     0.204 >> Model instance registered, version=526
# 2026.09.23-08:40:51.863286     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch526.ipynb"
# 2026.09.23-08:40:51.863500     0.005 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:526"; running launches=5
# 2026.09.23-08:41:23.096904     0.223 >> Model instance registered, version=527
# 2026.09.23-08:41:23.111609     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch527.ipynb"
# 2026.09.23-08:41:23.112130     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:527"; running launches=6
# 2026.09.23-09:11:32.100075     0.247 >> Model instance registered, version=528
# 2026.09.23-09:11:32.111090     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch528.ipynb"
# 2026.09.23-09:11:32.111314     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:528"; running launches=7
# 2026.09.23-09:12:03.023862     0.237 >> Model instance registered, version=529
# 2026.09.23-09:12:03.033879     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch529.ipynb"
# 2026.09.23-09:12:03.034385     0.005 >> 3.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:529"; running launches=8
# 2026.09.23-09:12:33.992250     0.209 >> Model instance registered, version=530
# 2026.09.23-09:12:34.002134     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch530.ipynb"
# 2026.09.23-09:12:34.003649     0.007 >> 2.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:530"; running launches=9
# 2026.09.23-09:13:05.430338     0.206 >> Model instance registered, version=531
# 2026.09.23-09:13:05.444094     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch531.ipynb"
# 2026.09.23-09:13:05.444902     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:531"; running launches=10
# 2026.09.23-09:29:38.844787     0.264 >> Trial 1 (18n_ppo_tr_frostbite_06:523) finished with value: 40404.00028219697 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 1 with value: 40404.00028219697
# 2026.09.23-09:29:43.698390     0.002 >> Launch "18n_ppo_tr_frostbite_06:523" completed
# 2026.09.23-09:29:43.699459     0.001 >> 1 (+1) launches completed; running launches=9
# 2026.09.23-09:29:49.991877     1.174 >> Trial 2 (18n_ppo_tr_frostbite_06:524) finished with value: 40404.00028582888 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 2 with value: 40404.00028582888
# 2026.09.23-09:29:53.939675     0.004 >> Launch "18n_ppo_tr_frostbite_06:524" completed
# 2026.09.23-09:29:53.940633     0.001 >> 2 (+1) launches completed; running launches=8
# 2026.09.23-09:29:59.452610     0.206 >> Model instance registered, version=532
# 2026.09.23-09:29:59.466023     0.004 >> 1.2 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:532"; running launches=9
# 2026.09.23-09:29:59.466169     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch532.ipynb"
# 2026.09.23-09:30:31.312706     0.224 >> Model instance registered, version=533
# 2026.09.23-09:30:31.325885     0.006 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:533"; running launches=10
# 2026.09.23-09:30:31.326110     0.006 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch533.ipynb"
# 2026.09.23-09:31:01.368232     4.468 >> Trial 0 (18n_ppo_tr_frostbite_06:522) finished with value: 40404.000276715684 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 2 with value: 40404.00028582888
# 2026.09.23-09:31:01.378506     0.010 >> Trial 5 (18n_ppo_tr_frostbite_06:527) finished with value: 40404.000297727274 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-09:31:02.020955     0.002 >> Launch "18n_ppo_tr_frostbite_06:522" completed
# 2026.09.23-09:31:02.021902     0.001 >> Launch "18n_ppo_tr_frostbite_06:527" completed
# 2026.09.23-09:31:02.022678     0.001 >> 4 (+2) launches completed; running launches=8
# 2026.09.23-09:31:12.991197     0.207 >> Model instance registered, version=534
# 2026.09.23-09:31:13.004734     0.005 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:534"; running launches=9
# 2026.09.23-09:31:13.004870     0.005 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch534.ipynb"
# 2026.09.23-09:31:44.436293     0.214 >> Model instance registered, version=535
# 2026.09.23-09:31:44.447938     0.004 >> 1.3 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:535"; running launches=10
# 2026.09.23-09:31:44.448065     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch535.ipynb"
# 2026.09.23-09:32:23.980739     3.595 >> Trial 3 (18n_ppo_tr_frostbite_06:525) finished with value: 40304.00027974599 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-09:32:25.503260     0.001 >> Launch "18n_ppo_tr_frostbite_06:525" completed
# 2026.09.23-09:32:25.504111     0.001 >> 5 (+1) launches completed; running launches=9
# 2026.09.23-09:32:51.401489     0.213 >> Model instance registered, version=536
# 2026.09.23-09:32:51.412450     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:536"; running launches=10
# 2026.09.23-09:32:51.412578     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch536.ipynb"
# 2026.09.23-09:33:15.291114     3.426 >> Trial 4 (18n_ppo_tr_frostbite_06:526) finished with value: 40303.00025568182 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-09:33:16.976849     0.001 >> Launch "18n_ppo_tr_frostbite_06:526" completed
# 2026.09.23-09:33:16.977495     0.001 >> 6 (+1) launches completed; running launches=9
# 2026.09.23-09:33:42.801238     0.217 >> Model instance registered, version=537
# 2026.09.23-09:33:42.810225     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:537"; running launches=10
# 2026.09.23-09:33:42.810308     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch537.ipynb"
# 2026.09.23-10:06:30.894359     4.450 >> Trial 6 (18n_ppo_tr_frostbite_06:528) finished with value: 40404.00026697861 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-10:06:31.606433     0.004 >> Launch "18n_ppo_tr_frostbite_06:528" completed
# 2026.09.23-10:06:31.607463     0.001 >> 7 (+1) launches completed; running launches=9
# 2026.09.23-10:06:57.489086     0.244 >> Model instance registered, version=538
# 2026.09.23-10:06:57.500679     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:538"; running launches=10
# 2026.09.23-10:06:57.500795     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch538.ipynb"
# 2026.09.23-10:07:39.482383     1.072 >> Trial 7 (18n_ppo_tr_frostbite_06:529) finished with value: 40404.00027731729 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-10:07:43.722035     0.003 >> Launch "18n_ppo_tr_frostbite_06:529" completed
# 2026.09.23-10:07:43.723016     0.001 >> 8 (+1) launches completed; running launches=9
# 2026.09.23-10:08:09.529631     0.235 >> Model instance registered, version=539
# 2026.09.23-10:08:09.538167     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:539"; running launches=10
# 2026.09.23-10:08:09.538350     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch539.ipynb"
# 2026.09.23-10:08:31.451503     1.377 >> Trial 8 (18n_ppo_tr_frostbite_06:530) finished with value: 40400.00024451872 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-10:08:35.195108     0.002 >> Launch "18n_ppo_tr_frostbite_06:530" completed
# 2026.09.23-10:08:35.196272     0.001 >> 9 (+1) launches completed; running launches=9
# 2026.09.23-10:09:01.172871     0.292 >> Model instance registered, version=540
# 2026.09.23-10:09:01.186279     0.004 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:540"; running launches=10
# 2026.09.23-10:09:01.186441     0.004 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch540.ipynb"
# 2026.09.23-10:09:51.302760     3.760 >> Trial 9 (18n_ppo_tr_frostbite_06:531) finished with value: 40404.00028845811 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-10:09:52.663750     0.002 >> Launch "18n_ppo_tr_frostbite_06:531" completed
# 2026.09.23-10:09:52.664664     0.001 >> 10 (+1) launches completed; running launches=9
# 2026.09.23-10:10:18.753439     0.202 >> Model instance registered, version=541
# 2026.09.23-10:10:18.762670     0.003 >> 1.0 idle runners exist, submitted launch "18n_ppo_tr_frostbite_06:541"; running launches=10
# 2026.09.23-10:10:18.762772     0.003 >> Launching "/home/misha/dev/mine/neurolab/run/18_rl/18n_ppo_tr_frostbite_06-launch541.ipynb"
# 2026.09.23-10:19:24.128892     4.602 >> Trial 10 (18n_ppo_tr_frostbite_06:532) finished with value: 40404.000276136365 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-10:19:24.648057     0.001 >> Launch "18n_ppo_tr_frostbite_06:532" completed
# 2026.09.23-10:19:24.649032     0.001 >> 11 (+1) launches completed; running launches=9
# 2026.09.23-10:19:54.042951     3.767 >> Trial 11 (18n_ppo_tr_frostbite_06:533) finished with value: 30403.00024725936 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-10:19:55.394455     0.002 >> Launch "18n_ppo_tr_frostbite_06:533" completed
# 2026.09.23-10:19:55.395246     0.001 >> 12 (+1) launches completed; running launches=8
# 2026.09.23-10:21:32.736714     4.771 >> Trial 13 (18n_ppo_tr_frostbite_06:535) finished with value: 40404.00028914884 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-10:21:33.084294     0.002 >> Launch "18n_ppo_tr_frostbite_06:535" completed
# 2026.09.23-10:21:33.085177     0.001 >> 13 (+1) launches completed; running launches=7
# 2026.09.23-10:22:53.677515     3.062 >> Trial 12 (18n_ppo_tr_frostbite_06:534) finished with value: 40403.00025824421 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-10:22:55.739313     0.003 >> Launch "18n_ppo_tr_frostbite_06:534" completed
# 2026.09.23-10:22:55.740135     0.001 >> 14 (+1) launches completed; running launches=6
# 2026.09.23-10:24:12.478734     4.873 >> Trial 14 (18n_ppo_tr_frostbite_06:536) finished with value: 40404.0002496435 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-10:24:12.724207     0.002 >> Launch "18n_ppo_tr_frostbite_06:536" completed
# 2026.09.23-10:24:12.725168     0.001 >> 15 (+1) launches completed; running launches=5
# 2026.09.23-10:25:56.627902     0.524 >> Trial 15 (18n_ppo_tr_frostbite_06:537) finished with value: 40404.00028714349 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-10:26:01.214902     0.001 >> Launch "18n_ppo_tr_frostbite_06:537" completed
# 2026.09.23-10:26:01.215527     0.001 >> 16 (+1) launches completed; running launches=4
# 2026.09.23-10:53:53.840579     3.265 >> Trial 19 (18n_ppo_tr_frostbite_06:541) finished with value: 40404.0002869281 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-10:53:55.693664     0.003 >> Launch "18n_ppo_tr_frostbite_06:541" completed
# 2026.09.23-10:53:55.694567     0.001 >> 17 (+1) launches completed; running launches=3
# 2026.09.23-10:54:12.404358     1.366 >> Trial 18 (18n_ppo_tr_frostbite_06:540) finished with value: 30404.000266666666 and parameters: {'parent': '18n_ppo_tr_frostbite_06:494'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-10:54:16.154426     0.001 >> Launch "18n_ppo_tr_frostbite_06:540" completed
# 2026.09.23-10:54:16.155273     0.001 >> 18 (+1) launches completed; running launches=2
# 2026.09.23-10:58:47.573869     1.317 >> Trial 17 (18n_ppo_tr_frostbite_06:539) finished with value: 40404.000294688056 and parameters: {'parent': '18n_ppo_tr_frostbite_06:519'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-10:58:51.373702     0.002 >> Launch "18n_ppo_tr_frostbite_06:539" completed
# 2026.09.23-10:58:51.374363     0.001 >> 19 (+1) launches completed; running launches=1
# 2026.09.23-10:58:56.399964     5.026 >> Trial 16 (18n_ppo_tr_frostbite_06:538) finished with value: 40404.00029456328 and parameters: {'parent': '18n_ppo_tr_frostbite_06:521'}. Best is trial 5 with value: 40404.000297727274
# 2026.09.23-10:58:56.482243     0.001 >> Launch "18n_ppo_tr_frostbite_06:538" completed
# 2026.09.23-10:58:56.482771     0.001 >> 20 (+1) launches completed; running launches=0

# %%
# @launchit.disable
study = optuna.create_study(
    study_name=optuna_study_name,
    storage=JournalStorage(JournalFileBackend(file_path=optuna_study_fname)),
    load_if_exists=True, 
)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

LOG('Study statistics: ')
LOG(f'\tNumber of finished trials: {len(study.trials)}')
LOG(f'\tNumber of pruned trials: {len(pruned_trials)}')
LOG(f'\tNumber of complete trials: {len(complete_trials)}')

if len(study.directions) == 1:
    LOG('Best trial:')
    trial = study.best_trial
    
    LOG(f'\tValue: {trial.value}')
    LOG(f'\tModel version: {trial.user_attrs.get('MODEL_VERSION', 'n/a')}')
    
    LOG('\tParams: ')
    
    for key, value in trial.params.items():
        LOG(f'\t\t{key}: {value}')
else:
    LOG(f"Number of trials on the Pareto front: {len(study.best_trials)}")

    for i in range(3):
        LOG(f"Trial with lowest loss_{i}:")
        trial = min(study.best_trials, key=lambda t: t.values[i])
        LOG(f"\tnumber: {trial.number}")
        LOG(f"\tmver: {trial.user_attrs['MODEL_VERSION']}")
        LOG(f"\tparams: {trial.params}")
        LOG(f"\tvalues: {trial.values}")
# Out:
# [I 2026-09-23 10:59:01,510] Using an existing study with name '18n_study_19.6a' instead of creating a new one.
# 2026.09.23-10:59:01.513712     5.031 >> Study statistics:
# 2026.09.23-10:59:01.515999     0.002 >> 	Number of finished trials: 20
# 2026.09.23-10:59:01.517853     0.002 >> 	Number of pruned trials: 0
# 2026.09.23-10:59:01.518369     0.001 >> 	Number of complete trials: 20
# 2026.09.23-10:59:01.519321     0.001 >> Best trial:
# 2026.09.23-10:59:01.520110     0.001 >> 	Value: 40404.000297727274
# 2026.09.23-10:59:01.520706     0.001 >> 	Model version: 527
# 2026.09.23-10:59:01.521005     0.000 >> 	Params:
# 2026.09.23-10:59:01.521275     0.000 >> 		parent: 18n_ppo_tr_frostbite_06:521
